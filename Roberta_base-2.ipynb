# %%
# !pip install textattack
# !pip install -U gensim==4.0.0
# !pip3 install transformers
# Out:
# Collecting textattack
#   Downloading https://files.pythonhosted.org/packages/0f/82/2f16ef7f22f19b3a49bbcd079dc31e53d362e1ef1299298c3eda05cf2b3a/textattack-0.2.15-py3-none-any.whl (349kB)
#      |████████████████████████████████| 358kB 7.1MB/s
# Collecting datasets
#   Downloading https://files.pythonhosted.org/packages/46/1a/b9f9b3bfef624686ae81c070f0a6bb635047b17cdb3698c7ad01281e6f9a/datasets-1.6.2-py3-none-any.whl (221kB)
#      |████████████████████████████████| 225kB 9.6MB/s
# Requirement already satisfied: editdistance in /usr/local/lib/python3.7/dist-packages (from textattack) (0.5.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from textattack) (1.8.1+cu101)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from textattack) (8.7.0)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.7/dist-packages (from textattack) (1.4.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from textattack) (1.7.1)
# Collecting transformers>=3.3.0
#   Downloading https://files.pythonhosted.org/packages/d8/b2/57495b5309f09fa501866e225c84532d1fd89536ea62406b2181933fb418/transformers-4.5.1-py3-none-any.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 9.8MB/s
# Requirement already satisfied: tqdm<4.50.0,>=4.27 in /usr/local/lib/python3.7/dist-packages (from textattack) (4.41.1)
# Collecting lru-dict
#   Downloading https://files.pythonhosted.org/packages/68/ea/997af58d4e6da019ad825a412f93081d9df67e9dda11cfb026a3d7cd0b6c/lru-dict-1.1.7.tar.gz
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from textattack) (1.1.5)
# Collecting bert-score>=0.3.5
#   Downloading https://files.pythonhosted.org/packages/38/fb/e63e7e231a79db0489dbf7e7d0ebfb279ccb3d8216aa0d133572f784f3fa/bert_score-0.3.9-py3-none-any.whl (59kB)
#      |████████████████████████████████| 61kB 7.1MB/s
# Collecting lemminflect
#   Downloading https://files.pythonhosted.org/packages/4b/67/d04ca98b661d4ad52b9b965c9dabb1f1a2c85541d20f8decb9a9df4e4b32/lemminflect-0.2.2-py3-none-any.whl (769kB)
#      |████████████████████████████████| 778kB 27.6MB/s
# Collecting language-tool-python
#   Downloading https://files.pythonhosted.org/packages/37/26/48b22ad565fd372edec3577218fb817e0e6626bf4e658033197470ad92b3/language_tool_python-2.5.3-py3-none-any.whl
# Collecting num2words
#   Downloading https://files.pythonhosted.org/packages/eb/a2/ea800689730732e27711c41beed4b2a129b34974435bdc450377ec407738/num2words-0.5.10-py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 9.4MB/s
# Collecting flair==0.6.1.post1
#   Downloading https://files.pythonhosted.org/packages/4a/49/a812ed93088ba9519cbb40eb9f52341694b31cfa126bfddcd9db3761f3ac/flair-0.6.1.post1-py3-none-any.whl (337kB)
#      |████████████████████████████████| 337kB 35.6MB/s
# Collecting terminaltables
#   Downloading https://files.pythonhosted.org/packages/9b/c4/4a21174f32f8a7e1104798c445dacdc1d4df86f2f26722767034e4de4bff/terminaltables-3.1.0.tar.gz
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from textattack) (3.0.12)
# Collecting numpy<1.19.0
#   Downloading https://files.pythonhosted.org/packages/d6/c6/58e517e8b1fb192725cfa23c01c2e60e4e6699314ee9684a1c5f5c9b27e1/numpy-1.18.5-cp37-cp37m-manylinux1_x86_64.whl (20.1MB)
#      |████████████████████████████████| 20.1MB 1.5MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from textattack) (3.2.5)
# Collecting word2number
#   Downloading https://files.pythonhosted.org/packages/4a/29/a31940c848521f0725f0df6b25dca8917f13a2025b0e8fcbe5d0457e45e6/word2number-1.1.zip
# Collecting fsspec
#   Downloading https://files.pythonhosted.org/packages/e9/91/2ef649137816850fa4f4c97c6f2eabb1a79bf0aa2c8ed198e387e373455e/fsspec-2021.4.0-py3-none-any.whl (108kB)
#      |████████████████████████████████| 112kB 40.0MB/s
# Requirement already satisfied: pyarrow>=1.0.0<4.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets->textattack) (3.0.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets->textattack) (2.23.0)
# Collecting xxhash
#   Downloading https://files.pythonhosted.org/packages/7d/4f/0a862cad26aa2ed7a7cd87178cbbfa824fc1383e472d63596a0d018374e7/xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243kB)
#      |████████████████████████████████| 245kB 28.9MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from datasets->textattack) (3.10.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets->textattack) (0.70.11.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets->textattack) (0.3.3)
# Collecting huggingface-hub<0.1.0
#   Downloading https://files.pythonhosted.org/packages/a1/88/7b1e45720ecf59c6c6737ff332f41c955963090a18e72acbcbeac6b25e86/huggingface_hub-0.0.8-py3-none-any.whl
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets->textattack) (20.9)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->textattack) (3.7.4.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.3.0->textattack) (2019.12.20)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 38.2MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/ae/04/5b870f26a858552025a62f1649c20d29d2672c02ff3c3fb4c688ca46467a/tokenizers-0.10.2-cp37-cp37m-manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 35.8MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.1->textattack) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.1->textattack) (2018.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from bert-score>=0.3.5->textattack) (3.2.2)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.7/dist-packages (from num2words->textattack) (0.6.2)
# Requirement already satisfied: gensim>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from flair==0.6.1.post1->textattack) (3.6.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from flair==0.6.1.post1->textattack) (4.2.6)
# Collecting janome
#   Downloading https://files.pythonhosted.org/packages/a8/63/98858cbead27df7536c7e300c169da0999e9704d02220dc6700b804eeff0/Janome-0.4.1-py2.py3-none-any.whl (19.7MB)
#      |████████████████████████████████| 19.7MB 1.3MB/s
# Collecting bpemb>=0.3.2
#   Downloading https://files.pythonhosted.org/packages/f2/6f/9191b85109772636a8f8accb122900c34db26c091d2793218aa94954524c/bpemb-0.3.3-py3-none-any.whl
# Collecting sentencepiece!=0.1.92
#   Downloading https://files.pythonhosted.org/packages/f5/99/e0808cb947ba10f575839c43e8fafc9cc44e4a7a2c8f79c60db48220a577/sentencepiece-0.1.95-cp37-cp37m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 29.1MB/s
# Collecting langdetect
#   Downloading https://files.pythonhosted.org/packages/0e/72/a3add0e4eec4eb9e2569554f7c70f4a3c27712f40e3284d483e88094cc0e/langdetect-1.0.9.tar.gz (981kB)
#      |████████████████████████████████| 983kB 34.5MB/s
# Collecting mpld3==0.3
#   Downloading https://files.pythonhosted.org/packages/91/95/a52d3a83d0a29ba0d6898f6727e9858fe7a43f6c2ce81a5fe7e05f0f4912/mpld3-0.3.tar.gz (788kB)
#      |████████████████████████████████| 798kB 37.3MB/s
# Requirement already satisfied: hyperopt>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from flair==0.6.1.post1->textattack) (0.1.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from flair==0.6.1.post1->textattack) (0.22.2.post1)
# Collecting konoha<5.0.0,>=4.0.0
#   Downloading https://files.pythonhosted.org/packages/02/be/4dd30d56a0a19619deb9bf41ba8202709fa83b1b301b876572cd6dc38117/konoha-4.6.4-py3-none-any.whl
# Collecting ftfy
#   Downloading https://files.pythonhosted.org/packages/ce/b5/5da463f9c7823e0e575e9908d004e2af4b36efa8d02d3d6dad57094fcb11/ftfy-6.0.1.tar.gz (63kB)
#      |████████████████████████████████| 71kB 7.9MB/s
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (from flair==0.6.1.post1->textattack) (3.6.4)
# Collecting sqlitedict>=1.6.0
#   Downloading https://files.pythonhosted.org/packages/5c/2d/b1d99e9ad157dd7de9cd0d36a8a5876b13b55e4b75f7498bc96035fb4e96/sqlitedict-1.7.0.tar.gz
# Collecting deprecated>=1.2.4
#   Downloading https://files.pythonhosted.org/packages/fb/73/994edfcba74443146c84b91921fcc269374354118d4f452fb0c54c1cbb12/Deprecated-1.2.12-py2.py3-none-any.whl
# Collecting segtok>=1.5.7
#   Downloading https://files.pythonhosted.org/packages/41/08/582dab5f4b1d5ca23bc6927b4bb977c8ff7f3a87a3b98844ef833e2f5623/segtok-1.5.10.tar.gz
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from flair==0.6.1.post1->textattack) (0.8.9)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->textattack) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets->textattack) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets->textattack) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets->textattack) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets->textattack) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->datasets->textattack) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets->textattack) (2.4.7)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=3.3.0->textattack) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=3.3.0->textattack) (1.0.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (1.3.1)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from gensim>=3.4.0->flair==0.6.1.post1->textattack) (5.0.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (from hyperopt>=0.1.1->flair==0.6.1.post1->textattack) (3.11.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from hyperopt>=0.1.1->flair==0.6.1.post1->textattack) (2.5.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from hyperopt>=0.1.1->flair==0.6.1.post1->textattack) (0.16.0)
# Collecting overrides<4.0.0,>=3.0.0
#   Downloading https://files.pythonhosted.org/packages/ff/b1/10f69c00947518e6676bbd43e739733048de64b8dd998e9c2d5a71f44c5d/overrides-3.1.0.tar.gz
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from ftfy->flair==0.6.1.post1->textattack) (0.2.5)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.4->flair==0.6.1.post1->textattack) (1.12.1)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.7/dist-packages (from networkx->hyperopt>=0.1.1->flair==0.6.1.post1->textattack) (4.4.2)
# Building wheels for collected packages: lru-dict, terminaltables, word2number, langdetect, mpld3, ftfy, sqlitedict, segtok, overrides
#   Building wheel for lru-dict (setup.py) ... done
#   Created wheel for lru-dict: filename=lru_dict-1.1.7-cp37-cp37m-linux_x86_64.whl size=28382 sha256=caafc4427ef19cc40b05aa5e4ba7fb0c7ffb09fbaa8a61caf440a0e44232fa57
#   Stored in directory: /root/.cache/pip/wheels/ae/51/23/0a416781dead9225c7d66d25b9f223c7e32304e99a0b01d566
#   Building wheel for terminaltables (setup.py) ... done
#   Created wheel for terminaltables: filename=terminaltables-3.1.0-cp37-none-any.whl size=15356 sha256=813cf5b6fbc3dec1f3d84f87c6c7dcab8ae93a8090d815500b455439bc354cd1
#   Stored in directory: /root/.cache/pip/wheels/30/6b/50/6c75775b681fb36cdfac7f19799888ef9d8813aff9e379663e
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-cp37-none-any.whl size=5589 sha256=1f6d79e93886f9473c6b0bc91e7dea628aeadb6503a5a7c63a44b2d6ed01e209
#   Stored in directory: /root/.cache/pip/wheels/46/2f/53/5f5c1d275492f2fce1cdab9a9bb12d49286dead829a4078e0e
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-cp37-none-any.whl size=993223 sha256=becd5b216453a625efcce7732d07a08ed7cdd6b4f802e6465751c3afc76fb287
#   Stored in directory: /root/.cache/pip/wheels/7e/18/13/038c34057808931c7ddc6c92d3aa015cf1a498df5a70268996
#   Building wheel for mpld3 (setup.py) ... done
#   Created wheel for mpld3: filename=mpld3-0.3-cp37-none-any.whl size=116679 sha256=0e168f26e4387b5fc19efba28da02d43bcb31e0413d8e6f963e0f8deb5ef08f9
#   Stored in directory: /root/.cache/pip/wheels/c0/47/fb/8a64f89aecfe0059830479308ad42d62e898a3e3cefdf6ba28
#   Building wheel for ftfy (setup.py) ... done
#   Created wheel for ftfy: filename=ftfy-6.0.1-cp37-none-any.whl size=41573 sha256=bbe701bd355779640727a82bb2ffe17273e73ba4f226a39c0b6ee1e48962ebf1
#   Stored in directory: /root/.cache/pip/wheels/ae/73/c7/9056e14b04919e5c262fe80b54133b1a88d73683d05d7ac65c
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-1.7.0-cp37-none-any.whl size=14376 sha256=fcd7173ffaf92da6cf73a95354412c4951ec816637dece66ce0cb95af4b482a8
#   Stored in directory: /root/.cache/pip/wheels/cf/c6/4f/2c64a43f041415eb8b8740bd80e15e92f0d46c5e464d8e4b9b
#   Building wheel for segtok (setup.py) ... done
#   Created wheel for segtok: filename=segtok-1.5.10-cp37-none-any.whl size=25019 sha256=276ffdacf002aa8724bfcc336d8f555843956ac1c874944720344f6e174c9257
#   Stored in directory: /root/.cache/pip/wheels/b4/39/f6/9ca1c5cabde964d728023b5751c3a206a5c8cc40252321fb6b
#   Building wheel for overrides (setup.py) ... done
#   Created wheel for overrides: filename=overrides-3.1.0-cp37-none-any.whl size=10174 sha256=488e38975f1e3c805ef49636454efe025c172581acf3b55e0c0546b3bb44db7c
#   Stored in directory: /root/.cache/pip/wheels/5c/24/13/6ef8600e6f147c95e595f1289a86a3cc82ed65df57582c65a9
# Successfully built lru-dict terminaltables word2number langdetect mpld3 ftfy sqlitedict segtok overrides
# ERROR: tensorflow 2.4.1 has requirement numpy~=1.19.2, but you'll have numpy 1.18.5 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ERROR: konoha 4.6.4 has requirement requests<3.0.0,>=2.25.1, but you'll have requests 2.23.0 which is incompatible.
# Installing collected packages: fsspec, xxhash, numpy, huggingface-hub, datasets, sacremoses, tokenizers, transformers, lru-dict, bert-score, lemminflect, language-tool-python, num2words, janome, sentencepiece, bpemb, langdetect, mpld3, overrides, konoha, ftfy, sqlitedict, deprecated, segtok, flair, terminaltables, word2number, textattack
#   Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
# Successfully installed bert-score-0.3.9 bpemb-0.3.3 datasets-1.6.2 deprecated-1.2.12 flair-0.6.1.post1 fsspec-2021.4.0 ftfy-6.0.1 huggingface-hub-0.0.8 janome-0.4.1 konoha-4.6.4 langdetect-1.0.9 language-tool-python-2.5.3 lemminflect-0.2.2 lru-dict-1.1.7 mpld3-0.3 num2words-0.5.10 numpy-1.18.5 overrides-3.1.0 sacremoses-0.0.45 segtok-1.5.10 sentencepiece-0.1.95 sqlitedict-1.7.0 terminaltables-3.1.0 textattack-0.2.15 tokenizers-0.10.2 transformers-4.5.1 word2number-1.1 xxhash-2.0.2
# Collecting gensim==4.0.0
#   Downloading https://files.pythonhosted.org/packages/c3/dd/5e00b6e788a9c522b48f9df10472b2017102ffa65b10bc657471e0713542/gensim-4.0.0-cp37-cp37m-manylinux1_x86_64.whl (23.9MB)
#      |████████████████████████████████| 23.9MB 131kB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in /usr/local/lib/python3.7/dist-packages (from gensim==4.0.0) (1.18.5)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in /usr/local/lib/python3.7/dist-packages (from gensim==4.0.0) (5.0.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in /usr/local/lib/python3.7/dist-packages (from gensim==4.0.0) (1.4.1)
# Installing collected packages: gensim
#   Found existing installation: gensim 3.6.0
#     Uninstalling gensim-3.6.0:
#       Successfully uninstalled gensim-3.6.0
# Successfully installed gensim-4.0.0
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.5.1)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.18.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.45)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)

# %%
# import gensim.downloader as api
# corpus = api.load('text8')
from gensim.models.fasttext import FastText
# model1 = FastText(corpus)
# Out:
# /usr/local/lib/python3.7/dist-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
from gensim.models.word2vec import Word2Vec
from gensim.models import KeyedVectors
# model2 = Word2Vec(corpus)

# %%
# print(model1.wv.most_similar(positive=['cat']))
# print(model2.wv.most_similar(positive=['cat']))

# %%
# print(model1.wv.most_similar(positive=['should']))
# print(model2.wv.most_similar(positive=['should']))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Dataset/models"
# Out:
# fasttext.model			      glove_vectors.txt
# fasttext.model.wv.vectors_ngrams.npy  glove_word2vec.txt
# gloveKeyVectors.kv		      word2vec.model
# gloveKeyVectors.kv.vectors.npy

# %%
model1 = FastText.load("/content/drive/My Drive/Dataset/models/fasttext.model")

# %%
model2 = Word2Vec.load("/content/drive/My Drive/Dataset/models/word2vec.model")

# %%
model3=KeyedVectors.load('/content/drive/My Drive/Dataset/models/gloveKeyVectors.kv')

# %%
print(model1.wv.most_similar(positive=['cat']))
print(model2.wv.most_similar(positive=['cat']))
print(model3.most_similar(positive=['cat']))
# Out:
# [('bobcat', 0.759185791015625), ('dog', 0.7208123803138733), ('foxglove', 0.7110776901245117), ('pig', 0.7088143229484558), ('goose', 0.7069101333618164), ('cats', 0.702387273311615), ('beak', 0.7008379697799683), ('catfish', 0.6987316608428955), ('foxhound', 0.696578860282898), ('catnip', 0.6960986852645874)]
# [('dog', 0.7193913459777832), ('squirrel', 0.696162760257721), ('leopardus', 0.6945451498031616), ('prionailurus', 0.688106894493103), ('albino', 0.6880608201026917), ('bird', 0.6836060285568237), ('eared', 0.6803243160247803), ('rhinoceros', 0.6769237518310547), ('hyena', 0.6756084561347961), ('badger', 0.6752869486808777)]
# [('cats', 0.7006820440292358), ('dog', 0.698471188545227), ('dogs', 0.6442825198173523), ('tervueren', 0.619421660900116), ('laekenois', 0.5972026586532593), ('lica', 0.5956287980079651), ('feral', 0.5899650454521179), ('goat', 0.5861616134643555), ('fish', 0.5746133327484131), ('malinois', 0.5737614631652832)]

# %%
# Import the model
import transformers
from textattack.models.tokenizers import AutoTokenizer
from textattack.models.wrappers import HuggingFaceModelWrapper
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data]   Unzipping corpora/omw.zip.
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# textattack: Downloading https://textattack.s3.amazonaws.com/word_embeddings/paragramcf.
# 100%|██████████| 481M/481M [00:11<00:00, 41.2MB/s]
# textattack: Unzipping file /root/.cache/textattack/tmpchlskvgk.zip to /root/.cache/textattack/word_embeddings/paragramcf.
# textattack: Successfully saved word_embeddings/paragramcf to cache.

# %%
# print([model1.wv.most_similar(positive=['science'])[0][0]])
# print([model2.wv.most_similar(positive=['science'])[0][0]])

# %%
# print([model1.wv.most_similar(positive=['Fears'])[0][0]])
# print([model2.wv.most_similar(positive=['Fears'])[0][0]])

# %%
from textattack.transformations import WordSwap

class Swapper(WordSwap): # For fasttext
    """ Transforms an input by replacing any word with its most similar counterpart
    """

    # We don't need a constructor, since our class doesn't require any parameters.

    def _get_replacement_words(self, word):
        for i in range(10):
            if word.lower() in model1.wv.most_similar(word)[i][0].lower():
                continue # Don't return a word containing the exact word
            elif word.isupper():
                return [model1.wv.most_similar(word)[i][0].upper()] # Preserving case
            elif word[0].isupper():
                return [model1.wv.most_similar(word)[i][0].capitalize()] # Preserving Capitalization in words
            else:
                return [model1.wv.most_similar(word)[i][0]]
            
        return [model1.wv.most_similar(word)[0][0]]

# %%
from textattack.transformations import WordSwap

class Swapper_(WordSwap): # For word2vec
    """ Transforms an input by replacing any word with its most similar counterpart
    """

    # We don't need a constructor, since our class doesn't require any parameters.

    def _get_replacement_words(self, word):
        if word in model2.wv.key_to_index:
            for i in range(10):
                if word.lower() in model2.wv.most_similar(word)[i][0].lower():
                    continue # Don't return a word containing the same word.
                elif word.isupper():
                    return [model2.wv.most_similar(word)[i][0].upper()]
                elif word[0].isupper():
                    return [model2.wv.most_similar(word)[i][0].capitalize()]
                else:
                    return [model2.wv.most_similar(word)[i][0]]
            return [model2.wv.most_similar(word)[0][0]]
        else:
            return [word]

# %%
from textattack.transformations import WordSwap

class Swapper3(WordSwap): # For glove
    """ Transforms an input by replacing any word with its most similar counterpart
    """

    # We don't need a constructor, since our class doesn't require any parameters.

    def _get_replacement_words(self, word):
        if word in model3.key_to_index:
            for i in range(10):
                if word.lower() in model3.most_similar(word)[i][0].lower():
                    continue # Don't return a word containing the same word.
                elif word.isupper():
                    return [model3.most_similar(word)[i][0].upper()]
                elif word[0].isupper():
                    return [model3.most_similar(word)[i][0].capitalize()]
                else:
                    return [model3.most_similar(word)[i][0]]
            return [model3.most_similar(word)[0][0]]
        else:
            return [word]

# %%
from collections import deque

import textattack
import tqdm
import time
from IPython.display import display, HTML

# %%
def table(dataset,attack):
    num_examples = 8
    num_remaining_attacks = num_examples
    pbar = tqdm.tqdm(total=num_remaining_attacks, smoothing=0)

    worklist = deque(range(0, num_examples))
    worklist_tail = worklist[-1]

    attack_log_manager = textattack.loggers.AttackLogManager()

    load_time = time.time()

    num_results = 0
    num_failures = 0
    num_successes = 0
    for result in attack.attack_dataset(dataset, indices=worklist):
        result_html_str = result.__str__(color_method="html").replace("\n\n", "<br>")
        display(HTML(result_html_str))
        attack_log_manager.log_result(result)

        if not isinstance(result, textattack.attack_results.SkippedAttackResult):
            pbar.update(1)
        else:
            worklist_tail += 1
            pbar.update(1)
            worklist.append(worklist_tail)

        num_results += 1

        if (
            type(result) == textattack.attack_results.SuccessfulAttackResult
            or type(result) == textattack.attack_results.MaximizedAttackResult
        ):
            num_successes += 1

        if type(result) == textattack.attack_results.FailedAttackResult:
            num_failures += 1
        pbar.set_description(
            "[Succeeded / Failed / Total] {} / {} / {}".format(
                num_successes, num_failures, num_results
            )
        )

    pbar.close()

    attack_log_manager.enable_stdout()
    attack_log_manager.log_summary()
    attack_log_manager.flush()

    textattack.shared.logger.info(f"Attack time: {time.time() - load_time}s")

# %%
model = transformers.AutoModelForSequenceClassification.from_pretrained("textattack/roberta-base-ag-news")
tokenizer = AutoTokenizer("textattack/roberta-base-ag-news")

model_wrapper = HuggingFaceModelWrapper(model, tokenizer)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=754.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=501009162.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at textattack/roberta-base-ag-news were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=798293.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456356.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=239.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=25.0, style=ProgressStyle(description_w…

# %%
from textattack.search_methods import GreedySearch
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedySearch()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("ag_news", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset ag_news (/root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a)
# textattack: Loading datasets dataset ag_news, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# <font color = blue>Business (99%)</font> --> <font color = red>World (57%)</font><br>Fears for T N pension after talks Unions representing workers at Turner   Newall say they are 'disappointed' after talks with stricken parent firm <font color = blue>Federal</font> <font color = blue>Mogul</font>.<br>Fears for T N pension after talks Unions representing workers at Turner   Newall say they are 'disappointed' after talks with stricken parent firm <font color = red>Constitutional</font> <font color = red>Ghul</font>.
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:01<00:10,  1.17s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:19<01:19, 10.00s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = blue>Business (98%)</font><br><font color = purple>Ky</font>. <font color = purple>Company</font> Wins <font color = purple>Grant</font> to <font color = purple>Study</font> <font color = purple>Peptides</font> (<font color = purple>AP</font>) <font color = purple>AP</font> - A <font color = purple>company</font> <font color = purple>founded</font> by a <font color = purple>chemistry</font> <font color = purple>researcher</font> at the University of <font color = purple>Louisville</font> won a <font color = purple>grant</font> to develop a <font color = purple>method</font> of <font color = purple>producing</font> <font color = purple>better</font> <font color = purple>peptides</font>, which are <font color = purple>short</font> <font color = purple>chains</font> of <font color = purple>amino</font> <font color = purple>acids</font>, the building <font color = purple>blocks</font> of proteins.<br><font color = blue>Oppressed</font>. <font color = blue>Comstock</font> Wins <font color = blue>Rant</font> to <font color = blue>Oncology</font> <font color = blue>Eubulides</font> (<font color = blue>LITIGIOUS</font>) <font color = blue>LITIGIOUS</font> - A <font color = blue>corporation</font> <font color = blue>foundered</font> by a <font color = blue>biophysics</font> <font color = blue>researchcyc</font> at the University of <font color = blue>Titusville</font> won a <font color = blue>charnley</font> to develop a <font color = blue>methoxy</font> of <font color = blue>produces</font> <font color = blue>getter</font> <font color = blue>peptide</font>, which are <font color = blue>long</font> <font color = blue>chain</font> of <font color = blue>acids</font> <font color = blue>acid</font>, the building <font color = blue>block</font> of proteins.
# [Succeeded / Failed / Total] 2 / 1 / 3:  30%|███       | 3/10 [00:28<01:07,  9.66s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = green>Sports (96%)</font><br>Prediction Unit Helps <font color = purple>Forecast</font> <font color = purple>Wildfires</font> (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.<br>Prediction Unit Helps <font color = green>Recast</font> <font color = green>Fires</font> (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
# [Succeeded / Failed / Total] 3 / 1 / 4:  40%|████      | 4/10 [00:30<00:45,  7.64s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>World (63%)</font><br>Calif. Aims to <font color = purple>Limit</font> <font color = purple>Farm-Related</font> <font color = purple>Smog</font> (AP) AP - Southern <font color = purple>California's</font> <font color = purple>smog-fighting</font> agency went after <font color = purple>emissions</font> of the bovine variety Friday, adopting the nation's first rules to reduce <font color = purple>air</font> <font color = purple>pollution</font> from dairy cow <font color = purple>manure</font>.<br>Calif. Aims to <font color = red>Unbeknownst</font> <font color = red>Belated</font> <font color = red>Fog</font> (AP) AP - Southern <font color = red>California</font> <font color = red>bullfighting</font> agency went after <font color = red>emission</font> of the bovine variety Friday, adopting the nation's first rules to reduce <font color = red>airforce</font> <font color = red>polluting</font> from dairy cow <font color = red>oatmeal</font>.
# [Succeeded / Failed / Total] 4 / 1 / 5:  50%|█████     | 5/10 [00:34<00:34,  6.93s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
# [Succeeded / Failed / Total] 4 / 2 / 6:  60%|██████    | 6/10 [01:50<01:13, 18.35s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
# [Succeeded / Failed / Total] 4 / 3 / 7:  70%|███████   | 7/10 [02:58<01:16, 25.50s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
# [Succeeded / Failed / Total] 4 / 4 / 8:  80%|████████  | 8/10 [04:34<01:08, 34.29s/it]
# <font color = purple>Sci/tech (98%)</font> --> <font color = red>World (65%)</font><br>E-mail scam targets police chief <font color = purple>Wiltshire</font> Police warns about "phishing" after its <font color = purple>fraud</font> squad chief was targeted.<br>E-mail scam targets police chief <font color = red>Ayrshire</font> Police warns about "phishing" after its <font color = red>bribery</font> squad chief was targeted.
# [Succeeded / Failed / Total] 5 / 4 / 9:  90%|█████████ | 9/10 [04:34<00:30, 30.54s/it]
# <font color = purple>Sci/tech (97%)</font> --> <font color = blue>Business (92%)</font><br>Card <font color = purple>fraud</font> unit nets 36,000 cards In its first two years, the UK's dedicated <font color = purple>card</font> fraud unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.<br>Card <font color = blue>bribery</font> unit nets 36,000 cards In its first two years, the UK's dedicated <font color = blue>blackjack</font> fraud unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
# [Succeeded / Failed / Total] 6 / 4 / 10: 100%|██████████| 10/10 [04:36<00:00, 27.60s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 6      |
# | Number of failed attacks:     | 4      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 40.0%  |
# | Attack success rate:          | 60.0%  |
# | Average perturbed word %:     | 17.83% |
# | Average num. words per input: | 63.0   |
# | Avg num queries:              | 1099.0 |
# +-------------------------------+--------+
# textattack: Attack time: 276.01109433174133s

# %%
#Word2vec
from textattack.search_methods import GreedySearch
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedySearch()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("ag_news", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset ag_news (/root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a)
# textattack: Loading datasets dataset ag_news, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedySearch
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = blue>Business (99%)</font> --> <font color = red>[FAILED]</font><br>Fears for T N pension after talks Unions representing workers at Turner   Newall say they are 'disappointed' after talks with stricken parent firm Federal Mogul.
# [Succeeded / Failed / Total] 0 / 1 / 1:  10%|█         | 1/10 [00:01<00:09,  1.07s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# [Succeeded / Failed / Total] 0 / 2 / 2:  20%|██        | 2/10 [00:05<00:20,  2.57s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Ky. Company Wins Grant to Study Peptides (AP) AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
# [Succeeded / Failed / Total] 0 / 3 / 3:  30%|███       | 3/10 [00:08<00:19,  2.78s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Prediction Unit Helps Forecast Wildfires (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
# [Succeeded / Failed / Total] 0 / 4 / 4:  40%|████      | 4/10 [00:14<00:21,  3.52s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Calif. Aims to Limit Farm-Related Smog (AP) AP - Southern California's smog-fighting agency went after emissions of the bovine variety Friday, adopting the nation's first rules to reduce air pollution from dairy cow manure.
# [Succeeded / Failed / Total] 0 / 5 / 5:  50%|█████     | 5/10 [00:16<00:16,  3.24s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
# [Succeeded / Failed / Total] 0 / 6 / 6:  60%|██████    | 6/10 [00:44<00:29,  7.45s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
# [Succeeded / Failed / Total] 0 / 7 / 7:  70%|███████   | 7/10 [01:02<00:26,  8.86s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
# [Succeeded / Failed / Total] 0 / 8 / 8:  80%|████████  | 8/10 [01:39<00:24, 12.41s/it]
# <font color = purple>Sci/tech (98%)</font> --> <font color = red>World (87%)</font><br>E-mail <font color = purple>scam</font> targets police chief Wiltshire Police warns about "phishing" after its <font color = purple>fraud</font> squad chief was targeted.<br>E-mail <font color = red>disguising</font> targets police chief Wiltshire Police warns about "phishing" after its <font color = red>bribery</font> squad chief was targeted.
# [Succeeded / Failed / Total] 1 / 8 / 9:  90%|█████████ | 9/10 [01:39<00:11, 11.07s/it]
# <font color = purple>Sci/tech (97%)</font> --> <font color = blue>Business (83%)</font><br>Card <font color = purple>fraud</font> unit nets 36,000 cards In its first two years, the UK's dedicated <font color = purple>card</font> fraud unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.<br>Card <font color = blue>bribery</font> unit nets 36,000 cards In its first two years, the UK's dedicated <font color = blue>collectible</font> fraud unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
# [Succeeded / Failed / Total] 2 / 8 / 10: 100%|██████████| 10/10 [01:40<00:00, 10.04s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 2      |
# | Number of failed attacks:     | 8      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 80.0%  |
# | Attack success rate:          | 20.0%  |
# | Average perturbed word %:     | 9.01%  |
# | Average num. words per input: | 63.0   |
# | Avg num queries:              | 439.3  |
# +-------------------------------+--------+
# textattack: Attack time: 100.3789918422699s

# %%
#glove
from textattack.search_methods import GreedySearch
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedySearch()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("ag_news", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1780.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1227.0, style=ProgressStyle(description…
# Using custom data configuration default
# Downloading and preparing dataset ag_news/default (download: 29.88 MiB, generated: 30.23 MiB, post-processed: Unknown size, total: 60.10 MiB) to /root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a...
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=11045148.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=751209.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Dataset ag_news downloaded and prepared to /root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a. Subsequent calls will reuse this data.
# textattack: Loading datasets dataset ag_news, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedySearch
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = blue>Business (99%)</font> --> <font color = red>[FAILED]</font><br>Fears for T N pension after talks Unions representing workers at Turner   Newall say they are 'disappointed' after talks with stricken parent firm Federal Mogul.
# [Succeeded / Failed / Total] 0 / 1 / 1:  10%|█         | 1/10 [00:02<00:18,  2.10s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# [Succeeded / Failed / Total] 0 / 2 / 2:  20%|██        | 2/10 [00:09<00:39,  4.95s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Ky. Company Wins Grant to Study Peptides (AP) AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
# [Succeeded / Failed / Total] 0 / 3 / 3:  30%|███       | 3/10 [00:15<00:36,  5.18s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Prediction Unit Helps Forecast Wildfires (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
# [Succeeded / Failed / Total] 0 / 4 / 4:  40%|████      | 4/10 [00:25<00:38,  6.39s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Calif. Aims to Limit Farm-Related Smog (AP) AP - Southern California's smog-fighting agency went after emissions of the bovine variety Friday, adopting the nation's first rules to reduce air pollution from dairy cow manure.
# [Succeeded / Failed / Total] 0 / 5 / 5:  50%|█████     | 5/10 [00:29<00:29,  5.89s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
# [Succeeded / Failed / Total] 0 / 6 / 6:  60%|██████    | 6/10 [01:18<00:52, 13.07s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
# [Succeeded / Failed / Total] 0 / 7 / 7:  70%|███████   | 7/10 [01:50<00:47, 15.74s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
# [Succeeded / Failed / Total] 0 / 8 / 8:  80%|████████  | 8/10 [02:57<00:44, 22.21s/it]
# <font color = purple>Sci/tech (98%)</font> --> <font color = red>World (79%)</font><br>E-mail <font color = purple>scam</font> targets police chief Wiltshire Police warns about "<font color = purple>phishing</font>" after its fraud squad chief was <font color = purple>targeted</font>.<br>E-mail <font color = red>widower</font> targets police chief Wiltshire Police warns about "<font color = red>lollen</font>" after its fraud squad chief was <font color = red>massacred</font>.
# [Succeeded / Failed / Total] 1 / 8 / 9:  90%|█████████ | 9/10 [02:58<00:19, 19.86s/it]
# <font color = purple>Sci/tech (97%)</font> --> <font color = blue>Business (85%)</font><br>Card <font color = purple>fraud</font> unit nets 36,000 cards In its first two years, the UK's dedicated card <font color = purple>fraud</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.<br>Card <font color = blue>runoff</font> unit nets 36,000 cards In its first two years, the UK's dedicated card <font color = blue>runoff</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
# [Succeeded / Failed / Total] 2 / 8 / 10: 100%|██████████| 10/10 [02:59<00:00, 18.00s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 2      |
# | Number of failed attacks:     | 8      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 80.0%  |
# | Attack success rate:          | 20.0%  |
# | Average perturbed word %:     | 11.95% |
# | Average num. words per input: | 63.0   |
# | Avg num queries:              | 460.7  |
# +-------------------------------+--------+
# textattack: Attack time: 179.9979817867279s

# %%
#Fasttext
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("ag_news", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset ag_news (/root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a)
# textattack: Loading datasets dataset ag_news, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = blue>Business (99%)</font> --> <font color = red>World (62%)</font><br>Fears for T N pension <font color = blue>after</font> talks <font color = blue>Unions</font> representing workers at Turner   <font color = blue>Newall</font> say they <font color = blue>are</font> '<font color = blue>disappointed'</font> <font color = blue>after</font> talks with stricken parent firm <font color = blue>Federal</font> <font color = blue>Mogul</font>.<br>Fears for T N pension <font color = red>before</font> talks <font color = red>Anions</font> representing workers at Turner   <font color = red>Sewall</font> say they <font color = red>were</font> '<font color = red>disappointed</font> <font color = red>before</font> talks with stricken parent firm <font color = red>Constitutional</font> <font color = red>Ghul</font>.
#  10%|█         | 1/10 [00:00<00:06,  1.42it/s]
#
#
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:06,  1.40it/s]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:02<00:10,  1.34s/it]
#
#
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:02<00:10,  1.34s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Ky. Company Wins Grant to Study Peptides (AP) AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
# [Succeeded / Failed / Total] 1 / 1 / 2:  30%|███       | 3/10 [00:04<00:10,  1.45s/it]
#
#
# [Succeeded / Failed / Total] 1 / 2 / 3:  30%|███       | 3/10 [00:04<00:10,  1.45s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = green>Sports (96%)</font><br>Prediction Unit Helps <font color = purple>Forecast</font> <font color = purple>Wildfires</font> (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.<br>Prediction Unit Helps <font color = green>Recast</font> <font color = green>Fires</font> (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
# [Succeeded / Failed / Total] 1 / 2 / 3:  40%|████      | 4/10 [00:05<00:07,  1.32s/it]
#
#
# [Succeeded / Failed / Total] 2 / 2 / 4:  40%|████      | 4/10 [00:05<00:07,  1.32s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Calif. Aims to Limit Farm-Related Smog (AP) AP - Southern California's smog-fighting agency went after emissions of the bovine variety Friday, adopting the nation's first rules to reduce air pollution from dairy cow manure.
# [Succeeded / Failed / Total] 2 / 2 / 4:  50%|█████     | 5/10 [00:06<00:06,  1.30s/it]
#
#
# [Succeeded / Failed / Total] 2 / 3 / 5:  50%|█████     | 5/10 [00:06<00:06,  1.30s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
# [Succeeded / Failed / Total] 2 / 3 / 5:  60%|██████    | 6/10 [00:11<00:07,  1.97s/it]
#
#
# [Succeeded / Failed / Total] 2 / 4 / 6:  60%|██████    | 6/10 [00:11<00:07,  1.97s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
# [Succeeded / Failed / Total] 2 / 4 / 6:  70%|███████   | 7/10 [00:16<00:06,  2.30s/it]
#
#
# [Succeeded / Failed / Total] 2 / 5 / 7:  70%|███████   | 7/10 [00:16<00:06,  2.30s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
# [Succeeded / Failed / Total] 2 / 5 / 7:  80%|████████  | 8/10 [00:21<00:05,  2.63s/it]
#
#
# [Succeeded / Failed / Total] 2 / 6 / 8:  80%|████████  | 8/10 [00:21<00:05,  2.63s/it]
# <font color = purple>Sci/tech (98%)</font> --> <font color = red>World (73%)</font><br>E-mail scam targets police chief Wiltshire Police warns about "<font color = purple>phishing</font>" after its <font color = purple>fraud</font> <font color = purple>squad</font> chief was targeted.<br>E-mail scam targets police chief Wiltshire Police warns about "<font color = red>furnishing</font>" after its <font color = red>bribery</font> <font color = red>bombers</font> chief was targeted.
# [Succeeded / Failed / Total] 2 / 6 / 8:  90%|█████████ | 9/10 [00:21<00:02,  2.38s/it]
#
#
# [Succeeded / Failed / Total] 3 / 6 / 9:  90%|█████████ | 9/10 [00:21<00:02,  2.38s/it]
# <font color = purple>Sci/tech (97%)</font> --> <font color = blue>Business (95%)</font><br>Card <font color = purple>fraud</font> unit nets 36,000 cards In its first two years, the <font color = purple>UK's</font> dedicated card fraud unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.<br>Card <font color = blue>bribery</font> unit nets 36,000 cards In its first two years, the <font color = blue>Nap</font> dedicated card fraud unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
# [Succeeded / Failed / Total] 3 / 6 / 9: 100%|██████████| 10/10 [00:22<00:00,  2.20s/it]
#
#
# [Succeeded / Failed / Total] 4 / 6 / 10: 100%|██████████| 10/10 [00:22<00:00,  2.20s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 4      |
# | Number of failed attacks:     | 6      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 60.0%  |
# | Attack success rate:          | 40.0%  |
# | Average perturbed word %:     | 14.9%  |
# | Average num. words per input: | 63.0   |
# | Avg num queries:              | 99.8   |
# +-------------------------------+--------+
# textattack: Attack time: 22.035689115524292s

# %%
#Word2vec
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("ag_news", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset ag_news (/root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a)
# textattack: Loading datasets dataset ag_news, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = blue>Business (99%)</font> --> <font color = red>[FAILED]</font><br>Fears for T N pension after talks Unions representing workers at Turner   Newall say they are 'disappointed' after talks with stricken parent firm Federal Mogul.
#  10%|█         | 1/10 [00:00<00:07,  1.24it/s]
#
#
# [Succeeded / Failed / Total] 0 / 1 / 1:  10%|█         | 1/10 [00:00<00:07,  1.23it/s]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# [Succeeded / Failed / Total] 0 / 1 / 1:  20%|██        | 2/10 [00:02<00:08,  1.09s/it]
#
#
# [Succeeded / Failed / Total] 0 / 2 / 2:  20%|██        | 2/10 [00:02<00:08,  1.09s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Ky. Company Wins Grant to Study Peptides (AP) AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
# [Succeeded / Failed / Total] 0 / 2 / 2:  30%|███       | 3/10 [00:03<00:08,  1.15s/it]
#
#
# [Succeeded / Failed / Total] 0 / 3 / 3:  30%|███       | 3/10 [00:03<00:08,  1.15s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Prediction Unit Helps Forecast Wildfires (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
# [Succeeded / Failed / Total] 0 / 3 / 3:  40%|████      | 4/10 [00:05<00:07,  1.28s/it]
#
#
# [Succeeded / Failed / Total] 0 / 4 / 4:  40%|████      | 4/10 [00:05<00:07,  1.28s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Calif. Aims to Limit Farm-Related Smog (AP) AP - Southern California's smog-fighting agency went after emissions of the bovine variety Friday, adopting the nation's first rules to reduce air pollution from dairy cow manure.
# [Succeeded / Failed / Total] 0 / 4 / 4:  50%|█████     | 5/10 [00:06<00:06,  1.20s/it]
#
#
# [Succeeded / Failed / Total] 0 / 5 / 5:  50%|█████     | 5/10 [00:06<00:06,  1.20s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
# [Succeeded / Failed / Total] 0 / 5 / 5:  60%|██████    | 6/10 [00:10<00:06,  1.72s/it]
#
#
# [Succeeded / Failed / Total] 0 / 6 / 6:  60%|██████    | 6/10 [00:10<00:06,  1.73s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
# [Succeeded / Failed / Total] 0 / 6 / 6:  70%|███████   | 7/10 [00:13<00:05,  1.95s/it]
#
#
# [Succeeded / Failed / Total] 0 / 7 / 7:  70%|███████   | 7/10 [00:13<00:05,  1.95s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
# [Succeeded / Failed / Total] 0 / 7 / 7:  80%|████████  | 8/10 [00:17<00:04,  2.20s/it]
#
#
# [Succeeded / Failed / Total] 0 / 8 / 8:  80%|████████  | 8/10 [00:17<00:04,  2.20s/it]
# <font color = purple>Sci/tech (98%)</font> --> <font color = red>World (51%)</font><br>E-mail scam targets police chief Wiltshire Police warns about "<font color = purple>phishing</font>" after its <font color = purple>fraud</font> <font color = purple>squad</font> <font color = purple>chief</font> was targeted.<br>E-mail scam targets police chief Wiltshire Police warns about "<font color = red>spamming</font>" after its <font color = red>bribery</font> <font color = red>sniper</font> <font color = red>commander</font> was targeted.
# [Succeeded / Failed / Total] 0 / 8 / 8:  90%|█████████ | 9/10 [00:18<00:02,  2.00s/it]
#
#
# [Succeeded / Failed / Total] 1 / 8 / 9:  90%|█████████ | 9/10 [00:18<00:02,  2.00s/it]
# <font color = purple>Sci/tech (97%)</font> --> <font color = blue>Business (83%)</font><br>Card <font color = purple>fraud</font> unit nets 36,000 cards In its first two years, the UK's <font color = purple>dedicated</font> card <font color = purple>fraud</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.<br>Card <font color = blue>bribery</font> unit nets 36,000 cards In its first two years, the UK's <font color = blue>devoted</font> card <font color = blue>bribery</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
# [Succeeded / Failed / Total] 1 / 8 / 9: 100%|██████████| 10/10 [00:18<00:00,  1.86s/it]
#
#
# [Succeeded / Failed / Total] 2 / 8 / 10: 100%|██████████| 10/10 [00:18<00:00,  1.86s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 2      |
# | Number of failed attacks:     | 8      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 80.0%  |
# | Attack success rate:          | 20.0%  |
# | Average perturbed word %:     | 16.45% |
# | Average num. words per input: | 63.0   |
# | Avg num queries:              | 90.2   |
# +-------------------------------+--------+
# textattack: Attack time: 18.641759872436523s

# %%
#glove
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("ag_news", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset ag_news (/root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a)
# textattack: Loading datasets dataset ag_news, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = blue>Business (99%)</font> --> <font color = red>[FAILED]</font><br>Fears for T N pension after talks Unions representing workers at Turner   Newall say they are 'disappointed' after talks with stricken parent firm Federal Mogul.
#  10%|█         | 1/10 [00:00<00:08,  1.01it/s]
#
#
# [Succeeded / Failed / Total] 0 / 1 / 1:  10%|█         | 1/10 [00:00<00:08,  1.00it/s]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# [Succeeded / Failed / Total] 0 / 1 / 1:  20%|██        | 2/10 [00:02<00:11,  1.44s/it]
#
#
# [Succeeded / Failed / Total] 0 / 2 / 2:  20%|██        | 2/10 [00:02<00:11,  1.44s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Ky. Company Wins Grant to Study Peptides (AP) AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
# [Succeeded / Failed / Total] 0 / 2 / 2:  30%|███       | 3/10 [00:04<00:11,  1.57s/it]
#
#
# [Succeeded / Failed / Total] 0 / 3 / 3:  30%|███       | 3/10 [00:04<00:11,  1.58s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Prediction Unit Helps Forecast Wildfires (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
# [Succeeded / Failed / Total] 0 / 3 / 3:  40%|████      | 4/10 [00:07<00:10,  1.76s/it]
#
#
# [Succeeded / Failed / Total] 0 / 4 / 4:  40%|████      | 4/10 [00:07<00:10,  1.76s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Calif. Aims to Limit Farm-Related Smog (AP) AP - Southern California's smog-fighting agency went after emissions of the bovine variety Friday, adopting the nation's first rules to reduce air pollution from dairy cow manure.
# [Succeeded / Failed / Total] 0 / 4 / 4:  50%|█████     | 5/10 [00:08<00:08,  1.65s/it]
#
#
# [Succeeded / Failed / Total] 0 / 5 / 5:  50%|█████     | 5/10 [00:08<00:08,  1.65s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
# [Succeeded / Failed / Total] 0 / 5 / 5:  60%|██████    | 6/10 [00:14<00:09,  2.40s/it]
#
#
# [Succeeded / Failed / Total] 0 / 6 / 6:  60%|██████    | 6/10 [00:14<00:09,  2.40s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
# [Succeeded / Failed / Total] 0 / 6 / 6:  70%|███████   | 7/10 [00:19<00:08,  2.72s/it]
#
#
# [Succeeded / Failed / Total] 0 / 7 / 7:  70%|███████   | 7/10 [00:19<00:08,  2.72s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
# [Succeeded / Failed / Total] 0 / 7 / 7:  80%|████████  | 8/10 [00:24<00:06,  3.11s/it]
#
#
# [Succeeded / Failed / Total] 0 / 8 / 8:  80%|████████  | 8/10 [00:24<00:06,  3.11s/it]
# <font color = purple>Sci/tech (98%)</font> --> <font color = red>[FAILED]</font><br>E-mail scam targets police chief Wiltshire Police warns about "phishing" after its fraud squad chief was targeted.
# [Succeeded / Failed / Total] 0 / 8 / 8:  90%|█████████ | 9/10 [00:25<00:02,  2.85s/it]
#
#
# [Succeeded / Failed / Total] 0 / 9 / 9:  90%|█████████ | 9/10 [00:25<00:02,  2.86s/it]
# <font color = purple>Sci/tech (97%)</font> --> <font color = blue>Business (96%)</font><br>Card <font color = purple>fraud</font> unit nets 36,000 cards In its first two years, the UK's <font color = purple>dedicated</font> card <font color = purple>fraud</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.<br>Card <font color = blue>runoff</font> unit nets 36,000 cards In its first two years, the UK's <font color = blue>devoted</font> card <font color = blue>runoff</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
# [Succeeded / Failed / Total] 0 / 9 / 9: 100%|██████████| 10/10 [00:26<00:00,  2.63s/it]
#
#
# [Succeeded / Failed / Total] 1 / 9 / 10: 100%|██████████| 10/10 [00:26<00:00,  2.63s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 1      |
# | Number of failed attacks:     | 9      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 90.0%  |
# | Attack success rate:          | 10.0%  |
# | Average perturbed word %:     | 9.38%  |
# | Average num. words per input: | 63.0   |
# | Avg num queries:              | 87.5   |
# +-------------------------------+--------+
# textattack: Attack time: 26.34866762161255s

# %%
#Fasttext
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("ag_news", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset ag_news (/root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a)
# textattack: Loading datasets dataset ag_news, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = blue>Business (99%)</font> --> <font color = red>World (95%)</font><br>Fears for T N <font color = blue>pension</font> after talks Unions representing workers at <font color = blue>Turner</font>   Newall say they are 'disappointed' after talks with stricken parent firm Federal <font color = blue>Mogul</font>.<br>Fears for T N <font color = red>privation</font> after talks Unions representing workers at <font color = red>Byner</font>   Newall say they are 'disappointed' after talks with stricken parent firm Federal <font color = red>Ghul</font>.
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:02<00:22,  2.54s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:48<03:15, 24.45s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Ky. Company Wins Grant to Study Peptides (AP) AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
# [Succeeded / Failed / Total] 1 / 2 / 3:  30%|███       | 3/10 [01:27<03:24, 29.25s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = green>Sports (99%)</font><br>Prediction Unit Helps <font color = purple>Forecast</font> Wildfires (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will <font color = purple>strike</font> in places he expects. Winds will pick up, moist places will dry and flames will roar.<br>Prediction Unit Helps <font color = green>Recast</font> Wildfires (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will <font color = green>shootout</font> in places he expects. Winds will pick up, moist places will dry and flames will roar.
# [Succeeded / Failed / Total] 2 / 2 / 4:  40%|████      | 4/10 [01:32<02:19, 23.19s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>World (74%)</font><br>Calif. Aims to <font color = purple>Limit</font> <font color = purple>Farm-Related</font> <font color = purple>Smog</font> (AP) AP - Southern California's <font color = purple>smog-fighting</font> agency went after <font color = purple>emissions</font> of the bovine variety Friday, adopting the nation's first rules to reduce <font color = purple>air</font> <font color = purple>pollution</font> from dairy cow <font color = purple>manure</font>.<br>Calif. Aims to <font color = red>Unbeknownst</font> <font color = red>Belated</font> <font color = red>Fog</font> (AP) AP - Southern California's <font color = red>fighting</font> agency went after <font color = red>emission</font> of the bovine variety Friday, adopting the nation's first rules to reduce <font color = red>airforce</font> <font color = red>polluting</font> from dairy cow <font color = red>oatmeal</font>.
# [Succeeded / Failed / Total] 3 / 2 / 5:  50%|█████     | 5/10 [01:51<01:51, 22.23s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
# [Succeeded / Failed / Total] 3 / 3 / 6:  60%|██████    | 6/10 [04:00<02:40, 40.02s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
# [Succeeded / Failed / Total] 3 / 4 / 7:  70%|███████   | 7/10 [05:49<02:29, 49.94s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
# [Succeeded / Failed / Total] 3 / 5 / 8:  80%|████████  | 8/10 [07:56<01:59, 59.62s/it]
# <font color = purple>Sci/tech (98%)</font> --> <font color = red>World (55%)</font><br>E-mail scam targets police chief Wiltshire Police warns about "phishing" after its <font color = purple>fraud</font> <font color = purple>squad</font> chief was targeted.<br>E-mail scam targets police chief Wiltshire Police warns about "phishing" after its <font color = red>bribery</font> <font color = red>bombers</font> chief was targeted.
# [Succeeded / Failed / Total] 4 / 5 / 9:  90%|█████████ | 9/10 [07:57<00:53, 53.05s/it]
# <font color = purple>Sci/tech (97%)</font> --> <font color = red>World (52%)</font><br>Card <font color = purple>fraud</font> unit nets 36,000 cards In its first two years, the UK's <font color = purple>dedicated</font> card <font color = purple>fraud</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.<br>Card <font color = red>bribery</font> unit nets 36,000 cards In its first two years, the UK's <font color = red>dedicates</font> card <font color = red>bribery</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
# [Succeeded / Failed / Total] 5 / 5 / 10: 100%|██████████| 10/10 [08:01<00:00, 48.13s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 5      |
# | Number of failed attacks:     | 5      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 50.0%  |
# | Attack success rate:          | 50.0%  |
# | Average perturbed word %:     | 12.22% |
# | Average num. words per input: | 63.0   |
# | Avg num queries:              | 1774.3 |
# +-------------------------------+--------+
# textattack: Attack time: 481.2864520549774s

# %%
#Word2vec
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset


transformation = Swapper_()

constraints = [PartOfSpeech()]

search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("ag_news", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset ag_news (/root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a)
# textattack: Loading datasets dataset ag_news, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = blue>Business (99%)</font> --> <font color = red>[FAILED]</font><br>Fears for T N pension after talks Unions representing workers at Turner   Newall say they are 'disappointed' after talks with stricken parent firm Federal Mogul.
# [Succeeded / Failed / Total] 0 / 1 / 1:  10%|█         | 1/10 [00:06<01:01,  6.86s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# [Succeeded / Failed / Total] 0 / 2 / 2:  20%|██        | 2/10 [00:28<01:52, 14.07s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Ky. Company Wins Grant to Study Peptides (AP) AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
# [Succeeded / Failed / Total] 0 / 3 / 3:  30%|███       | 3/10 [00:48<01:54, 16.29s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Prediction Unit Helps Forecast Wildfires (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
# [Succeeded / Failed / Total] 0 / 4 / 4:  40%|████      | 4/10 [01:20<02:00, 20.11s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Calif. Aims to Limit Farm-Related Smog (AP) AP - Southern California's smog-fighting agency went after emissions of the bovine variety Friday, adopting the nation's first rules to reduce air pollution from dairy cow manure.
# [Succeeded / Failed / Total] 0 / 5 / 5:  50%|█████     | 5/10 [01:31<01:31, 18.39s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
# [Succeeded / Failed / Total] 0 / 6 / 6:  60%|██████    | 6/10 [02:56<01:57, 29.35s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
# [Succeeded / Failed / Total] 0 / 7 / 7:  70%|███████   | 7/10 [03:56<01:41, 33.82s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
# [Succeeded / Failed / Total] 0 / 8 / 8:  80%|████████  | 8/10 [05:09<01:17, 38.74s/it]
# <font color = purple>Sci/tech (98%)</font> --> <font color = red>World (51%)</font><br>E-mail scam targets police chief Wiltshire Police warns about "phishing" after its <font color = purple>fraud</font> <font color = purple>squad</font> chief was targeted.<br>E-mail scam targets police chief Wiltshire Police warns about "phishing" after its <font color = red>bribery</font> <font color = red>sniper</font> chief was targeted.
# [Succeeded / Failed / Total] 1 / 8 / 9:  90%|█████████ | 9/10 [05:10<00:34, 34.47s/it]
# <font color = purple>Sci/tech (97%)</font> --> <font color = blue>Business (69%)</font><br>Card <font color = purple>fraud</font> unit nets 36,000 cards In its first two years, the UK's dedicated card <font color = purple>fraud</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.<br>Card <font color = blue>bribery</font> unit nets 36,000 cards In its first two years, the UK's dedicated card <font color = blue>bribery</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
# [Succeeded / Failed / Total] 2 / 8 / 10: 100%|██████████| 10/10 [05:12<00:00, 31.29s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 2      |
# | Number of failed attacks:     | 8      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 80.0%  |
# | Attack success rate:          | 20.0%  |
# | Average perturbed word %:     | 9.01%  |
# | Average num. words per input: | 63.0   |
# | Avg num queries:              | 1298.0 |
# +-------------------------------+--------+
# textattack: Attack time: 312.894633769989s

# %%
#glove
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset


transformation = Swapper3()

constraints = [PartOfSpeech()]

search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("ag_news", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset ag_news (/root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a)
# textattack: Loading datasets dataset ag_news, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = blue>Business (99%)</font> --> <font color = red>World (50%)</font><br>Fears for T N pension <font color = blue>after</font> <font color = blue>talks</font> Unions representing workers at Turner   Newall say they <font color = blue>are</font> 'disappointed' after <font color = blue>talks</font> with stricken parent <font color = blue>firm</font> Federal Mogul.<br>Fears for T N pension <font color = red>before</font> <font color = red>peace</font> Unions representing workers at Turner   Newall say they <font color = red>washerwomen</font> 'disappointed' after <font color = red>peace</font> with stricken parent <font color = red>services</font> Federal Mogul.
#  10%|█         | 1/10 [00:15<02:17, 15.33s/it]
#
#
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:15<02:18, 15.34s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [01:02<04:10, 31.25s/it]
#
#
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [01:02<04:10, 31.26s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Ky. Company Wins Grant to Study Peptides (AP) AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
# [Succeeded / Failed / Total] 1 / 1 / 2:  30%|███       | 3/10 [01:43<04:00, 34.37s/it]
#
#
# [Succeeded / Failed / Total] 1 / 2 / 3:  30%|███       | 3/10 [01:43<04:00, 34.38s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Prediction Unit Helps Forecast Wildfires (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
# [Succeeded / Failed / Total] 1 / 2 / 3:  40%|████      | 4/10 [02:40<04:01, 40.17s/it]
#
#
# [Succeeded / Failed / Total] 1 / 3 / 4:  40%|████      | 4/10 [02:40<04:01, 40.17s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Calif. Aims to Limit Farm-Related Smog (AP) AP - Southern California's smog-fighting agency went after emissions of the bovine variety Friday, adopting the nation's first rules to reduce air pollution from dairy cow manure.
# [Succeeded / Failed / Total] 1 / 3 / 4:  50%|█████     | 5/10 [02:56<02:56, 35.22s/it]
#
#
# [Succeeded / Failed / Total] 1 / 4 / 5:  50%|█████     | 5/10 [02:56<02:56, 35.22s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
# [Succeeded / Failed / Total] 1 / 4 / 5:  60%|██████    | 6/10 [05:49<03:53, 58.33s/it]
#
#
# [Succeeded / Failed / Total] 1 / 5 / 6:  60%|██████    | 6/10 [05:50<03:53, 58.33s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
# [Succeeded / Failed / Total] 1 / 5 / 6:  70%|███████   | 7/10 [07:43<03:18, 66.25s/it]
#
#
# [Succeeded / Failed / Total] 1 / 6 / 7:  70%|███████   | 7/10 [07:43<03:18, 66.26s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
# [Succeeded / Failed / Total] 1 / 6 / 7:  80%|████████  | 8/10 [10:28<02:37, 78.55s/it]
#
#
# [Succeeded / Failed / Total] 1 / 7 / 8:  80%|████████  | 8/10 [10:28<02:37, 78.55s/it]
# <font color = purple>Sci/tech (98%)</font> --> <font color = red>World (93%)</font><br>E-mail scam targets <font color = purple>police</font> <font color = purple>chief</font> Wiltshire Police <font color = purple>warns</font> about "<font color = purple>phishing</font>" after its <font color = purple>fraud</font> <font color = purple>squad</font> chief was <font color = purple>targeted</font>.<br>E-mail scam targets <font color = red>soldiers</font> <font color = red>lebowa</font> Wiltshire Police <font color = red>warned</font> about "<font color = red>lollen</font>" after its <font color = red>voting</font> <font color = red>firing</font> chief was <font color = red>massacred</font>.
# [Succeeded / Failed / Total] 1 / 7 / 8:  90%|█████████ | 9/10 [10:38<01:10, 70.94s/it]
#
#
# [Succeeded / Failed / Total] 2 / 7 / 9:  90%|█████████ | 9/10 [10:38<01:10, 70.94s/it]
# <font color = purple>Sci/tech (97%)</font> --> <font color = blue>Business (97%)</font><br>Card fraud unit nets 36,000 cards In its first two years, the UK's dedicated card <font color = purple>fraud</font> unit, <font color = purple>has</font> recovered 36,000 <font color = purple>stolen</font> cards and 171 <font color = purple>arrests</font> - and estimates it saved 65m.<br>Card fraud unit nets 36,000 cards In its first two years, the UK's dedicated card <font color = blue>runoff</font> unit, <font color = blue>viestimies</font> recovered 36,000 <font color = blue>withdrawn</font> cards and 171 <font color = blue>executions</font> - and estimates it saved 65m.
# [Succeeded / Failed / Total] 2 / 7 / 9: 100%|██████████| 10/10 [10:45<00:00, 64.57s/it]
#
#
# [Succeeded / Failed / Total] 3 / 7 / 10: 100%|██████████| 10/10 [10:45<00:00, 64.58s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 3      |
# | Number of failed attacks:     | 7      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 70.0%  |
# | Attack success rate:          | 30.0%  |
# | Average perturbed word %:     | 24.56% |
# | Average num. words per input: | 63.0   |
# | Avg num queries:              | 1199.1 |
# +-------------------------------+--------+
# textattack: Attack time: 645.754510641098s

# %%
#fasttext
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("ag_news", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1780.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1227.0, style=ProgressStyle(description…
# Using custom data configuration default
# Downloading and preparing dataset ag_news/default (download: 29.88 MiB, generated: 30.23 MiB, post-processed: Unknown size, total: 60.10 MiB) to /root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a...
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=11045148.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=751209.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# textattack: Loading datasets dataset ag_news, split test.
# Dataset ag_news downloaded and prepared to /root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a. Subsequent calls will reuse this data.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = blue>Business (99%)</font> --> <font color = red>World (100%)</font><br>Fears for T N <font color = blue>pension</font> after talks Unions representing workers at Turner   Newall say they are 'disappointed' after <font color = blue>talks</font> with stricken parent firm <font color = blue>Federal</font> <font color = blue>Mogul</font>.<br>Fears for T N <font color = red>privation</font> after talks Unions representing workers at Turner   Newall say they are 'disappointed' after <font color = red>negotiations</font> with stricken parent firm <font color = red>Constitutional</font> <font color = red>Ghul</font>.
#  10%|█         | 1/10 [00:04<00:44,  4.89s/it]
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:04<00:44,  4.90s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [01:34<06:16, 47.04s/it]
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [01:34<06:16, 47.05s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Ky. Company Wins Grant to Study Peptides (AP) AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
# [Succeeded / Failed / Total] 1 / 1 / 2:  30%|███       | 3/10 [02:30<05:51, 50.19s/it]
# [Succeeded / Failed / Total] 1 / 2 / 3:  30%|███       | 3/10 [02:30<05:51, 50.20s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = green>Sports (93%)</font><br>Prediction Unit Helps Forecast <font color = purple>Wildfires</font> (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will <font color = purple>strike</font> in places he expects. Winds will pick up, moist places will dry and flames will roar.<br>Prediction Unit Helps Forecast <font color = green>Fires</font> (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will <font color = green>shootout</font> in places he expects. Winds will pick up, moist places will dry and flames will roar.
# [Succeeded / Failed / Total] 1 / 2 / 3:  40%|████      | 4/10 [02:38<03:58, 39.67s/it]
# [Succeeded / Failed / Total] 2 / 2 / 4:  40%|████      | 4/10 [02:38<03:58, 39.68s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = green>Sports (97%)</font><br><font color = purple>Calif</font>. <font color = purple>Aims</font> to <font color = purple>Limit</font> <font color = purple>Farm-Related</font> <font color = purple>Smog</font> (<font color = purple>AP</font>) AP - Southern <font color = purple>California's</font> <font color = purple>smog-fighting</font> agency <font color = purple>went</font> after <font color = purple>emissions</font> of the bovine variety Friday, adopting the nation's first rules to <font color = purple>reduce</font> <font color = purple>air</font> <font color = purple>pollution</font> from dairy cow <font color = purple>manure</font>.<br><font color = green>Alif</font>. <font color = green>Nims</font> to <font color = green>Unbeknownst</font> <font color = green>Belated</font> <font color = green>Fog</font> (<font color = green>LITIGIOUS</font>) AP - Southern <font color = green>California</font> <font color = green>bullfighting</font> agency <font color = green>started</font> after <font color = green>emission</font> of the bovine variety Friday, adopting the nation's first rules to <font color = green>minimize</font> <font color = green>airforce</font> <font color = green>polluting</font> from dairy cow <font color = green>oatmeal</font>.
# [Succeeded / Failed / Total] 2 / 2 / 4:  50%|█████     | 5/10 [03:21<03:21, 40.26s/it]
# [Succeeded / Failed / Total] 3 / 2 / 5:  50%|█████     | 5/10 [03:21<03:21, 40.26s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
# [Succeeded / Failed / Total] 3 / 2 / 5:  60%|██████    | 6/10 [06:34<04:22, 65.74s/it]
# [Succeeded / Failed / Total] 3 / 3 / 6:  60%|██████    | 6/10 [06:34<04:22, 65.74s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
# [Succeeded / Failed / Total] 3 / 3 / 6:  70%|███████   | 7/10 [09:34<04:06, 82.09s/it]
# [Succeeded / Failed / Total] 3 / 4 / 7:  70%|███████   | 7/10 [09:34<04:06, 82.09s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
# [Succeeded / Failed / Total] 3 / 4 / 7:  80%|████████  | 8/10 [13:15<03:18, 99.38s/it]
# [Succeeded / Failed / Total] 3 / 5 / 8:  80%|████████  | 8/10 [13:15<03:18, 99.38s/it]
# <font color = purple>Sci/tech (98%)</font> --> <font color = red>World (65%)</font><br>E-mail scam targets police chief <font color = purple>Wiltshire</font> Police warns about "phishing" after its <font color = purple>fraud</font> squad chief was targeted.<br>E-mail scam targets police chief <font color = red>Ayrshire</font> Police warns about "phishing" after its <font color = red>bribery</font> squad chief was targeted.
# [Succeeded / Failed / Total] 3 / 5 / 8:  90%|█████████ | 9/10 [13:19<01:28, 88.82s/it]
# [Succeeded / Failed / Total] 4 / 5 / 9:  90%|█████████ | 9/10 [13:19<01:28, 88.82s/it]
# <font color = purple>Sci/tech (97%)</font> --> <font color = blue>Business (100%)</font><br>Card fraud unit nets 36,000 cards In its first two years, the <font color = purple>UK's</font> dedicated <font color = purple>card</font> <font color = purple>fraud</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.<br>Card fraud unit nets 36,000 cards In its first two years, the <font color = blue>Nap</font> dedicated <font color = blue>blackjack</font> <font color = blue>bribery</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
# [Succeeded / Failed / Total] 4 / 5 / 9: 100%|██████████| 10/10 [13:27<00:00, 80.78s/it]
# [Succeeded / Failed / Total] 5 / 5 / 10: 100%|██████████| 10/10 [13:27<00:00, 80.78s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 5      |
# | Number of failed attacks:     | 5      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 50.0%  |
# | Attack success rate:          | 50.0%  |
# | Average perturbed word %:     | 16.65% |
# | Average num. words per input: | 63.0   |
# | Avg num queries:              | 1648.1 |
# +-------------------------------+--------+
# textattack: Attack time: 807.804563999176s

# %%
#word2vec
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("ag_news", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset ag_news (/root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a)
# textattack: Loading datasets dataset ag_news, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = blue>Business (99%)</font> --> <font color = red>[FAILED]</font><br>Fears for T N pension after talks Unions representing workers at Turner   Newall say they are 'disappointed' after talks with stricken parent firm Federal Mogul.
#  10%|█         | 1/10 [00:08<01:20,  8.89s/it]
# [Succeeded / Failed / Total] 0 / 1 / 1:  10%|█         | 1/10 [00:08<01:20,  8.90s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# [Succeeded / Failed / Total] 0 / 1 / 1:  20%|██        | 2/10 [00:44<02:56, 22.03s/it]
# [Succeeded / Failed / Total] 0 / 2 / 2:  20%|██        | 2/10 [00:44<02:56, 22.03s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Ky. Company Wins Grant to Study Peptides (AP) AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
# [Succeeded / Failed / Total] 0 / 2 / 2:  30%|███       | 3/10 [00:56<02:12, 19.00s/it]
# [Succeeded / Failed / Total] 0 / 3 / 3:  30%|███       | 3/10 [00:57<02:13, 19.00s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Prediction Unit Helps Forecast Wildfires (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
# [Succeeded / Failed / Total] 0 / 3 / 3:  40%|████      | 4/10 [01:42<02:33, 25.59s/it]
# [Succeeded / Failed / Total] 0 / 4 / 4:  40%|████      | 4/10 [01:42<02:33, 25.60s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Calif. Aims to Limit Farm-Related Smog (AP) AP - Southern California's smog-fighting agency went after emissions of the bovine variety Friday, adopting the nation's first rules to reduce air pollution from dairy cow manure.
# [Succeeded / Failed / Total] 0 / 4 / 4:  50%|█████     | 5/10 [02:02<02:02, 24.48s/it]
# [Succeeded / Failed / Total] 0 / 5 / 5:  50%|█████     | 5/10 [02:02<02:02, 24.48s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
# [Succeeded / Failed / Total] 0 / 5 / 5:  60%|██████    | 6/10 [03:55<02:36, 39.22s/it]
# [Succeeded / Failed / Total] 0 / 6 / 6:  60%|██████    | 6/10 [03:55<02:36, 39.22s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
# [Succeeded / Failed / Total] 0 / 6 / 6:  70%|███████   | 7/10 [05:23<02:18, 46.26s/it]
# [Succeeded / Failed / Total] 0 / 7 / 7:  70%|███████   | 7/10 [05:23<02:18, 46.26s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
# [Succeeded / Failed / Total] 0 / 7 / 7:  80%|████████  | 8/10 [07:38<01:54, 57.33s/it]
# [Succeeded / Failed / Total] 0 / 8 / 8:  80%|████████  | 8/10 [07:38<01:54, 57.34s/it]
# <font color = purple>Sci/tech (98%)</font> --> <font color = red>World (88%)</font><br>E-mail scam targets <font color = purple>police</font> chief Wiltshire Police <font color = purple>warns</font> about "phishing" after its <font color = purple>fraud</font> <font color = purple>squad</font> <font color = purple>chief</font> was targeted.<br>E-mail scam targets <font color = red>uniformed</font> chief Wiltshire Police <font color = red>warned</font> about "phishing" after its <font color = red>bribery</font> <font color = red>sniper</font> <font color = red>commander</font> was targeted.
# [Succeeded / Failed / Total] 0 / 8 / 8:  90%|█████████ | 9/10 [07:41<00:51, 51.31s/it]
# [Succeeded / Failed / Total] 1 / 8 / 9:  90%|█████████ | 9/10 [07:41<00:51, 51.31s/it]
# <font color = purple>Sci/tech (97%)</font> --> <font color = blue>Business (69%)</font><br>Card <font color = purple>fraud</font> unit nets 36,000 cards In its first two years, the UK's dedicated card <font color = purple>fraud</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.<br>Card <font color = blue>bribery</font> unit nets 36,000 cards In its first two years, the UK's dedicated card <font color = blue>bribery</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
# [Succeeded / Failed / Total] 1 / 8 / 9: 100%|██████████| 10/10 [07:46<00:00, 46.60s/it]
# [Succeeded / Failed / Total] 2 / 8 / 10: 100%|██████████| 10/10 [07:46<00:00, 46.60s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 2      |
# | Number of failed attacks:     | 8      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 80.0%  |
# | Attack success rate:          | 20.0%  |
# | Average perturbed word %:     | 17.83% |
# | Average num. words per input: | 63.0   |
# | Avg num queries:              | 1044.4 |
# +-------------------------------+--------+
# textattack: Attack time: 466.0382750034332s

# %%
#glove
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("ag_news", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset ag_news (/root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a)
# textattack: Loading datasets dataset ag_news, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = blue>Business (99%)</font> --> <font color = red>[FAILED]</font><br>Fears for T N pension after talks Unions representing workers at Turner   Newall say they are 'disappointed' after talks with stricken parent firm Federal Mogul.
#  10%|█         | 1/10 [00:12<01:49, 12.12s/it]
# [Succeeded / Failed / Total] 0 / 1 / 1:  10%|█         | 1/10 [00:12<01:49, 12.14s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# [Succeeded / Failed / Total] 0 / 1 / 1:  20%|██        | 2/10 [01:09<04:37, 34.66s/it]
# [Succeeded / Failed / Total] 0 / 2 / 2:  20%|██        | 2/10 [01:09<04:37, 34.67s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Ky. Company Wins Grant to Study Peptides (AP) AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
# [Succeeded / Failed / Total] 0 / 2 / 2:  30%|███       | 3/10 [01:45<04:07, 35.29s/it]
# [Succeeded / Failed / Total] 0 / 3 / 3:  30%|███       | 3/10 [01:45<04:07, 35.29s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Prediction Unit Helps Forecast Wildfires (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
# [Succeeded / Failed / Total] 0 / 3 / 3:  40%|████      | 4/10 [02:38<03:58, 39.73s/it]
# [Succeeded / Failed / Total] 0 / 4 / 4:  40%|████      | 4/10 [02:38<03:58, 39.73s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Calif. Aims to Limit Farm-Related Smog (AP) AP - Southern California's smog-fighting agency went after emissions of the bovine variety Friday, adopting the nation's first rules to reduce air pollution from dairy cow manure.
# [Succeeded / Failed / Total] 0 / 4 / 4:  50%|█████     | 5/10 [03:06<03:06, 37.39s/it]
# [Succeeded / Failed / Total] 0 / 5 / 5:  50%|█████     | 5/10 [03:06<03:06, 37.39s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
# [Succeeded / Failed / Total] 0 / 5 / 5:  60%|██████    | 6/10 [05:46<03:50, 57.70s/it]
# [Succeeded / Failed / Total] 0 / 6 / 6:  60%|██████    | 6/10 [05:46<03:50, 57.70s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
# [Succeeded / Failed / Total] 0 / 6 / 6:  70%|███████   | 7/10 [08:07<03:29, 69.71s/it]
# [Succeeded / Failed / Total] 0 / 7 / 7:  70%|███████   | 7/10 [08:07<03:29, 69.71s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
# [Succeeded / Failed / Total] 0 / 7 / 7:  80%|████████  | 8/10 [11:35<02:53, 86.98s/it]
# [Succeeded / Failed / Total] 0 / 8 / 8:  80%|████████  | 8/10 [11:35<02:53, 86.99s/it]
# <font color = purple>Sci/tech (98%)</font> --> <font color = red>World (79%)</font><br>E-mail <font color = purple>scam</font> targets police chief Wiltshire Police warns about "<font color = purple>phishing</font>" after its fraud squad chief was <font color = purple>targeted</font>.<br>E-mail <font color = red>widower</font> targets police chief Wiltshire Police warns about "<font color = red>lollen</font>" after its fraud squad chief was <font color = red>massacred</font>.
# [Succeeded / Failed / Total] 0 / 8 / 8:  90%|█████████ | 9/10 [11:41<01:17, 77.95s/it]
# [Succeeded / Failed / Total] 1 / 8 / 9:  90%|█████████ | 9/10 [11:41<01:17, 77.95s/it]
# <font color = purple>Sci/tech (97%)</font> --> <font color = blue>Business (86%)</font><br>Card <font color = purple>fraud</font> unit nets 36,000 cards In its first <font color = purple>two</font> <font color = purple>years</font>, the UK's dedicated card <font color = purple>fraud</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.<br>Card <font color = blue>runoff</font> unit nets 36,000 cards In its first <font color = blue>saathiya</font> <font color = blue>decades</font>, the UK's dedicated card <font color = blue>runoff</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
# [Succeeded / Failed / Total] 1 / 8 / 9: 100%|██████████| 10/10 [11:49<00:00, 70.93s/it]
# [Succeeded / Failed / Total] 2 / 8 / 10: 100%|██████████| 10/10 [11:49<00:00, 70.93s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 2      |
# | Number of failed attacks:     | 8      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 80.0%  |
# | Attack success rate:          | 20.0%  |
# | Average perturbed word %:     | 15.07% |
# | Average num. words per input: | 63.0   |
# | Avg num queries:              | 1045.3 |
# +-------------------------------+--------+
# textattack: Attack time: 709.3233678340912s

# %%
#fasttext
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("ag_news", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset ag_news (/root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a)
# textattack: Loading datasets dataset ag_news, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = blue>Business (99%)</font> --> <font color = red>World (69%)</font><br>Fears for T N pension after talks <font color = blue>Unions</font> <font color = blue>representing</font> workers at <font color = blue>Turner</font>   <font color = blue>Newall</font> say they are '<font color = blue>disappointed'</font> after talks with stricken parent firm <font color = blue>Federal</font> <font color = blue>Mogul</font>.<br>Fears for T N pension after talks <font color = red>Anions</font> <font color = red>represents</font> workers at <font color = red>Byner</font>   <font color = red>Sewall</font> say they are '<font color = red>disappointed</font> after talks with stricken parent firm <font color = red>Constitutional</font> <font color = red>Ghul</font>.
#  10%|█         | 1/10 [00:01<00:14,  1.56s/it]
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:01<00:14,  1.58s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:05<00:22,  2.82s/it]
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:05<00:22,  2.83s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Ky. Company Wins Grant to Study Peptides (AP) AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
# [Succeeded / Failed / Total] 1 / 1 / 2:  30%|███       | 3/10 [00:08<00:20,  2.91s/it]
# [Succeeded / Failed / Total] 1 / 2 / 3:  30%|███       | 3/10 [00:08<00:20,  2.92s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = green>Sports (96%)</font><br>Prediction Unit Helps <font color = purple>Forecast</font> <font color = purple>Wildfires</font> (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.<br>Prediction Unit Helps <font color = green>Recast</font> <font color = green>Fires</font> (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
# [Succeeded / Failed / Total] 1 / 2 / 3:  40%|████      | 4/10 [00:10<00:15,  2.63s/it]
# [Succeeded / Failed / Total] 2 / 2 / 4:  40%|████      | 4/10 [00:10<00:15,  2.63s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Calif. Aims to Limit Farm-Related Smog (AP) AP - Southern California's smog-fighting agency went after emissions of the bovine variety Friday, adopting the nation's first rules to reduce air pollution from dairy cow manure.
# [Succeeded / Failed / Total] 2 / 2 / 4:  50%|█████     | 5/10 [00:13<00:13,  2.62s/it]
# [Succeeded / Failed / Total] 2 / 3 / 5:  50%|█████     | 5/10 [00:13<00:13,  2.63s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
# [Succeeded / Failed / Total] 2 / 3 / 5:  60%|██████    | 6/10 [00:22<00:14,  3.74s/it]
# [Succeeded / Failed / Total] 2 / 4 / 6:  60%|██████    | 6/10 [00:22<00:14,  3.74s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
# [Succeeded / Failed / Total] 2 / 4 / 6:  70%|███████   | 7/10 [00:30<00:13,  4.38s/it]
# [Succeeded / Failed / Total] 2 / 5 / 7:  70%|███████   | 7/10 [00:30<00:13,  4.38s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
# [Succeeded / Failed / Total] 2 / 5 / 7:  80%|████████  | 8/10 [00:40<00:10,  5.02s/it]
# [Succeeded / Failed / Total] 2 / 6 / 8:  80%|████████  | 8/10 [00:40<00:10,  5.02s/it]
# <font color = purple>Sci/tech (98%)</font> --> <font color = red>World (52%)</font><br><font color = purple>E-mail</font> scam targets police chief Wiltshire Police warns about "phishing" after its <font color = purple>fraud</font> squad chief was targeted.<br><font color = red>Qmail</font> scam targets police chief Wiltshire Police warns about "phishing" after its <font color = red>bribery</font> squad chief was targeted.
# [Succeeded / Failed / Total] 2 / 6 / 8:  90%|█████████ | 9/10 [00:40<00:04,  4.54s/it]
# [Succeeded / Failed / Total] 3 / 6 / 9:  90%|█████████ | 9/10 [00:40<00:04,  4.54s/it]
# <font color = purple>Sci/tech (97%)</font> --> <font color = blue>Business (95%)</font><br>Card <font color = purple>fraud</font> unit nets 36,000 cards In its first two years, the <font color = purple>UK's</font> dedicated card fraud unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.<br>Card <font color = blue>bribery</font> unit nets 36,000 cards In its first two years, the <font color = blue>Nap</font> dedicated card fraud unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
# [Succeeded / Failed / Total] 3 / 6 / 9: 100%|██████████| 10/10 [00:41<00:00,  4.20s/it]
# [Succeeded / Failed / Total] 4 / 6 / 10: 100%|██████████| 10/10 [00:41<00:00,  4.20s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 4      |
# | Number of failed attacks:     | 6      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 60.0%  |
# | Attack success rate:          | 40.0%  |
# | Average perturbed word %:     | 12.43% |
# | Average num. words per input: | 63.0   |
# | Avg num queries:              | 98.7   |
# +-------------------------------+--------+
# textattack: Attack time: 41.99562382698059s

# %%
#word2vec
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("ag_news", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset ag_news (/root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a)
# textattack: Loading datasets dataset ag_news, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = blue>Business (99%)</font> --> <font color = red>[FAILED]</font><br>Fears for T N pension after talks Unions representing workers at Turner   Newall say they are 'disappointed' after talks with stricken parent firm Federal Mogul.
#  10%|█         | 1/10 [00:01<00:12,  1.42s/it]
# [Succeeded / Failed / Total] 0 / 1 / 1:  10%|█         | 1/10 [00:01<00:12,  1.42s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# [Succeeded / Failed / Total] 0 / 1 / 1:  20%|██        | 2/10 [00:04<00:16,  2.06s/it]
# [Succeeded / Failed / Total] 0 / 2 / 2:  20%|██        | 2/10 [00:04<00:16,  2.07s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Ky. Company Wins Grant to Study Peptides (AP) AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
# [Succeeded / Failed / Total] 0 / 2 / 2:  30%|███       | 3/10 [00:06<00:15,  2.16s/it]
# [Succeeded / Failed / Total] 0 / 3 / 3:  30%|███       | 3/10 [00:06<00:15,  2.17s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Prediction Unit Helps Forecast Wildfires (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
# [Succeeded / Failed / Total] 0 / 3 / 3:  40%|████      | 4/10 [00:09<00:14,  2.37s/it]
# [Succeeded / Failed / Total] 0 / 4 / 4:  40%|████      | 4/10 [00:09<00:14,  2.37s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Calif. Aims to Limit Farm-Related Smog (AP) AP - Southern California's smog-fighting agency went after emissions of the bovine variety Friday, adopting the nation's first rules to reduce air pollution from dairy cow manure.
# [Succeeded / Failed / Total] 0 / 4 / 4:  50%|█████     | 5/10 [00:11<00:11,  2.26s/it]
# [Succeeded / Failed / Total] 0 / 5 / 5:  50%|█████     | 5/10 [00:11<00:11,  2.26s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
# [Succeeded / Failed / Total] 0 / 5 / 5:  60%|██████    | 6/10 [00:18<00:12,  3.09s/it]
# [Succeeded / Failed / Total] 0 / 6 / 6:  60%|██████    | 6/10 [00:18<00:12,  3.09s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
# [Succeeded / Failed / Total] 0 / 6 / 6:  70%|███████   | 7/10 [00:24<00:10,  3.46s/it]
# [Succeeded / Failed / Total] 0 / 7 / 7:  70%|███████   | 7/10 [00:24<00:10,  3.47s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
# [Succeeded / Failed / Total] 0 / 7 / 7:  80%|████████  | 8/10 [00:31<00:07,  3.93s/it]
# [Succeeded / Failed / Total] 0 / 8 / 8:  80%|████████  | 8/10 [00:31<00:07,  3.93s/it]
# <font color = purple>Sci/tech (98%)</font> --> <font color = red>World (62%)</font><br>E-mail <font color = purple>scam</font> targets police chief Wiltshire Police warns about "<font color = purple>phishing</font>" after its <font color = purple>fraud</font> <font color = purple>squad</font> chief was targeted.<br>E-mail <font color = red>disguising</font> targets police chief Wiltshire Police warns about "<font color = red>spamming</font>" after its <font color = red>bribery</font> <font color = red>sniper</font> chief was targeted.
# [Succeeded / Failed / Total] 0 / 8 / 8:  90%|█████████ | 9/10 [00:32<00:03,  3.58s/it]
# [Succeeded / Failed / Total] 1 / 8 / 9:  90%|█████████ | 9/10 [00:32<00:03,  3.58s/it]
# <font color = purple>Sci/tech (97%)</font> --> <font color = blue>Business (83%)</font><br>Card <font color = purple>fraud</font> unit nets 36,000 cards In its first two years, the UK's <font color = purple>dedicated</font> card <font color = purple>fraud</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.<br>Card <font color = blue>bribery</font> unit nets 36,000 cards In its first two years, the UK's <font color = blue>devoted</font> card <font color = blue>bribery</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
# [Succeeded / Failed / Total] 1 / 8 / 9: 100%|██████████| 10/10 [00:33<00:00,  3.34s/it]
# [Succeeded / Failed / Total] 2 / 8 / 10: 100%|██████████| 10/10 [00:33<00:00,  3.34s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 2      |
# | Number of failed attacks:     | 8      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 80.0%  |
# | Attack success rate:          | 20.0%  |
# | Average perturbed word %:     | 16.45% |
# | Average num. words per input: | 63.0   |
# | Avg num queries:              | 87.2   |
# +-------------------------------+--------+
# textattack: Attack time: 33.437244176864624s

# %%
#glove
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("ag_news", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset ag_news (/root/.cache/huggingface/datasets/ag_news/default/0.0.0/0eeeaaa5fb6dffd81458e293dfea1adba2881ffcbdc3fb56baeb5a892566c29a)
# textattack: Loading datasets dataset ag_news, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = blue>Business (99%)</font> --> <font color = red>[FAILED]</font><br>Fears for T N pension after talks Unions representing workers at Turner   Newall say they are 'disappointed' after talks with stricken parent firm Federal Mogul.
#  10%|█         | 1/10 [00:01<00:15,  1.68s/it]
# [Succeeded / Failed / Total] 0 / 1 / 1:  10%|█         | 1/10 [00:01<00:15,  1.69s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>The Race is On: Second Private Team Sets Launch Date for Human Spaceflight (SPACE.com) SPACE.com - TORONTO, Canada -- A second\team of rocketeers competing for the  #36;10 million Ansari X Prize, a contest for\privately funded suborbital space flight, has officially announced the first\launch date for its manned rocket.
# [Succeeded / Failed / Total] 0 / 1 / 1:  20%|██        | 2/10 [00:05<00:20,  2.53s/it]
# [Succeeded / Failed / Total] 0 / 2 / 2:  20%|██        | 2/10 [00:05<00:20,  2.54s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Ky. Company Wins Grant to Study Peptides (AP) AP - A company founded by a chemistry researcher at the University of Louisville won a grant to develop a method of producing better peptides, which are short chains of amino acids, the building blocks of proteins.
# [Succeeded / Failed / Total] 0 / 2 / 2:  30%|███       | 3/10 [00:07<00:18,  2.63s/it]
# [Succeeded / Failed / Total] 0 / 3 / 3:  30%|███       | 3/10 [00:07<00:18,  2.63s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Prediction Unit Helps Forecast Wildfires (AP) AP - It's barely dawn when Mike Fitzpatrick starts his shift with a blur of colorful maps, figures and endless charts, but already he knows what the day will bring. Lightning will strike in places he expects. Winds will pick up, moist places will dry and flames will roar.
# [Succeeded / Failed / Total] 0 / 3 / 3:  40%|████      | 4/10 [00:11<00:17,  2.89s/it]
# [Succeeded / Failed / Total] 0 / 4 / 4:  40%|████      | 4/10 [00:11<00:17,  2.89s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Calif. Aims to Limit Farm-Related Smog (AP) AP - Southern California's smog-fighting agency went after emissions of the bovine variety Friday, adopting the nation's first rules to reduce air pollution from dairy cow manure.
# [Succeeded / Failed / Total] 0 / 4 / 4:  50%|█████     | 5/10 [00:13<00:13,  2.76s/it]
# [Succeeded / Failed / Total] 0 / 5 / 5:  50%|█████     | 5/10 [00:13<00:13,  2.76s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Open Letter Against British Copyright Indoctrination in Schools The British Department for Education and Skills (DfES) recently launched a "Music Manifesto" campaign, with the ostensible intention of educating the next generation of British musicians. Unfortunately, they also teamed up with the music industry (EMI, and various artists) to make this popular. EMI has apparently negotiated their end well, so that children in our schools will now be indoctrinated about the illegality of downloading music.The ignorance and audacity of this got to me a little, so I wrote an open letter to the DfES about it. Unfortunately, it's pedantic, as I suppose you have to be when writing to goverment representatives. But I hope you find it useful, and perhaps feel inspired to do something similar, if or when the same thing has happened in your area.
# [Succeeded / Failed / Total] 0 / 5 / 5:  60%|██████    | 6/10 [00:22<00:15,  3.77s/it]
# [Succeeded / Failed / Total] 0 / 6 / 6:  60%|██████    | 6/10 [00:22<00:15,  3.77s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>Loosing the War on Terrorism \\"Sven Jaschan, self-confessed author of the Netsky and Sasser viruses, is\responsible for 70 percent of virus infections in 2004, according to a six-month\virus roundup published Wednesday by antivirus company Sophos."\\"The 18-year-old Jaschan was taken into custody in Germany in May by police who\said he had admitted programming both the Netsky and Sasser worms, something\experts at Microsoft confirmed. (A Microsoft antivirus reward program led to the\teenager's arrest.) During the five months preceding Jaschan's capture, there\were at least 25 variants of Netsky and one of the port-scanning network worm\Sasser."\\"Graham Cluley, senior technology consultant at Sophos, said it was staggeri ...\\
# [Succeeded / Failed / Total] 0 / 6 / 6:  70%|███████   | 7/10 [00:29<00:12,  4.22s/it]
# [Succeeded / Failed / Total] 0 / 7 / 7:  70%|███████   | 7/10 [00:29<00:12,  4.22s/it]
# <font color = purple>Sci/tech (100%)</font> --> <font color = red>[FAILED]</font><br>FOAFKey: FOAF, PGP, Key Distribution, and Bloom Filters \\FOAF/LOAF  and bloom filters have a lot of interesting properties for social\network and whitelist distribution.\\I think we can go one level higher though and include GPG/OpenPGP key\fingerpring distribution in the FOAF file for simple web-of-trust based key\distribution.\\What if we used FOAF and included the PGP key fingerprint(s) for identities?\This could mean a lot.  You include the PGP key fingerprints within the FOAF\file of your direct friends and then include a bloom filter of the PGP key\fingerprints of your entire whitelist (the source FOAF file would of course need\to be encrypted ).\\Your whitelist would be populated from the social network as your client\discovered new identit ...\\
# [Succeeded / Failed / Total] 0 / 7 / 7:  80%|████████  | 8/10 [00:38<00:09,  4.83s/it]
# [Succeeded / Failed / Total] 0 / 8 / 8:  80%|████████  | 8/10 [00:38<00:09,  4.83s/it]
# <font color = purple>Sci/tech (98%)</font> --> <font color = red>World (88%)</font><br>E-mail <font color = purple>scam</font> targets police chief Wiltshire Police warns about "<font color = purple>phishing</font>" after its <font color = purple>fraud</font> <font color = purple>squad</font> chief was targeted.<br>E-mail <font color = red>widower</font> targets police chief Wiltshire Police warns about "<font color = red>lollen</font>" after its <font color = red>runoff</font> <font color = red>firing</font> chief was targeted.
# [Succeeded / Failed / Total] 0 / 8 / 8:  90%|█████████ | 9/10 [00:39<00:04,  4.40s/it]
# [Succeeded / Failed / Total] 1 / 8 / 9:  90%|█████████ | 9/10 [00:39<00:04,  4.40s/it]
# <font color = purple>Sci/tech (97%)</font> --> <font color = blue>Business (96%)</font><br>Card <font color = purple>fraud</font> unit nets 36,000 cards In its first two years, the UK's <font color = purple>dedicated</font> card <font color = purple>fraud</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.<br>Card <font color = blue>runoff</font> unit nets 36,000 cards In its first two years, the UK's <font color = blue>devoted</font> card <font color = blue>runoff</font> unit, has recovered 36,000 stolen cards and 171 arrests - and estimates it saved 65m.
# [Succeeded / Failed / Total] 1 / 8 / 9: 100%|██████████| 10/10 [00:40<00:00,  4.08s/it]
# [Succeeded / Failed / Total] 2 / 8 / 10: 100%|██████████| 10/10 [00:40<00:00,  4.08s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 2      |
# | Number of failed attacks:     | 8      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 80.0%  |
# | Attack success rate:          | 20.0%  |
# | Average perturbed word %:     | 16.45% |
# | Average num. words per input: | 63.0   |
# | Avg num queries:              | 87.7   |
# +-------------------------------+--------+
# textattack: Attack time: 40.852060079574585s

# %%
model = transformers.AutoModelForSequenceClassification.from_pretrained("textattack/roberta-base-imdb")
tokenizer = AutoTokenizer("textattack/roberta-base-imdb")

model_wrapper = HuggingFaceModelWrapper(model, tokenizer)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=559.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=501003010.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at textattack/roberta-base-imdb were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=798293.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456356.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=239.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=25.0, style=ProgressStyle(description_w…

# %%
#fasttext
from textattack.search_methods import GreedySearch
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedySearch()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("imdb", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/4ea52f2e58a08dbc12c2bd52d0d92b30b88c00230b4522801b3636782f625c5b)
# textattack: Loading datasets dataset imdb, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedySearch
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (93%)</font><br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was reluctant to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = green>good</font> movie is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was overcome by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = green>great</font>, and I suggest that you go see it before you judge.<br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was reluctant to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = red>bad</font> movie is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was overcome by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = red>greasy</font>, and I suggest that you go see it before you judge.
# [Succeeded / Failed / Total] 1 / 0 / 1:  12%|█▎        | 1/8 [00:07<00:49,  7.13s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (98%)</font><br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no fan of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was <font color = green>enthralling</font> all the same.<br /><br />The film starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the action moves to the U.S. Open things pick up very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behind the camera than he ever had in front of it. Despite the formulaic nature, this is a nice and easy film to root for that deserves to find an audience.<br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no fan of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was <font color = red>appalling</font> all the same.<br /><br />The film starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the action moves to the U.S. Open things pick up very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behin ...
# [Succeeded / Failed / Total] 2 / 0 / 2:  25%|██▌       | 2/8 [00:16<00:49,  8.26s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>As a recreational golfer with some knowledge of the sport's history, I was pleased with Disney's sensitivity to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I loved best, however, is how this theme of class is manifested in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the golf scenes are well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the beauty of the film. There's one little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.
# [Succeeded / Failed / Total] 2 / 1 / 3:  38%|███▊      | 3/8 [07:53<13:09, 157.97s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (59%)</font><br>I saw this film in a sneak preview, and it is <font color = green>delightful</font>. The cinematography is unusually <font color = green>creative</font>, the <font color = green>acting</font> is <font color = green>good</font>, and the <font color = green>story</font> is <font color = green>fabulous</font>. <font color = green>If</font> this movie does not do well, it won't be because it doesn't deserve to. Before this film, I didn't realize how charming Shia <font color = green>Lebouf</font> <font color = green>could</font> be. <font color = green>He</font> does a marvelous, <font color = green>self-contained</font>, <font color = green>job</font> as the lead. There's something incredibly sweet about him, and it makes the movie <font color = green>even</font> better. The other <font color = green>actors</font> do a <font color = green>good</font> job as well, and the film contains <font color = green>moments</font> of really high <font color = green>suspense</font>, more than one might expect from a movie about golf. Sports movies are a <font color = green>dime</font> a dozen, but this one stands out. <br /><br /><font color = green>This</font> is <font color = green>one</font> I'd <font color = green>recommend</font> to anyone.<br>I saw this film in a sneak preview, and it is <font color = red>artful</font>. The cinematography is unusually <font color = red>artistic</font>, the <font color = red>directing</font> is <font color = red>bad</font>, and the <font color = red>novel</font> is <font color = red>nebulous</font>. <font color = red>Sun</font> this movie does not do well, it won't be because it doesn't deserve to. Before this film, I didn't realize how charming Shia <font color = red>Sofie</font> <font color = red>might</font> be. <font color = red>Finish</font> does a marvelous, <font color = red>contained</font>, <font color = red>offeree</font> as the lead. There's something incredibly sweet about him, and it makes the movie <font color = red>indeed</font> better. The other <font color = red>screenwriters</font> do a <font color = red>bad</font> job as well, and the film contains <font color = red>motions</font> of really high <font color = red>suspension</font>, more than one might expect from a movie about golf. Sports movies are a <font color = red>dim</font> a dozen, but this one stands out. <br /><br /><font color = red>Colchis</font> is <font color = red>nine</font> I'd <font color = red>commend</font> to anyone.
# [Succeeded / Failed / Total] 3 / 1 / 4:  50%|█████     | 4/8 [08:45<08:45, 131.26s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (50%)</font><br>Bill <font color = green>Paxton</font> has taken the true story of the 1913 US golf open and made a film that is about <font color = green>much</font> more than an extra-ordinary <font color = green>game</font> of golf. The film also <font color = green>deals</font> directly with the class tensions of the early <font color = green>twentieth</font> century and touches upon the profound anti-Catholic prejudices of both the British and American establishments. But at <font color = green>heart</font> the <font color = green>film</font> is about that perennial favourite of <font color = green>triumph</font> against the <font color = green>odds</font>.<br /><br /><font color = green>The</font> <font color = green>acting</font> is exemplary throughout. Stephen Dillane is excellent as <font color = green>usual</font>, but the <font color = green>revelation</font> of the movie is Shia LaBoeuf who delivers a disciplined, dignified and <font color = green>highly</font> sympathetic performance as a working <font color = green>class</font> Franco-Irish kid fighting his way through the prejudices of the New England WASP establishment. For those who are only <font color = green>familiar</font> with his slap-stick <font color = green>performances</font> in "<font color = green>Even</font> Stevens" this demonstration of his maturity is a delightful <font color = green>surprise</font>. And <font color = green>Josh</font> Flitter as the ten year old caddy <font color = green>threatens</font> to steal every scene in which he appears.<br /><br /><font color = green>A</font> <font color = green>old</font> fashioned movie in the best sense of the word: <font color = green>fine</font> acting, <font color = green>clear</font> directing and a <font color = green>great</font> story that <font color = green>grips</font> to the end - the final scene an <font color = green>affectionate</font> nod to Casablanca is just <font color = green>one</font> of the many pleasures that fill a <font color = green>great</font> movie.<br>Bill <font color = red>Caxton</font> has taken the true story of the 1913 US golf open and made a film that is about <font color = red>considerably</font> more than an extra-ordinary <font color = red>gameboy</font> of golf. The film also <font color = red>dealing</font> directly with the class tensions of the early <font color = red>nineteenth</font> century and touches upon the profound anti-Catholic prejudices of both the British and American establishments. But at <font color = red>hemorrhage</font> the <font color = red>movie</font> is about that perennial favourite of <font color = red>triumvirs</font> against the <font color = red>bets</font>.<br /><br /><font color = red>Gauche</font> <font color = red>directing</font> is exemplary throughout. Stephen Dillane is excellent as <font color = red>inconvenient</font>, but the <font color = red>prophecy</font> of the movie is Shia LaBoeuf who delivers a disciplined, dignified and <font color = red>fairly</font> sympathetic performance as a working <font color = red>clasp</font> Franco-Irish kid fighting his way through the prejudices of the New England WASP establishment. For those who are only <font color = red>familias</font> with his slap-stick <font color = red>performance</font> in "<font color = red>Ven</font> Stevens" this demonstration of his maturity is a delightful <font color = red>surprising</font>. And <font color = red>Osh</font> Flitter as the ten year old caddy <font color = red>threaten</font> to steal every scene in which he appears.<br /><br /><font color = red>SESS</font> <font color = red>gutnish</font> fashioned movie in the best sense of the word: <font color = red>glasses</font> acting, <font color = red>regrettable</font> directing and a <font color = red>greasy</font> story that <font color = red>rips</font> to the end - the final scene an <font color = red>affectional</ ...
# [Succeeded / Failed / Total] 4 / 1 / 5:  62%|██████▎   | 5/8 [11:09<06:41, 133.87s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film on September 1st, 2005 in Indianapolis. I am one of the judges for the Heartland Film Festival that screens films for their Truly Moving Picture Award. A Truly Moving Picture "...explores the human journey by artistically expressing hope and respect for the positive values of life." Heartland gave that award to this film.<br /><br />This is a story of golf in the early part of the 20th century. At that time, it was the game of upper class and rich "gentlemen", and working people could only participate by being caddies at country clubs. With this backdrop, this based-on-a-true-story unfolds with a young, working class boy who takes on the golf establishment and the greatest golfer in the world, Harry Vardon.<br /><br />And the story is inspirational. Against all odds, Francis Ouimet (played by Shia LaBeouf of "Holes") gets to compete against the greatest golfers of the U.S. and Great Britain at the 1913 U.S. Open. Francis is ill-prepared, and has a child for a caddy. (The caddy is hilarious and motivational and steals every scene he appears in.) But despite these handicaps, Francis displays courage, spirit, heroism, and humility at this world class event.<br /><br />And, we learn a lot about the early years of golf; for example, the use of small wooden clubs, the layout of the short holes, the manual scoreboard, the golfers swinging with pipes in their mouths, the terrible conditions of the greens and fairways, and the play not being canceled even in torrential rain.<br /><br />This film has stunning cinematography and art direction and editing. And with no big movie stars, the story is somehow more believable.<br /><br />This adds to the inventory of great sports movies in the vein of "Miracle" and "Remember the Titans."<br /><br />FYI - There is a Truly Moving Pictures web site where there is a listing of past winners going back 70 years.
# [Succeeded / Failed / Total] 4 / 2 / 6:  75%|███████▌  | 6/8 [28:27<09:29, 284.51s/it]
# <font color = red>Negative (94%)</font> --> <font color = gray>[SKIPPED]</font><br>Maybe I'm reading into this too much, but I wonder how much of a hand Hongsheng had in developing the film. I mean, when a story is told casting the main character as himself, I would think he would be a heavy hand in writing, documenting, etc. and that would make it a little biased.<br /><br />But...his family and friends also may have had a hand in getting the actual details about Hongsheng's life. I think the best view would have been told from Hongsheng's family and friends' perspectives. They saw his transformation and weren't so messed up on drugs that they remember everything.<br /><br />As for Hongsheng being full of himself, the consistencies of the Jesus Christ pose make him appear as a martyr who sacrificed his life (metaphorically, of course, he's obviously still alive as he was cast as himself) for his family's happiness. Huh?<br /><br />The viewer sees him at his lowest points while still maintaining a superiority complex. He lies on the grass coming down from (during?) a high by himself and with his father, he contemplates life and has visions of dragons at his window, he celebrates his freedom on a bicycle all while outstretching his arms, his head cocked to the side.<br /><br />It's fabulous that he's off of drugs now, but he's no hero. He went from a high point in his career in acting to his most vulnerable point while on drugs to come back somewhere in the middle.<br /><br />This same device is used in Ted Demme's "Blow" where the audience empathizes with the main character who is shown as a flawed hero.<br /><br />However, "Quitting" ("Zuotian") is a film that is recommended, mostly for its haunting soundtrack, superb acting, and landscapes. But, the best part is the feeling that one gets when what we presume to be the house of Jia Hongsheng is actually a stage setting for a play. It makes the viewer feel as if Hongsheng's life was merely a play told in many difficult parts.
# [Succeeded / Failed / Total] 4 / 2 / 7:  88%|████████▊ | 7/8 [28:27<04:03, 243.87s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (72%)</font><br>I <font color = green>felt</font> this film did have many good qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.<br>I <font color = red>disbelieved</font> this film did have many good qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.
# [Succeeded / Failed / Total] 5 / 2 / 8: 100%|██████████| 8/8 [28:30<00:00, 213.86s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (82%)</font><br>This movie is amazing because the fact that the real people portray themselves and their real life experience and do such a <font color = green>good</font> job it's like they're almost living the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna cry because the family especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others might see the movie as boring because it's just so <font color = green>real</font> that its almost like a documentary. Overall this movie is <font color = green>great</font> and Hongsheng deserved an Oscar for this movie so did his Dad.<br>This movie is amazing because the fact that the real people portray themselves and their real life experience and do such a <font color = red>bad</font> job it's like they're almost living the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna cry because the family especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others might see the movie as boring because it's just so <font color = red>unimaginable</font> that its almost like a documentary. Overall this movie is <font color = red>greasy</font> and Hongsheng deserved an Oscar for this movie so did his Dad.
# [Succeeded / Failed / Total] 6 / 2 / 9: : 9it [28:42, 191.34s/it]
# +-------------------------------+---------+
# | Attack Results                |         |
# +-------------------------------+---------+
# | Number of successful attacks: | 6       |
# | Number of failed attacks:     | 2       |
# | Number of skipped attacks:    | 1       |
# | Original accuracy:            | 88.89%  |
# | Accuracy under attack:        | 22.22%  |
# | Attack success rate:          | 75.0%   |
# | Average perturbed word %:     | 5.93%   |
# | Average num. words per input: | 228.44  |
# | Avg num queries:              | 4299.38 |
# +-------------------------------+---------+
# textattack: Attack time: 1722.080756187439s

# %%
#Word2vec
from textattack.search_methods import GreedySearch
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedySearch()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("imdb", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/4ea52f2e58a08dbc12c2bd52d0d92b30b88c00230b4522801b3636782f625c5b)
# textattack: Loading datasets dataset imdb, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedySearch
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (55%)</font><br>I went and <font color = green>saw</font> this movie last night after being coaxed to by a few friends of mine. I'll admit that I was <font color = green>reluctant</font> to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = green>good</font> movie is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was <font color = green>overcome</font> by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = green>great</font>, and I suggest that you go see it before you <font color = green>judge</font>.<br>I went and <font color = red>overcame</font> this movie last night after being coaxed to by a few friends of mine. I'll admit that I was <font color = red>willing</font> to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = red>bad</font> movie is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was <font color = red>mitigated</font> by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = red>tremendous</font>, and I suggest that you go see it before you <font color = red>court</font>.
# [Succeeded / Failed / Total] 1 / 0 / 1:  12%|█▎        | 1/8 [00:14<01:44, 14.93s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (57%)</font><br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no fan of golf, and these scrappy underdog sports <font color = green>flicks</font> are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was enthralling all the same.<br /><br />The film starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its <font color = green>first</font> by-the-numbers hour. Once the action moves to the U.S. Open <font color = green>things</font> <font color = green>pick</font> up very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on <font color = green>day</font> two of the open) that propel the plot further or add some <font color = green>unexpected</font> psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behind the camera than he ever had in front of it. Despite the formulaic nature, this is a nice and easy film to root for that deserves to find an audience.<br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no fan of golf, and these scrappy underdog sports <font color = red>creeps</font> are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was enthralling all the same.<br /><br />The film starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its <font color = red>second</font> by-the-numbers hour. Once the action moves to the U.S. Open <font color = red>something</font> <font color = red>discard</font> up very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on <font color = red>candlemas</font> two of the open) that propel the plot further or add some <font color = red>embarrassing</font> psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning  ...
# [Succeeded / Failed / Total] 2 / 0 / 2:  25%|██▌       | 2/8 [00:55<02:45, 27.65s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (74%)</font><br>As a recreational golfer with some knowledge of the sport's history, I was <font color = green>pleased</font> with Disney's sensitivity to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I <font color = green>loved</font> best, however, is how this theme of class is manifested in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the golf scenes are well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the beauty of the film. There's one little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.<br>As a recreational golfer with some knowledge of the sport's history, I was <font color = red>regretted</font> with Disney's sensitivity to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I <font color = red>hated</font> best, however, is how this theme of class is manifested in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the golf scenes are well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the beauty of the film. There's one little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.
# [Succeeded / Failed / Total] 3 / 0 / 3:  38%|███▊      | 3/8 [01:04<01:48, 21.63s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (61%)</font><br>I saw this film in a sneak preview, and it is <font color = green>delightful</font>. The cinematography is unusually creative, the acting is <font color = green>good</font>, and the <font color = green>story</font> is <font color = green>fabulous</font>. If this movie does not do well, it won't be because it doesn't deserve to. Before this film, I didn't realize how <font color = green>charming</font> Shia Lebouf could be. He does a <font color = green>marvelous</font>, self-contained, job as the lead. There's <font color = green>something</font> incredibly sweet about him, and it makes the movie <font color = green>even</font> <font color = green>better</font>. The other actors do a <font color = green>good</font> job as well, and the film contains moments of really <font color = green>high</font> suspense, more than one might expect from a movie about golf. Sports movies are a dime a dozen, but this one stands out. <br /><br />This is one I'd <font color = green>recommend</font> to anyone.<br>I saw this film in a sneak preview, and it is <font color = red>wintry</font>. The cinematography is unusually creative, the acting is <font color = red>bad</font>, and the <font color = red>novel</font> is <font color = red>bytb</font>. If this movie does not do well, it won't be because it doesn't deserve to. Before this film, I didn't realize how <font color = red>laconic</font> Shia Lebouf could be. He does a <font color = red>understatement</font>, self-contained, job as the lead. There's <font color = red>anything</font> incredibly sweet about him, and it makes the movie <font color = red>indeed</font> <font color = red>safer</font>. The other actors do a <font color = red>bad</font> job as well, and the film contains moments of really <font color = red>low</font> suspense, more than one might expect from a movie about golf. Sports movies are a dime a dozen, but this one stands out. <br /><br />This is one I'd <font color = red>prescribe</font> to anyone.
# [Succeeded / Failed / Total] 4 / 0 / 4:  50%|█████     | 4/8 [01:28<01:28, 22.18s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (55%)</font><br>Bill Paxton has taken the true story of the 1913 US golf open and made a film that is about <font color = green>much</font> more than an extra-ordinary game of golf. The film also deals directly with the class tensions of the early twentieth century and touches upon the profound anti-Catholic prejudices of both the British and American establishments. But at <font color = green>heart</font> the film is about that perennial favourite of triumph against the odds.<br /><br />The <font color = green>acting</font> is exemplary <font color = green>throughout</font>. Stephen Dillane is <font color = green>excellent</font> as usual, but the <font color = green>revelation</font> of the movie is Shia LaBoeuf who <font color = green>delivers</font> a disciplined, dignified and <font color = green>highly</font> sympathetic <font color = green>performance</font> as a working class Franco-Irish kid fighting his way through the prejudices of the New England WASP establishment. For those who are only <font color = green>familiar</font> with his slap-stick performances in "Even Stevens" this demonstration of his maturity is a <font color = green>delightful</font> <font color = green>surprise</font>. And Josh Flitter as the ten year old <font color = green>caddy</font> threatens to steal every scene in which he appears.<br /><br />A old <font color = green>fashioned</font> movie in the <font color = green>best</font> sense of the <font color = green>word</font>: <font color = green>fine</font> acting, <font color = green>clear</font> directing and a great <font color = green>story</font> that grips to the end - the final <font color = green>scene</font> an <font color = green>affectionate</font> nod to Casablanca is just one of the <font color = green>many</font> <font color = green>pleasures</font> that <font color = green>fill</font> a great movie.<br>Bill Paxton has taken the true story of the 1913 US golf open and made a film that is about <font color = red>considerably</font> more than an extra-ordinary game of golf. The film also deals directly with the class tensions of the early twentieth century and touches upon the profound anti-Catholic prejudices of both the British and American establishments. But at <font color = red>congestive</font> the film is about that perennial favourite of triumph against the odds.<br /><br />The <font color = red>directing</font> is exemplary <font color = red>during</font>. Stephen Dillane is <font color = red>adequate</font> as usual, but the <font color = red>prophecy</font> of the movie is Shia LaBoeuf who <font color = red>delivering</font> a disciplined, dignified and <font color = red>fairly</font> sympathetic <font color = red>versatility</font> as a working class Franco-Irish kid fighting his way through the prejudices of the New England WASP establishment. For those who are only <font color = red>synonymous</font> with his slap-stick performances in "Even Stevens" this demonstration of his maturity is a <font color = red>wintry</font> <font color = red>blunder</font>. And Josh Flitter as the ten year old <font color = red>backfield</font> threatens to steal every scene in which he appears.<br /><br />A old <font color = red>embroidered</font> movie in the <font color = red>filmfare</font> sense of the <font color = red>phrase</font>: <font color = red>grained</font> acting, <font color = red>arguable</font> directing and a great <font color = red>novel</font> that grips to the end - the final <font color = red>craze</font> an <font color = red>effeminate</font> nod to Casablanca is just one of the <font color = red>some</font> <font color = red>disgusting</font> that <font color = red>lengthen</font> a great movie.
# [Succeeded / Failed / Total] 5 / 0 / 5:  62%|██████▎   | 5/8 [02:53<01:43, 34.61s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film on September 1st, 2005 in Indianapolis. I am one of the judges for the Heartland Film Festival that screens films for their Truly Moving Picture Award. A Truly Moving Picture "...explores the human journey by artistically expressing hope and respect for the positive values of life." Heartland gave that award to this film.<br /><br />This is a story of golf in the early part of the 20th century. At that time, it was the game of upper class and rich "gentlemen", and working people could only participate by being caddies at country clubs. With this backdrop, this based-on-a-true-story unfolds with a young, working class boy who takes on the golf establishment and the greatest golfer in the world, Harry Vardon.<br /><br />And the story is inspirational. Against all odds, Francis Ouimet (played by Shia LaBeouf of "Holes") gets to compete against the greatest golfers of the U.S. and Great Britain at the 1913 U.S. Open. Francis is ill-prepared, and has a child for a caddy. (The caddy is hilarious and motivational and steals every scene he appears in.) But despite these handicaps, Francis displays courage, spirit, heroism, and humility at this world class event.<br /><br />And, we learn a lot about the early years of golf; for example, the use of small wooden clubs, the layout of the short holes, the manual scoreboard, the golfers swinging with pipes in their mouths, the terrible conditions of the greens and fairways, and the play not being canceled even in torrential rain.<br /><br />This film has stunning cinematography and art direction and editing. And with no big movie stars, the story is somehow more believable.<br /><br />This adds to the inventory of great sports movies in the vein of "Miracle" and "Remember the Titans."<br /><br />FYI - There is a Truly Moving Pictures web site where there is a listing of past winners going back 70 years.
# [Succeeded / Failed / Total] 5 / 1 / 6:  75%|███████▌  | 6/8 [10:41<03:33, 106.95s/it]
# <font color = red>Negative (94%)</font> --> <font color = gray>[SKIPPED]</font><br>Maybe I'm reading into this too much, but I wonder how much of a hand Hongsheng had in developing the film. I mean, when a story is told casting the main character as himself, I would think he would be a heavy hand in writing, documenting, etc. and that would make it a little biased.<br /><br />But...his family and friends also may have had a hand in getting the actual details about Hongsheng's life. I think the best view would have been told from Hongsheng's family and friends' perspectives. They saw his transformation and weren't so messed up on drugs that they remember everything.<br /><br />As for Hongsheng being full of himself, the consistencies of the Jesus Christ pose make him appear as a martyr who sacrificed his life (metaphorically, of course, he's obviously still alive as he was cast as himself) for his family's happiness. Huh?<br /><br />The viewer sees him at his lowest points while still maintaining a superiority complex. He lies on the grass coming down from (during?) a high by himself and with his father, he contemplates life and has visions of dragons at his window, he celebrates his freedom on a bicycle all while outstretching his arms, his head cocked to the side.<br /><br />It's fabulous that he's off of drugs now, but he's no hero. He went from a high point in his career in acting to his most vulnerable point while on drugs to come back somewhere in the middle.<br /><br />This same device is used in Ted Demme's "Blow" where the audience empathizes with the main character who is shown as a flawed hero.<br /><br />However, "Quitting" ("Zuotian") is a film that is recommended, mostly for its haunting soundtrack, superb acting, and landscapes. But, the best part is the feeling that one gets when what we presume to be the house of Jia Hongsheng is actually a stage setting for a play. It makes the viewer feel as if Hongsheng's life was merely a play told in many difficult parts.
# [Succeeded / Failed / Total] 5 / 1 / 7:  88%|████████▊ | 7/8 [10:41<01:31, 91.68s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (60%)</font><br>I felt this film did have many <font color = green>good</font> qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.<br>I felt this film did have many <font color = red>bad</font> qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.
# [Succeeded / Failed / Total] 6 / 1 / 8: 100%|██████████| 8/8 [10:57<00:00, 82.17s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>This movie is amazing because the fact that the real people portray themselves and their real life experience and do such a good job it's like they're almost living the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna cry because the family especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others might see the movie as boring because it's just so real that its almost like a documentary. Overall this movie is great and Hongsheng deserved an Oscar for this movie so did his Dad.
# [Succeeded / Failed / Total] 6 / 2 / 9: : 9it [12:32, 83.63s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 6      |
# | Number of failed attacks:     | 2      |
# | Number of skipped attacks:    | 1      |
# | Original accuracy:            | 88.89% |
# | Accuracy under attack:        | 22.22% |
# | Attack success rate:          | 75.0%  |
# | Average perturbed word %:     | 4.75%  |
# | Average num. words per input: | 228.44 |
# | Avg num queries:              | 2077.0 |
# +-------------------------------+--------+
# textattack: Attack time: 752.7035300731659s

# %%
#glove
from textattack.search_methods import GreedySearch
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedySearch()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("imdb", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/4ea52f2e58a08dbc12c2bd52d0d92b30b88c00230b4522801b3636782f625c5b)
# textattack: Loading datasets dataset imdb, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedySearch
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (66%)</font><br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was <font color = green>reluctant</font> to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = green>good</font> movie is that it can toy with our emotions. This <font color = green>one</font> did exactly that. The entire theater (which was sold out) was <font color = green>overcome</font> by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = green>great</font>, and I <font color = green>suggest</font> that you go see it before you judge.<br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was <font color = red>obliged</font> to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = red>benimens</font> movie is that it can toy with our emotions. This <font color = red>ffffffarm</font> did exactly that. The entire theater (which was sold out) was <font color = red>tempted</font> by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = red>inaco</font>, and I <font color = red>hypothesize</font> that you go see it before you judge.
#  12%|█▎        | 1/8 [00:13<01:34, 13.57s/it]
#
#
#
# [Succeeded / Failed / Total] 1 / 0 / 1:  12%|█▎        | 1/8 [00:13<01:35, 13.58s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (53%)</font><br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no <font color = green>fan</font> of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was <font color = green>enthralling</font> all the same.<br /><br />The film starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the action moves to the U.S. Open <font color = green>things</font> pick up very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behind the camera than he ever had in front of it. Despite the formulaic nature, this is a nice and easy film to root for that deserves to find an audience.<br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no <font color = red>plicatilis</font> of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was <font color = red>dzia</font> all the same.<br /><br />The film starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the action moves to the U.S. Open <font color = red>endureth</font> pick up very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same t ...
# [Succeeded / Failed / Total] 1 / 0 / 1:  25%|██▌       | 2/8 [00:32<01:38, 16.49s/it]
#
#
#
# [Succeeded / Failed / Total] 2 / 0 / 2:  25%|██▌       | 2/8 [00:32<01:38, 16.50s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>As a recreational golfer with some knowledge of the sport's history, I was pleased with Disney's sensitivity to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I loved best, however, is how this theme of class is manifested in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the golf scenes are well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the beauty of the film. There's one little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.
# [Succeeded / Failed / Total] 2 / 0 / 2:  38%|███▊      | 3/8 [04:37<07:41, 92.33s/it]
#
#
#
# [Succeeded / Failed / Total] 2 / 1 / 3:  38%|███▊      | 3/8 [04:37<07:41, 92.34s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (81%)</font><br>I saw this film in a sneak preview, and it is <font color = green>delightful</font>. The cinematography is unusually creative, the acting is <font color = green>good</font>, and the story is <font color = green>fabulous</font>. If this movie does not do <font color = green>well</font>, it won't be because it doesn't deserve to. Before this film, I didn't realize how <font color = green>charming</font> Shia Lebouf could be. He does a <font color = green>marvelous</font>, self-contained, job as the lead. There's <font color = green>something</font> incredibly sweet about him, and it makes the movie <font color = green>even</font> <font color = green>better</font>. The other actors do a good job as well, and the film contains moments of really <font color = green>high</font> suspense, more than one might expect from a movie about golf. Sports movies are a dime a dozen, but this one <font color = green>stands</font> out. <br /><br />This is one I'd <font color = green>recommend</font> to anyone.<br>I saw this film in a sneak preview, and it is <font color = red>redder</font>. The cinematography is unusually creative, the acting is <font color = red>benimens</font>, and the story is <font color = red>centralizing</font>. If this movie does not do <font color = red>siehr</font>, it won't be because it doesn't deserve to. Before this film, I didn't realize how <font color = red>pedantic</font> Shia Lebouf could be. He does a <font color = red>denouncement</font>, self-contained, job as the lead. There's <font color = red>anything</font> incredibly sweet about him, and it makes the movie <font color = red>but</font> <font color = red>eret</font>. The other actors do a good job as well, and the film contains moments of really <font color = red>low</font> suspense, more than one might expect from a movie about golf. Sports movies are a dime a dozen, but this one <font color = red>hmkorf</font> out. <br /><br />This is one I'd <font color = red>utilize</font> to anyone.
# [Succeeded / Failed / Total] 2 / 1 / 3:  50%|█████     | 4/8 [04:58<04:58, 74.61s/it]
#
#
#
# [Succeeded / Failed / Total] 3 / 1 / 4:  50%|█████     | 4/8 [04:58<04:58, 74.61s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (53%)</font><br>Bill Paxton has taken the true story of the 1913 US golf open and made a film that is about <font color = green>much</font> more than an extra-ordinary game of golf. The film also deals directly with the class tensions of the early twentieth century and <font color = green>touches</font> upon the profound anti-Catholic prejudices of both the British and American establishments. But at <font color = green>heart</font> the film is about that perennial <font color = green>favourite</font> of <font color = green>triumph</font> against the odds.<br /><br />The acting is <font color = green>exemplary</font> <font color = green>throughout</font>. Stephen Dillane is <font color = green>excellent</font> as usual, but the revelation of the movie is Shia LaBoeuf who <font color = green>delivers</font> a <font color = green>disciplined</font>, <font color = green>dignified</font> and highly <font color = green>sympathetic</font> performance as a working class Franco-Irish kid fighting his <font color = green>way</font> through the prejudices of the New England WASP establishment. For those who are only <font color = green>familiar</font> with his slap-stick performances in "Even Stevens" this <font color = green>demonstration</font> of his <font color = green>maturity</font> is a <font color = green>delightful</font> <font color = green>surprise</font>. And Josh Flitter as the ten year <font color = green>old</font> <font color = green>caddy</font> threatens to steal every scene in which he appears.<br /><br />A <font color = green>old</font> <font color = green>fashioned</font> movie in the best <font color = green>sense</font> of the word: <font color = green>fine</font> acting, <font color = green>clear</font> directing and a <font color = green>great</font> story that <font color = green>grips</font> to the <font color = green>end</font> - the final scene an <font color = green>affectionate</font> nod to Casablanca is just <font color = green>one</font> of the many pleasures that fill a great movie.<br>Bill Paxton has taken the true story of the 1913 US golf open and made a film that is about <font color = red>than</font> more than an extra-ordinary game of golf. The film also deals directly with the class tensions of the early twentieth century and <font color = red>exiting</font> upon the profound anti-Catholic prejudices of both the British and American establishments. But at <font color = red>lung</font> the film is about that perennial <font color = red>favorite</font> of <font color = red>downfall</font> against the odds.<br /><br />The acting is <font color = red>allegorical</font> <font color = red>europe</font>. Stephen Dillane is <font color = red>accomplice</font> as usual, but the revelation of the movie is Shia LaBoeuf who <font color = red>snowmobile</font> a <font color = red>esteemed</font>, <font color = red>clumsy</font> and highly <font color = red>cautious</font> performance as a working class Franco-Irish kid fighting his <font color = red>icknield</font> through the prejudices of the New England WASP establishment. For those who are only <font color = red>most</font> with his slap-stick performances in "Even Stevens" this <font color = red>jackass</font> of his <font color = red>obkoms</font> is a <font color = red>redder</font> <font color = red>lsil</font>. And Josh Flitter as the ten year <font color = red>devonien</font> <font color = red>interpolant</font> threatens to steal every scene in which he appears.<br /><br />A <font color = red>devonien</font> <font color = red>old</font> movie in the best <font color = red>idea</font> of the word: <font color = red>gael</font> acting, <font color = red>sherkin</font> directing and a <font color = red>inaco</font> story that <font color = red>fins</font> to the <font color = red>beginning</font> - the final scene an <font color = red>abrasive</font> nod to Casablanca is just < ...
# [Succeeded / Failed / Total] 3 / 1 / 4:  62%|██████▎   | 5/8 [06:32<03:55, 78.54s/it]
#
#
#
# [Succeeded / Failed / Total] 4 / 1 / 5:  62%|██████▎   | 5/8 [06:32<03:55, 78.55s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (57%)</font><br>I saw this <font color = green>film</font> on September 1st, 2005 in Indianapolis. I am <font color = green>one</font> of the <font color = green>judges</font> for the Heartland Film Festival that <font color = green>screens</font> <font color = green>films</font> for their Truly Moving Picture Award. A Truly Moving Picture "...explores the <font color = green>human</font> <font color = green>journey</font> by <font color = green>artistically</font> <font color = green>expressing</font> <font color = green>hope</font> and respect for the <font color = green>positive</font> <font color = green>values</font> of <font color = green>life</font>." Heartland <font color = green>gave</font> that award to this <font color = green>film</font>.<br /><br />This is a <font color = green>story</font> of golf in the early part of the 20th century. At that time, it was the <font color = green>game</font> of upper class and <font color = green>rich</font> "<font color = green>gentlemen</font>", and <font color = green>working</font> people <font color = green>could</font> only <font color = green>participate</font> by being caddies at country <font color = green>clubs</font>. With this <font color = green>backdrop</font>, this based-on-a-true-story <font color = green>unfolds</font> with a young, <font color = green>working</font> <font color = green>class</font> <font color = green>boy</font> who <font color = green>takes</font> on the golf <font color = green>establishment</font> and the greatest <font color = green>golfer</font> in the world, Harry Vardon.<br /><<font color = green>br</font> />And the <font color = green>story</font> is <font color = green>inspirational</font>. Against all <font color = green>odds</font>, Francis Ouimet (played by Shia LaBeouf of "Holes") <font color = green>gets</font> to compete against the <font color = green>greatest</font> <font color = green>golfers</font> of the U.S. and Great Britain at the 1913 U.S. Open. Francis is ill-prepared, and has a child for a <font color = green>caddy</font>. (The <font color = green>caddy</font> is hilarious and <font color = green>motivational</font> and <font color = green>steals</font> <font color = green>every</font> <font color = green>scene</font> he <font color = green>appears</font> in.) But <font color = green>despite</font> these <font color = green>handicaps</font>, Francis <font color = green>displays</font> <font color = green>courage</font>, <font color = green>spirit</font>, <font color = green>heroism</font>, and <font color = green>humility</font> at this <font color = green>world</font> <font color = green>class</font> <font color = green>event</font>.<<font color = green>br</font> /><<font color = green>br</font> />And, we <font color = green>learn</font> a <font color = green>lot</font> about the <font color = green>early</font> <font color = green>years</font> of <font color = green>golf</font>; for <font color = green>example</font>, the <font color = green>use</font> of <font color = green>small</font> <font color = green>wooden</font> <font color = green>clubs</font>, the <font color = green>layout</font> of the <font color = green>short</font> <font color = green>holes</font>, the <font color = green>manual</font> <font color = green>scoreboard</font>, the <font color = green>golfers</font> <font color = green>swinging</font> with <font color = green>pipes</font> in their <font color = green>mouths</font>, the <font color = green>terrible</font> <font color = green>conditions</font> of the <font color = green>greens</font> and <font color = green>fairways</font>, and the <font color = green>play</font> not being <font color = green>canceled</font> <font color = green>even</font> in <font color = green>torrential</font> <font color = green>rain</font>.<<font color = green>br</font> /><<font color = green>br</font> />This <font color = green>film</font> has <f ...
# [Succeeded / Failed / Total] 4 / 1 / 5:  75%|███████▌  | 6/8 [13:44<04:34, 137.38s/it]
#
#
#
# [Succeeded / Failed / Total] 5 / 1 / 6:  75%|███████▌  | 6/8 [13:44<04:34, 137.38s/it]
# <font color = red>Negative (94%)</font> --> <font color = gray>[SKIPPED]</font><br>Maybe I'm reading into this too much, but I wonder how much of a hand Hongsheng had in developing the film. I mean, when a story is told casting the main character as himself, I would think he would be a heavy hand in writing, documenting, etc. and that would make it a little biased.<br /><br />But...his family and friends also may have had a hand in getting the actual details about Hongsheng's life. I think the best view would have been told from Hongsheng's family and friends' perspectives. They saw his transformation and weren't so messed up on drugs that they remember everything.<br /><br />As for Hongsheng being full of himself, the consistencies of the Jesus Christ pose make him appear as a martyr who sacrificed his life (metaphorically, of course, he's obviously still alive as he was cast as himself) for his family's happiness. Huh?<br /><br />The viewer sees him at his lowest points while still maintaining a superiority complex. He lies on the grass coming down from (during?) a high by himself and with his father, he contemplates life and has visions of dragons at his window, he celebrates his freedom on a bicycle all while outstretching his arms, his head cocked to the side.<br /><br />It's fabulous that he's off of drugs now, but he's no hero. He went from a high point in his career in acting to his most vulnerable point while on drugs to come back somewhere in the middle.<br /><br />This same device is used in Ted Demme's "Blow" where the audience empathizes with the main character who is shown as a flawed hero.<br /><br />However, "Quitting" ("Zuotian") is a film that is recommended, mostly for its haunting soundtrack, superb acting, and landscapes. But, the best part is the feeling that one gets when what we presume to be the house of Jia Hongsheng is actually a stage setting for a play. It makes the viewer feel as if Hongsheng's life was merely a play told in many difficult parts.
# [Succeeded / Failed / Total] 5 / 1 / 7:  88%|████████▊ | 7/8 [13:44<01:57, 117.76s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (70%)</font><br>I felt this <font color = green>film</font> did have <font color = green>many</font> <font color = green>good</font> <font color = green>qualities</font>. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of <font color = green>course</font> they are playing themselves, but definitely unique. The cultural aspects <font color = green>may</font> <font color = green>leave</font> <font color = green>many</font> disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I <font color = green>found</font> the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, <font color = green>check</font> it out.<br>I felt this <font color = red>remodernist</font> did have <font color = red>multiperforata</font> <font color = red>benimens</font> <font color = red>motives</font>. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of <font color = red>armyworm</font> they are playing themselves, but definitely unique. The cultural aspects <font color = red>can</font> <font color = red>flatline</font> <font color = red>multiperforata</font> disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I <font color = red>noluisse</font> the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, <font color = red>spell</font> it out.
# [Succeeded / Failed / Total] 5 / 1 / 7: 100%|██████████| 8/8 [14:08<00:00, 106.06s/it]
#
#
#
# [Succeeded / Failed / Total] 6 / 1 / 8: 100%|██████████| 8/8 [14:08<00:00, 106.06s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (57%)</font><br>This movie is <font color = green>amazing</font> because the fact that the <font color = green>real</font> people portray themselves and their real life experience and do such a <font color = green>good</font> job it's like they're almost <font color = green>living</font> the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna <font color = green>cry</font> because the <font color = green>family</font> especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others <font color = green>might</font> <font color = green>see</font> the movie as <font color = green>boring</font> because it's just so <font color = green>real</font> that its <font color = green>almost</font> <font color = green>like</font> a documentary. Overall this movie is <font color = green>great</font> and Hongsheng deserved an Oscar for this movie so did his Dad.<br>This movie is <font color = red>autobiography</font> because the fact that the <font color = red>numbers</font> people portray themselves and their real life experience and do such a <font color = red>benimens</font> job it's like they're almost <font color = red>amebic</font> the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna <font color = red>fuck</font> because the <font color = red>pantolambdodontidae</font> especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others <font color = red>diplodocids</font> <font color = red>ankaa</font> the movie as <font color = red>trap</font> because it's just so <font color = red>numbers</font> that its <font color = red>nearly</font> <font color = red>bitterling</font> a documentary. Overall this movie is <font color = red>inaco</font> and Hongsheng deserved an Oscar for this movie so did his Dad.
# [Succeeded / Failed / Total] 6 / 1 / 8: : 9it [14:40, 97.88s/it]
#
#
#
# [Succeeded / Failed / Total] 7 / 1 / 9: : 9it [14:40, 97.89s/it]
# +-------------------------------+---------+
# | Attack Results                |         |
# +-------------------------------+---------+
# | Number of successful attacks: | 7       |
# | Number of failed attacks:     | 1       |
# | Number of skipped attacks:    | 1       |
# | Original accuracy:            | 88.89%  |
# | Accuracy under attack:        | 11.11%  |
# | Attack success rate:          | 87.5%   |
# | Average perturbed word %:     | 11.4%   |
# | Average num. words per input: | 228.44  |
# | Avg num queries:              | 2629.88 |
# +-------------------------------+---------+
# textattack: Attack time: 880.9915037155151s

# %%
#Fasttext
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("imdb", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/4ea52f2e58a08dbc12c2bd52d0d92b30b88c00230b4522801b3636782f625c5b)
# textattack: Loading datasets dataset imdb, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (99%)</font><br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was reluctant to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = green>good</font> movie is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was overcome by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = green>great</font>, and I suggest that you go <font color = green>see</font> it before you judge.<br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was reluctant to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = red>bad</font> movie is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was overcome by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = red>greasy</font>, and I suggest that you go <font color = red>disambiguation</font> it before you judge.
# [Succeeded / Failed / Total] 1 / 0 / 1:  12%|█▎        | 1/8 [00:05<00:39,  5.69s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (98%)</font><br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no fan of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was <font color = green>enthralling</font> all the same.<br /><br />The film starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the action moves to the U.S. Open things pick up very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behind the camera than he ever had in front of it. Despite the formulaic nature, this is a nice and easy film to root for that deserves to find an audience.<br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no fan of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was <font color = red>appalling</font> all the same.<br /><br />The film starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the action moves to the U.S. Open things pick up very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behin ...
# [Succeeded / Failed / Total] 2 / 0 / 2:  25%|██▌       | 2/8 [00:18<00:55,  9.25s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>As a recreational golfer with some knowledge of the sport's history, I was pleased with Disney's sensitivity to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I loved best, however, is how this theme of class is manifested in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the golf scenes are well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the beauty of the film. There's one little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.
# [Succeeded / Failed / Total] 2 / 1 / 3:  38%|███▊      | 3/8 [00:39<01:06, 13.23s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (58%)</font><br>I saw this film <font color = green>in</font> a sneak preview, and it <font color = green>is</font> <font color = green>delightful</font>. The cinematography is unusually <font color = green>creative</font>, the acting is <font color = green>good</font>, and the <font color = green>story</font> is <font color = green>fabulous</font>. If this movie does not <font color = green>do</font> well, it won't be <font color = green>because</font> it <font color = green>doesn't</font> deserve to. Before this film, I <font color = green>didn't</font> realize how charming Shia Lebouf could be. He does a <font color = green>marvelous</font>, <font color = green>self-contained</font>, <font color = green>job</font> as the lead. There's something incredibly <font color = green>sweet</font> about him, and it <font color = green>makes</font> the movie <font color = green>even</font> better. The other actors do a good job as well, and the film contains <font color = green>moments</font> of really high <font color = green>suspense</font>, more than one might expect from a movie <font color = green>about</font> golf. Sports movies <font color = green>are</font> <font color = green>a</font> <font color = green>dime</font> a <font color = green>dozen</font>, but <font color = green>this</font> one <font color = green>stands</font> out. <<font color = green>br</font> /><br />This <font color = green>is</font> <font color = green>one</font> <font color = green>I'd</font> <font color = green>recommend</font> to <font color = green>anyone</font>.<br>I saw this film <font color = red>of</font> a sneak preview, and it <font color = red>was</font> <font color = red>artful</font>. The cinematography is unusually <font color = red>artistic</font>, the acting is <font color = red>bad</font>, and the <font color = red>novel</font> is <font color = red>nebulous</font>. If this movie does not <font color = red>want</font> well, it won't be <font color = red>although</font> it <font color = red>doesn</font> deserve to. Before this film, I <font color = red>didn</font> realize how charming Shia Lebouf could be. He does a <font color = red>marvellous</font>, <font color = red>contained</font>, <font color = red>offeree</font> as the lead. There's something incredibly <font color = red>creamy</font> about him, and it <font color = red>making</font> the movie <font color = red>indeed</font> better. The other actors do a good job as well, and the film contains <font color = red>motions</font> of really high <font color = red>suspension</font>, more than one might expect from a movie <font color = red>abound</font> golf. Sports movies <font color = red>were</font> <font color = red>the</font> <font color = red>dim</font> a <font color = red>hundred</font>, but <font color = red>which</font> one <font color = red>stood</font> out. <<font color = red>ck</font> /><br />This <font color = red>was</font> <font color = red>nine</font> <font color = red>Bed</font> <font color = red>commend</font> to <font color = red>anybody</font>.
# [Succeeded / Failed / Total] 3 / 1 / 4:  50%|█████     | 4/8 [00:47<00:47, 11.79s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (64%)</font><br>Bill Paxton has taken the true story of the 1913 US golf open and made <font color = green>a</font> <font color = green>film</font> that <font color = green>is</font> <font color = green>about</font> much <font color = green>more</font> than an extra-ordinary game of golf. The film also deals directly with the class tensions of the early twentieth century and touches upon the profound anti-Catholic prejudices of both the British and American establishments. But <font color = green>at</font> <font color = green>heart</font> the film <font color = green>is</font> about that <font color = green>perennial</font> favourite of <font color = green>triumph</font> against the <font color = green>odds</font>.<<font color = green>br</font> /><<font color = green>br</font> />The acting <font color = green>is</font> exemplary <font color = green>throughout</font>. Stephen Dillane is excellent as usual, but the revelation of the movie is Shia LaBoeuf who delivers a disciplined, dignified and highly <font color = green>sympathetic</font> performance as a working class Franco-Irish kid fighting his way through the prejudices of the New England WASP establishment. For those who <font color = green>are</font> only <font color = green>familiar</font> with his slap-stick performances <font color = green>in</font> "Even Stevens" <font color = green>this</font> <font color = green>demonstration</font> of <font color = green>his</font> maturity <font color = green>is</font> <font color = green>a</font> <font color = green>delightful</font> <font color = green>surprise</font>. And Josh Flitter as the ten year old caddy threatens to steal every scene in which he appears.<br /><br />A <font color = green>old</font> <font color = green>fashioned</font> <font color = green>movie</font> in the best sense of the word: <font color = green>fine</font> <font color = green>acting</font>, clear directing and a <font color = green>great</font> story that <font color = green>grips</font> to the <font color = green>end</font> - the final scene an affectionate nod to Casablanca <font color = green>is</font> just one of the many pleasures that <font color = green>fill</font> a <font color = green>great</font> <font color = green>movie</font>.<br>Bill Paxton has taken the true story of the 1913 US golf open and made <font color = red>the</font> <font color = red>movie</font> that <font color = red>was</font> <font color = red>abound</font> much <font color = red>less</font> than an extra-ordinary game of golf. The film also deals directly with the class tensions of the early twentieth century and touches upon the profound anti-Catholic prejudices of both the British and American establishments. But <font color = red>near</font> <font color = red>hemorrhage</font> the film <font color = red>was</font> about that <font color = red>biennial</font> favourite of <font color = red>triumvirs</font> against the <font color = red>bets</font>.<<font color = red>ck</font> /><<font color = red>ck</font> />The acting <font color = red>was</font> exemplary <font color = red>thoughout</font>. Stephen Dillane is excellent as usual, but the revelation of the movie is Shia LaBoeuf who delivers a disciplined, dignified and highly <font color = red>apathetic</font> performance as a working class Franco-Irish kid fighting his way through the prejudices of the New England WASP establishment. For those who <font color = red>were</font> only <font color = red>familias</font> with his slap-stick performances <font color = red>of</font> "Even Stevens" <font color = red>which</font> <font color = red>demonstrating</font> of <font color = red>her</font> maturity <font color = red>was</font> <font color = red>the</font> <font color = red>artful</font> <font color = red>surprising</font>. And Josh Flitter as the ten year old caddy threatens to steal every scene in which he appears.<br /><br />A <font color = ...
# [Succeeded / Failed / Total] 4 / 1 / 5:  62%|██████▎   | 5/8 [00:58<00:35, 11.77s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film on September 1st, 2005 in Indianapolis. I am one of the judges for the Heartland Film Festival that screens films for their Truly Moving Picture Award. A Truly Moving Picture "...explores the human journey by artistically expressing hope and respect for the positive values of life." Heartland gave that award to this film.<br /><br />This is a story of golf in the early part of the 20th century. At that time, it was the game of upper class and rich "gentlemen", and working people could only participate by being caddies at country clubs. With this backdrop, this based-on-a-true-story unfolds with a young, working class boy who takes on the golf establishment and the greatest golfer in the world, Harry Vardon.<br /><br />And the story is inspirational. Against all odds, Francis Ouimet (played by Shia LaBeouf of "Holes") gets to compete against the greatest golfers of the U.S. and Great Britain at the 1913 U.S. Open. Francis is ill-prepared, and has a child for a caddy. (The caddy is hilarious and motivational and steals every scene he appears in.) But despite these handicaps, Francis displays courage, spirit, heroism, and humility at this world class event.<br /><br />And, we learn a lot about the early years of golf; for example, the use of small wooden clubs, the layout of the short holes, the manual scoreboard, the golfers swinging with pipes in their mouths, the terrible conditions of the greens and fairways, and the play not being canceled even in torrential rain.<br /><br />This film has stunning cinematography and art direction and editing. And with no big movie stars, the story is somehow more believable.<br /><br />This adds to the inventory of great sports movies in the vein of "Miracle" and "Remember the Titans."<br /><br />FYI - There is a Truly Moving Pictures web site where there is a listing of past winners going back 70 years.
# [Succeeded / Failed / Total] 4 / 2 / 6:  75%|███████▌  | 6/8 [01:25<00:28, 14.24s/it]
# <font color = red>Negative (94%)</font> --> <font color = gray>[SKIPPED]</font><br>Maybe I'm reading into this too much, but I wonder how much of a hand Hongsheng had in developing the film. I mean, when a story is told casting the main character as himself, I would think he would be a heavy hand in writing, documenting, etc. and that would make it a little biased.<br /><br />But...his family and friends also may have had a hand in getting the actual details about Hongsheng's life. I think the best view would have been told from Hongsheng's family and friends' perspectives. They saw his transformation and weren't so messed up on drugs that they remember everything.<br /><br />As for Hongsheng being full of himself, the consistencies of the Jesus Christ pose make him appear as a martyr who sacrificed his life (metaphorically, of course, he's obviously still alive as he was cast as himself) for his family's happiness. Huh?<br /><br />The viewer sees him at his lowest points while still maintaining a superiority complex. He lies on the grass coming down from (during?) a high by himself and with his father, he contemplates life and has visions of dragons at his window, he celebrates his freedom on a bicycle all while outstretching his arms, his head cocked to the side.<br /><br />It's fabulous that he's off of drugs now, but he's no hero. He went from a high point in his career in acting to his most vulnerable point while on drugs to come back somewhere in the middle.<br /><br />This same device is used in Ted Demme's "Blow" where the audience empathizes with the main character who is shown as a flawed hero.<br /><br />However, "Quitting" ("Zuotian") is a film that is recommended, mostly for its haunting soundtrack, superb acting, and landscapes. But, the best part is the feeling that one gets when what we presume to be the house of Jia Hongsheng is actually a stage setting for a play. It makes the viewer feel as if Hongsheng's life was merely a play told in many difficult parts.
# [Succeeded / Failed / Total] 4 / 2 / 7:  88%|████████▊ | 7/8 [01:25<00:12, 12.21s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (72%)</font><br>I <font color = green>felt</font> this film did have many good qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.<br>I <font color = red>disbelieved</font> this film did have many good qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.
# [Succeeded / Failed / Total] 5 / 2 / 8: 100%|██████████| 8/8 [01:30<00:00, 11.30s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (82%)</font><br>This movie is amazing because the fact that the real people portray themselves and their real life experience and do such a <font color = green>good</font> job it's like they're almost living the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna cry because the family especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others might see the movie as boring because it's just so <font color = green>real</font> that its almost like a documentary. Overall this movie is <font color = green>great</font> and Hongsheng deserved an Oscar for this movie so did his Dad.<br>This movie is amazing because the fact that the real people portray themselves and their real life experience and do such a <font color = red>bad</font> job it's like they're almost living the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna cry because the family especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others might see the movie as boring because it's just so <font color = red>unimaginable</font> that its almost like a documentary. Overall this movie is <font color = red>greasy</font> and Hongsheng deserved an Oscar for this movie so did his Dad.
# [Succeeded / Failed / Total] 6 / 2 / 9: : 9it [01:36, 10.71s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 6      |
# | Number of failed attacks:     | 2      |
# | Number of skipped attacks:    | 1      |
# | Original accuracy:            | 88.89% |
# | Accuracy under attack:        | 22.22% |
# | Attack success rate:          | 75.0%  |
# | Average perturbed word %:     | 8.17%  |
# | Average num. words per input: | 228.44 |
# | Avg num queries:              | 276.62 |
# +-------------------------------+--------+
# textattack: Attack time: 96.43835806846619s

# %%
#Word2vec
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("imdb", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/4ea52f2e58a08dbc12c2bd52d0d92b30b88c00230b4522801b3636782f625c5b)
# textattack: Loading datasets dataset imdb, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (52%)</font><br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was <font color = green>reluctant</font> to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = green>good</font> movie is that it can toy with <font color = green>our</font> <font color = green>emotions</font>. This one did exactly that. The entire theater (which was sold out) was overcome by laughter during the first half of the movie, and were moved to <font color = green>tears</font> during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = green>great</font>, and I <font color = green>suggest</font> that you go see it <font color = green>before</font> you judge.<br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was <font color = red>willing</font> to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = red>bad</font> movie is that it can toy with <font color = red>my</font> <font color = red>emotion</font>. This one did exactly that. The entire theater (which was sold out) was overcome by laughter during the first half of the movie, and were moved to <font color = red>cries</font> during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = red>tremendous</font>, and I <font color = red>speculate</font> that you go see it <font color = red>after</font> you judge.
# [Succeeded / Failed / Total] 1 / 0 / 1:  12%|█▎        | 1/8 [00:05<00:41,  5.94s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (74%)</font><br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no fan of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some <font color = green>how</font> <font color = green>this</font> film was enthralling all the same.<br /><br />The film <font color = green>starts</font> with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the action moves to the U.S. Open <font color = green>things</font> <font color = green>pick</font> <font color = green>up</font> very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behind the camera than he ever had in front of it. Despite the formulaic nature, this is a nice and easy film to root for that deserves to find an audience.<br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no fan of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some <font color = red>why</font> <font color = red>which</font> film was enthralling all the same.<br /><br />The film <font color = red>begins</font> with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the action moves to the U.S. Open <font color = red>something</font> <font color = red>discard</font> <font color = red>out</font> very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the  ...
# [Succeeded / Failed / Total] 2 / 0 / 2:  25%|██▌       | 2/8 [00:19<00:57,  9.59s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (55%)</font><br>As a recreational golfer with some knowledge of the sport's history, I was pleased with Disney's <font color = green>sensitivity</font> to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I <font color = green>loved</font> best, however, is how this theme of class is manifested in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the golf <font color = green>scenes</font> <font color = green>are</font> well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do <font color = green>not</font> detract from the <font color = green>beauty</font> of the film. There's <font color = green>one</font> little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.<br>As a recreational golfer with some knowledge of the sport's history, I was pleased with Disney's <font color = red>susceptibility</font> to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I <font color = red>hated</font> best, however, is how this theme of class is manifested in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the golf <font color = red>skits</font> <font color = red>were</font> well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do <font color = red>necessarily</font> detract from the <font color = red>modesty</font> of the film. There's <font color = red>six</font> little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.
# [Succeeded / Failed / Total] 3 / 0 / 3:  38%|███▊      | 3/8 [00:28<00:47,  9.53s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (50%)</font><br>I <font color = green>saw</font> this film in a sneak <font color = green>preview</font>, and it <font color = green>is</font> delightful. The cinematography is unusually creative, the acting <font color = green>is</font> <font color = green>good</font>, and the <font color = green>story</font> <font color = green>is</font> fabulous. If this movie does not <font color = green>do</font> well, it won't be <font color = green>because</font> it doesn't <font color = green>deserve</font> to. Before this <font color = green>film</font>, I didn't realize how charming Shia Lebouf could be. He does a <font color = green>marvelous</font>, self-contained, <font color = green>job</font> as the lead. There's something incredibly sweet about him, and it makes the movie <font color = green>even</font> better. The other <font color = green>actors</font> do a <font color = green>good</font> job as well, and the film contains <font color = green>moments</font> of really <font color = green>high</font> suspense, <font color = green>more</font> than <font color = green>one</font> might <font color = green>expect</font> from a movie about golf. Sports movies <font color = green>are</font> a dime a <font color = green>dozen</font>, but <font color = green>this</font> one <font color = green>stands</font> out. <<font color = green>br</font> /><br />This is <font color = green>one</font> I'd <font color = green>recommend</font> to <font color = green>anyone</font>.<br>I <font color = red>overcame</font> this film in a sneak <font color = red>imovie</font>, and it <font color = red>was</font> delightful. The cinematography is unusually creative, the acting <font color = red>was</font> <font color = red>bad</font>, and the <font color = red>novel</font> <font color = red>was</font> fabulous. If this movie does not <font color = red>want</font> well, it won't be <font color = red>though</font> it doesn't <font color = red>despise</font> to. Before this <font color = red>movie</font>, I didn't realize how charming Shia Lebouf could be. He does a <font color = red>understatement</font>, self-contained, <font color = red>homework</font> as the lead. There's something incredibly sweet about him, and it makes the movie <font color = red>indeed</font> better. The other <font color = red>comedians</font> do a <font color = red>bad</font> job as well, and the film contains <font color = red>moment</font> of really <font color = red>low</font> suspense, <font color = red>less</font> than <font color = red>six</font> might <font color = red>stipulate</font> from a movie about golf. Sports movies <font color = red>were</font> a dime a <font color = red>hundred</font>, but <font color = red>which</font> one <font color = red>stood</font> out. <<font color = red>nsted</font> /><br />This is <font color = red>six</font> I'd <font color = red>prescribe</font> to <font color = red>anybody</font>.
# [Succeeded / Failed / Total] 4 / 0 / 4:  50%|█████     | 4/8 [00:35<00:35,  8.98s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (54%)</font><br>Bill Paxton has taken the <font color = green>true</font> <font color = green>story</font> of the 1913 US golf open and made a <font color = green>film</font> that <font color = green>is</font> <font color = green>about</font> much <font color = green>more</font> than an extra-ordinary <font color = green>game</font> of <font color = green>golf</font>. The <font color = green>film</font> also deals directly with the class tensions of the early <font color = green>twentieth</font> century and touches <font color = green>upon</font> the profound anti-Catholic <font color = green>prejudices</font> of both the British and American establishments. But at heart the film <font color = green>is</font> about <font color = green>that</font> perennial <font color = green>favourite</font> of <font color = green>triumph</font> against the <font color = green>odds</font>.<br /><<font color = green>br</font> />The acting <font color = green>is</font> exemplary <font color = green>throughout</font>. Stephen Dillane is <font color = green>excellent</font> as usual, but the revelation of the movie is Shia LaBoeuf who delivers a disciplined, dignified and <font color = green>highly</font> <font color = green>sympathetic</font> <font color = green>performance</font> as a working class Franco-Irish kid fighting his way through the prejudices of the New England WASP <font color = green>establishment</font>. For those who <font color = green>are</font> <font color = green>only</font> <font color = green>familiar</font> with <font color = green>his</font> slap-stick <font color = green>performances</font> <font color = green>in</font> "Even Stevens" this demonstration of <font color = green>his</font> <font color = green>maturity</font> <font color = green>is</font> a delightful <font color = green>surprise</font>. And Josh Flitter as the ten <font color = green>year</font> old caddy threatens to steal every scene <font color = green>in</font> which he appears.<br /><br />A old fashioned <font color = green>movie</font> <font color = green>in</font> the <font color = green>best</font> sense of the <font color = green>word</font>: <font color = green>fine</font> <font color = green>acting</font>, <font color = green>clear</font> directing and a <font color = green>great</font> <font color = green>story</font> <font color = green>that</font> grips to the end - the <font color = green>final</font> scene an affectionate <font color = green>nod</font> to Casablanca is <font color = green>just</font> one of the many pleasures that <font color = green>fill</font> a <font color = green>great</font> movie.<br>Bill Paxton has taken the <font color = red>illusory</font> <font color = red>novel</font> of the 1913 US golf open and made a <font color = red>movie</font> that <font color = red>was</font> <font color = red>approximately</font> much <font color = red>less</font> than an extra-ordinary <font color = red>starcraft</font> of <font color = red>sport</font>. The <font color = red>movie</font> also deals directly with the class tensions of the early <font color = red>nineteenth</font> century and touches <font color = red>on</font> the profound anti-Catholic <font color = red>mores</font> of both the British and American establishments. But at heart the film <font color = red>was</font> about <font color = red>which</font> perennial <font color = red>favorite</font> of <font color = red>culmination</font> against the <font color = red>bets</font>.<br /><<font color = red>nsted</font> />The acting <font color = red>was</font> exemplary <font color = red>during</font>. Stephen Dillane is <font color = red>adequate</font> as usual, but the revelation of the movie is Shia LaBoeuf who delivers a disciplined, dignified and <font color = red>fairly</font> <font color = red>averse</font> <font color = red>versatility</font> as a working class Franco-Irish kid fighting his way  ...
# [Succeeded / Failed / Total] 5 / 0 / 5:  62%|██████▎   | 5/8 [00:49<00:29,  9.93s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film on September 1st, 2005 in Indianapolis. I am one of the judges for the Heartland Film Festival that screens films for their Truly Moving Picture Award. A Truly Moving Picture "...explores the human journey by artistically expressing hope and respect for the positive values of life." Heartland gave that award to this film.<br /><br />This is a story of golf in the early part of the 20th century. At that time, it was the game of upper class and rich "gentlemen", and working people could only participate by being caddies at country clubs. With this backdrop, this based-on-a-true-story unfolds with a young, working class boy who takes on the golf establishment and the greatest golfer in the world, Harry Vardon.<br /><br />And the story is inspirational. Against all odds, Francis Ouimet (played by Shia LaBeouf of "Holes") gets to compete against the greatest golfers of the U.S. and Great Britain at the 1913 U.S. Open. Francis is ill-prepared, and has a child for a caddy. (The caddy is hilarious and motivational and steals every scene he appears in.) But despite these handicaps, Francis displays courage, spirit, heroism, and humility at this world class event.<br /><br />And, we learn a lot about the early years of golf; for example, the use of small wooden clubs, the layout of the short holes, the manual scoreboard, the golfers swinging with pipes in their mouths, the terrible conditions of the greens and fairways, and the play not being canceled even in torrential rain.<br /><br />This film has stunning cinematography and art direction and editing. And with no big movie stars, the story is somehow more believable.<br /><br />This adds to the inventory of great sports movies in the vein of "Miracle" and "Remember the Titans."<br /><br />FYI - There is a Truly Moving Pictures web site where there is a listing of past winners going back 70 years.
# [Succeeded / Failed / Total] 5 / 1 / 6:  75%|███████▌  | 6/8 [01:12<00:24, 12.09s/it]
# <font color = red>Negative (94%)</font> --> <font color = gray>[SKIPPED]</font><br>Maybe I'm reading into this too much, but I wonder how much of a hand Hongsheng had in developing the film. I mean, when a story is told casting the main character as himself, I would think he would be a heavy hand in writing, documenting, etc. and that would make it a little biased.<br /><br />But...his family and friends also may have had a hand in getting the actual details about Hongsheng's life. I think the best view would have been told from Hongsheng's family and friends' perspectives. They saw his transformation and weren't so messed up on drugs that they remember everything.<br /><br />As for Hongsheng being full of himself, the consistencies of the Jesus Christ pose make him appear as a martyr who sacrificed his life (metaphorically, of course, he's obviously still alive as he was cast as himself) for his family's happiness. Huh?<br /><br />The viewer sees him at his lowest points while still maintaining a superiority complex. He lies on the grass coming down from (during?) a high by himself and with his father, he contemplates life and has visions of dragons at his window, he celebrates his freedom on a bicycle all while outstretching his arms, his head cocked to the side.<br /><br />It's fabulous that he's off of drugs now, but he's no hero. He went from a high point in his career in acting to his most vulnerable point while on drugs to come back somewhere in the middle.<br /><br />This same device is used in Ted Demme's "Blow" where the audience empathizes with the main character who is shown as a flawed hero.<br /><br />However, "Quitting" ("Zuotian") is a film that is recommended, mostly for its haunting soundtrack, superb acting, and landscapes. But, the best part is the feeling that one gets when what we presume to be the house of Jia Hongsheng is actually a stage setting for a play. It makes the viewer feel as if Hongsheng's life was merely a play told in many difficult parts.
# [Succeeded / Failed / Total] 5 / 1 / 7:  88%|████████▊ | 7/8 [01:12<00:10, 10.37s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (61%)</font><br>I <font color = green>felt</font> this film did have many good <font color = green>qualities</font>. The <font color = green>cinematography</font> was <font color = green>certainly</font> different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I <font color = green>felt</font> most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really <font color = green>cheesy</font> <font color = green>sometimes</font> (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.<br>I <font color = red>feared</font> this film did have many good <font color = red>virtues</font>. The <font color = red>cine</font> was <font color = red>indeed</font> different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I <font color = red>feared</font> most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really <font color = red>nigga</font> <font color = red>often</font> (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.
# [Succeeded / Failed / Total] 6 / 1 / 8: 100%|██████████| 8/8 [01:18<00:00,  9.75s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (57%)</font><br>This movie is amazing <font color = green>because</font> the fact that the real <font color = green>people</font> portray themselves and their real life experience and do such a <font color = green>good</font> job it's like they're almost living the past over <font color = green>again</font>. Jia Hongsheng plays himself an actor who <font color = green>quit</font> <font color = green>everything</font> except music and drugs struggling with depression and searching for the meaning of life while being angry <font color = green>at</font> <font color = green>everyone</font> <font color = green>especially</font> the <font color = green>people</font> who care for him most. There's moments <font color = green>in</font> the movie that <font color = green>will</font> <font color = green>make</font> you wanna cry <font color = green>because</font> the family <font color = green>especially</font> the father did such a good job. However, this movie <font color = green>is</font> not for <font color = green>everyone</font>. Many <font color = green>people</font> who <font color = green>suffer</font> from <font color = green>depression</font> <font color = green>will</font> understand Hongsheng's problem and <font color = green>why</font> he <font color = green>does</font> the things he <font color = green>does</font> for <font color = green>example</font> keep himself <font color = green>shut</font> <font color = green>in</font> a dark room or go for <font color = green>walks</font> or <font color = green>bike</font> <font color = green>rides</font> by himself. Others might <font color = green>see</font> the movie as <font color = green>boring</font> because it's just so <font color = green>real</font> that its almost like a documentary. Overall <font color = green>this</font> <font color = green>movie</font> <font color = green>is</font> <font color = green>great</font> and Hongsheng deserved an Oscar for this movie so did his Dad.<br>This movie is amazing <font color = red>though</font> the fact that the real <font color = red>residents</font> portray themselves and their real life experience and do such a <font color = red>bad</font> job it's like they're almost living the past over <font color = red>finally</font>. Jia Hongsheng plays himself an actor who <font color = red>waited</font> <font color = red>nothing</font> except music and drugs struggling with depression and searching for the meaning of life while being angry <font color = red>near</font> <font color = red>everybody</font> <font color = red>particularly</font> the <font color = red>residents</font> who care for him most. There's moments <font color = red>throughout</font> the movie that <font color = red>would</font> <font color = red>give</font> you wanna cry <font color = red>though</font> the family <font color = red>particularly</font> the father did such a good job. However, this movie <font color = red>was</font> not for <font color = red>everybody</font>. Many <font color = red>residents</font> who <font color = red>worsen</font> from <font color = red>mania</font> <font color = red>would</font> understand Hongsheng's problem and <font color = red>how</font> he <font color = red>did</font> the things he <font color = red>did</font> for <font color = red>instance</font> keep himself <font color = red>bounced</font> <font color = red>throughout</font> a dark room or go for <font color = red>kisses</font> or <font color = red>bmx</font> <font color = red>chasing</font> by himself. Others might <font color = red>list</font> the movie as <font color = red>salesman</font> because it's just so <font color = red>nonnegative</font> that its almost like a documentary. Overall <font color = red>which</font> <font color = red>film</font> <font color = red>was</font> <font color = red>tremendous</font> and Hongsheng deserved an Oscar for this movie so did his Dad.
# [Succeeded / Failed / Total] 7 / 1 / 9: : 9it [01:28,  9.88s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 7      |
# | Number of failed attacks:     | 1      |
# | Number of skipped attacks:    | 1      |
# | Original accuracy:            | 88.89% |
# | Accuracy under attack:        | 11.11% |
# | Attack success rate:          | 87.5%  |
# | Average perturbed word %:     | 12.19% |
# | Average num. words per input: | 228.44 |
# | Avg num queries:              | 267.88 |
# +-------------------------------+--------+
# textattack: Attack time: 88.89116907119751s

# %%
#glove
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("imdb", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/4ea52f2e58a08dbc12c2bd52d0d92b30b88c00230b4522801b3636782f625c5b)
# textattack: Loading datasets dataset imdb, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (60%)</font><br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was reluctant to <font color = green>see</font> it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such <font color = green>professionalism</font>. The <font color = green>sign</font> of a <font color = green>good</font> movie is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was overcome by <font color = green>laughter</font> during the <font color = green>first</font> half of the movie, and were moved to tears during the <font color = green>second</font> half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie <font color = green>was</font> <font color = green>great</font>, and I <font color = green>suggest</font> that you go <font color = green>see</font> it before you judge.<br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was reluctant to <font color = red>ankaa</font> it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such <font color = red>remixing</font>. The <font color = red>proper</font> of a <font color = red>benimens</font> movie is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was overcome by <font color = red>flees</font> during the <font color = red>ahad</font> half of the movie, and were moved to tears during the <font color = red>third</font> half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie <font color = red>rescinded</font> <font color = red>inaco</font>, and I <font color = red>hypothesize</font> that you go <font color = red>ankaa</font> it before you judge.
#  12%|█▎        | 1/8 [00:03<00:24,  3.46s/it]
#
#
#
# [Succeeded / Failed / Total] 1 / 0 / 1:  12%|█▎        | 1/8 [00:03<00:24,  3.48s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (50%)</font><br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this <font color = green>family</font> friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no <font color = green>fan</font> of golf, and these scrappy underdog sports <font color = green>flicks</font> are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was enthralling all the <font color = green>same</font>.<<font color = green>br</font> /><br />The film <font color = green>starts</font> with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the <font color = green>action</font> <font color = green>moves</font> to the U.S. Open <font color = green>things</font> <font color = green>pick</font> up very well. Paxton does a nice job and <font color = green>shows</font> a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behind the camera than he ever had in front of it. Despite the formulaic nature, this is a nice and easy film to root for that deserves to find an audience.<br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this <font color = red>pantolambdodontidae</font> friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no <font color = red>plicatilis</font> of golf, and these scrappy underdog sports <font color = red>bumping</font> are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was enthralling all the <font color = red>particular</font>.<<font color = red>nnhilde</font> /><br />The film <font color = red>begins</font> with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the <font color = red>republicaine</font> <font color = red>move</font> to the U.S. Open <font color = red>endureth</font> <font color = red>waa</font> up very well. Paxton does a nice job and <font color = red>show</font> a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visuall ...
# [Succeeded / Failed / Total] 1 / 0 / 1:  25%|██▌       | 2/8 [00:12<00:37,  6.30s/it]
#
#
#
# [Succeeded / Failed / Total] 2 / 0 / 2:  25%|██▌       | 2/8 [00:12<00:37,  6.31s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>As a recreational golfer with some knowledge of the sport's history, I was pleased with Disney's sensitivity to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I loved best, however, is how this theme of class is manifested in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the golf scenes are well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the beauty of the film. There's one little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.
# [Succeeded / Failed / Total] 2 / 0 / 2:  38%|███▊      | 3/8 [00:25<00:42,  8.49s/it]
#
#
#
# [Succeeded / Failed / Total] 2 / 1 / 3:  38%|███▊      | 3/8 [00:25<00:42,  8.49s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film in a sneak preview, and it is delightful. The cinematography is unusually creative, the acting is good, and the story is fabulous. If this movie does not do well, it won't be because it doesn't deserve to. Before this film, I didn't realize how charming Shia Lebouf could be. He does a marvelous, self-contained, job as the lead. There's something incredibly sweet about him, and it makes the movie even better. The other actors do a good job as well, and the film contains moments of really high suspense, more than one might expect from a movie about golf. Sports movies are a dime a dozen, but this one stands out. <br /><br />This is one I'd recommend to anyone.
# [Succeeded / Failed / Total] 2 / 1 / 3:  50%|█████     | 4/8 [00:31<00:31,  7.87s/it]
#
#
#
# [Succeeded / Failed / Total] 2 / 2 / 4:  50%|█████     | 4/8 [00:31<00:31,  7.87s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>Bill Paxton has taken the true story of the 1913 US golf open and made a film that is about much more than an extra-ordinary game of golf. The film also deals directly with the class tensions of the early twentieth century and touches upon the profound anti-Catholic prejudices of both the British and American establishments. But at heart the film is about that perennial favourite of triumph against the odds.<br /><br />The acting is exemplary throughout. Stephen Dillane is excellent as usual, but the revelation of the movie is Shia LaBoeuf who delivers a disciplined, dignified and highly sympathetic performance as a working class Franco-Irish kid fighting his way through the prejudices of the New England WASP establishment. For those who are only familiar with his slap-stick performances in "Even Stevens" this demonstration of his maturity is a delightful surprise. And Josh Flitter as the ten year old caddy threatens to steal every scene in which he appears.<br /><br />A old fashioned movie in the best sense of the word: fine acting, clear directing and a great story that grips to the end - the final scene an affectionate nod to Casablanca is just one of the many pleasures that fill a great movie.
# [Succeeded / Failed / Total] 2 / 2 / 4:  62%|██████▎   | 5/8 [00:41<00:25,  8.35s/it]
#
#
#
# [Succeeded / Failed / Total] 2 / 3 / 5:  62%|██████▎   | 5/8 [00:41<00:25,  8.36s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film on September 1st, 2005 in Indianapolis. I am one of the judges for the Heartland Film Festival that screens films for their Truly Moving Picture Award. A Truly Moving Picture "...explores the human journey by artistically expressing hope and respect for the positive values of life." Heartland gave that award to this film.<br /><br />This is a story of golf in the early part of the 20th century. At that time, it was the game of upper class and rich "gentlemen", and working people could only participate by being caddies at country clubs. With this backdrop, this based-on-a-true-story unfolds with a young, working class boy who takes on the golf establishment and the greatest golfer in the world, Harry Vardon.<br /><br />And the story is inspirational. Against all odds, Francis Ouimet (played by Shia LaBeouf of "Holes") gets to compete against the greatest golfers of the U.S. and Great Britain at the 1913 U.S. Open. Francis is ill-prepared, and has a child for a caddy. (The caddy is hilarious and motivational and steals every scene he appears in.) But despite these handicaps, Francis displays courage, spirit, heroism, and humility at this world class event.<br /><br />And, we learn a lot about the early years of golf; for example, the use of small wooden clubs, the layout of the short holes, the manual scoreboard, the golfers swinging with pipes in their mouths, the terrible conditions of the greens and fairways, and the play not being canceled even in torrential rain.<br /><br />This film has stunning cinematography and art direction and editing. And with no big movie stars, the story is somehow more believable.<br /><br />This adds to the inventory of great sports movies in the vein of "Miracle" and "Remember the Titans."<br /><br />FYI - There is a Truly Moving Pictures web site where there is a listing of past winners going back 70 years.
# [Succeeded / Failed / Total] 2 / 3 / 5:  75%|███████▌  | 6/8 [00:58<00:19,  9.82s/it]
#
#
#
# [Succeeded / Failed / Total] 2 / 4 / 6:  75%|███████▌  | 6/8 [00:58<00:19,  9.82s/it]
# <font color = red>Negative (94%)</font> --> <font color = gray>[SKIPPED]</font><br>Maybe I'm reading into this too much, but I wonder how much of a hand Hongsheng had in developing the film. I mean, when a story is told casting the main character as himself, I would think he would be a heavy hand in writing, documenting, etc. and that would make it a little biased.<br /><br />But...his family and friends also may have had a hand in getting the actual details about Hongsheng's life. I think the best view would have been told from Hongsheng's family and friends' perspectives. They saw his transformation and weren't so messed up on drugs that they remember everything.<br /><br />As for Hongsheng being full of himself, the consistencies of the Jesus Christ pose make him appear as a martyr who sacrificed his life (metaphorically, of course, he's obviously still alive as he was cast as himself) for his family's happiness. Huh?<br /><br />The viewer sees him at his lowest points while still maintaining a superiority complex. He lies on the grass coming down from (during?) a high by himself and with his father, he contemplates life and has visions of dragons at his window, he celebrates his freedom on a bicycle all while outstretching his arms, his head cocked to the side.<br /><br />It's fabulous that he's off of drugs now, but he's no hero. He went from a high point in his career in acting to his most vulnerable point while on drugs to come back somewhere in the middle.<br /><br />This same device is used in Ted Demme's "Blow" where the audience empathizes with the main character who is shown as a flawed hero.<br /><br />However, "Quitting" ("Zuotian") is a film that is recommended, mostly for its haunting soundtrack, superb acting, and landscapes. But, the best part is the feeling that one gets when what we presume to be the house of Jia Hongsheng is actually a stage setting for a play. It makes the viewer feel as if Hongsheng's life was merely a play told in many difficult parts.
# [Succeeded / Failed / Total] 2 / 4 / 7:  88%|████████▊ | 7/8 [00:58<00:08,  8.42s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (73%)</font><br>I <font color = green>felt</font> this <font color = green>film</font> <font color = green>did</font> have many good qualities. The cinematography <font color = green>was</font> certainly different <font color = green>exposing</font> the stage <font color = green>aspect</font> of the set and story. The original <font color = green>characters</font> as <font color = green>actors</font> <font color = green>was</font> certainly an achievement and I felt most <font color = green>played</font> <font color = green>quite</font> convincingly, of <font color = green>course</font> they <font color = green>are</font> playing themselves, but definitely unique. The <font color = green>cultural</font> aspects <font color = green>may</font> <font color = green>leave</font> many disappointed as a familiarity with the Chinese and Oriental culture <font color = green>will</font> answer a <font color = green>lot</font> of questions regarding <font color = green>parent</font>/<font color = green>child</font> relationships and the stigma that goes with any drug <font color = green>use</font>. I <font color = green>found</font> the Jia Hongsheng story interesting. On a down <font color = green>note</font>, the story <font color = green>is</font> in Beijing and some of the fashion and music <font color = green>reek</font> of early 90s even though this <font color = green>was</font> made in 2001, so it's really <font color = green>cheesy</font> <font color = green>sometimes</font> (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, <font color = green>check</font> it out.<br>I <font color = red>convinced</font> this <font color = red>remodernist</font> <font color = red>would</font> have many good qualities. The cinematography <font color = red>rescinded</font> certainly different <font color = red>issuing</font> the stage <font color = red>tense</font> of the set and story. The original <font color = red>character</font> as <font color = red>actresses</font> <font color = red>rescinded</font> certainly an achievement and I felt most <font color = red>kusakari</font> <font color = red>very</font> convincingly, of <font color = red>armyworm</font> they <font color = red>washerwomen</font> playing themselves, but definitely unique. The <font color = red>socio</font> aspects <font color = red>can</font> <font color = red>flatline</font> many disappointed as a familiarity with the Chinese and Oriental culture <font color = red>would</font> answer a <font color = red>parking</font> of questions regarding <font color = red>spouse</font>/<font color = red>prodigy</font> relationships and the stigma that goes with any drug <font color = red>ensiferum</font>. I <font color = red>noluisse</font> the Jia Hongsheng story interesting. On a down <font color = red>example</font>, the story <font color = red>polylogarithm</font> in Beijing and some of the fashion and music <font color = red>hushing</font> of early 90s even though this <font color = red>rescinded</font> made in 2001, so it's really <font color = red>ramad</font> <font color = red>often</font> (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, <font color = red>spell</font> it out.
# [Succeeded / Failed / Total] 2 / 4 / 7: 100%|██████████| 8/8 [01:05<00:00,  8.22s/it]
#
#
#
# [Succeeded / Failed / Total] 3 / 4 / 8: 100%|██████████| 8/8 [01:05<00:00,  8.22s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>This movie is amazing because the fact that the real people portray themselves and their real life experience and do such a good job it's like they're almost living the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna cry because the family especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others might see the movie as boring because it's just so real that its almost like a documentary. Overall this movie is great and Hongsheng deserved an Oscar for this movie so did his Dad.
# [Succeeded / Failed / Total] 3 / 5 / 9: : 9it [01:14,  8.24s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 3      |
# | Number of failed attacks:     | 5      |
# | Number of skipped attacks:    | 1      |
# | Original accuracy:            | 88.89% |
# | Accuracy under attack:        | 55.56% |
# | Attack success rate:          | 37.5%  |
# | Average perturbed word %:     | 10.27% |
# | Average num. words per input: | 228.44 |
# | Avg num queries:              | 279.38 |
# +-------------------------------+--------+
# textattack: Attack time: 74.14125800132751s

# %%
#Fasttext
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("imdb", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/4ea52f2e58a08dbc12c2bd52d0d92b30b88c00230b4522801b3636782f625c5b)
# textattack: Loading datasets dataset imdb, split test.

# %%
# print(attack)
# table(dataset,attack)

# %%
#Word2vec
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("imdb", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/4ea52f2e58a08dbc12c2bd52d0d92b30b88c00230b4522801b3636782f625c5b)
# textattack: Loading datasets dataset imdb, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (73%)</font><br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was reluctant to see it because from what I knew of Ashton Kutcher he was <font color = green>only</font> able to do <font color = green>comedy</font>. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = green>good</font> movie is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was overcome by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = green>great</font>, and I suggest that you go see it before you judge.<br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was reluctant to see it because from what I knew of Ashton Kutcher he was <font color = red>ordinarily</font> able to do <font color = red>drama</font>. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = red>bad</font> movie is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was overcome by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = red>considerable</font>, and I suggest that you go see it before you judge.
# [Succeeded / Failed / Total] 1 / 0 / 1:  12%|█▎        | 1/8 [00:34<04:03, 34.81s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (63%)</font><br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no <font color = green>fan</font> of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how <font color = green>this</font> film was enthralling all the same.<br /><br />The film starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the action <font color = green>moves</font> to the U.S. Open things <font color = green>pick</font> up very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behind the camera than he ever had in front of it. Despite the formulaic nature, this is a nice and easy film to root for that deserves to find an audience.<br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no <font color = red>shirow</font> of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how <font color = red>which</font> film was enthralling all the same.<br /><br />The film starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the action <font color = red>bounces</font> to the U.S. Open things <font color = red>discard</font> up very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true s ...
# [Succeeded / Failed / Total] 2 / 0 / 2:  25%|██▌       | 2/8 [03:47<11:23, 113.88s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (52%)</font><br>As a recreational golfer with some knowledge of the sport's history, I was pleased with Disney's <font color = green>sensitivity</font> to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I <font color = green>loved</font> best, however, is <font color = green>how</font> this theme of class <font color = green>is</font> manifested in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the golf scenes are well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the <font color = green>beauty</font> of the film. There's one little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.<br>As a recreational golfer with some knowledge of the sport's history, I was pleased with Disney's <font color = red>susceptibility</font> to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I <font color = red>hated</font> best, however, is <font color = red>why</font> this theme of class <font color = red>was</font> manifested in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the golf scenes are well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the <font color = red>modesty</font> of the film. There's one little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.
# [Succeeded / Failed / Total] 3 / 0 / 3:  38%|███▊      | 3/8 [05:42<09:30, 114.02s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film in a sneak preview, and it is delightful. The cinematography is unusually creative, the acting is good, and the story is fabulous. If this movie does not do well, it won't be because it doesn't deserve to. Before this film, I didn't realize how charming Shia Lebouf could be. He does a marvelous, self-contained, job as the lead. There's something incredibly sweet about him, and it makes the movie even better. The other actors do a good job as well, and the film contains moments of really high suspense, more than one might expect from a movie about golf. Sports movies are a dime a dozen, but this one stands out. <br /><br />This is one I'd recommend to anyone.
# [Succeeded / Failed / Total] 3 / 1 / 4:  50%|█████     | 4/8 [08:54<08:54, 133.56s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>Bill Paxton has taken the true story of the 1913 US golf open and made a film that is about much more than an extra-ordinary game of golf. The film also deals directly with the class tensions of the early twentieth century and touches upon the profound anti-Catholic prejudices of both the British and American establishments. But at heart the film is about that perennial favourite of triumph against the odds.<br /><br />The acting is exemplary throughout. Stephen Dillane is excellent as usual, but the revelation of the movie is Shia LaBoeuf who delivers a disciplined, dignified and highly sympathetic performance as a working class Franco-Irish kid fighting his way through the prejudices of the New England WASP establishment. For those who are only familiar with his slap-stick performances in "Even Stevens" this demonstration of his maturity is a delightful surprise. And Josh Flitter as the ten year old caddy threatens to steal every scene in which he appears.<br /><br />A old fashioned movie in the best sense of the word: fine acting, clear directing and a great story that grips to the end - the final scene an affectionate nod to Casablanca is just one of the many pleasures that fill a great movie.
# [Succeeded / Failed / Total] 3 / 2 / 5:  62%|██████▎   | 5/8 [14:23<08:37, 172.64s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film on September 1st, 2005 in Indianapolis. I am one of the judges for the Heartland Film Festival that screens films for their Truly Moving Picture Award. A Truly Moving Picture "...explores the human journey by artistically expressing hope and respect for the positive values of life." Heartland gave that award to this film.<br /><br />This is a story of golf in the early part of the 20th century. At that time, it was the game of upper class and rich "gentlemen", and working people could only participate by being caddies at country clubs. With this backdrop, this based-on-a-true-story unfolds with a young, working class boy who takes on the golf establishment and the greatest golfer in the world, Harry Vardon.<br /><br />And the story is inspirational. Against all odds, Francis Ouimet (played by Shia LaBeouf of "Holes") gets to compete against the greatest golfers of the U.S. and Great Britain at the 1913 U.S. Open. Francis is ill-prepared, and has a child for a caddy. (The caddy is hilarious and motivational and steals every scene he appears in.) But despite these handicaps, Francis displays courage, spirit, heroism, and humility at this world class event.<br /><br />And, we learn a lot about the early years of golf; for example, the use of small wooden clubs, the layout of the short holes, the manual scoreboard, the golfers swinging with pipes in their mouths, the terrible conditions of the greens and fairways, and the play not being canceled even in torrential rain.<br /><br />This film has stunning cinematography and art direction and editing. And with no big movie stars, the story is somehow more believable.<br /><br />This adds to the inventory of great sports movies in the vein of "Miracle" and "Remember the Titans."<br /><br />FYI - There is a Truly Moving Pictures web site where there is a listing of past winners going back 70 years.
# [Succeeded / Failed / Total] 3 / 3 / 6:  75%|███████▌  | 6/8 [22:08<07:22, 221.42s/it]
# <font color = red>Negative (94%)</font> --> <font color = gray>[SKIPPED]</font><br>Maybe I'm reading into this too much, but I wonder how much of a hand Hongsheng had in developing the film. I mean, when a story is told casting the main character as himself, I would think he would be a heavy hand in writing, documenting, etc. and that would make it a little biased.<br /><br />But...his family and friends also may have had a hand in getting the actual details about Hongsheng's life. I think the best view would have been told from Hongsheng's family and friends' perspectives. They saw his transformation and weren't so messed up on drugs that they remember everything.<br /><br />As for Hongsheng being full of himself, the consistencies of the Jesus Christ pose make him appear as a martyr who sacrificed his life (metaphorically, of course, he's obviously still alive as he was cast as himself) for his family's happiness. Huh?<br /><br />The viewer sees him at his lowest points while still maintaining a superiority complex. He lies on the grass coming down from (during?) a high by himself and with his father, he contemplates life and has visions of dragons at his window, he celebrates his freedom on a bicycle all while outstretching his arms, his head cocked to the side.<br /><br />It's fabulous that he's off of drugs now, but he's no hero. He went from a high point in his career in acting to his most vulnerable point while on drugs to come back somewhere in the middle.<br /><br />This same device is used in Ted Demme's "Blow" where the audience empathizes with the main character who is shown as a flawed hero.<br /><br />However, "Quitting" ("Zuotian") is a film that is recommended, mostly for its haunting soundtrack, superb acting, and landscapes. But, the best part is the feeling that one gets when what we presume to be the house of Jia Hongsheng is actually a stage setting for a play. It makes the viewer feel as if Hongsheng's life was merely a play told in many difficult parts.
# [Succeeded / Failed / Total] 3 / 3 / 7:  88%|████████▊ | 7/8 [22:08<03:09, 189.80s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (60%)</font><br>I felt this film did have many <font color = green>good</font> qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.<br>I felt this film did have many <font color = red>bad</font> qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.
# [Succeeded / Failed / Total] 4 / 3 / 8: 100%|██████████| 8/8 [22:29<00:00, 168.69s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>This movie is amazing because the fact that the real people portray themselves and their real life experience and do such a good job it's like they're almost living the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna cry because the family especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others might see the movie as boring because it's just so real that its almost like a documentary. Overall this movie is great and Hongsheng deserved an Oscar for this movie so did his Dad.
# [Succeeded / Failed / Total] 4 / 4 / 9: : 9it [27:04, 180.46s/it]
# +-------------------------------+---------+
# | Attack Results                |         |
# +-------------------------------+---------+
# | Number of successful attacks: | 4       |
# | Number of failed attacks:     | 4       |
# | Number of skipped attacks:    | 1       |
# | Original accuracy:            | 88.89%  |
# | Accuracy under attack:        | 44.44%  |
# | Attack success rate:          | 50.0%   |
# | Average perturbed word %:     | 1.63%   |
# | Average num. words per input: | 228.44  |
# | Avg num queries:              | 3649.75 |
# +-------------------------------+---------+
# textattack: Attack time: 1624.1847748756409s

# %%
#glove
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("imdb", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/4ea52f2e58a08dbc12c2bd52d0d92b30b88c00230b4522801b3636782f625c5b)
# textattack: Loading datasets dataset imdb, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (81%)</font><br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was reluctant to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I <font color = green>was</font> wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such <font color = green>professionalism</font>. The sign of a <font color = green>good</font> movie is that it <font color = green>can</font> toy with our emotions. This one did exactly that. The entire theater (which was sold out) <font color = green>was</font> <font color = green>overcome</font> by laughter during the first half of the movie, and were moved to tears <font color = green>during</font> the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie <font color = green>was</font> <font color = green>great</font>, and I suggest that you go <font color = green>see</font> it before you judge.<br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was reluctant to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I <font color = red>rescinded</font> wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such <font color = red>remixing</font>. The sign of a <font color = red>benimens</font> movie is that it <font color = red>peguera</font> toy with our emotions. This one did exactly that. The entire theater (which was sold out) <font color = red>rescinded</font> <font color = red>tempted</font> by laughter during the first half of the movie, and were moved to tears <font color = red>after</font> the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie <font color = red>rescinded</font> <font color = red>inaco</font>, and I suggest that you go <font color = red>ankaa</font> it before you judge.
#  12%|█▎        | 1/8 [03:11<22:21, 191.68s/it]
#
#
#
# [Succeeded / Failed / Total] 1 / 0 / 1:  12%|█▎        | 1/8 [03:11<22:21, 191.69s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (64%)</font><br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no <font color = green>fan</font> of golf, and these <font color = green>scrappy</font> underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was enthralling all the <font color = green>same</font>.<br /><br />The <font color = green>film</font> starts with some <font color = green>creative</font> <font color = green>opening</font> credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its <font color = green>first</font> by-the-numbers hour. Once the <font color = green>action</font> moves to the U.S. Open <font color = green>things</font> pick up very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected <font color = green>psychological</font> depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behind the camera than he ever had in front of it. Despite the formulaic nature, this is a nice and easy film to root for that deserves to find an audience.<br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no <font color = red>plicatilis</font> of golf, and these <font color = red>notebaert</font> underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was enthralling all the <font color = red>particular</font>.<br /><br />The <font color = red>remodernist</font> starts with some <font color = red>artistic</font> <font color = red>closing</font> credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its <font color = red>ahad</font> by-the-numbers hour. Once the <font color = red>republicaine</font> moves to the U.S. Open <font color = red>endureth</font> pick up very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected <font color = red>sociological</font> depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure ...
# [Succeeded / Failed / Total] 1 / 0 / 1:  25%|██▌       | 2/8 [09:46<29:19, 293.17s/it]
#
#
#
# [Succeeded / Failed / Total] 2 / 0 / 2:  25%|██▌       | 2/8 [09:46<29:19, 293.18s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (87%)</font><br>As a <font color = green>recreational</font> golfer with some knowledge of the sport's history, I <font color = green>was</font> pleased with Disney's <font color = green>sensitivity</font> to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass <font color = green>ceiling</font> that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I <font color = green>loved</font> best, however, <font color = green>is</font> how this theme of class is manifested in the characters of Ouimet's parents. His father <font color = green>is</font> a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the golf scenes <font color = green>are</font> <font color = green>well</font> photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the beauty of the <font color = green>film</font>. There's one little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.<br>As a <font color = red>hallucinogenic</font> golfer with some knowledge of the sport's history, I <font color = red>rescinded</font> pleased with Disney's <font color = red>attribution</font> to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass <font color = red>shaft</font> that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I <font color = red>disavows</font> best, however, <font color = red>polylogarithm</font> how this theme of class is manifested in the characters of Ouimet's parents. His father <font color = red>polylogarithm</font> a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the golf scenes <font color = red>washerwomen</font> <font color = red>siehr</font> photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the beauty of the <font color = red>remodernist</font>. There's one little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.
# [Succeeded / Failed / Total] 2 / 0 / 2:  38%|███▊      | 3/8 [15:18<25:30, 306.18s/it]
#
#
#
# [Succeeded / Failed / Total] 3 / 0 / 3:  38%|███▊      | 3/8 [15:18<25:30, 306.19s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film in a sneak preview, and it is delightful. The cinematography is unusually creative, the acting is good, and the story is fabulous. If this movie does not do well, it won't be because it doesn't deserve to. Before this film, I didn't realize how charming Shia Lebouf could be. He does a marvelous, self-contained, job as the lead. There's something incredibly sweet about him, and it makes the movie even better. The other actors do a good job as well, and the film contains moments of really high suspense, more than one might expect from a movie about golf. Sports movies are a dime a dozen, but this one stands out. <br /><br />This is one I'd recommend to anyone.
# [Succeeded / Failed / Total] 3 / 0 / 3:  50%|█████     | 4/8 [18:06<18:06, 271.51s/it]
#
#
#
# [Succeeded / Failed / Total] 3 / 1 / 4:  50%|█████     | 4/8 [18:06<18:06, 271.51s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>Bill Paxton has taken the true story of the 1913 US golf open and made a film that is about much more than an extra-ordinary game of golf. The film also deals directly with the class tensions of the early twentieth century and touches upon the profound anti-Catholic prejudices of both the British and American establishments. But at heart the film is about that perennial favourite of triumph against the odds.<br /><br />The acting is exemplary throughout. Stephen Dillane is excellent as usual, but the revelation of the movie is Shia LaBoeuf who delivers a disciplined, dignified and highly sympathetic performance as a working class Franco-Irish kid fighting his way through the prejudices of the New England WASP establishment. For those who are only familiar with his slap-stick performances in "Even Stevens" this demonstration of his maturity is a delightful surprise. And Josh Flitter as the ten year old caddy threatens to steal every scene in which he appears.<br /><br />A old fashioned movie in the best sense of the word: fine acting, clear directing and a great story that grips to the end - the final scene an affectionate nod to Casablanca is just one of the many pleasures that fill a great movie.
# [Succeeded / Failed / Total] 3 / 1 / 4:  62%|██████▎   | 5/8 [23:00<13:48, 276.04s/it]
#
#
#
# [Succeeded / Failed / Total] 3 / 2 / 5:  62%|██████▎   | 5/8 [23:00<13:48, 276.04s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film on September 1st, 2005 in Indianapolis. I am one of the judges for the Heartland Film Festival that screens films for their Truly Moving Picture Award. A Truly Moving Picture "...explores the human journey by artistically expressing hope and respect for the positive values of life." Heartland gave that award to this film.<br /><br />This is a story of golf in the early part of the 20th century. At that time, it was the game of upper class and rich "gentlemen", and working people could only participate by being caddies at country clubs. With this backdrop, this based-on-a-true-story unfolds with a young, working class boy who takes on the golf establishment and the greatest golfer in the world, Harry Vardon.<br /><br />And the story is inspirational. Against all odds, Francis Ouimet (played by Shia LaBeouf of "Holes") gets to compete against the greatest golfers of the U.S. and Great Britain at the 1913 U.S. Open. Francis is ill-prepared, and has a child for a caddy. (The caddy is hilarious and motivational and steals every scene he appears in.) But despite these handicaps, Francis displays courage, spirit, heroism, and humility at this world class event.<br /><br />And, we learn a lot about the early years of golf; for example, the use of small wooden clubs, the layout of the short holes, the manual scoreboard, the golfers swinging with pipes in their mouths, the terrible conditions of the greens and fairways, and the play not being canceled even in torrential rain.<br /><br />This film has stunning cinematography and art direction and editing. And with no big movie stars, the story is somehow more believable.<br /><br />This adds to the inventory of great sports movies in the vein of "Miracle" and "Remember the Titans."<br /><br />FYI - There is a Truly Moving Pictures web site where there is a listing of past winners going back 70 years.
# [Succeeded / Failed / Total] 3 / 2 / 5:  75%|███████▌  | 6/8 [30:18<10:06, 303.16s/it]
#
#
#
# [Succeeded / Failed / Total] 3 / 3 / 6:  75%|███████▌  | 6/8 [30:18<10:06, 303.16s/it]
# <font color = red>Negative (94%)</font> --> <font color = gray>[SKIPPED]</font><br>Maybe I'm reading into this too much, but I wonder how much of a hand Hongsheng had in developing the film. I mean, when a story is told casting the main character as himself, I would think he would be a heavy hand in writing, documenting, etc. and that would make it a little biased.<br /><br />But...his family and friends also may have had a hand in getting the actual details about Hongsheng's life. I think the best view would have been told from Hongsheng's family and friends' perspectives. They saw his transformation and weren't so messed up on drugs that they remember everything.<br /><br />As for Hongsheng being full of himself, the consistencies of the Jesus Christ pose make him appear as a martyr who sacrificed his life (metaphorically, of course, he's obviously still alive as he was cast as himself) for his family's happiness. Huh?<br /><br />The viewer sees him at his lowest points while still maintaining a superiority complex. He lies on the grass coming down from (during?) a high by himself and with his father, he contemplates life and has visions of dragons at his window, he celebrates his freedom on a bicycle all while outstretching his arms, his head cocked to the side.<br /><br />It's fabulous that he's off of drugs now, but he's no hero. He went from a high point in his career in acting to his most vulnerable point while on drugs to come back somewhere in the middle.<br /><br />This same device is used in Ted Demme's "Blow" where the audience empathizes with the main character who is shown as a flawed hero.<br /><br />However, "Quitting" ("Zuotian") is a film that is recommended, mostly for its haunting soundtrack, superb acting, and landscapes. But, the best part is the feeling that one gets when what we presume to be the house of Jia Hongsheng is actually a stage setting for a play. It makes the viewer feel as if Hongsheng's life was merely a play told in many difficult parts.
# [Succeeded / Failed / Total] 3 / 3 / 7:  88%|████████▊ | 7/8 [30:18<04:19, 259.86s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (55%)</font><br>I felt this film <font color = green>did</font> have many good qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects <font color = green>may</font> <font color = green>leave</font> many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really <font color = green>cheesy</font> sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.<br>I felt this film <font color = red>could</font> have many good qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects <font color = red>can</font> <font color = red>flatline</font> many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really <font color = red>ramad</font> sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.
# [Succeeded / Failed / Total] 3 / 3 / 7: 100%|██████████| 8/8 [31:22<00:00, 235.30s/it]
#
#
#
# [Succeeded / Failed / Total] 4 / 3 / 8: 100%|██████████| 8/8 [31:22<00:00, 235.30s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>This movie is amazing because the fact that the real people portray themselves and their real life experience and do such a good job it's like they're almost living the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna cry because the family especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others might see the movie as boring because it's just so real that its almost like a documentary. Overall this movie is great and Hongsheng deserved an Oscar for this movie so did his Dad.
# [Succeeded / Failed / Total] 4 / 3 / 8: : 9it [35:10, 234.47s/it]
#
#
#
# [Succeeded / Failed / Total] 4 / 4 / 9: : 9it [35:10, 234.47s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 4      |
# | Number of failed attacks:     | 4      |
# | Number of skipped attacks:    | 1      |
# | Original accuracy:            | 88.89% |
# | Accuracy under attack:        | 44.44% |
# | Attack success rate:          | 50.0%  |
# | Average perturbed word %:     | 4.09%  |
# | Average num. words per input: | 228.44 |
# | Avg num queries:              | 3884.0 |
# +-------------------------------+--------+
# textattack: Attack time: 2110.230605840683s

# %%
#fasttext
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("imdb", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1867.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1004.0, style=ProgressStyle(description…
# Downloading and preparing dataset imdb/plain_text (download: 80.23 MiB, generated: 127.06 MiB, post-processed: Unknown size, total: 207.28 MiB) to /root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/4ea52f2e58a08dbc12c2bd52d0d92b30b88c00230b4522801b3636782f625c5b...
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=84125825.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# textattack: Loading datasets dataset imdb, split test.
# Dataset imdb downloaded and prepared to /root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/4ea52f2e58a08dbc12c2bd52d0d92b30b88c00230b4522801b3636782f625c5b. Subsequent calls will reuse this data.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (99%)</font><br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was reluctant to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = green>good</font> movie is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was overcome by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = green>great</font>, and <font color = green>I</font> suggest that you go <font color = green>see</font> it before you judge.<br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was reluctant to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = red>bad</font> movie is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was overcome by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = red>greasy</font>, and <font color = red>ENCHANTER</font> suggest that you go <font color = red>disambiguation</font> it before you judge.
#  12%|█▎        | 1/8 [00:22<02:34, 22.04s/it]
# [Succeeded / Failed / Total] 1 / 0 / 1:  12%|█▎        | 1/8 [00:22<02:34, 22.06s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (98%)</font><br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no fan of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was <font color = green>enthralling</font> all the same.<br /><br />The film starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the action moves to the U.S. Open things pick up very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behind the camera than he ever had in front of it. Despite the formulaic nature, this is a nice and easy film to root for that deserves to find an audience.<br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no fan of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was <font color = red>appalling</font> all the same.<br /><br />The film starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the action moves to the U.S. Open things pick up very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behin ...
# [Succeeded / Failed / Total] 1 / 0 / 1:  25%|██▌       | 2/8 [00:33<01:40, 16.81s/it]
# [Succeeded / Failed / Total] 2 / 0 / 2:  25%|██▌       | 2/8 [00:33<01:40, 16.82s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>As a recreational golfer with some knowledge of the sport's history, I was pleased with Disney's sensitivity to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I loved best, however, is how this theme of class is manifested in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the golf scenes are well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the beauty of the film. There's one little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.
# [Succeeded / Failed / Total] 2 / 0 / 2:  38%|███▊      | 3/8 [06:15<10:25, 125.15s/it]
# [Succeeded / Failed / Total] 2 / 1 / 3:  38%|███▊      | 3/8 [06:15<10:25, 125.15s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film in a sneak preview, and it is delightful. The cinematography is unusually creative, the acting is good, and the story is fabulous. If this movie does not do well, it won't be because it doesn't deserve to. Before this film, I didn't realize how charming Shia Lebouf could be. He does a marvelous, self-contained, job as the lead. There's something incredibly sweet about him, and it makes the movie even better. The other actors do a good job as well, and the film contains moments of really high suspense, more than one might expect from a movie about golf. Sports movies are a dime a dozen, but this one stands out. <br /><br />This is one I'd recommend to anyone.
# [Succeeded / Failed / Total] 2 / 1 / 3:  50%|█████     | 4/8 [08:49<08:49, 132.43s/it]
# [Succeeded / Failed / Total] 2 / 2 / 4:  50%|█████     | 4/8 [08:49<08:49, 132.43s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>Bill Paxton has taken the true story of the 1913 US golf open and made a film that is about much more than an extra-ordinary game of golf. The film also deals directly with the class tensions of the early twentieth century and touches upon the profound anti-Catholic prejudices of both the British and American establishments. But at heart the film is about that perennial favourite of triumph against the odds.<br /><br />The acting is exemplary throughout. Stephen Dillane is excellent as usual, but the revelation of the movie is Shia LaBoeuf who delivers a disciplined, dignified and highly sympathetic performance as a working class Franco-Irish kid fighting his way through the prejudices of the New England WASP establishment. For those who are only familiar with his slap-stick performances in "Even Stevens" this demonstration of his maturity is a delightful surprise. And Josh Flitter as the ten year old caddy threatens to steal every scene in which he appears.<br /><br />A old fashioned movie in the best sense of the word: fine acting, clear directing and a great story that grips to the end - the final scene an affectionate nod to Casablanca is just one of the many pleasures that fill a great movie.
# [Succeeded / Failed / Total] 2 / 2 / 4:  62%|██████▎   | 5/8 [14:00<08:24, 168.11s/it]
# [Succeeded / Failed / Total] 2 / 3 / 5:  62%|██████▎   | 5/8 [14:00<08:24, 168.11s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film on September 1st, 2005 in Indianapolis. I am one of the judges for the Heartland Film Festival that screens films for their Truly Moving Picture Award. A Truly Moving Picture "...explores the human journey by artistically expressing hope and respect for the positive values of life." Heartland gave that award to this film.<br /><br />This is a story of golf in the early part of the 20th century. At that time, it was the game of upper class and rich "gentlemen", and working people could only participate by being caddies at country clubs. With this backdrop, this based-on-a-true-story unfolds with a young, working class boy who takes on the golf establishment and the greatest golfer in the world, Harry Vardon.<br /><br />And the story is inspirational. Against all odds, Francis Ouimet (played by Shia LaBeouf of "Holes") gets to compete against the greatest golfers of the U.S. and Great Britain at the 1913 U.S. Open. Francis is ill-prepared, and has a child for a caddy. (The caddy is hilarious and motivational and steals every scene he appears in.) But despite these handicaps, Francis displays courage, spirit, heroism, and humility at this world class event.<br /><br />And, we learn a lot about the early years of golf; for example, the use of small wooden clubs, the layout of the short holes, the manual scoreboard, the golfers swinging with pipes in their mouths, the terrible conditions of the greens and fairways, and the play not being canceled even in torrential rain.<br /><br />This film has stunning cinematography and art direction and editing. And with no big movie stars, the story is somehow more believable.<br /><br />This adds to the inventory of great sports movies in the vein of "Miracle" and "Remember the Titans."<br /><br />FYI - There is a Truly Moving Pictures web site where there is a listing of past winners going back 70 years.
# [Succeeded / Failed / Total] 2 / 3 / 5:  75%|███████▌  | 6/8 [22:59<07:39, 229.93s/it]
# [Succeeded / Failed / Total] 2 / 4 / 6:  75%|███████▌  | 6/8 [22:59<07:39, 229.93s/it]
# <font color = red>Negative (94%)</font> --> <font color = gray>[SKIPPED]</font><br>Maybe I'm reading into this too much, but I wonder how much of a hand Hongsheng had in developing the film. I mean, when a story is told casting the main character as himself, I would think he would be a heavy hand in writing, documenting, etc. and that would make it a little biased.<br /><br />But...his family and friends also may have had a hand in getting the actual details about Hongsheng's life. I think the best view would have been told from Hongsheng's family and friends' perspectives. They saw his transformation and weren't so messed up on drugs that they remember everything.<br /><br />As for Hongsheng being full of himself, the consistencies of the Jesus Christ pose make him appear as a martyr who sacrificed his life (metaphorically, of course, he's obviously still alive as he was cast as himself) for his family's happiness. Huh?<br /><br />The viewer sees him at his lowest points while still maintaining a superiority complex. He lies on the grass coming down from (during?) a high by himself and with his father, he contemplates life and has visions of dragons at his window, he celebrates his freedom on a bicycle all while outstretching his arms, his head cocked to the side.<br /><br />It's fabulous that he's off of drugs now, but he's no hero. He went from a high point in his career in acting to his most vulnerable point while on drugs to come back somewhere in the middle.<br /><br />This same device is used in Ted Demme's "Blow" where the audience empathizes with the main character who is shown as a flawed hero.<br /><br />However, "Quitting" ("Zuotian") is a film that is recommended, mostly for its haunting soundtrack, superb acting, and landscapes. But, the best part is the feeling that one gets when what we presume to be the house of Jia Hongsheng is actually a stage setting for a play. It makes the viewer feel as if Hongsheng's life was merely a play told in many difficult parts.
# [Succeeded / Failed / Total] 2 / 4 / 7:  88%|████████▊ | 7/8 [22:59<03:17, 197.09s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (72%)</font><br>I <font color = green>felt</font> this film did have many good qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.<br>I <font color = red>disbelieved</font> this film did have many good qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.
# [Succeeded / Failed / Total] 2 / 4 / 7: 100%|██████████| 8/8 [23:04<00:00, 173.03s/it]
# [Succeeded / Failed / Total] 3 / 4 / 8: 100%|██████████| 8/8 [23:04<00:00, 173.03s/it]
# [Succeeded / Failed / Total] 3 / 4 / 8: 100%|██████████| 8/8 [23:17<00:00, 174.73s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (82%)</font><br>This movie is amazing because the fact that the real people portray themselves and their real life experience and do such a <font color = green>good</font> job it's like they're almost living the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna cry because the family especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others might see the movie as boring because it's just so <font color = green>real</font> that its almost like a documentary. Overall this movie is <font color = green>great</font> and Hongsheng deserved an Oscar for this movie so did his Dad.<br>This movie is amazing because the fact that the real people portray themselves and their real life experience and do such a <font color = red>bad</font> job it's like they're almost living the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna cry because the family especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others might see the movie as boring because it's just so <font color = red>unimaginable</font> that its almost like a documentary. Overall this movie is <font color = red>greasy</font> and Hongsheng deserved an Oscar for this movie so did his Dad.
# [Succeeded / Failed / Total] 3 / 4 / 8: : 9it [24:08, 160.93s/it]
# [Succeeded / Failed / Total] 4 / 4 / 9: : 9it [24:08, 160.93s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 4      |
# | Number of failed attacks:     | 4      |
# | Number of skipped attacks:    | 1      |
# | Original accuracy:            | 88.89% |
# | Accuracy under attack:        | 44.44% |
# | Attack success rate:          | 50.0%  |
# | Average perturbed word %:     | 1.35%  |
# | Average num. words per input: | 228.44 |
# | Avg num queries:              | 3593.0 |
# +-------------------------------+--------+
# textattack: Attack time: 1448.3683023452759s

# %%
#word2vec
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("imdb", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/4ea52f2e58a08dbc12c2bd52d0d92b30b88c00230b4522801b3636782f625c5b)
# textattack: Loading datasets dataset imdb, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (83%)</font><br>I went and <font color = green>saw</font> this movie last night after being coaxed to by a few friends of mine. I'll admit that I was <font color = green>reluctant</font> to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = green>good</font> <font color = green>movie</font> is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was <font color = green>overcome</font> by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many <font color = green>full</font> grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = green>great</font>, and I suggest that you go <font color = green>see</font> it before you <font color = green>judge</font>.<br>I went and <font color = red>overcame</font> this movie last night after being coaxed to by a few friends of mine. I'll admit that I was <font color = red>willing</font> to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = red>bad</font> <font color = red>film</font> is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was <font color = red>mitigated</font> by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many <font color = red>complete</font> grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = red>tremendous</font>, and I suggest that you go <font color = red>list</font> it before you <font color = red>court</font>.
#  12%|█▎        | 1/8 [01:33<10:52, 93.15s/it]
# [Succeeded / Failed / Total] 1 / 0 / 1:  12%|█▎        | 1/8 [01:33<10:52, 93.16s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (63%)</font><br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no fan of golf, and these scrappy underdog sports <font color = green>flicks</font> are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was enthralling all the same.<br /><br />The film starts with some creative <font color = green>opening</font> credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its <font color = green>first</font> by-the-numbers hour. Once the <font color = green>action</font> moves to the U.S. Open <font color = green>things</font> <font color = green>pick</font> up very well. Paxton does a nice job and shows a knack for effective <font color = green>directorial</font> flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some <font color = green>unexpected</font> psychological depth to the proceedings. There's some compelling character <font color = green>development</font> when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behind the camera than he ever had in front of it. Despite the formulaic nature, this is a nice and easy film to root for that deserves to find an audience.<br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no fan of golf, and these scrappy underdog sports <font color = red>creeps</font> are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was enthralling all the same.<br /><br />The film starts with some creative <font color = red>closing</font> credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its <font color = red>second</font> by-the-numbers hour. Once the <font color = red>affirmative</font> moves to the U.S. Open <font color = red>something</font> <font color = red>discard</font> up very well. Paxton does a nice job and shows a knack for effective <font color = red>cukor</font> flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some <font color = red>embarrassing</font> psychological depth to the proceedings. There's some compelling character <font color = red>revitalization</font> when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Cred ...
# [Succeeded / Failed / Total] 1 / 0 / 1:  25%|██▌       | 2/8 [04:17<12:53, 128.85s/it]
# [Succeeded / Failed / Total] 2 / 0 / 2:  25%|██▌       | 2/8 [04:17<12:53, 128.85s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (90%)</font><br>As a recreational golfer with some knowledge of the sport's history, I was <font color = green>pleased</font> with Disney's sensitivity to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I <font color = green>loved</font> best, however, is how this theme of class is manifested in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the <font color = green>golf</font> scenes are well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the <font color = green>beauty</font> of the film. There's one little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.<br>As a recreational golfer with some knowledge of the sport's history, I was <font color = red>regretted</font> with Disney's sensitivity to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I <font color = red>hated</font> best, however, is how this theme of class is manifested in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the <font color = red>sport</font> scenes are well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the <font color = red>modesty</font> of the film. There's one little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.
# [Succeeded / Failed / Total] 2 / 0 / 2:  38%|███▊      | 3/8 [04:40<07:48, 93.62s/it]
# [Succeeded / Failed / Total] 3 / 0 / 3:  38%|███▊      | 3/8 [04:40<07:48, 93.62s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film in a sneak preview, and it is delightful. The cinematography is unusually creative, the acting is good, and the story is fabulous. If this movie does not do well, it won't be because it doesn't deserve to. Before this film, I didn't realize how charming Shia Lebouf could be. He does a marvelous, self-contained, job as the lead. There's something incredibly sweet about him, and it makes the movie even better. The other actors do a good job as well, and the film contains moments of really high suspense, more than one might expect from a movie about golf. Sports movies are a dime a dozen, but this one stands out. <br /><br />This is one I'd recommend to anyone.
# [Succeeded / Failed / Total] 3 / 0 / 3:  50%|█████     | 4/8 [06:47<06:47, 101.85s/it]
# [Succeeded / Failed / Total] 3 / 1 / 4:  50%|█████     | 4/8 [06:47<06:47, 101.86s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>Bill Paxton has taken the true story of the 1913 US golf open and made a film that is about much more than an extra-ordinary game of golf. The film also deals directly with the class tensions of the early twentieth century and touches upon the profound anti-Catholic prejudices of both the British and American establishments. But at heart the film is about that perennial favourite of triumph against the odds.<br /><br />The acting is exemplary throughout. Stephen Dillane is excellent as usual, but the revelation of the movie is Shia LaBoeuf who delivers a disciplined, dignified and highly sympathetic performance as a working class Franco-Irish kid fighting his way through the prejudices of the New England WASP establishment. For those who are only familiar with his slap-stick performances in "Even Stevens" this demonstration of his maturity is a delightful surprise. And Josh Flitter as the ten year old caddy threatens to steal every scene in which he appears.<br /><br />A old fashioned movie in the best sense of the word: fine acting, clear directing and a great story that grips to the end - the final scene an affectionate nod to Casablanca is just one of the many pleasures that fill a great movie.
# [Succeeded / Failed / Total] 3 / 1 / 4:  62%|██████▎   | 5/8 [10:25<06:15, 125.19s/it]
# [Succeeded / Failed / Total] 3 / 2 / 5:  62%|██████▎   | 5/8 [10:25<06:15, 125.19s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film on September 1st, 2005 in Indianapolis. I am one of the judges for the Heartland Film Festival that screens films for their Truly Moving Picture Award. A Truly Moving Picture "...explores the human journey by artistically expressing hope and respect for the positive values of life." Heartland gave that award to this film.<br /><br />This is a story of golf in the early part of the 20th century. At that time, it was the game of upper class and rich "gentlemen", and working people could only participate by being caddies at country clubs. With this backdrop, this based-on-a-true-story unfolds with a young, working class boy who takes on the golf establishment and the greatest golfer in the world, Harry Vardon.<br /><br />And the story is inspirational. Against all odds, Francis Ouimet (played by Shia LaBeouf of "Holes") gets to compete against the greatest golfers of the U.S. and Great Britain at the 1913 U.S. Open. Francis is ill-prepared, and has a child for a caddy. (The caddy is hilarious and motivational and steals every scene he appears in.) But despite these handicaps, Francis displays courage, spirit, heroism, and humility at this world class event.<br /><br />And, we learn a lot about the early years of golf; for example, the use of small wooden clubs, the layout of the short holes, the manual scoreboard, the golfers swinging with pipes in their mouths, the terrible conditions of the greens and fairways, and the play not being canceled even in torrential rain.<br /><br />This film has stunning cinematography and art direction and editing. And with no big movie stars, the story is somehow more believable.<br /><br />This adds to the inventory of great sports movies in the vein of "Miracle" and "Remember the Titans."<br /><br />FYI - There is a Truly Moving Pictures web site where there is a listing of past winners going back 70 years.
# [Succeeded / Failed / Total] 3 / 2 / 5:  75%|███████▌  | 6/8 [16:38<05:32, 166.45s/it]
# [Succeeded / Failed / Total] 3 / 3 / 6:  75%|███████▌  | 6/8 [16:38<05:32, 166.45s/it]
# <font color = red>Negative (94%)</font> --> <font color = gray>[SKIPPED]</font><br>Maybe I'm reading into this too much, but I wonder how much of a hand Hongsheng had in developing the film. I mean, when a story is told casting the main character as himself, I would think he would be a heavy hand in writing, documenting, etc. and that would make it a little biased.<br /><br />But...his family and friends also may have had a hand in getting the actual details about Hongsheng's life. I think the best view would have been told from Hongsheng's family and friends' perspectives. They saw his transformation and weren't so messed up on drugs that they remember everything.<br /><br />As for Hongsheng being full of himself, the consistencies of the Jesus Christ pose make him appear as a martyr who sacrificed his life (metaphorically, of course, he's obviously still alive as he was cast as himself) for his family's happiness. Huh?<br /><br />The viewer sees him at his lowest points while still maintaining a superiority complex. He lies on the grass coming down from (during?) a high by himself and with his father, he contemplates life and has visions of dragons at his window, he celebrates his freedom on a bicycle all while outstretching his arms, his head cocked to the side.<br /><br />It's fabulous that he's off of drugs now, but he's no hero. He went from a high point in his career in acting to his most vulnerable point while on drugs to come back somewhere in the middle.<br /><br />This same device is used in Ted Demme's "Blow" where the audience empathizes with the main character who is shown as a flawed hero.<br /><br />However, "Quitting" ("Zuotian") is a film that is recommended, mostly for its haunting soundtrack, superb acting, and landscapes. But, the best part is the feeling that one gets when what we presume to be the house of Jia Hongsheng is actually a stage setting for a play. It makes the viewer feel as if Hongsheng's life was merely a play told in many difficult parts.
# [Succeeded / Failed / Total] 3 / 3 / 7:  88%|████████▊ | 7/8 [16:38<02:22, 142.68s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (60%)</font><br>I felt this film did have many <font color = green>good</font> qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.<br>I felt this film did have many <font color = red>bad</font> qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.
# [Succeeded / Failed / Total] 3 / 3 / 7: 100%|██████████| 8/8 [16:42<00:00, 125.28s/it]
# [Succeeded / Failed / Total] 4 / 3 / 8: 100%|██████████| 8/8 [16:42<00:00, 125.28s/it]
# [Succeeded / Failed / Total] 4 / 3 / 8: 100%|██████████| 8/8 [16:54<00:00, 126.81s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>This movie is amazing because the fact that the real people portray themselves and their real life experience and do such a good job it's like they're almost living the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna cry because the family especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others might see the movie as boring because it's just so real that its almost like a documentary. Overall this movie is great and Hongsheng deserved an Oscar for this movie so did his Dad.
# [Succeeded / Failed / Total] 4 / 3 / 8: : 9it [18:56, 126.24s/it]
# [Succeeded / Failed / Total] 4 / 4 / 9: : 9it [18:56, 126.25s/it]
# +-------------------------------+---------+
# | Attack Results                |         |
# +-------------------------------+---------+
# | Number of successful attacks: | 4       |
# | Number of failed attacks:     | 4       |
# | Number of skipped attacks:    | 1       |
# | Original accuracy:            | 88.89%  |
# | Accuracy under attack:        | 44.44%  |
# | Attack success rate:          | 50.0%   |
# | Average perturbed word %:     | 2.71%   |
# | Average num. words per input: | 228.44  |
# | Avg num queries:              | 3058.88 |
# +-------------------------------+---------+
# textattack: Attack time: 1136.2181930541992s

# %%
#glove
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("imdb", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/4ea52f2e58a08dbc12c2bd52d0d92b30b88c00230b4522801b3636782f625c5b)
# textattack: Loading datasets dataset imdb, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (54%)</font><br>I went and saw this movie last <font color = green>night</font> after being coaxed to by a few friends of mine. I'll admit that I was <font color = green>reluctant</font> to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the <font color = green>character</font> of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = green>good</font> movie is that it can toy with our emotions. This <font color = green>one</font> did exactly that. The entire theater (which was sold out) was <font color = green>overcome</font> by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = green>great</font>, and I suggest that you <font color = green>go</font> see it before you judge.<br>I went and saw this movie last <font color = red>xantusiidae</font> after being coaxed to by a few friends of mine. I'll admit that I was <font color = red>obliged</font> to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the <font color = red>playable</font> of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = red>benimens</font> movie is that it can toy with our emotions. This <font color = red>ffffffarm</font> did exactly that. The entire theater (which was sold out) was <font color = red>tempted</font> by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = red>inaco</font>, and I suggest that you <font color = red>flatline</font> see it before you judge.
#  12%|█▎        | 1/8 [01:34<10:58, 94.09s/it]
# [Succeeded / Failed / Total] 1 / 0 / 1:  12%|█▎        | 1/8 [01:34<10:58, 94.10s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (85%)</font><br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no <font color = green>fan</font> of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was <font color = green>enthralling</font> all the same.<br /><br />The <font color = green>film</font> starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the <font color = green>action</font> moves to the U.S. Open <font color = green>things</font> pick up very <font color = green>well</font>. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behind the camera than he ever had in front of it. Despite the formulaic nature, this is a nice and easy film to root for that deserves to find an audience.<br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no <font color = red>plicatilis</font> of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was <font color = red>dzia</font> all the same.<br /><br />The <font color = red>remodernist</font> starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the <font color = red>republicaine</font> moves to the U.S. Open <font color = red>endureth</font> pick up very <font color = red>siehr</font>. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning ...
# [Succeeded / Failed / Total] 1 / 0 / 1:  25%|██▌       | 2/8 [07:00<21:02, 210.44s/it]
# [Succeeded / Failed / Total] 2 / 0 / 2:  25%|██▌       | 2/8 [07:00<21:02, 210.44s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>As a recreational golfer with some knowledge of the sport's history, I was pleased with Disney's sensitivity to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I loved best, however, is how this theme of class is manifested in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the golf scenes are well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the beauty of the film. There's one little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.
# [Succeeded / Failed / Total] 2 / 0 / 2:  38%|███▊      | 3/8 [13:11<21:59, 263.83s/it]
# [Succeeded / Failed / Total] 2 / 1 / 3:  38%|███▊      | 3/8 [13:11<21:59, 263.83s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film in a sneak preview, and it is delightful. The cinematography is unusually creative, the acting is good, and the story is fabulous. If this movie does not do well, it won't be because it doesn't deserve to. Before this film, I didn't realize how charming Shia Lebouf could be. He does a marvelous, self-contained, job as the lead. There's something incredibly sweet about him, and it makes the movie even better. The other actors do a good job as well, and the film contains moments of really high suspense, more than one might expect from a movie about golf. Sports movies are a dime a dozen, but this one stands out. <br /><br />This is one I'd recommend to anyone.
# [Succeeded / Failed / Total] 2 / 1 / 3:  50%|█████     | 4/8 [15:55<15:55, 238.89s/it]
# [Succeeded / Failed / Total] 2 / 2 / 4:  50%|█████     | 4/8 [15:55<15:55, 238.89s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>Bill Paxton has taken the true story of the 1913 US golf open and made a film that is about much more than an extra-ordinary game of golf. The film also deals directly with the class tensions of the early twentieth century and touches upon the profound anti-Catholic prejudices of both the British and American establishments. But at heart the film is about that perennial favourite of triumph against the odds.<br /><br />The acting is exemplary throughout. Stephen Dillane is excellent as usual, but the revelation of the movie is Shia LaBoeuf who delivers a disciplined, dignified and highly sympathetic performance as a working class Franco-Irish kid fighting his way through the prejudices of the New England WASP establishment. For those who are only familiar with his slap-stick performances in "Even Stevens" this demonstration of his maturity is a delightful surprise. And Josh Flitter as the ten year old caddy threatens to steal every scene in which he appears.<br /><br />A old fashioned movie in the best sense of the word: fine acting, clear directing and a great story that grips to the end - the final scene an affectionate nod to Casablanca is just one of the many pleasures that fill a great movie.
# [Succeeded / Failed / Total] 2 / 2 / 4:  62%|██████▎   | 5/8 [21:08<12:41, 253.80s/it]
# [Succeeded / Failed / Total] 2 / 3 / 5:  62%|██████▎   | 5/8 [21:08<12:41, 253.80s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film on September 1st, 2005 in Indianapolis. I am one of the judges for the Heartland Film Festival that screens films for their Truly Moving Picture Award. A Truly Moving Picture "...explores the human journey by artistically expressing hope and respect for the positive values of life." Heartland gave that award to this film.<br /><br />This is a story of golf in the early part of the 20th century. At that time, it was the game of upper class and rich "gentlemen", and working people could only participate by being caddies at country clubs. With this backdrop, this based-on-a-true-story unfolds with a young, working class boy who takes on the golf establishment and the greatest golfer in the world, Harry Vardon.<br /><br />And the story is inspirational. Against all odds, Francis Ouimet (played by Shia LaBeouf of "Holes") gets to compete against the greatest golfers of the U.S. and Great Britain at the 1913 U.S. Open. Francis is ill-prepared, and has a child for a caddy. (The caddy is hilarious and motivational and steals every scene he appears in.) But despite these handicaps, Francis displays courage, spirit, heroism, and humility at this world class event.<br /><br />And, we learn a lot about the early years of golf; for example, the use of small wooden clubs, the layout of the short holes, the manual scoreboard, the golfers swinging with pipes in their mouths, the terrible conditions of the greens and fairways, and the play not being canceled even in torrential rain.<br /><br />This film has stunning cinematography and art direction and editing. And with no big movie stars, the story is somehow more believable.<br /><br />This adds to the inventory of great sports movies in the vein of "Miracle" and "Remember the Titans."<br /><br />FYI - There is a Truly Moving Pictures web site where there is a listing of past winners going back 70 years.
# [Succeeded / Failed / Total] 2 / 3 / 5:  75%|███████▌  | 6/8 [29:15<09:45, 292.64s/it]
# [Succeeded / Failed / Total] 2 / 4 / 6:  75%|███████▌  | 6/8 [29:15<09:45, 292.64s/it]
# <font color = red>Negative (94%)</font> --> <font color = gray>[SKIPPED]</font><br>Maybe I'm reading into this too much, but I wonder how much of a hand Hongsheng had in developing the film. I mean, when a story is told casting the main character as himself, I would think he would be a heavy hand in writing, documenting, etc. and that would make it a little biased.<br /><br />But...his family and friends also may have had a hand in getting the actual details about Hongsheng's life. I think the best view would have been told from Hongsheng's family and friends' perspectives. They saw his transformation and weren't so messed up on drugs that they remember everything.<br /><br />As for Hongsheng being full of himself, the consistencies of the Jesus Christ pose make him appear as a martyr who sacrificed his life (metaphorically, of course, he's obviously still alive as he was cast as himself) for his family's happiness. Huh?<br /><br />The viewer sees him at his lowest points while still maintaining a superiority complex. He lies on the grass coming down from (during?) a high by himself and with his father, he contemplates life and has visions of dragons at his window, he celebrates his freedom on a bicycle all while outstretching his arms, his head cocked to the side.<br /><br />It's fabulous that he's off of drugs now, but he's no hero. He went from a high point in his career in acting to his most vulnerable point while on drugs to come back somewhere in the middle.<br /><br />This same device is used in Ted Demme's "Blow" where the audience empathizes with the main character who is shown as a flawed hero.<br /><br />However, "Quitting" ("Zuotian") is a film that is recommended, mostly for its haunting soundtrack, superb acting, and landscapes. But, the best part is the feeling that one gets when what we presume to be the house of Jia Hongsheng is actually a stage setting for a play. It makes the viewer feel as if Hongsheng's life was merely a play told in many difficult parts.
# [Succeeded / Failed / Total] 2 / 4 / 7:  88%|████████▊ | 7/8 [29:15<04:10, 250.84s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I felt this film did have many good qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.
# [Succeeded / Failed / Total] 2 / 4 / 7: 100%|██████████| 8/8 [33:02<00:00, 247.76s/it]
# [Succeeded / Failed / Total] 2 / 5 / 8: 100%|██████████| 8/8 [33:02<00:00, 247.76s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (79%)</font><br>This movie is <font color = green>amazing</font> because the fact that the <font color = green>real</font> people portray themselves and their real <font color = green>life</font> <font color = green>experience</font> and do such a <font color = green>good</font> job it's like they're <font color = green>almost</font> <font color = green>living</font> the past over again. Jia Hongsheng plays himself an actor who <font color = green>quit</font> everything except <font color = green>music</font> and drugs struggling with depression and searching for the meaning of life while being <font color = green>angry</font> at everyone especially the people who care for him most. There's moments in the movie that will make you wanna <font color = green>cry</font> because the family especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will <font color = green>understand</font> Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for <font color = green>walks</font> or bike rides by himself. Others <font color = green>might</font> <font color = green>see</font> the movie as boring because it's just so <font color = green>real</font> that its almost like a documentary. Overall this movie is <font color = green>great</font> and Hongsheng <font color = green>deserved</font> an Oscar for this movie so did his Dad.<br>This movie is <font color = red>autobiography</font> because the fact that the <font color = red>numbers</font> people portray themselves and their real <font color = red>imminently</font> <font color = red>knowledge</font> and do such a <font color = red>benimens</font> job it's like they're <font color = red>nearly</font> <font color = red>amebic</font> the past over again. Jia Hongsheng plays himself an actor who <font color = red>yongkang</font> everything except <font color = red>carnatic</font> and drugs struggling with depression and searching for the meaning of life while being <font color = red>furious</font> at everyone especially the people who care for him most. There's moments in the movie that will make you wanna <font color = red>fuck</font> because the family especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will <font color = red>know</font> Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for <font color = red>marrying</font> or bike rides by himself. Others <font color = red>diplodocids</font> <font color = red>ankaa</font> the movie as boring because it's just so <font color = red>numbers</font> that its almost like a documentary. Overall this movie is <font color = red>inaco</font> and Hongsheng <font color = red>reasonably</font> an Oscar for this movie so did his Dad.
# [Succeeded / Failed / Total] 2 / 5 / 8: : 9it [36:09, 241.06s/it]
# [Succeeded / Failed / Total] 3 / 5 / 9: : 9it [36:09, 241.06s/it]
# +-------------------------------+---------+
# | Attack Results                |         |
# +-------------------------------+---------+
# | Number of successful attacks: | 3       |
# | Number of failed attacks:     | 5       |
# | Number of skipped attacks:    | 1       |
# | Original accuracy:            | 88.89%  |
# | Accuracy under attack:        | 55.56%  |
# | Attack success rate:          | 37.5%   |
# | Average perturbed word %:     | 5.88%   |
# | Average num. words per input: | 228.44  |
# | Avg num queries:              | 4055.62 |
# +-------------------------------+---------+
# textattack: Attack time: 2169.5357315540314s

# %%
#fasttext
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("imdb", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/4ea52f2e58a08dbc12c2bd52d0d92b30b88c00230b4522801b3636782f625c5b)
# textattack: Loading datasets dataset imdb, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (99%)</font><br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was reluctant to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was <font color = green>wrong</font>. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = green>good</font> movie is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was overcome by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = green>great</font>, and I suggest that you go <font color = green>see</font> it before you judge.<br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was reluctant to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was <font color = red>knowing</font>. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = red>bad</font> movie is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was overcome by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = red>greasy</font>, and I suggest that you go <font color = red>disambiguation</font> it before you judge.
#  12%|█▎        | 1/8 [00:05<00:35,  5.11s/it]
# [Succeeded / Failed / Total] 1 / 0 / 1:  12%|█▎        | 1/8 [00:05<00:35,  5.11s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (98%)</font><br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no fan of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was <font color = green>enthralling</font> all the same.<br /><br />The film starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the action moves to the U.S. Open things pick up very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behind the camera than he ever had in front of it. Despite the formulaic nature, this is a nice and easy film to root for that deserves to find an audience.<br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no fan of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was <font color = red>appalling</font> all the same.<br /><br />The film starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the action moves to the U.S. Open things pick up very well. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behin ...
# [Succeeded / Failed / Total] 1 / 0 / 1:  25%|██▌       | 2/8 [00:16<00:49,  8.27s/it]
# [Succeeded / Failed / Total] 2 / 0 / 2:  25%|██▌       | 2/8 [00:16<00:49,  8.27s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>As a recreational golfer with some knowledge of the sport's history, I was pleased with Disney's sensitivity to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I loved best, however, is how this theme of class is manifested in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the golf scenes are well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the beauty of the film. There's one little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.
# [Succeeded / Failed / Total] 2 / 0 / 2:  38%|███▊      | 3/8 [00:32<00:53, 10.78s/it]
# [Succeeded / Failed / Total] 2 / 1 / 3:  38%|███▊      | 3/8 [00:32<00:53, 10.78s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (51%)</font><br><font color = green>I</font> <font color = green>saw</font> this film in a sneak <font color = green>preview</font>, and it is <font color = green>delightful</font>. The cinematography is unusually <font color = green>creative</font>, the acting is <font color = green>good</font>, and the <font color = green>story</font> is <font color = green>fabulous</font>. <font color = green>If</font> this movie does not do well, it won't be because it doesn't deserve to. <font color = green>Before</font> this <font color = green>film</font>, I didn't realize how charming Shia Lebouf could be. He does a <font color = green>marvelous</font>, self-contained, <font color = green>job</font> as the <font color = green>lead</font>. There's something <font color = green>incredibly</font> <font color = green>sweet</font> about him, and it <font color = green>makes</font> the movie <font color = green>even</font> <font color = green>better</font>. The other <font color = green>actors</font> do a good job as <font color = green>well</font>, and the film contains <font color = green>moments</font> of really <font color = green>high</font> <font color = green>suspense</font>, more than <font color = green>one</font> might <font color = green>expect</font> from a movie about golf. Sports movies are a <font color = green>dime</font> a <font color = green>dozen</font>, but this one <font color = green>stands</font> out. <<font color = green>br</font> /><<font color = green>br</font> /><font color = green>This</font> is <font color = green>one</font> <font color = green>I'd</font> <font color = green>recommend</font> to <font color = green>anyone</font>.<br><font color = red>ENCHANTER</font> <font color = red>gave</font> this film in a sneak <font color = red>review</font>, and it is <font color = red>artful</font>. The cinematography is unusually <font color = red>artistic</font>, the acting is <font color = red>bad</font>, and the <font color = red>novel</font> is <font color = red>nebulous</font>. <font color = red>Sun</font> this movie does not do well, it won't be because it doesn't deserve to. <font color = red>Wherefore</font> this <font color = red>movie</font>, I didn't realize how charming Shia Lebouf could be. He does a <font color = red>marvellous</font>, self-contained, <font color = red>offeree</font> as the <font color = red>contribute</font>. There's something <font color = red>incredibles</font> <font color = red>creamy</font> about him, and it <font color = red>making</font> the movie <font color = red>indeed</font> <font color = red>getter</font>. The other <font color = red>screenwriters</font> do a good job as <font color = red>such</font>, and the film contains <font color = red>motions</font> of really <font color = red>low</font> <font color = red>suspension</font>, more than <font color = red>nine</font> might <font color = red>want</font> from a movie about golf. Sports movies are a <font color = red>dim</font> a <font color = red>hundred</font>, but this one <font color = red>stood</font> out. <<font color = red>ck</font> /><<font color = red>ck</font> /><font color = red>Colchis</font> is <font color = red>nine</font> <font color = red>Bed</font> <font color = red>commend</font> to <font color = red>anybody</font>.
# [Succeeded / Failed / Total] 2 / 1 / 3:  50%|█████     | 4/8 [00:38<00:38,  9.66s/it]
# [Succeeded / Failed / Total] 3 / 1 / 4:  50%|█████     | 4/8 [00:38<00:38,  9.67s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>Bill Paxton has taken the true story of the 1913 US golf open and made a film that is about much more than an extra-ordinary game of golf. The film also deals directly with the class tensions of the early twentieth century and touches upon the profound anti-Catholic prejudices of both the British and American establishments. But at heart the film is about that perennial favourite of triumph against the odds.<br /><br />The acting is exemplary throughout. Stephen Dillane is excellent as usual, but the revelation of the movie is Shia LaBoeuf who delivers a disciplined, dignified and highly sympathetic performance as a working class Franco-Irish kid fighting his way through the prejudices of the New England WASP establishment. For those who are only familiar with his slap-stick performances in "Even Stevens" this demonstration of his maturity is a delightful surprise. And Josh Flitter as the ten year old caddy threatens to steal every scene in which he appears.<br /><br />A old fashioned movie in the best sense of the word: fine acting, clear directing and a great story that grips to the end - the final scene an affectionate nod to Casablanca is just one of the many pleasures that fill a great movie.
# [Succeeded / Failed / Total] 3 / 1 / 4:  62%|██████▎   | 5/8 [00:52<00:31, 10.40s/it]
# [Succeeded / Failed / Total] 3 / 2 / 5:  62%|██████▎   | 5/8 [00:52<00:31, 10.40s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film on September 1st, 2005 in Indianapolis. I am one of the judges for the Heartland Film Festival that screens films for their Truly Moving Picture Award. A Truly Moving Picture "...explores the human journey by artistically expressing hope and respect for the positive values of life." Heartland gave that award to this film.<br /><br />This is a story of golf in the early part of the 20th century. At that time, it was the game of upper class and rich "gentlemen", and working people could only participate by being caddies at country clubs. With this backdrop, this based-on-a-true-story unfolds with a young, working class boy who takes on the golf establishment and the greatest golfer in the world, Harry Vardon.<br /><br />And the story is inspirational. Against all odds, Francis Ouimet (played by Shia LaBeouf of "Holes") gets to compete against the greatest golfers of the U.S. and Great Britain at the 1913 U.S. Open. Francis is ill-prepared, and has a child for a caddy. (The caddy is hilarious and motivational and steals every scene he appears in.) But despite these handicaps, Francis displays courage, spirit, heroism, and humility at this world class event.<br /><br />And, we learn a lot about the early years of golf; for example, the use of small wooden clubs, the layout of the short holes, the manual scoreboard, the golfers swinging with pipes in their mouths, the terrible conditions of the greens and fairways, and the play not being canceled even in torrential rain.<br /><br />This film has stunning cinematography and art direction and editing. And with no big movie stars, the story is somehow more believable.<br /><br />This adds to the inventory of great sports movies in the vein of "Miracle" and "Remember the Titans."<br /><br />FYI - There is a Truly Moving Pictures web site where there is a listing of past winners going back 70 years.
# [Succeeded / Failed / Total] 3 / 2 / 5:  75%|███████▌  | 6/8 [01:14<00:24, 12.46s/it]
# [Succeeded / Failed / Total] 3 / 3 / 6:  75%|███████▌  | 6/8 [01:14<00:24, 12.47s/it]
# <font color = red>Negative (94%)</font> --> <font color = gray>[SKIPPED]</font><br>Maybe I'm reading into this too much, but I wonder how much of a hand Hongsheng had in developing the film. I mean, when a story is told casting the main character as himself, I would think he would be a heavy hand in writing, documenting, etc. and that would make it a little biased.<br /><br />But...his family and friends also may have had a hand in getting the actual details about Hongsheng's life. I think the best view would have been told from Hongsheng's family and friends' perspectives. They saw his transformation and weren't so messed up on drugs that they remember everything.<br /><br />As for Hongsheng being full of himself, the consistencies of the Jesus Christ pose make him appear as a martyr who sacrificed his life (metaphorically, of course, he's obviously still alive as he was cast as himself) for his family's happiness. Huh?<br /><br />The viewer sees him at his lowest points while still maintaining a superiority complex. He lies on the grass coming down from (during?) a high by himself and with his father, he contemplates life and has visions of dragons at his window, he celebrates his freedom on a bicycle all while outstretching his arms, his head cocked to the side.<br /><br />It's fabulous that he's off of drugs now, but he's no hero. He went from a high point in his career in acting to his most vulnerable point while on drugs to come back somewhere in the middle.<br /><br />This same device is used in Ted Demme's "Blow" where the audience empathizes with the main character who is shown as a flawed hero.<br /><br />However, "Quitting" ("Zuotian") is a film that is recommended, mostly for its haunting soundtrack, superb acting, and landscapes. But, the best part is the feeling that one gets when what we presume to be the house of Jia Hongsheng is actually a stage setting for a play. It makes the viewer feel as if Hongsheng's life was merely a play told in many difficult parts.
# [Succeeded / Failed / Total] 3 / 3 / 7:  88%|████████▊ | 7/8 [01:14<00:10, 10.69s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (72%)</font><br>I <font color = green>felt</font> this film did have many good qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.<br>I <font color = red>disbelieved</font> this film did have many good qualities. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I felt most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy sometimes (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.
# [Succeeded / Failed / Total] 3 / 3 / 7: 100%|██████████| 8/8 [01:19<00:00,  9.91s/it]
# [Succeeded / Failed / Total] 4 / 3 / 8: 100%|██████████| 8/8 [01:19<00:00,  9.91s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (82%)</font><br>This movie is amazing because the fact that the real people portray themselves and their real life experience and do such a <font color = green>good</font> job it's like they're almost living the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna cry because the family especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others might see the movie as boring because it's just so <font color = green>real</font> that its almost like a documentary. Overall this movie is <font color = green>great</font> and Hongsheng deserved an Oscar for this movie so did his Dad.<br>This movie is amazing because the fact that the real people portray themselves and their real life experience and do such a <font color = red>bad</font> job it's like they're almost living the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna cry because the family especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others might see the movie as boring because it's just so <font color = red>unimaginable</font> that its almost like a documentary. Overall this movie is <font color = red>greasy</font> and Hongsheng deserved an Oscar for this movie so did his Dad.
# [Succeeded / Failed / Total] 5 / 3 / 9: : 9it [01:24,  9.42s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 5      |
# | Number of failed attacks:     | 3      |
# | Number of skipped attacks:    | 1      |
# | Original accuracy:            | 88.89% |
# | Accuracy under attack:        | 33.33% |
# | Attack success rate:          | 62.5%  |
# | Average perturbed word %:     | 6.89%  |
# | Average num. words per input: | 228.44 |
# | Avg num queries:              | 278.88 |
# +-------------------------------+--------+
# textattack: Attack time: 84.7826681137085s

# %%
#word2vec
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("imdb", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/4ea52f2e58a08dbc12c2bd52d0d92b30b88c00230b4522801b3636782f625c5b)
# textattack: Loading datasets dataset imdb, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (50%)</font><br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was <font color = green>reluctant</font> to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was <font color = green>wrong</font>. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = green>good</font> movie is that it can toy with our <font color = green>emotions</font>. This one did exactly that. The entire theater (which was sold out) was overcome by laughter during the first half of the movie, and were moved to <font color = green>tears</font> during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = green>great</font>, and I <font color = green>suggest</font> that you go <font color = green>see</font> it before you judge.<br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was <font color = red>willing</font> to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was <font color = red>hurts</font>. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = red>bad</font> movie is that it can toy with our <font color = red>emotion</font>. This one did exactly that. The entire theater (which was sold out) was overcome by laughter during the first half of the movie, and were moved to <font color = red>cries</font> during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = red>tremendous</font>, and I <font color = red>speculate</font> that you go <font color = red>list</font> it before you judge.
#  12%|█▎        | 1/8 [00:05<00:38,  5.44s/it]
# [Succeeded / Failed / Total] 1 / 0 / 1:  12%|█▎        | 1/8 [00:05<00:38,  5.45s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (52%)</font><br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no <font color = green>fan</font> of golf, and these scrappy underdog sports flicks are a dime a <font color = green>dozen</font> (most recently <font color = green>done</font> to grand effect with "Miracle" and "Cinderella Man"), but some how this film was enthralling all the same.<br /><br />The film <font color = green>starts</font> with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its <font color = green>first</font> by-the-numbers hour. Once the action moves to the U.S. Open <font color = green>things</font> <font color = green>pick</font> up very <font color = green>well</font>. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behind the camera than he ever had in front of it. Despite the formulaic nature, this is a nice and easy film to root for that deserves to find an audience.<br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no <font color = red>shirow</font> of golf, and these scrappy underdog sports flicks are a dime a <font color = red>hundred</font> (most recently <font color = red>parsed</font> to grand effect with "Miracle" and "Cinderella Man"), but some how this film was enthralling all the same.<br /><br />The film <font color = red>begins</font> with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its <font color = red>second</font> by-the-numbers hour. Once the action moves to the U.S. Open <font color = red>something</font> <font color = red>discard</font> up very <font color = red>such</font>. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and cos ...
# [Succeeded / Failed / Total] 1 / 0 / 1:  25%|██▌       | 2/8 [00:17<00:53,  8.84s/it]
# [Succeeded / Failed / Total] 2 / 0 / 2:  25%|██▌       | 2/8 [00:17<00:53,  8.84s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (55%)</font><br>As a recreational golfer with some knowledge of the sport's history, I was pleased with Disney's <font color = green>sensitivity</font> to the issues of class in golf in the early twentieth century. The movie depicted well the psychological <font color = green>battles</font> that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the <font color = green>young</font> Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I <font color = green>loved</font> best, however, is how this theme of class is <font color = green>manifested</font> in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the <font color = green>golf</font> <font color = green>scenes</font> are well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the <font color = green>beauty</font> of the <font color = green>film</font>. There's <font color = green>one</font> <font color = green>little</font> Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.<br>As a recreational golfer with some knowledge of the sport's history, I was pleased with Disney's <font color = red>susceptibility</font> to the issues of class in golf in the early twentieth century. The movie depicted well the psychological <font color = red>battle</font> that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the <font color = red>gifted</font> Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I <font color = red>hated</font> best, however, is how this theme of class is <font color = red>manifests</font> in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the <font color = red>sport</font> <font color = red>skits</font> are well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the <font color = red>modesty</font> of the <font color = red>movie</font>. There's <font color = red>six</font> <font color = red>no</font> Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.
# [Succeeded / Failed / Total] 2 / 0 / 2:  38%|███▊      | 3/8 [00:26<00:44,  8.81s/it]
# [Succeeded / Failed / Total] 3 / 0 / 3:  38%|███▊      | 3/8 [00:26<00:44,  8.81s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (54%)</font><br>I <font color = green>saw</font> this film in a sneak <font color = green>preview</font>, and it is <font color = green>delightful</font>. The cinematography is unusually creative, the acting is <font color = green>good</font>, and the <font color = green>story</font> is <font color = green>fabulous</font>. If this movie does not do <font color = green>well</font>, it won't be because it doesn't deserve to. Before this <font color = green>film</font>, I didn't realize how charming Shia Lebouf could be. He does a <font color = green>marvelous</font>, self-contained, <font color = green>job</font> as the lead. There's <font color = green>something</font> incredibly <font color = green>sweet</font> about him, and it <font color = green>makes</font> the movie <font color = green>even</font> better. The other actors do a <font color = green>good</font> <font color = green>job</font> as <font color = green>well</font>, and the <font color = green>film</font> contains <font color = green>moments</font> of really <font color = green>high</font> suspense, more than <font color = green>one</font> might <font color = green>expect</font> from a movie about golf. Sports movies are a <font color = green>dime</font> a <font color = green>dozen</font>, but this one <font color = green>stands</font> out. <br /><br />This is <font color = green>one</font> I'd <font color = green>recommend</font> to <font color = green>anyone</font>.<br>I <font color = red>overcame</font> this film in a sneak <font color = red>imovie</font>, and it is <font color = red>wintry</font>. The cinematography is unusually creative, the acting is <font color = red>bad</font>, and the <font color = red>novel</font> is <font color = red>bytb</font>. If this movie does not do <font color = red>such</font>, it won't be because it doesn't deserve to. Before this <font color = red>movie</font>, I didn't realize how charming Shia Lebouf could be. He does a <font color = red>understatement</font>, self-contained, <font color = red>homework</font> as the lead. There's <font color = red>anything</font> incredibly <font color = red>lamb</font> about him, and it <font color = red>making</font> the movie <font color = red>indeed</font> better. The other actors do a <font color = red>bad</font> <font color = red>homework</font> as <font color = red>such</font>, and the <font color = red>movie</font> contains <font color = red>moment</font> of really <font color = red>low</font> suspense, more than <font color = red>six</font> might <font color = red>stipulate</font> from a movie about golf. Sports movies are a <font color = red>fistful</font> a <font color = red>hundred</font>, but this one <font color = red>stood</font> out. <br /><br />This is <font color = red>six</font> I'd <font color = red>prescribe</font> to <font color = red>anybody</font>.
# [Succeeded / Failed / Total] 3 / 0 / 3:  50%|█████     | 4/8 [00:32<00:32,  8.15s/it]
# [Succeeded / Failed / Total] 4 / 0 / 4:  50%|█████     | 4/8 [00:32<00:32,  8.15s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>Bill Paxton has taken the true story of the 1913 US golf open and made a film that is about much more than an extra-ordinary game of golf. The film also deals directly with the class tensions of the early twentieth century and touches upon the profound anti-Catholic prejudices of both the British and American establishments. But at heart the film is about that perennial favourite of triumph against the odds.<br /><br />The acting is exemplary throughout. Stephen Dillane is excellent as usual, but the revelation of the movie is Shia LaBoeuf who delivers a disciplined, dignified and highly sympathetic performance as a working class Franco-Irish kid fighting his way through the prejudices of the New England WASP establishment. For those who are only familiar with his slap-stick performances in "Even Stevens" this demonstration of his maturity is a delightful surprise. And Josh Flitter as the ten year old caddy threatens to steal every scene in which he appears.<br /><br />A old fashioned movie in the best sense of the word: fine acting, clear directing and a great story that grips to the end - the final scene an affectionate nod to Casablanca is just one of the many pleasures that fill a great movie.
# [Succeeded / Failed / Total] 4 / 0 / 4:  62%|██████▎   | 5/8 [00:44<00:26,  8.83s/it]
# [Succeeded / Failed / Total] 4 / 1 / 5:  62%|██████▎   | 5/8 [00:44<00:26,  8.83s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film on September 1st, 2005 in Indianapolis. I am one of the judges for the Heartland Film Festival that screens films for their Truly Moving Picture Award. A Truly Moving Picture "...explores the human journey by artistically expressing hope and respect for the positive values of life." Heartland gave that award to this film.<br /><br />This is a story of golf in the early part of the 20th century. At that time, it was the game of upper class and rich "gentlemen", and working people could only participate by being caddies at country clubs. With this backdrop, this based-on-a-true-story unfolds with a young, working class boy who takes on the golf establishment and the greatest golfer in the world, Harry Vardon.<br /><br />And the story is inspirational. Against all odds, Francis Ouimet (played by Shia LaBeouf of "Holes") gets to compete against the greatest golfers of the U.S. and Great Britain at the 1913 U.S. Open. Francis is ill-prepared, and has a child for a caddy. (The caddy is hilarious and motivational and steals every scene he appears in.) But despite these handicaps, Francis displays courage, spirit, heroism, and humility at this world class event.<br /><br />And, we learn a lot about the early years of golf; for example, the use of small wooden clubs, the layout of the short holes, the manual scoreboard, the golfers swinging with pipes in their mouths, the terrible conditions of the greens and fairways, and the play not being canceled even in torrential rain.<br /><br />This film has stunning cinematography and art direction and editing. And with no big movie stars, the story is somehow more believable.<br /><br />This adds to the inventory of great sports movies in the vein of "Miracle" and "Remember the Titans."<br /><br />FYI - There is a Truly Moving Pictures web site where there is a listing of past winners going back 70 years.
# [Succeeded / Failed / Total] 4 / 1 / 5:  75%|███████▌  | 6/8 [01:03<00:21, 10.51s/it]
# [Succeeded / Failed / Total] 4 / 2 / 6:  75%|███████▌  | 6/8 [01:03<00:21, 10.51s/it]
# <font color = red>Negative (94%)</font> --> <font color = gray>[SKIPPED]</font><br>Maybe I'm reading into this too much, but I wonder how much of a hand Hongsheng had in developing the film. I mean, when a story is told casting the main character as himself, I would think he would be a heavy hand in writing, documenting, etc. and that would make it a little biased.<br /><br />But...his family and friends also may have had a hand in getting the actual details about Hongsheng's life. I think the best view would have been told from Hongsheng's family and friends' perspectives. They saw his transformation and weren't so messed up on drugs that they remember everything.<br /><br />As for Hongsheng being full of himself, the consistencies of the Jesus Christ pose make him appear as a martyr who sacrificed his life (metaphorically, of course, he's obviously still alive as he was cast as himself) for his family's happiness. Huh?<br /><br />The viewer sees him at his lowest points while still maintaining a superiority complex. He lies on the grass coming down from (during?) a high by himself and with his father, he contemplates life and has visions of dragons at his window, he celebrates his freedom on a bicycle all while outstretching his arms, his head cocked to the side.<br /><br />It's fabulous that he's off of drugs now, but he's no hero. He went from a high point in his career in acting to his most vulnerable point while on drugs to come back somewhere in the middle.<br /><br />This same device is used in Ted Demme's "Blow" where the audience empathizes with the main character who is shown as a flawed hero.<br /><br />However, "Quitting" ("Zuotian") is a film that is recommended, mostly for its haunting soundtrack, superb acting, and landscapes. But, the best part is the feeling that one gets when what we presume to be the house of Jia Hongsheng is actually a stage setting for a play. It makes the viewer feel as if Hongsheng's life was merely a play told in many difficult parts.
# [Succeeded / Failed / Total] 4 / 2 / 7:  88%|████████▊ | 7/8 [01:03<00:09,  9.02s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (62%)</font><br>I <font color = green>felt</font> this film did have <font color = green>many</font> good <font color = green>qualities</font>. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I <font color = green>felt</font> most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy <font color = green>sometimes</font> (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.<br>I <font color = red>feared</font> this film did have <font color = red>some</font> good <font color = red>virtues</font>. The cinematography was certainly different exposing the stage aspect of the set and story. The original characters as actors was certainly an achievement and I <font color = red>feared</font> most played quite convincingly, of course they are playing themselves, but definitely unique. The cultural aspects may leave many disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I found the Jia Hongsheng story interesting. On a down note, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really cheesy <font color = red>often</font> (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, check it out.
# [Succeeded / Failed / Total] 4 / 2 / 7: 100%|██████████| 8/8 [01:07<00:00,  8.48s/it]
# [Succeeded / Failed / Total] 5 / 2 / 8: 100%|██████████| 8/8 [01:07<00:00,  8.48s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>This movie is amazing because the fact that the real people portray themselves and their real life experience and do such a good job it's like they're almost living the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna cry because the family especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others might see the movie as boring because it's just so real that its almost like a documentary. Overall this movie is great and Hongsheng deserved an Oscar for this movie so did his Dad.
# [Succeeded / Failed / Total] 5 / 3 / 9: : 9it [01:16,  8.55s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 5      |
# | Number of failed attacks:     | 3      |
# | Number of skipped attacks:    | 1      |
# | Original accuracy:            | 88.89% |
# | Accuracy under attack:        | 33.33% |
# | Attack success rate:          | 62.5%  |
# | Average perturbed word %:     | 7.63%  |
# | Average num. words per input: | 228.44 |
# | Avg num queries:              | 264.38 |
# +-------------------------------+--------+
# textattack: Attack time: 76.92448830604553s

# %%
#glove
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("imdb", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/4ea52f2e58a08dbc12c2bd52d0d92b30b88c00230b4522801b3636782f625c5b)
# textattack: Loading datasets dataset imdb, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/8 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (74%)</font><br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was <font color = green>reluctant</font> to <font color = green>see</font> it because from what I knew of Ashton Kutcher he was only able to do comedy. I was <font color = green>wrong</font>. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = green>good</font> movie is that it can toy with our <font color = green>emotions</font>. This one did exactly that. The entire theater (which was sold out) was overcome by <font color = green>laughter</font> during the first half of the movie, and were moved to tears during the <font color = green>second</font> half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = green>great</font>, and I <font color = green>suggest</font> that you go <font color = green>see</font> it before you judge.<br>I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was <font color = red>obliged</font> to <font color = red>ankaa</font> it because from what I knew of Ashton Kutcher he was only able to do comedy. I was <font color = red>doing</font>. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a <font color = red>benimens</font> movie is that it can toy with our <font color = red>desires</font>. This one did exactly that. The entire theater (which was sold out) was overcome by <font color = red>flees</font> during the first half of the movie, and were moved to tears during the <font color = red>third</font> half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was <font color = red>inaco</font>, and I <font color = red>hypothesize</font> that you go <font color = red>ankaa</font> it before you judge.
#  12%|█▎        | 1/8 [00:05<00:40,  5.79s/it]
# [Succeeded / Failed / Total] 1 / 0 / 1:  12%|█▎        | 1/8 [00:05<00:40,  5.80s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (50%)</font><br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no fan of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was <font color = green>enthralling</font> all the same.<br /><br />The film starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the action moves to the U.S. Open <font color = green>things</font> <font color = green>pick</font> up very <font color = green>well</font>. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also because films in this genre follow the same template over and over, but Paxton puts on a better than average show and perhaps indicates more talent behind the camera than he ever had in front of it. Despite the formulaic nature, this is a nice and easy film to root for that deserves to find an audience.<br>Actor turned director Bill Paxton follows up his promising debut, the Gothic-horror "Frailty", with this family friendly sports drama about the 1913 U.S. Open where a young American caddy rises from his humble background to play against his Bristish idol in what was dubbed as "The Greatest Game Ever Played." I'm no fan of golf, and these scrappy underdog sports flicks are a dime a dozen (most recently done to grand effect with "Miracle" and "Cinderella Man"), but some how this film was <font color = red>dzia</font> all the same.<br /><br />The film starts with some creative opening credits (imagine a Disneyfied version of the animated opening credits of HBO's "Carnivale" and "Rome"), but lumbers along slowly for its first by-the-numbers hour. Once the action moves to the U.S. Open <font color = red>endureth</font> <font color = red>waa</font> up very <font color = red>siehr</font>. Paxton does a nice job and shows a knack for effective directorial flourishes (I loved the rain-soaked montage of the action on day two of the open) that propel the plot further or add some unexpected psychological depth to the proceedings. There's some compelling character development when the British Harry Vardon is haunted by images of the aristocrats in black suits and top hats who destroyed his family cottage as a child to make way for a golf course. He also does a good job of visually depicting what goes on in the players' heads under pressure. Golf, a painfully boring sport, is brought vividly alive here. Credit should also be given the set designers and costume department for creating an engaging period-piece atmosphere of London and Boston at the beginning of the twentieth century.<br /><br />You know how this is going to end not only because it's based on a true story but also  ...
# [Succeeded / Failed / Total] 1 / 0 / 1:  25%|██▌       | 2/8 [00:17<00:52,  8.77s/it]
# [Succeeded / Failed / Total] 2 / 0 / 2:  25%|██▌       | 2/8 [00:17<00:52,  8.78s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>As a recreational golfer with some knowledge of the sport's history, I was pleased with Disney's sensitivity to the issues of class in golf in the early twentieth century. The movie depicted well the psychological battles that Harry Vardon fought within himself, from his childhood trauma of being evicted to his own inability to break that glass ceiling that prevents him from being accepted as an equal in English golf society. Likewise, the young Ouimet goes through his own class struggles, being a mere caddie in the eyes of the upper crust Americans who scoff at his attempts to rise above his standing. <br /><br />What I loved best, however, is how this theme of class is manifested in the characters of Ouimet's parents. His father is a working-class drone who sees the value of hard work but is intimidated by the upper class; his mother, however, recognizes her son's talent and desire and encourages him to pursue his dream of competing against those who think he is inferior.<br /><br />Finally, the golf scenes are well photographed. Although the course used in the movie was not the actual site of the historical tournament, the little liberties taken by Disney do not detract from the beauty of the film. There's one little Disney moment at the pool table; otherwise, the viewer does not really think Disney. The ending, as in "Miracle," is not some Disney creation, but one that only human history could have written.
# [Succeeded / Failed / Total] 2 / 0 / 2:  38%|███▊      | 3/8 [00:34<00:57, 11.50s/it]
# [Succeeded / Failed / Total] 2 / 1 / 3:  38%|███▊      | 3/8 [00:34<00:57, 11.50s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (61%)</font><br>I saw this film in a sneak <font color = green>preview</font>, and it is <font color = green>delightful</font>. The cinematography is unusually <font color = green>creative</font>, the acting is <font color = green>good</font>, and the <font color = green>story</font> is <font color = green>fabulous</font>. If this <font color = green>movie</font> does not do <font color = green>well</font>, it won't be because it doesn't deserve to. Before this film, I didn't realize how <font color = green>charming</font> Shia Lebouf could be. He does a <font color = green>marvelous</font>, self-contained, <font color = green>job</font> as the lead. There's something incredibly <font color = green>sweet</font> about him, and it makes the movie <font color = green>even</font> <font color = green>better</font>. The other actors do a good job as <font color = green>well</font>, and the film contains <font color = green>moments</font> of really high <font color = green>suspense</font>, more than one <font color = green>might</font> expect from a movie about golf. Sports movies are a dime a <font color = green>dozen</font>, but this one <font color = green>stands</font> out. <br /><br />This is <font color = green>one</font> I'd <font color = green>recommend</font> to <font color = green>anyone</font>.<br>I saw this film in a sneak <font color = red>auditing</font>, and it is <font color = red>redder</font>. The cinematography is unusually <font color = red>artistic</font>, the acting is <font color = red>benimens</font>, and the <font color = red>ssres</font> is <font color = red>centralizing</font>. If this <font color = red>film</font> does not do <font color = red>siehr</font>, it won't be because it doesn't deserve to. Before this film, I didn't realize how <font color = red>pedantic</font> Shia Lebouf could be. He does a <font color = red>denouncement</font>, self-contained, <font color = red>henni</font> as the lead. There's something incredibly <font color = red>honey</font> about him, and it makes the movie <font color = red>but</font> <font color = red>eret</font>. The other actors do a good job as <font color = red>siehr</font>, and the film contains <font color = red>memorable</font> of really high <font color = red>dunwich</font>, more than one <font color = red>diplodocids</font> expect from a movie about golf. Sports movies are a dime a <font color = red>hundred</font>, but this one <font color = red>hmkorf</font> out. <br /><br />This is <font color = red>ffffffarm</font> I'd <font color = red>utilize</font> to <font color = red>anybody</font>.
# [Succeeded / Failed / Total] 2 / 1 / 3:  50%|█████     | 4/8 [00:40<00:40, 10.19s/it]
# [Succeeded / Failed / Total] 3 / 1 / 4:  50%|█████     | 4/8 [00:40<00:40, 10.19s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>Bill Paxton has taken the true story of the 1913 US golf open and made a film that is about much more than an extra-ordinary game of golf. The film also deals directly with the class tensions of the early twentieth century and touches upon the profound anti-Catholic prejudices of both the British and American establishments. But at heart the film is about that perennial favourite of triumph against the odds.<br /><br />The acting is exemplary throughout. Stephen Dillane is excellent as usual, but the revelation of the movie is Shia LaBoeuf who delivers a disciplined, dignified and highly sympathetic performance as a working class Franco-Irish kid fighting his way through the prejudices of the New England WASP establishment. For those who are only familiar with his slap-stick performances in "Even Stevens" this demonstration of his maturity is a delightful surprise. And Josh Flitter as the ten year old caddy threatens to steal every scene in which he appears.<br /><br />A old fashioned movie in the best sense of the word: fine acting, clear directing and a great story that grips to the end - the final scene an affectionate nod to Casablanca is just one of the many pleasures that fill a great movie.
# [Succeeded / Failed / Total] 3 / 1 / 4:  62%|██████▎   | 5/8 [00:54<00:32, 10.90s/it]
# [Succeeded / Failed / Total] 3 / 2 / 5:  62%|██████▎   | 5/8 [00:54<00:32, 10.90s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>I saw this film on September 1st, 2005 in Indianapolis. I am one of the judges for the Heartland Film Festival that screens films for their Truly Moving Picture Award. A Truly Moving Picture "...explores the human journey by artistically expressing hope and respect for the positive values of life." Heartland gave that award to this film.<br /><br />This is a story of golf in the early part of the 20th century. At that time, it was the game of upper class and rich "gentlemen", and working people could only participate by being caddies at country clubs. With this backdrop, this based-on-a-true-story unfolds with a young, working class boy who takes on the golf establishment and the greatest golfer in the world, Harry Vardon.<br /><br />And the story is inspirational. Against all odds, Francis Ouimet (played by Shia LaBeouf of "Holes") gets to compete against the greatest golfers of the U.S. and Great Britain at the 1913 U.S. Open. Francis is ill-prepared, and has a child for a caddy. (The caddy is hilarious and motivational and steals every scene he appears in.) But despite these handicaps, Francis displays courage, spirit, heroism, and humility at this world class event.<br /><br />And, we learn a lot about the early years of golf; for example, the use of small wooden clubs, the layout of the short holes, the manual scoreboard, the golfers swinging with pipes in their mouths, the terrible conditions of the greens and fairways, and the play not being canceled even in torrential rain.<br /><br />This film has stunning cinematography and art direction and editing. And with no big movie stars, the story is somehow more believable.<br /><br />This adds to the inventory of great sports movies in the vein of "Miracle" and "Remember the Titans."<br /><br />FYI - There is a Truly Moving Pictures web site where there is a listing of past winners going back 70 years.
# [Succeeded / Failed / Total] 3 / 2 / 5:  75%|███████▌  | 6/8 [01:16<00:25, 12.83s/it]
# [Succeeded / Failed / Total] 3 / 3 / 6:  75%|███████▌  | 6/8 [01:16<00:25, 12.83s/it]
# <font color = red>Negative (94%)</font> --> <font color = gray>[SKIPPED]</font><br>Maybe I'm reading into this too much, but I wonder how much of a hand Hongsheng had in developing the film. I mean, when a story is told casting the main character as himself, I would think he would be a heavy hand in writing, documenting, etc. and that would make it a little biased.<br /><br />But...his family and friends also may have had a hand in getting the actual details about Hongsheng's life. I think the best view would have been told from Hongsheng's family and friends' perspectives. They saw his transformation and weren't so messed up on drugs that they remember everything.<br /><br />As for Hongsheng being full of himself, the consistencies of the Jesus Christ pose make him appear as a martyr who sacrificed his life (metaphorically, of course, he's obviously still alive as he was cast as himself) for his family's happiness. Huh?<br /><br />The viewer sees him at his lowest points while still maintaining a superiority complex. He lies on the grass coming down from (during?) a high by himself and with his father, he contemplates life and has visions of dragons at his window, he celebrates his freedom on a bicycle all while outstretching his arms, his head cocked to the side.<br /><br />It's fabulous that he's off of drugs now, but he's no hero. He went from a high point in his career in acting to his most vulnerable point while on drugs to come back somewhere in the middle.<br /><br />This same device is used in Ted Demme's "Blow" where the audience empathizes with the main character who is shown as a flawed hero.<br /><br />However, "Quitting" ("Zuotian") is a film that is recommended, mostly for its haunting soundtrack, superb acting, and landscapes. But, the best part is the feeling that one gets when what we presume to be the house of Jia Hongsheng is actually a stage setting for a play. It makes the viewer feel as if Hongsheng's life was merely a play told in many difficult parts.
# [Succeeded / Failed / Total] 3 / 3 / 7:  88%|████████▊ | 7/8 [01:17<00:11, 11.01s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (66%)</font><br>I <font color = green>felt</font> this <font color = green>film</font> did have <font color = green>many</font> good qualities. The <font color = green>cinematography</font> was <font color = green>certainly</font> different <font color = green>exposing</font> the <font color = green>stage</font> aspect of the set and story. The original <font color = green>characters</font> as <font color = green>actors</font> was certainly an <font color = green>achievement</font> and I felt most played quite convincingly, of <font color = green>course</font> they are playing themselves, but definitely unique. The cultural aspects <font color = green>may</font> <font color = green>leave</font> <font color = green>many</font> disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I <font color = green>found</font> the Jia Hongsheng story interesting. On a down <font color = green>note</font>, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really <font color = green>cheesy</font> <font color = green>sometimes</font> (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, <font color = green>check</font> it out.<br>I <font color = red>convinced</font> this <font color = red>remodernist</font> did have <font color = red>multiperforata</font> good qualities. The <font color = red>choreography</font> was <font color = red>smalleiffel</font> different <font color = red>issuing</font> the <font color = red>larval</font> aspect of the set and story. The original <font color = red>character</font> as <font color = red>actresses</font> was certainly an <font color = red>lifetime</font> and I felt most played quite convincingly, of <font color = red>armyworm</font> they are playing themselves, but definitely unique. The cultural aspects <font color = red>can</font> <font color = red>flatline</font> <font color = red>multiperforata</font> disappointed as a familiarity with the Chinese and Oriental culture will answer a lot of questions regarding parent/child relationships and the stigma that goes with any drug use. I <font color = red>noluisse</font> the Jia Hongsheng story interesting. On a down <font color = red>example</font>, the story is in Beijing and some of the fashion and music reek of early 90s even though this was made in 2001, so it's really <font color = red>ramad</font> <font color = red>often</font> (the Beatles crap, etc). Whatever, not a top ten or twenty but if it's on the television, <font color = red>spell</font> it out.
# [Succeeded / Failed / Total] 3 / 3 / 7: 100%|██████████| 8/8 [01:23<00:00, 10.48s/it]
# [Succeeded / Failed / Total] 4 / 3 / 8: 100%|██████████| 8/8 [01:23<00:00, 10.48s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (65%)</font><br>This movie is <font color = green>amazing</font> because the fact that the <font color = green>real</font> people portray themselves and their <font color = green>real</font> life experience and do such a <font color = green>good</font> job it's like they're <font color = green>almost</font> <font color = green>living</font> the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna <font color = green>cry</font> because the <font color = green>family</font> especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others <font color = green>might</font> <font color = green>see</font> the movie as <font color = green>boring</font> because it's just so <font color = green>real</font> that its <font color = green>almost</font> <font color = green>like</font> a documentary. Overall this movie is <font color = green>great</font> and Hongsheng deserved an Oscar for this movie so did his Dad.<br>This movie is <font color = red>autobiography</font> because the fact that the <font color = red>numbers</font> people portray themselves and their <font color = red>numbers</font> life experience and do such a <font color = red>benimens</font> job it's like they're <font color = red>nearly</font> <font color = red>amebic</font> the past over again. Jia Hongsheng plays himself an actor who quit everything except music and drugs struggling with depression and searching for the meaning of life while being angry at everyone especially the people who care for him most. There's moments in the movie that will make you wanna <font color = red>fuck</font> because the <font color = red>pantolambdodontidae</font> especially the father did such a good job. However, this movie is not for everyone. Many people who suffer from depression will understand Hongsheng's problem and why he does the things he does for example keep himself shut in a dark room or go for walks or bike rides by himself. Others <font color = red>diplodocids</font> <font color = red>ankaa</font> the movie as <font color = red>trap</font> because it's just so <font color = red>numbers</font> that its <font color = red>nearly</font> <font color = red>bitterling</font> a documentary. Overall this movie is <font color = red>inaco</font> and Hongsheng deserved an Oscar for this movie so did his Dad.
# [Succeeded / Failed / Total] 5 / 3 / 9: : 9it [01:31, 10.18s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 5      |
# | Number of failed attacks:     | 3      |
# | Number of skipped attacks:    | 1      |
# | Original accuracy:            | 88.89% |
# | Accuracy under attack:        | 33.33% |
# | Attack success rate:          | 62.5%  |
# | Average perturbed word %:     | 9.71%  |
# | Average num. words per input: | 228.44 |
# | Avg num queries:              | 271.5  |
# +-------------------------------+--------+
# textattack: Attack time: 91.58479332923889s

# %%
model = transformers.AutoModelForSequenceClassification.from_pretrained("textattack/roberta-base-rotten-tomatoes")
tokenizer = AutoTokenizer("textattack/roberta-base-rotten-tomatoes")

model_wrapper = HuggingFaceModelWrapper(model, tokenizer)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=535.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=501003010.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at textattack/roberta-base-rotten-tomatoes were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=798293.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456356.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=150.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=25.0, style=ProgressStyle(description_w…

# %%
#Fasttext
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("rotten_tomatoes", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1860.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=869.0, style=ProgressStyle(description_…
# Using custom data configuration default
# Downloading and preparing dataset rotten_tomatoes_movie_review/default (download: 476.34 KiB, generated: 1.28 MiB, post-processed: Unknown size, total: 1.75 MiB) to /root/.cache/huggingface/datasets/rotten_tomatoes_movie_review/default/1.0.0/9c411f7ecd9f3045389de0d9ce984061a1056507703d2e3183b1ac1a90816e4d...
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=487770.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# textattack: Loading datasets dataset rotten_tomatoes, split test.
# Dataset rotten_tomatoes_movie_review downloaded and prepared to /root/.cache/huggingface/datasets/rotten_tomatoes_movie_review/default/1.0.0/9c411f7ecd9f3045389de0d9ce984061a1056507703d2e3183b1ac1a90816e4d. Subsequent calls will reuse this data.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (59%)</font><br>lovingly photographed <font color = green>in</font> the manner of a golden book sprung to life , <font color = green>stuart</font> little 2 <font color = green>manages</font> sweetness largely without stickiness .<br>lovingly photographed <font color = red>of</font> the manner of a golden book sprung to life , <font color = red>dudley</font> little 2 <font color = red>manage</font> sweetness largely without stickiness .
#  10%|█         | 1/10 [00:02<00:19,  2.12s/it]
#
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:02<00:19,  2.13s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>consistently clever and suspenseful .
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:02<00:10,  1.31s/it]
#
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:02<00:10,  1.31s/it]
# <font color = red>Negative (92%)</font> --> <font color = gray>[SKIPPED]</font><br>it's like a " big chill " reunion of the baader-meinhof gang , only these guys are more harmless pranksters than political activists .
# [Succeeded / Failed / Total] 1 / 1 / 3:  30%|███       | 3/10 [00:02<00:06,  1.13it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (57%)</font><br>the story <font color = green>gives</font> ample opportunity for <font color = green>large-scale</font> <font color = green>action</font> and <font color = green>suspense</font> , which director shekhar kapur <font color = green>supplies</font> with <font color = green>tremendous</font> <font color = green>skill</font> .<br>the story <font color = red>gave</font> ample opportunity for <font color = red>largescale</font> <font color = red>cessation</font> and <font color = red>suspension</font> , which director shekhar kapur <font color = red>supply</font> with <font color = red>stupendous</font> <font color = red>skilful</font> .
# [Succeeded / Failed / Total] 1 / 1 / 3:  40%|████      | 4/10 [00:10<00:15,  2.56s/it]
#
# [Succeeded / Failed / Total] 2 / 1 / 4:  40%|████      | 4/10 [00:10<00:15,  2.56s/it]
# <font color = green>Positive (88%)</font> --> <font color = red>Negative (99%)</font><br>red dragon " never cuts <font color = green>corners</font> .<br>red dragon " never cuts <font color = red>corner</font> .
# [Succeeded / Failed / Total] 3 / 1 / 5:  50%|█████     | 5/10 [00:10<00:10,  2.08s/it]
# <font color = green>Positive (91%)</font> --> <font color = red>Negative (52%)</font><br>fresnadillo <font color = green>has</font> something serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense .<br>fresnadillo <font color = red>had</font> something serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense .
# [Succeeded / Failed / Total] 3 / 1 / 5:  60%|██████    | 6/10 [00:10<00:07,  1.83s/it]
#
# [Succeeded / Failed / Total] 4 / 1 / 6:  60%|██████    | 6/10 [00:11<00:07,  1.83s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (77%)</font><br><font color = green>throws</font> in enough clever and <font color = green>unexpected</font> twists to make the formula feel <font color = green>fresh</font> .<br><font color = red>throw</font> in enough clever and <font color = red>unexposed</font> twists to make the formula feel <font color = red>vegetable</font> .
# [Succeeded / Failed / Total] 5 / 1 / 7:  70%|███████   | 7/10 [00:12<00:05,  1.74s/it]
# <font color = red>Negative (54%)</font> --> <font color = gray>[SKIPPED]</font><br>weighty and ponderous but every bit as filling as the treat of the title .
# [Succeeded / Failed / Total] 5 / 1 / 7:  80%|████████  | 8/10 [00:12<00:03,  1.53s/it]
#
# [Succeeded / Failed / Total] 5 / 1 / 8:  80%|████████  | 8/10 [00:12<00:03,  1.53s/it]
# <font color = green>Positive (99%)</font> --> <font color = red>Negative (73%)</font><br><font color = green>a</font> <font color = green>real</font> audience-pleaser that <font color = green>will</font> strike a chord with anyone who's ever waited in a doctor's office , emergency room , <font color = green>hospital</font> bed or <font color = green>insurance</font> company office .<br><font color = red>the</font> <font color = red>imaginary</font> audience-pleaser that <font color = red>would</font> strike a chord with anyone who's ever waited in a doctor's office , emergency room , <font color = red>hospice</font> bed or <font color = red>insure</font> company office .
# [Succeeded / Failed / Total] 6 / 1 / 9:  90%|█████████ | 9/10 [00:21<00:02,  2.36s/it]
# <font color = green>Positive (99%)</font> --> <font color = red>Negative (98%)</font><br>generates an enormous feeling of <font color = green>empathy</font> for its characters .<br>generates an enormous feeling of <font color = red>apathy</font> for its characters .
# [Succeeded / Failed / Total] 6 / 1 / 9: 100%|██████████| 10/10 [00:21<00:00,  2.14s/it]
#
# [Succeeded / Failed / Total] 7 / 1 / 10: 100%|██████████| 10/10 [00:21<00:00,  2.14s/it]
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (82%)</font><br><font color = green>exposing</font> the <font color = green>ways</font> we fool ourselves is <font color = green>one</font> hour <font color = green>photo's</font> <font color = green>real</font> <font color = green>strength</font> .<br><font color = red>alluding</font> the <font color = red>way</font> we fool ourselves is <font color = red>nine</font> hour <font color = red>photo</font> <font color = red>unimaginable</font> <font color = red>toughness</font> .
# [Succeeded / Failed / Total] 8 / 1 / 11: : 11it [00:24,  2.23s/it]
# <font color = green>Positive (80%)</font> --> <font color = red>Negative (80%)</font><br><font color = green>it's</font> up to you to decide whether to admire these people's dedication to their cause or be repelled by their dogmatism , manipulativeness and narrow , <font color = green>fearful</font> view of <font color = green>american</font> life .<br><font color = red>itn</font> up to you to decide whether to admire these people's dedication to their cause or be repelled by their dogmatism , manipulativeness and narrow , <font color = red>dreadful</font> view of <font color = red>rican</font> life .
# [Succeeded / Failed / Total] 8 / 1 / 11: : 12it [00:28,  2.41s/it]
#
# [Succeeded / Failed / Total] 9 / 1 / 12: : 12it [00:28,  2.41s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 9      |
# | Number of failed attacks:     | 1      |
# | Number of skipped attacks:    | 2      |
# | Original accuracy:            | 83.33% |
# | Accuracy under attack:        | 8.33%  |
# | Attack success rate:          | 90.0%  |
# | Average perturbed word %:     | 21.36% |
# | Average num. words per input: | 16.25  |
# | Avg num queries:              | 152.5  |
# +-------------------------------+--------+
# textattack: Attack time: 28.972859621047974s

# %%
#Word2vec
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("rotten_tomatoes", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset rotten_tomatoes_movie_review (/root/.cache/huggingface/datasets/rotten_tomatoes_movie_review/default/1.0.0/9c411f7ecd9f3045389de0d9ce984061a1056507703d2e3183b1ac1a90816e4d)
# textattack: Loading datasets dataset rotten_tomatoes, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (68%)</font><br>lovingly <font color = green>photographed</font> in the manner of a <font color = green>golden</font> <font color = green>book</font> sprung to life , stuart little 2 manages <font color = green>sweetness</font> <font color = green>largely</font> without stickiness .<br>lovingly <font color = red>greeted</font> in the manner of a <font color = red>fleece</font> <font color = red>memoir</font> sprung to life , stuart little 2 manages <font color = red>ripening</font> <font color = red>mostly</font> without stickiness .
#  10%|█         | 1/10 [00:04<00:40,  4.52s/it]
#
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:04<00:40,  4.53s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>consistently clever and suspenseful .
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:04<00:19,  2.39s/it]
#
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:04<00:19,  2.39s/it]
# <font color = red>Negative (92%)</font> --> <font color = gray>[SKIPPED]</font><br>it's like a " big chill " reunion of the baader-meinhof gang , only these guys are more harmless pranksters than political activists .
# [Succeeded / Failed / Total] 1 / 1 / 3:  30%|███       | 3/10 [00:04<00:11,  1.61s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (87%)</font><br>the story gives <font color = green>ample</font> opportunity for large-scale action and suspense , which director shekhar kapur supplies with tremendous skill .<br>the story gives <font color = red>insufficient</font> opportunity for large-scale action and suspense , which director shekhar kapur supplies with tremendous skill .
# [Succeeded / Failed / Total] 1 / 1 / 3:  40%|████      | 4/10 [00:05<00:07,  1.28s/it]
#
# [Succeeded / Failed / Total] 2 / 1 / 4:  40%|████      | 4/10 [00:05<00:07,  1.28s/it]
# <font color = green>Positive (88%)</font> --> <font color = red>Negative (99%)</font><br>red dragon " <font color = green>never</font> cuts corners .<br>red dragon " <font color = red>already</font> cuts corners .
# [Succeeded / Failed / Total] 3 / 1 / 5:  50%|█████     | 5/10 [00:05<00:05,  1.05s/it]
# <font color = green>Positive (91%)</font> --> <font color = red>Negative (97%)</font><br>fresnadillo has <font color = green>something</font> serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense .<br>fresnadillo has <font color = red>anything</font> serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense .
# [Succeeded / Failed / Total] 3 / 1 / 5:  60%|██████    | 6/10 [00:05<00:03,  1.04it/s]
#
# [Succeeded / Failed / Total] 4 / 1 / 6:  60%|██████    | 6/10 [00:05<00:03,  1.04it/s]
# <font color = green>Positive (98%)</font> --> <font color = red>[FAILED]</font><br>throws in enough clever and unexpected twists to make the formula feel fresh .
# [Succeeded / Failed / Total] 4 / 2 / 7:  70%|███████   | 7/10 [00:10<00:04,  1.45s/it]
# <font color = red>Negative (54%)</font> --> <font color = gray>[SKIPPED]</font><br>weighty and ponderous but every bit as filling as the treat of the title .
# [Succeeded / Failed / Total] 4 / 2 / 7:  80%|████████  | 8/10 [00:10<00:02,  1.28s/it]
#
# [Succeeded / Failed / Total] 4 / 2 / 8:  80%|████████  | 8/10 [00:10<00:02,  1.28s/it]
#
# [Succeeded / Failed / Total] 4 / 2 / 8:  80%|████████  | 8/10 [00:24<00:06,  3.02s/it]
# <font color = green>Positive (99%)</font> --> <font color = red>Negative (54%)</font><br>a <font color = green>real</font> audience-pleaser <font color = green>that</font> <font color = green>will</font> <font color = green>strike</font> a <font color = green>chord</font> with <font color = green>anyone</font> who's ever waited in a doctor's <font color = green>office</font> , emergency room , <font color = green>hospital</font> bed or <font color = green>insurance</font> company <font color = green>office</font> .<br>a <font color = red>nonnegative</font> audience-pleaser <font color = red>which</font> <font color = red>would</font> <font color = red>downed</font> a <font color = red>flatted</font> with <font color = red>anybody</font> who's ever waited in a doctor's <font color = red>portfolio</font> , emergency room , <font color = red>deaconess</font> bed or <font color = red>liability</font> company <font color = red>portfolio</font> .
# [Succeeded / Failed / Total] 4 / 2 / 8:  90%|█████████ | 9/10 [00:25<00:02,  2.82s/it]
#
# [Succeeded / Failed / Total] 5 / 2 / 9:  90%|█████████ | 9/10 [00:25<00:02,  2.82s/it]
# <font color = green>Positive (99%)</font> --> <font color = red>Negative (92%)</font><br>generates an enormous <font color = green>feeling</font> of empathy for its characters .<br>generates an enormous <font color = red>unhappiness</font> of empathy for its characters .
# [Succeeded / Failed / Total] 5 / 2 / 9: 100%|██████████| 10/10 [00:25<00:00,  2.60s/it]
#
# [Succeeded / Failed / Total] 6 / 2 / 10: 100%|██████████| 10/10 [00:25<00:00,  2.60s/it]
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (89%)</font><br><font color = green>exposing</font> the <font color = green>ways</font> we fool ourselves <font color = green>is</font> <font color = green>one</font> <font color = green>hour</font> photo's <font color = green>real</font> <font color = green>strength</font> .<br><font color = red>evoking</font> the <font color = red>thing</font> we fool ourselves <font color = red>was</font> <font color = red>six</font> <font color = red>seconds</font> photo's <font color = red>nonnegative</font> <font color = red>maneuverability</font> .
# [Succeeded / Failed / Total] 6 / 2 / 10: : 11it [00:29,  2.68s/it]
#
# [Succeeded / Failed / Total] 7 / 2 / 11: : 11it [00:29,  2.68s/it]
# <font color = green>Positive (80%)</font> --> <font color = red>Negative (61%)</font><br>it's up to <font color = green>you</font> to <font color = green>decide</font> whether to <font color = green>admire</font> these people's dedication to <font color = green>their</font> cause <font color = green>or</font> be repelled by their dogmatism , manipulativeness and narrow , fearful view of american life .<br>it's up to <font color = red>we</font> to <font color = red>instruct</font> whether to <font color = red>reconsider</font> these people's dedication to <font color = red>its</font> cause <font color = red>either</font> be repelled by their dogmatism , manipulativeness and narrow , fearful view of american life .
# [Succeeded / Failed / Total] 7 / 2 / 11: : 12it [00:38,  3.19s/it]
#
# [Succeeded / Failed / Total] 8 / 2 / 12: : 12it [00:38,  3.20s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 8      |
# | Number of failed attacks:     | 2      |
# | Number of skipped attacks:    | 2      |
# | Original accuracy:            | 83.33% |
# | Accuracy under attack:        | 16.67% |
# | Attack success rate:          | 80.0%  |
# | Average perturbed word %:     | 22.64% |
# | Average num. words per input: | 16.25  |
# | Avg num queries:              | 207.3  |
# +-------------------------------+--------+
# textattack: Attack time: 38.356719970703125s

# %%
#glove
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("rotten_tomatoes", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1860.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=869.0, style=ProgressStyle(description_…
# Using custom data configuration default
# Downloading and preparing dataset rotten_tomatoes_movie_review/default (download: 476.34 KiB, generated: 1.28 MiB, post-processed: Unknown size, total: 1.75 MiB) to /root/.cache/huggingface/datasets/rotten_tomatoes_movie_review/default/1.0.0/9c411f7ecd9f3045389de0d9ce984061a1056507703d2e3183b1ac1a90816e4d...
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=487770.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# textattack: Loading datasets dataset rotten_tomatoes, split test.
# Dataset rotten_tomatoes_movie_review downloaded and prepared to /root/.cache/huggingface/datasets/rotten_tomatoes_movie_review/default/1.0.0/9c411f7ecd9f3045389de0d9ce984061a1056507703d2e3183b1ac1a90816e4d. Subsequent calls will reuse this data.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (57%)</font><br>lovingly photographed in the manner of a <font color = green>golden</font> book sprung to life , stuart little 2 <font color = green>manages</font> sweetness largely without stickiness .<br>lovingly photographed in the manner of a <font color = red>rhynchostruthus</font> book sprung to life , stuart little 2 <font color = red>vowed</font> sweetness largely without stickiness .
#  10%|█         | 1/10 [00:02<00:25,  2.85s/it]
#
#
#
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:02<00:25,  2.86s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>consistently clever and suspenseful .
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:03<00:14,  1.85s/it]
#
#
#
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:03<00:14,  1.85s/it]
# <font color = red>Negative (92%)</font> --> <font color = gray>[SKIPPED]</font><br>it's like a " big chill " reunion of the baader-meinhof gang , only these guys are more harmless pranksters than political activists .
# [Succeeded / Failed / Total] 1 / 1 / 3:  30%|███       | 3/10 [00:03<00:08,  1.24s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (55%)</font><br>the story gives ample opportunity for large-scale action and <font color = green>suspense</font> , which director shekhar kapur <font color = green>supplies</font> with tremendous skill .<br>the story gives ample opportunity for large-scale action and <font color = red>dunwich</font> , which director shekhar kapur <font color = red>inadequate</font> with tremendous skill .
# [Succeeded / Failed / Total] 1 / 1 / 3:  40%|████      | 4/10 [00:06<00:09,  1.54s/it]
#
#
#
# [Succeeded / Failed / Total] 2 / 1 / 4:  40%|████      | 4/10 [00:06<00:09,  1.54s/it]
# <font color = green>Positive (88%)</font> --> <font color = red>Negative (99%)</font><br>red dragon " never <font color = green>cuts</font> corners .<br>red dragon " never <font color = red>profits</font> corners .
# [Succeeded / Failed / Total] 3 / 1 / 5:  50%|█████     | 5/10 [00:06<00:06,  1.28s/it]
# <font color = green>Positive (91%)</font> --> <font color = red>Negative (97%)</font><br>fresnadillo has <font color = green>something</font> serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense .<br>fresnadillo has <font color = red>anything</font> serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense .
# [Succeeded / Failed / Total] 3 / 1 / 5:  60%|██████    | 6/10 [00:07<00:04,  1.20s/it]
#
#
#
# [Succeeded / Failed / Total] 4 / 1 / 6:  60%|██████    | 6/10 [00:07<00:04,  1.20s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (59%)</font><br><font color = green>throws</font> in enough clever and <font color = green>unexpected</font> <font color = green>twists</font> to make the formula feel fresh .<br><font color = red>throw</font> in enough clever and <font color = red>repeated</font> <font color = red>dumfries</font> to make the formula feel fresh .
# [Succeeded / Failed / Total] 5 / 1 / 7:  70%|███████   | 7/10 [00:08<00:03,  1.26s/it]
# <font color = red>Negative (54%)</font> --> <font color = gray>[SKIPPED]</font><br>weighty and ponderous but every bit as filling as the treat of the title .
# [Succeeded / Failed / Total] 5 / 1 / 7:  80%|████████  | 8/10 [00:08<00:02,  1.11s/it]
#
#
#
# [Succeeded / Failed / Total] 5 / 1 / 8:  80%|████████  | 8/10 [00:08<00:02,  1.11s/it]
#
#
#
# [Succeeded / Failed / Total] 5 / 1 / 8:  80%|████████  | 8/10 [00:27<00:06,  3.45s/it]
# <font color = green>Positive (99%)</font> --> <font color = red>[FAILED]</font><br>a real audience-pleaser that will strike a chord with anyone who's ever waited in a doctor's office , emergency room , hospital bed or insurance company office .
# [Succeeded / Failed / Total] 5 / 1 / 8:  90%|█████████ | 9/10 [00:42<00:04,  4.75s/it]
#
#
#
# [Succeeded / Failed / Total] 5 / 2 / 9:  90%|█████████ | 9/10 [00:42<00:04,  4.75s/it]
# <font color = green>Positive (99%)</font> --> <font color = red>Negative (73%)</font><br>generates an enormous <font color = green>feeling</font> of <font color = green>empathy</font> for its characters .<br>generates an enormous <font color = red>fear</font> of <font color = red>decompression</font> for its characters .
# [Succeeded / Failed / Total] 5 / 2 / 9: 100%|██████████| 10/10 [00:43<00:00,  4.36s/it]
#
#
#
# [Succeeded / Failed / Total] 6 / 2 / 10: 100%|██████████| 10/10 [00:43<00:00,  4.36s/it]
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (68%)</font><br><font color = green>exposing</font> the ways <font color = green>we</font> fool ourselves <font color = green>is</font> one <font color = green>hour</font> photo's real <font color = green>strength</font> .<br><font color = red>issuing</font> the ways <font color = red>you</font> fool ourselves <font color = red>polylogarithm</font> one <font color = red>minutes</font> photo's real <font color = red>tensile</font> .
# [Succeeded / Failed / Total] 6 / 2 / 10: : 11it [00:47,  4.29s/it]
#
#
#
# [Succeeded / Failed / Total] 7 / 2 / 11: : 11it [00:47,  4.29s/it]
# <font color = green>Positive (80%)</font> --> <font color = red>Negative (59%)</font><br>it's up to you to decide whether to <font color = green>admire</font> these people's dedication to their cause or be repelled by their dogmatism , manipulativeness and narrow , fearful <font color = green>view</font> of american life .<br>it's up to you to decide whether to <font color = red>drown</font> these people's dedication to their cause or be repelled by their dogmatism , manipulativeness and narrow , fearful <font color = red>cheltonians</font> of american life .
# [Succeeded / Failed / Total] 7 / 2 / 11: : 12it [00:48,  4.01s/it]
#
#
#
# [Succeeded / Failed / Total] 8 / 2 / 12: : 12it [00:48,  4.01s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 8      |
# | Number of failed attacks:     | 2      |
# | Number of skipped attacks:    | 2      |
# | Original accuracy:            | 83.33% |
# | Accuracy under attack:        | 16.67% |
# | Attack success rate:          | 80.0%  |
# | Average perturbed word %:     | 17.35% |
# | Average num. words per input: | 16.25  |
# | Avg num queries:              | 122.7  |
# +-------------------------------+--------+
# textattack: Attack time: 48.096123456954956s

# %%
#fasttext
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("rotten_tomatoes", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset rotten_tomatoes_movie_review (/root/.cache/huggingface/datasets/rotten_tomatoes_movie_review/default/1.0.0/9c411f7ecd9f3045389de0d9ce984061a1056507703d2e3183b1ac1a90816e4d)
# textattack: Loading datasets dataset rotten_tomatoes, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (51%)</font><br><font color = green>lovingly</font> photographed in the manner of a <font color = green>golden</font> book sprung to life , stuart little 2 <font color = green>manages</font> <font color = green>sweetness</font> largely without stickiness .<br><font color = red>kingly</font> photographed in the manner of a <font color = red>olden</font> book sprung to life , stuart little 2 <font color = red>manage</font> <font color = red>softness</font> largely without stickiness .
#  10%|█         | 1/10 [00:00<00:04,  2.12it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:04,  2.09it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>consistently clever and suspenseful .
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:00<00:02,  3.29it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:00<00:02,  3.26it/s]
# <font color = red>Negative (92%)</font> --> <font color = gray>[SKIPPED]</font><br>it's like a " big chill " reunion of the baader-meinhof gang , only these guys are more harmless pranksters than political activists .
# [Succeeded / Failed / Total] 1 / 1 / 3:  30%|███       | 3/10 [00:00<00:01,  4.67it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (70%)</font><br>the story <font color = green>gives</font> ample <font color = green>opportunity</font> for large-scale <font color = green>action</font> and <font color = green>suspense</font> , <font color = green>which</font> director <font color = green>shekhar</font> kapur <font color = green>supplies</font> with <font color = green>tremendous</font> <font color = green>skill</font> .<br>the story <font color = red>gave</font> ample <font color = red>opportune</font> for large-scale <font color = red>cessation</font> and <font color = red>suspension</font> , <font color = red>that</font> director <font color = red>dzhokhar</font> kapur <font color = red>supply</font> with <font color = red>stupendous</font> <font color = red>skilful</font> .
# [Succeeded / Failed / Total] 1 / 1 / 3:  40%|████      | 4/10 [00:01<00:01,  3.39it/s]
#
#
#
# [Succeeded / Failed / Total] 2 / 1 / 4:  40%|████      | 4/10 [00:01<00:01,  3.37it/s]
# <font color = green>Positive (88%)</font> --> <font color = red>Negative (99%)</font><br>red dragon " never cuts <font color = green>corners</font> .<br>red dragon " never cuts <font color = red>corner</font> .
# [Succeeded / Failed / Total] 3 / 1 / 5:  50%|█████     | 5/10 [00:01<00:01,  3.84it/s]
# <font color = green>Positive (91%)</font> --> <font color = red>Negative (72%)</font><br>fresnadillo has something serious to say <font color = green>about</font> the <font color = green>ways</font> in which extravagant chance <font color = green>can</font> distort <font color = green>our</font> perspective and throw us off the path of good sense .<br>fresnadillo has something serious to say <font color = red>abound</font> the <font color = red>way</font> in which extravagant chance <font color = red>could</font> distort <font color = red>my</font> perspective and throw us off the path of good sense .
# [Succeeded / Failed / Total] 3 / 1 / 5:  60%|██████    | 6/10 [00:01<00:01,  3.28it/s]
#
#
#
# [Succeeded / Failed / Total] 4 / 1 / 6:  60%|██████    | 6/10 [00:01<00:01,  3.26it/s]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (55%)</font><br><font color = green>throws</font> in enough <font color = green>clever</font> and unexpected twists to make the formula feel <font color = green>fresh</font> .<br><font color = red>throw</font> in enough <font color = red>cleve</font> and unexpected twists to make the formula feel <font color = red>vegetable</font> .
# [Succeeded / Failed / Total] 5 / 1 / 7:  70%|███████   | 7/10 [00:02<00:00,  3.29it/s]
# <font color = red>Negative (54%)</font> --> <font color = gray>[SKIPPED]</font><br>weighty and ponderous but every bit as filling as the treat of the title .
# [Succeeded / Failed / Total] 5 / 1 / 7:  80%|████████  | 8/10 [00:02<00:00,  3.70it/s]
#
#
#
# [Succeeded / Failed / Total] 5 / 1 / 8:  80%|████████  | 8/10 [00:02<00:00,  3.69it/s]
# <font color = green>Positive (99%)</font> --> <font color = red>[FAILED]</font><br>a real audience-pleaser that will strike a chord with anyone who's ever waited in a doctor's office , emergency room , hospital bed or insurance company office .
# [Succeeded / Failed / Total] 5 / 2 / 9:  90%|█████████ | 9/10 [00:03<00:00,  2.88it/s]
# <font color = green>Positive (99%)</font> --> <font color = red>Negative (98%)</font><br>generates an enormous feeling of <font color = green>empathy</font> for its <font color = green>characters</font> .<br>generates an enormous feeling of <font color = red>apathy</font> for its <font color = red>character</font> .
# [Succeeded / Failed / Total] 5 / 2 / 9: 100%|██████████| 10/10 [00:03<00:00,  3.00it/s]
#
#
#
# [Succeeded / Failed / Total] 6 / 2 / 10: 100%|██████████| 10/10 [00:03<00:00,  2.99it/s]
# <font color = green>Positive (97%)</font> --> <font color = red>[FAILED]</font><br>exposing the ways we fool ourselves is one hour photo's real strength .
# [Succeeded / Failed / Total] 6 / 3 / 11: : 11it [00:03,  2.90it/s]
# <font color = green>Positive (80%)</font> --> <font color = red>Negative (77%)</font><br><font color = green>it's</font> up to you to decide whether to admire these people's dedication to their cause or be <font color = green>repelled</font> by their dogmatism , manipulativeness and narrow , <font color = green>fearful</font> view of american life .<br><font color = red>itn</font> up to you to decide whether to admire these people's dedication to their cause or be <font color = red>dispelled</font> by their dogmatism , manipulativeness and narrow , <font color = red>dreadful</font> view of american life .
# [Succeeded / Failed / Total] 6 / 3 / 11: : 12it [00:04,  2.76it/s]
#
#
#
# [Succeeded / Failed / Total] 7 / 3 / 12: : 12it [00:04,  2.75it/s]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 7      |
# | Number of failed attacks:     | 3      |
# | Number of skipped attacks:    | 2      |
# | Original accuracy:            | 83.33% |
# | Accuracy under attack:        | 25.0%  |
# | Attack success rate:          | 70.0%  |
# | Average perturbed word %:     | 23.0%  |
# | Average num. words per input: | 16.25  |
# | Avg num queries:              | 23.3   |
# +-------------------------------+--------+
# textattack: Attack time: 4.364678382873535s

# %%
#word2vec
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("rotten_tomatoes", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset rotten_tomatoes_movie_review (/root/.cache/huggingface/datasets/rotten_tomatoes_movie_review/default/1.0.0/9c411f7ecd9f3045389de0d9ce984061a1056507703d2e3183b1ac1a90816e4d)
# textattack: Loading datasets dataset rotten_tomatoes, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (54%)</font><br>lovingly <font color = green>photographed</font> in the manner of a <font color = green>golden</font> <font color = green>book</font> sprung to <font color = green>life</font> , stuart little 2 manages <font color = green>sweetness</font> largely without stickiness .<br>lovingly <font color = red>greeted</font> in the manner of a <font color = red>fleece</font> <font color = red>memoir</font> sprung to <font color = red>lives</font> , stuart little 2 manages <font color = red>ripening</font> largely without stickiness .
#  10%|█         | 1/10 [00:00<00:04,  1.80it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:05,  1.79it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>consistently clever and suspenseful .
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:00<00:02,  2.87it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:00<00:02,  2.84it/s]
# <font color = red>Negative (92%)</font> --> <font color = gray>[SKIPPED]</font><br>it's like a " big chill " reunion of the baader-meinhof gang , only these guys are more harmless pranksters than political activists .
# [Succeeded / Failed / Total] 1 / 1 / 3:  30%|███       | 3/10 [00:00<00:01,  4.12it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (96%)</font><br>the story <font color = green>gives</font> <font color = green>ample</font> <font color = green>opportunity</font> for large-scale action and <font color = green>suspense</font> , <font color = green>which</font> director shekhar kapur <font color = green>supplies</font> with <font color = green>tremendous</font> skill .<br>the story <font color = red>gave</font> <font color = red>insufficient</font> <font color = red>incentive</font> for large-scale action and <font color = red>thrillers</font> , <font color = red>that</font> director shekhar kapur <font color = red>supply</font> with <font color = red>considerable</font> skill .
# [Succeeded / Failed / Total] 1 / 1 / 3:  40%|████      | 4/10 [00:01<00:01,  3.26it/s]
#
#
#
# [Succeeded / Failed / Total] 2 / 1 / 4:  40%|████      | 4/10 [00:01<00:01,  3.25it/s]
# <font color = green>Positive (88%)</font> --> <font color = red>Negative (98%)</font><br>red dragon " never cuts <font color = green>corners</font> .<br>red dragon " never cuts <font color = red>edges</font> .
# [Succeeded / Failed / Total] 3 / 1 / 5:  50%|█████     | 5/10 [00:01<00:01,  3.70it/s]
# <font color = green>Positive (91%)</font> --> <font color = red>Negative (57%)</font><br>fresnadillo has something <font color = green>serious</font> to say about the <font color = green>ways</font> in which extravagant chance can distort <font color = green>our</font> perspective and throw us off the <font color = green>path</font> of good sense .<br>fresnadillo has something <font color = red>severe</font> to say about the <font color = red>way</font> in which extravagant chance can distort <font color = red>my</font> perspective and throw us off the <font color = red>eightfold</font> of good sense .
# [Succeeded / Failed / Total] 3 / 1 / 5:  60%|██████    | 6/10 [00:01<00:01,  3.22it/s]
#
#
#
# [Succeeded / Failed / Total] 4 / 1 / 6:  60%|██████    | 6/10 [00:01<00:01,  3.20it/s]
# <font color = green>Positive (98%)</font> --> <font color = red>[FAILED]</font><br>throws in enough clever and unexpected twists to make the formula feel fresh .
# [Succeeded / Failed / Total] 4 / 2 / 7:  70%|███████   | 7/10 [00:02<00:00,  3.06it/s]
# <font color = red>Negative (54%)</font> --> <font color = gray>[SKIPPED]</font><br>weighty and ponderous but every bit as filling as the treat of the title .
# [Succeeded / Failed / Total] 4 / 2 / 7:  80%|████████  | 8/10 [00:02<00:00,  3.46it/s]
#
#
#
# [Succeeded / Failed / Total] 4 / 2 / 8:  80%|████████  | 8/10 [00:02<00:00,  3.45it/s]
# <font color = green>Positive (99%)</font> --> <font color = red>[FAILED]</font><br>a real audience-pleaser that will strike a chord with anyone who's ever waited in a doctor's office , emergency room , hospital bed or insurance company office .
# [Succeeded / Failed / Total] 4 / 3 / 9:  90%|█████████ | 9/10 [00:03<00:00,  2.88it/s]
# <font color = green>Positive (99%)</font> --> <font color = red>[FAILED]</font><br>generates an enormous feeling of empathy for its characters .
# [Succeeded / Failed / Total] 4 / 3 / 9: 100%|██████████| 10/10 [00:03<00:00,  2.92it/s]
#
#
#
# [Succeeded / Failed / Total] 4 / 4 / 10: 100%|██████████| 10/10 [00:03<00:00,  2.91it/s]
# <font color = green>Positive (97%)</font> --> <font color = red>[FAILED]</font><br>exposing the ways we fool ourselves is one hour photo's real strength .
# [Succeeded / Failed / Total] 4 / 5 / 11: : 11it [00:03,  2.87it/s]
# <font color = green>Positive (80%)</font> --> <font color = red>Negative (57%)</font><br>it's <font color = green>up</font> to <font color = green>you</font> to decide whether to <font color = green>admire</font> these people's dedication to <font color = green>their</font> cause <font color = green>or</font> be <font color = green>repelled</font> by their dogmatism , manipulativeness and narrow , <font color = green>fearful</font> <font color = green>view</font> of american life .<br>it's <font color = red>out</font> to <font color = red>we</font> to decide whether to <font color = red>reconsider</font> these people's dedication to <font color = red>its</font> cause <font color = red>either</font> be <font color = red>repulsed</font> by their dogmatism , manipulativeness and narrow , <font color = red>stubborn</font> <font color = red>perspective</font> of american life .
# [Succeeded / Failed / Total] 4 / 5 / 11: : 12it [00:04,  2.63it/s]
#
#
#
# [Succeeded / Failed / Total] 5 / 5 / 12: : 12it [00:04,  2.63it/s]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 5      |
# | Number of failed attacks:     | 5      |
# | Number of skipped attacks:    | 2      |
# | Original accuracy:            | 83.33% |
# | Accuracy under attack:        | 41.67% |
# | Attack success rate:          | 50.0%  |
# | Average perturbed word %:     | 25.37% |
# | Average num. words per input: | 16.25  |
# | Avg num queries:              | 24.2   |
# +-------------------------------+--------+
# textattack: Attack time: 4.575262546539307s

# %%
#glove
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("rotten_tomatoes", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset rotten_tomatoes_movie_review (/root/.cache/huggingface/datasets/rotten_tomatoes_movie_review/default/1.0.0/9c411f7ecd9f3045389de0d9ce984061a1056507703d2e3183b1ac1a90816e4d)
# textattack: Loading datasets dataset rotten_tomatoes, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (54%)</font><br><font color = green>lovingly</font> photographed in the manner of a golden book sprung to life , stuart little 2 <font color = green>manages</font> sweetness largely without stickiness .<br><font color = red>retroactively</font> photographed in the manner of a golden book sprung to life , stuart little 2 <font color = red>vowed</font> sweetness largely without stickiness .
#  10%|█         | 1/10 [00:00<00:04,  2.17it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:04,  2.14it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>consistently clever and suspenseful .
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:00<00:02,  3.05it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:00<00:02,  3.03it/s]
# <font color = red>Negative (92%)</font> --> <font color = gray>[SKIPPED]</font><br>it's like a " big chill " reunion of the baader-meinhof gang , only these guys are more harmless pranksters than political activists .
# [Succeeded / Failed / Total] 1 / 1 / 3:  30%|███       | 3/10 [00:00<00:01,  4.37it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (60%)</font><br>the story gives ample <font color = green>opportunity</font> for large-scale action and <font color = green>suspense</font> , which director shekhar kapur <font color = green>supplies</font> with <font color = green>tremendous</font> <font color = green>skill</font> .<br>the story gives ample <font color = red>homage</font> for large-scale action and <font color = red>dunwich</font> , which director shekhar kapur <font color = red>inadequate</font> with <font color = red>enormous</font> <font color = red>experience</font> .
# [Succeeded / Failed / Total] 1 / 1 / 3:  40%|████      | 4/10 [00:01<00:01,  3.50it/s]
#
#
#
# [Succeeded / Failed / Total] 2 / 1 / 4:  40%|████      | 4/10 [00:01<00:01,  3.48it/s]
# <font color = green>Positive (88%)</font> --> <font color = red>Negative (96%)</font><br>red dragon " never cuts <font color = green>corners</font> .<br>red dragon " never cuts <font color = red>bats</font> .
# [Succeeded / Failed / Total] 3 / 1 / 5:  50%|█████     | 5/10 [00:01<00:01,  3.91it/s]
# <font color = green>Positive (91%)</font> --> <font color = red>Negative (56%)</font><br>fresnadillo has something <font color = green>serious</font> to say <font color = green>about</font> the ways in which extravagant chance <font color = green>can</font> distort our perspective and throw us off the path of good sense .<br>fresnadillo has something <font color = red>severe</font> to say <font color = red>worry</font> the ways in which extravagant chance <font color = red>peguera</font> distort our perspective and throw us off the path of good sense .
# [Succeeded / Failed / Total] 3 / 1 / 5:  60%|██████    | 6/10 [00:01<00:01,  3.30it/s]
#
#
#
# [Succeeded / Failed / Total] 4 / 1 / 6:  60%|██████    | 6/10 [00:01<00:01,  3.28it/s]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (59%)</font><br><font color = green>throws</font> in enough clever and <font color = green>unexpected</font> <font color = green>twists</font> to make the formula feel fresh .<br><font color = red>throw</font> in enough clever and <font color = red>repeated</font> <font color = red>dumfries</font> to make the formula feel fresh .
# [Succeeded / Failed / Total] 5 / 1 / 7:  70%|███████   | 7/10 [00:02<00:00,  3.16it/s]
# <font color = red>Negative (54%)</font> --> <font color = gray>[SKIPPED]</font><br>weighty and ponderous but every bit as filling as the treat of the title .
# [Succeeded / Failed / Total] 5 / 1 / 7:  80%|████████  | 8/10 [00:02<00:00,  3.56it/s]
#
#
#
# [Succeeded / Failed / Total] 5 / 1 / 8:  80%|████████  | 8/10 [00:02<00:00,  3.54it/s]
# <font color = green>Positive (99%)</font> --> <font color = red>[FAILED]</font><br>a real audience-pleaser that will strike a chord with anyone who's ever waited in a doctor's office , emergency room , hospital bed or insurance company office .
# [Succeeded / Failed / Total] 5 / 2 / 9:  90%|█████████ | 9/10 [00:03<00:00,  2.61it/s]
# <font color = green>Positive (99%)</font> --> <font color = red>Negative (71%)</font><br>generates an enormous <font color = green>feeling</font> of <font color = green>empathy</font> for its <font color = green>characters</font> .<br>generates an enormous <font color = red>fear</font> of <font color = red>decompression</font> for its <font color = red>character</font> .
# [Succeeded / Failed / Total] 5 / 2 / 9: 100%|██████████| 10/10 [00:03<00:00,  2.64it/s]
#
#
#
# [Succeeded / Failed / Total] 6 / 2 / 10: 100%|██████████| 10/10 [00:03<00:00,  2.64it/s]
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (54%)</font><br><font color = green>exposing</font> the ways we fool ourselves <font color = green>is</font> one hour photo's real <font color = green>strength</font> .<br><font color = red>issuing</font> the ways we fool ourselves <font color = red>polylogarithm</font> one hour photo's real <font color = red>tensile</font> .
# [Succeeded / Failed / Total] 7 / 2 / 11: : 11it [00:04,  2.67it/s]
# <font color = green>Positive (80%)</font> --> <font color = red>Negative (57%)</font><br>it's up to you to decide whether to <font color = green>admire</font> these people's dedication to their cause or be <font color = green>repelled</font> by their dogmatism , manipulativeness and narrow , <font color = green>fearful</font> view of american life .<br>it's up to you to decide whether to <font color = red>drown</font> these people's dedication to their cause or be <font color = red>distracted</font> by their dogmatism , manipulativeness and narrow , <font color = red>metaphysical</font> view of american life .
# [Succeeded / Failed / Total] 7 / 2 / 11: : 12it [00:04,  2.51it/s]
#
#
#
# [Succeeded / Failed / Total] 8 / 2 / 12: : 12it [00:04,  2.51it/s]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 8      |
# | Number of failed attacks:     | 2      |
# | Number of skipped attacks:    | 2      |
# | Original accuracy:            | 83.33% |
# | Accuracy under attack:        | 16.67% |
# | Attack success rate:          | 80.0%  |
# | Average perturbed word %:     | 20.13% |
# | Average num. words per input: | 16.25  |
# | Avg num queries:              | 20.9   |
# +-------------------------------+--------+
# textattack: Attack time: 4.793666362762451s

# %%
#fasttext
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("rotten_tomatoes", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1860.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=869.0, style=ProgressStyle(description_…
# Using custom data configuration default
# Downloading and preparing dataset rotten_tomatoes_movie_review/default (download: 476.34 KiB, generated: 1.28 MiB, post-processed: Unknown size, total: 1.75 MiB) to /root/.cache/huggingface/datasets/rotten_tomatoes_movie_review/default/1.0.0/9c411f7ecd9f3045389de0d9ce984061a1056507703d2e3183b1ac1a90816e4d...
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=487770.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# textattack: Loading datasets dataset rotten_tomatoes, split test.
# Dataset rotten_tomatoes_movie_review downloaded and prepared to /root/.cache/huggingface/datasets/rotten_tomatoes_movie_review/default/1.0.0/9c411f7ecd9f3045389de0d9ce984061a1056507703d2e3183b1ac1a90816e4d. Subsequent calls will reuse this data.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (53%)</font><br>lovingly photographed in the manner of a golden book sprung to life , <font color = green>stuart</font> little 2 <font color = green>manages</font> sweetness largely without stickiness .<br>lovingly photographed in the manner of a golden book sprung to life , <font color = red>dudley</font> little 2 <font color = red>manage</font> sweetness largely without stickiness .
#  10%|█         | 1/10 [00:03<00:34,  3.87s/it]
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:03<00:34,  3.88s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>consistently clever and suspenseful .
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:04<00:18,  2.35s/it]
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:04<00:18,  2.35s/it]
# <font color = red>Negative (92%)</font> --> <font color = gray>[SKIPPED]</font><br>it's like a " big chill " reunion of the baader-meinhof gang , only these guys are more harmless pranksters than political activists .
# [Succeeded / Failed / Total] 1 / 1 / 3:  30%|███       | 3/10 [00:04<00:11,  1.59s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (66%)</font><br>the story <font color = green>gives</font> ample <font color = green>opportunity</font> for <font color = green>large-scale</font> <font color = green>action</font> and <font color = green>suspense</font> , which director <font color = green>shekhar</font> kapur <font color = green>supplies</font> with tremendous skill .<br>the story <font color = red>gave</font> ample <font color = red>opportune</font> for <font color = red>largescale</font> <font color = red>cessation</font> and <font color = red>suspension</font> , which director <font color = red>dzhokhar</font> kapur <font color = red>supply</font> with tremendous skill .
# [Succeeded / Failed / Total] 1 / 1 / 3:  40%|████      | 4/10 [00:17<00:26,  4.41s/it]
# [Succeeded / Failed / Total] 2 / 1 / 4:  40%|████      | 4/10 [00:17<00:26,  4.41s/it]
# <font color = green>Positive (88%)</font> --> <font color = red>Negative (99%)</font><br>red dragon " never cuts <font color = green>corners</font> .<br>red dragon " never cuts <font color = red>corner</font> .
# [Succeeded / Failed / Total] 2 / 1 / 4:  50%|█████     | 5/10 [00:17<00:17,  3.59s/it]
# [Succeeded / Failed / Total] 3 / 1 / 5:  50%|█████     | 5/10 [00:17<00:17,  3.59s/it]
# <font color = green>Positive (91%)</font> --> <font color = red>Negative (50%)</font><br>fresnadillo has <font color = green>something</font> <font color = green>serious</font> to say about the ways in which <font color = green>extravagant</font> chance can distort our <font color = green>perspective</font> and throw us off the path of good sense .<br>fresnadillo has <font color = red>seething</font> <font color = red>contagious</font> to say about the ways in which <font color = red>extravagance</font> chance can distort our <font color = red>viewpoint</font> and throw us off the path of good sense .
# [Succeeded / Failed / Total] 3 / 1 / 5:  60%|██████    | 6/10 [00:23<00:15,  3.90s/it]
# [Succeeded / Failed / Total] 4 / 1 / 6:  60%|██████    | 6/10 [00:23<00:15,  3.90s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (99%)</font><br>throws in <font color = green>enough</font> clever and unexpected twists to make the formula feel fresh .<br>throws in <font color = red>too</font> clever and unexpected twists to make the formula feel fresh .
# [Succeeded / Failed / Total] 4 / 1 / 6:  70%|███████   | 7/10 [00:23<00:10,  3.42s/it]
# [Succeeded / Failed / Total] 5 / 1 / 7:  70%|███████   | 7/10 [00:23<00:10,  3.42s/it]
# <font color = red>Negative (54%)</font> --> <font color = gray>[SKIPPED]</font><br>weighty and ponderous but every bit as filling as the treat of the title .
# [Succeeded / Failed / Total] 5 / 1 / 8:  80%|████████  | 8/10 [00:24<00:06,  3.00s/it]
# <font color = green>Positive (99%)</font> --> <font color = red>[FAILED]</font><br>a real audience-pleaser that will strike a chord with anyone who's ever waited in a doctor's office , emergency room , hospital bed or insurance company office .
# [Succeeded / Failed / Total] 5 / 1 / 8:  90%|█████████ | 9/10 [00:52<00:05,  5.80s/it]
# [Succeeded / Failed / Total] 5 / 2 / 9:  90%|█████████ | 9/10 [00:52<00:05,  5.80s/it]
# <font color = green>Positive (99%)</font> --> <font color = red>Negative (98%)</font><br>generates an enormous feeling of <font color = green>empathy</font> for its characters .<br>generates an enormous feeling of <font color = red>apathy</font> for its characters .
# [Succeeded / Failed / Total] 5 / 2 / 9: 100%|██████████| 10/10 [00:52<00:00,  5.25s/it]
# [Succeeded / Failed / Total] 6 / 2 / 10: 100%|██████████| 10/10 [00:52<00:00,  5.26s/it]
# <font color = green>Positive (97%)</font> --> <font color = red>[FAILED]</font><br>exposing the ways we fool ourselves is one hour photo's real strength .
# [Succeeded / Failed / Total] 6 / 2 / 10: : 11it [00:57,  5.21s/it]
# [Succeeded / Failed / Total] 6 / 3 / 11: : 11it [00:57,  5.21s/it]
# <font color = green>Positive (80%)</font> --> <font color = red>Negative (62%)</font><br>it's up to you to decide whether to admire these people's dedication to their cause or be <font color = green>repelled</font> by their dogmatism , manipulativeness and narrow , <font color = green>fearful</font> <font color = green>view</font> of american life .<br>it's up to you to decide whether to admire these people's dedication to their cause or be <font color = red>dispelled</font> by their dogmatism , manipulativeness and narrow , <font color = red>dreadful</font> <font color = red>misinterpretation</font> of american life .
# [Succeeded / Failed / Total] 6 / 3 / 11: : 12it [01:02,  5.24s/it]
# [Succeeded / Failed / Total] 7 / 3 / 12: : 12it [01:02,  5.24s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 7      |
# | Number of failed attacks:     | 3      |
# | Number of skipped attacks:    | 2      |
# | Original accuracy:            | 83.33% |
# | Accuracy under attack:        | 25.0%  |
# | Attack success rate:          | 70.0%  |
# | Average perturbed word %:     | 16.2%  |
# | Average num. words per input: | 16.25  |
# | Avg num queries:              | 182.5  |
# +-------------------------------+--------+
# textattack: Attack time: 62.8687219619751s

# %%
#word2vec
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("rotten_tomatoes", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset rotten_tomatoes_movie_review (/root/.cache/huggingface/datasets/rotten_tomatoes_movie_review/default/1.0.0/9c411f7ecd9f3045389de0d9ce984061a1056507703d2e3183b1ac1a90816e4d)
# textattack: Loading datasets dataset rotten_tomatoes, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (96%)</font><br><font color = green>lovingly</font> photographed in the manner of a golden book sprung to life , stuart little 2 manages <font color = green>sweetness</font> largely <font color = green>without</font> stickiness .<br><font color = red>giantesses</font> photographed in the manner of a golden book sprung to life , stuart little 2 manages <font color = red>ripening</font> largely <font color = red>whatsoever</font> stickiness .
#  10%|█         | 1/10 [00:05<00:49,  5.48s/it]
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:05<00:49,  5.49s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>consistently clever and suspenseful .
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:06<00:25,  3.16s/it]
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:06<00:25,  3.16s/it]
# <font color = red>Negative (92%)</font> --> <font color = gray>[SKIPPED]</font><br>it's like a " big chill " reunion of the baader-meinhof gang , only these guys are more harmless pranksters than political activists .
# [Succeeded / Failed / Total] 1 / 1 / 3:  30%|███       | 3/10 [00:06<00:14,  2.12s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (87%)</font><br>the story gives <font color = green>ample</font> opportunity for large-scale action and suspense , which director shekhar kapur supplies with tremendous skill .<br>the story gives <font color = red>insufficient</font> opportunity for large-scale action and suspense , which director shekhar kapur supplies with tremendous skill .
# [Succeeded / Failed / Total] 1 / 1 / 3:  40%|████      | 4/10 [00:06<00:10,  1.73s/it]
# [Succeeded / Failed / Total] 2 / 1 / 4:  40%|████      | 4/10 [00:06<00:10,  1.73s/it]
# <font color = green>Positive (88%)</font> --> <font color = red>Negative (99%)</font><br>red dragon " <font color = green>never</font> cuts corners .<br>red dragon " <font color = red>already</font> cuts corners .
# [Succeeded / Failed / Total] 3 / 1 / 5:  50%|█████     | 5/10 [00:07<00:07,  1.45s/it]
# <font color = green>Positive (91%)</font> --> <font color = red>Negative (97%)</font><br>fresnadillo has <font color = green>something</font> serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense .<br>fresnadillo has <font color = red>anything</font> serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense .
# [Succeeded / Failed / Total] 3 / 1 / 5:  60%|██████    | 6/10 [00:07<00:05,  1.32s/it]
# [Succeeded / Failed / Total] 4 / 1 / 6:  60%|██████    | 6/10 [00:07<00:05,  1.32s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (99%)</font><br>throws in <font color = green>enough</font> clever and unexpected twists to make the formula feel fresh .<br>throws in <font color = red>too</font> clever and unexpected twists to make the formula feel fresh .
# [Succeeded / Failed / Total] 5 / 1 / 7:  70%|███████   | 7/10 [00:08<00:03,  1.20s/it]
# <font color = red>Negative (54%)</font> --> <font color = gray>[SKIPPED]</font><br>weighty and ponderous but every bit as filling as the treat of the title .
# [Succeeded / Failed / Total] 5 / 1 / 7:  80%|████████  | 8/10 [00:08<00:02,  1.06s/it]
# [Succeeded / Failed / Total] 5 / 1 / 8:  80%|████████  | 8/10 [00:08<00:02,  1.06s/it]
# [Succeeded / Failed / Total] 5 / 1 / 8:  80%|████████  | 8/10 [00:19<00:04,  2.41s/it]
# <font color = green>Positive (99%)</font> --> <font color = red>[FAILED]</font><br>a real audience-pleaser that will strike a chord with anyone who's ever waited in a doctor's office , emergency room , hospital bed or insurance company office .
# [Succeeded / Failed / Total] 5 / 1 / 8:  90%|█████████ | 9/10 [00:23<00:02,  2.56s/it]
# [Succeeded / Failed / Total] 5 / 2 / 9:  90%|█████████ | 9/10 [00:23<00:02,  2.56s/it]
# <font color = green>Positive (99%)</font> --> <font color = red>[FAILED]</font><br>generates an enormous feeling of empathy for its characters .
# [Succeeded / Failed / Total] 5 / 2 / 9: 100%|██████████| 10/10 [00:25<00:00,  2.58s/it]
# [Succeeded / Failed / Total] 5 / 3 / 10: 100%|██████████| 10/10 [00:25<00:00,  2.58s/it]
# <font color = green>Positive (97%)</font> --> <font color = red>[FAILED]</font><br>exposing the ways we fool ourselves is one hour photo's real strength .
# [Succeeded / Failed / Total] 5 / 3 / 10: : 11it [00:29,  2.64s/it]
# [Succeeded / Failed / Total] 5 / 4 / 11: : 11it [00:29,  2.64s/it]
# <font color = green>Positive (80%)</font> --> <font color = red>Negative (53%)</font><br>it's up to you to decide whether to <font color = green>admire</font> these people's dedication to their cause or be repelled by their dogmatism , manipulativeness and narrow , fearful <font color = green>view</font> of <font color = green>american</font> life .<br>it's up to you to decide whether to <font color = red>reconsider</font> these people's dedication to their cause or be repelled by their dogmatism , manipulativeness and narrow , fearful <font color = red>perspective</font> of <font color = red>bronxites</font> life .
# [Succeeded / Failed / Total] 5 / 4 / 11: : 12it [00:32,  2.70s/it]
# [Succeeded / Failed / Total] 6 / 4 / 12: : 12it [00:32,  2.70s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 6      |
# | Number of failed attacks:     | 4      |
# | Number of skipped attacks:    | 2      |
# | Original accuracy:            | 83.33% |
# | Accuracy under attack:        | 33.33% |
# | Attack success rate:          | 60.0%  |
# | Average perturbed word %:     | 10.41% |
# | Average num. words per input: | 16.25  |
# | Avg num queries:              | 132.2  |
# +-------------------------------+--------+
# textattack: Attack time: 32.39119625091553s

# %%
#glove
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("rotten_tomatoes", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset rotten_tomatoes_movie_review (/root/.cache/huggingface/datasets/rotten_tomatoes_movie_review/default/1.0.0/9c411f7ecd9f3045389de0d9ce984061a1056507703d2e3183b1ac1a90816e4d)
# textattack: Loading datasets dataset rotten_tomatoes, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (69%)</font><br><font color = green>lovingly</font> photographed in the manner of a golden book sprung to <font color = green>life</font> , stuart little 2 manages <font color = green>sweetness</font> largely without stickiness .<br><font color = red>retroactively</font> photographed in the manner of a golden book sprung to <font color = red>imminently</font> , stuart little 2 manages <font color = red>thematic</font> largely without stickiness .
#  10%|█         | 1/10 [00:08<01:18,  8.69s/it]
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:08<01:18,  8.71s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (85%)</font><br>consistently <font color = green>clever</font> and <font color = green>suspenseful</font> .<br>consistently <font color = red>comical</font> and <font color = red>mannitol</font> .
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:09<00:37,  4.64s/it]
# [Succeeded / Failed / Total] 2 / 0 / 2:  20%|██        | 2/10 [00:09<00:37,  4.65s/it]
# <font color = red>Negative (92%)</font> --> <font color = gray>[SKIPPED]</font><br>it's like a " big chill " reunion of the baader-meinhof gang , only these guys are more harmless pranksters than political activists .
# [Succeeded / Failed / Total] 2 / 0 / 3:  30%|███       | 3/10 [00:09<00:21,  3.12s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (89%)</font><br>the story gives ample opportunity for large-scale <font color = green>action</font> and suspense , which director <font color = green>shekhar</font> kapur <font color = green>supplies</font> with <font color = green>tremendous</font> <font color = green>skill</font> .<br>the story gives ample opportunity for large-scale <font color = red>republicaine</font> and suspense , which director <font color = red>mayim</font> kapur <font color = red>inadequate</font> with <font color = red>enormous</font> <font color = red>experience</font> .
# [Succeeded / Failed / Total] 2 / 0 / 3:  40%|████      | 4/10 [00:13<00:20,  3.49s/it]
# [Succeeded / Failed / Total] 3 / 0 / 4:  40%|████      | 4/10 [00:13<00:20,  3.49s/it]
# <font color = green>Positive (88%)</font> --> <font color = red>Negative (99%)</font><br>red dragon " never <font color = green>cuts</font> corners .<br>red dragon " never <font color = red>profits</font> corners .
# [Succeeded / Failed / Total] 4 / 0 / 5:  50%|█████     | 5/10 [00:14<00:14,  2.88s/it]
# <font color = green>Positive (91%)</font> --> <font color = red>Negative (97%)</font><br>fresnadillo has <font color = green>something</font> serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense .<br>fresnadillo has <font color = red>anything</font> serious to say about the ways in which extravagant chance can distort our perspective and throw us off the path of good sense .
# [Succeeded / Failed / Total] 4 / 0 / 5:  60%|██████    | 6/10 [00:15<00:10,  2.56s/it]
# [Succeeded / Failed / Total] 5 / 0 / 6:  60%|██████    | 6/10 [00:15<00:10,  2.56s/it]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (64%)</font><br><font color = green>throws</font> in enough clever and <font color = green>unexpected</font> twists to make the formula feel <font color = green>fresh</font> .<br><font color = red>throw</font> in enough clever and <font color = red>repeated</font> twists to make the formula feel <font color = red>supplies</font> .
# [Succeeded / Failed / Total] 6 / 0 / 7:  70%|███████   | 7/10 [00:18<00:08,  2.70s/it]
# <font color = red>Negative (54%)</font> --> <font color = gray>[SKIPPED]</font><br>weighty and ponderous but every bit as filling as the treat of the title .
# [Succeeded / Failed / Total] 6 / 0 / 7:  80%|████████  | 8/10 [00:18<00:04,  2.37s/it]
# [Succeeded / Failed / Total] 6 / 0 / 8:  80%|████████  | 8/10 [00:18<00:04,  2.37s/it]
# [Succeeded / Failed / Total] 6 / 0 / 8:  80%|████████  | 8/10 [00:29<00:07,  3.68s/it]
# <font color = green>Positive (99%)</font> --> <font color = red>Negative (57%)</font><br>a <font color = green>real</font> audience-pleaser that will <font color = green>strike</font> a chord with <font color = green>anyone</font> who's <font color = green>ever</font> <font color = green>waited</font> in a doctor's office , emergency <font color = green>room</font> , <font color = green>hospital</font> <font color = green>bed</font> or insurance <font color = green>company</font> office .<br>a <font color = red>numbers</font> audience-pleaser that will <font color = red>counter</font> a chord with <font color = red>anybody</font> who's <font color = red>once</font> <font color = red>prayed</font> in a doctor's office , emergency <font color = red>darkened</font> , <font color = red>eagleville</font> <font color = red>vajrapoha</font> or insurance <font color = red>corporation</font> office .
# [Succeeded / Failed / Total] 6 / 0 / 8:  90%|█████████ | 9/10 [00:43<00:04,  4.82s/it]
# [Succeeded / Failed / Total] 7 / 0 / 9:  90%|█████████ | 9/10 [00:43<00:04,  4.82s/it]
# <font color = green>Positive (99%)</font> --> <font color = red>Negative (73%)</font><br>generates an enormous <font color = green>feeling</font> of <font color = green>empathy</font> for its characters .<br>generates an enormous <font color = red>fear</font> of <font color = red>decompression</font> for its characters .
# [Succeeded / Failed / Total] 7 / 0 / 9: 100%|██████████| 10/10 [00:44<00:00,  4.43s/it]
# [Succeeded / Failed / Total] 8 / 0 / 10: 100%|██████████| 10/10 [00:44<00:00,  4.43s/it]
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (94%)</font><br><font color = green>exposing</font> the ways we fool ourselves is <font color = green>one</font> <font color = green>hour</font> photo's <font color = green>real</font> <font color = green>strength</font> .<br><font color = red>issuing</font> the ways we fool ourselves is <font color = red>ffffffarm</font> <font color = red>minutes</font> photo's <font color = red>numbers</font> <font color = red>tensile</font> .
# [Succeeded / Failed / Total] 8 / 0 / 10: : 11it [00:46,  4.24s/it]
# [Succeeded / Failed / Total] 9 / 0 / 11: : 11it [00:46,  4.25s/it]
# <font color = green>Positive (80%)</font> --> <font color = red>Negative (59%)</font><br>it's up to you to decide whether to <font color = green>admire</font> these people's dedication to their cause or be repelled by their dogmatism , manipulativeness and narrow , fearful <font color = green>view</font> of american life .<br>it's up to you to decide whether to <font color = red>drown</font> these people's dedication to their cause or be repelled by their dogmatism , manipulativeness and narrow , fearful <font color = red>cheltonians</font> of american life .
# [Succeeded / Failed / Total] 9 / 0 / 11: : 12it [00:52,  4.39s/it]
# [Succeeded / Failed / Total] 10 / 0 / 12: : 12it [00:52,  4.39s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 10     |
# | Number of failed attacks:     | 0      |
# | Number of skipped attacks:    | 2      |
# | Original accuracy:            | 83.33% |
# | Accuracy under attack:        | 0.0%   |
# | Attack success rate:          | 100.0% |
# | Average perturbed word %:     | 24.65% |
# | Average num. words per input: | 16.25  |
# | Avg num queries:              | 100.9  |
# +-------------------------------+--------+
# textattack: Attack time: 52.64467930793762s

# %%
#fasttext
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("rotten_tomatoes", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset rotten_tomatoes_movie_review (/root/.cache/huggingface/datasets/rotten_tomatoes_movie_review/default/1.0.0/9c411f7ecd9f3045389de0d9ce984061a1056507703d2e3183b1ac1a90816e4d)
# textattack: Loading datasets dataset rotten_tomatoes, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (79%)</font><br><font color = green>lovingly</font> photographed in the manner of a golden book sprung to life , stuart little 2 <font color = green>manages</font> <font color = green>sweetness</font> largely <font color = green>without</font> stickiness .<br><font color = red>kingly</font> photographed in the manner of a golden book sprung to life , stuart little 2 <font color = red>manage</font> <font color = red>softness</font> largely <font color = red>any</font> stickiness .
#  10%|█         | 1/10 [00:00<00:08,  1.03it/s]
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:08,  1.02it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>consistently clever and suspenseful .
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:01<00:05,  1.51it/s]
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:01<00:05,  1.50it/s]
# <font color = red>Negative (92%)</font> --> <font color = gray>[SKIPPED]</font><br>it's like a " big chill " reunion of the baader-meinhof gang , only these guys are more harmless pranksters than political activists .
# [Succeeded / Failed / Total] 1 / 1 / 3:  30%|███       | 3/10 [00:01<00:03,  2.15it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (66%)</font><br>the story <font color = green>gives</font> ample <font color = green>opportunity</font> for large-scale <font color = green>action</font> and <font color = green>suspense</font> , which director <font color = green>shekhar</font> kapur <font color = green>supplies</font> with <font color = green>tremendous</font> <font color = green>skill</font> .<br>the story <font color = red>gave</font> ample <font color = red>opportune</font> for large-scale <font color = red>cessation</font> and <font color = red>suspension</font> , which director <font color = red>dzhokhar</font> kapur <font color = red>supply</font> with <font color = red>stupendous</font> <font color = red>skilful</font> .
# [Succeeded / Failed / Total] 1 / 1 / 3:  40%|████      | 4/10 [00:02<00:03,  1.61it/s]
# [Succeeded / Failed / Total] 2 / 1 / 4:  40%|████      | 4/10 [00:02<00:03,  1.60it/s]
# <font color = green>Positive (88%)</font> --> <font color = red>Negative (99%)</font><br>red dragon " never cuts <font color = green>corners</font> .<br>red dragon " never cuts <font color = red>corner</font> .
# [Succeeded / Failed / Total] 3 / 1 / 5:  50%|█████     | 5/10 [00:02<00:02,  1.80it/s]
# <font color = green>Positive (91%)</font> --> <font color = red>Negative (55%)</font><br>fresnadillo has <font color = green>something</font> serious to say about the <font color = green>ways</font> in which extravagant <font color = green>chance</font> can <font color = green>distort</font> our perspective and throw <font color = green>us</font> off the <font color = green>path</font> of good sense .<br>fresnadillo has <font color = red>seething</font> serious to say about the <font color = red>way</font> in which extravagant <font color = red>guess</font> can <font color = red>noisy</font> our perspective and throw <font color = red>united</font> off the <font color = red>midpoint</font> of good sense .
# [Succeeded / Failed / Total] 3 / 1 / 5:  60%|██████    | 6/10 [00:04<00:02,  1.45it/s]
# [Succeeded / Failed / Total] 4 / 1 / 6:  60%|██████    | 6/10 [00:04<00:02,  1.44it/s]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (55%)</font><br><font color = green>throws</font> in enough <font color = green>clever</font> and unexpected twists to make the formula feel <font color = green>fresh</font> .<br><font color = red>throw</font> in enough <font color = red>cleve</font> and unexpected twists to make the formula feel <font color = red>vegetable</font> .
# [Succeeded / Failed / Total] 5 / 1 / 7:  70%|███████   | 7/10 [00:04<00:02,  1.48it/s]
# <font color = red>Negative (54%)</font> --> <font color = gray>[SKIPPED]</font><br>weighty and ponderous but every bit as filling as the treat of the title .
# [Succeeded / Failed / Total] 5 / 1 / 7:  80%|████████  | 8/10 [00:04<00:01,  1.67it/s]
# [Succeeded / Failed / Total] 5 / 1 / 8:  80%|████████  | 8/10 [00:04<00:01,  1.66it/s]
# <font color = green>Positive (99%)</font> --> <font color = red>[FAILED]</font><br>a real audience-pleaser that will strike a chord with anyone who's ever waited in a doctor's office , emergency room , hospital bed or insurance company office .
# [Succeeded / Failed / Total] 5 / 2 / 9:  90%|█████████ | 9/10 [00:06<00:00,  1.37it/s]
# <font color = green>Positive (99%)</font> --> <font color = red>Negative (98%)</font><br>generates an enormous feeling of <font color = green>empathy</font> for its <font color = green>characters</font> .<br>generates an enormous feeling of <font color = red>apathy</font> for its <font color = red>character</font> .
# [Succeeded / Failed / Total] 5 / 2 / 9: 100%|██████████| 10/10 [00:07<00:00,  1.42it/s]
# [Succeeded / Failed / Total] 6 / 2 / 10: 100%|██████████| 10/10 [00:07<00:00,  1.41it/s]
# <font color = green>Positive (97%)</font> --> <font color = red>[FAILED]</font><br>exposing the ways we fool ourselves is one hour photo's real strength .
# [Succeeded / Failed / Total] 6 / 3 / 11: : 11it [00:07,  1.39it/s]
# <font color = green>Positive (80%)</font> --> <font color = red>Negative (61%)</font><br>it's up to you to <font color = green>decide</font> whether to <font color = green>admire</font> these people's dedication to their cause or be <font color = green>repelled</font> by their dogmatism , manipulativeness and narrow , <font color = green>fearful</font> <font color = green>view</font> of american life .<br>it's up to you to <font color = red>deciding</font> whether to <font color = red>admiring</font> these people's dedication to their cause or be <font color = red>dispelled</font> by their dogmatism , manipulativeness and narrow , <font color = red>dreadful</font> <font color = red>misinterpretation</font> of american life .
# [Succeeded / Failed / Total] 6 / 3 / 11: : 12it [00:09,  1.31it/s]
# [Succeeded / Failed / Total] 7 / 3 / 12: : 12it [00:09,  1.31it/s]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 7      |
# | Number of failed attacks:     | 3      |
# | Number of skipped attacks:    | 2      |
# | Original accuracy:            | 83.33% |
# | Accuracy under attack:        | 25.0%  |
# | Attack success rate:          | 70.0%  |
# | Average perturbed word %:     | 24.29% |
# | Average num. words per input: | 16.25  |
# | Avg num queries:              | 23.5   |
# +-------------------------------+--------+
# textattack: Attack time: 9.184903144836426s

# %%
#word2vec
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("rotten_tomatoes", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset rotten_tomatoes_movie_review (/root/.cache/huggingface/datasets/rotten_tomatoes_movie_review/default/1.0.0/9c411f7ecd9f3045389de0d9ce984061a1056507703d2e3183b1ac1a90816e4d)
# textattack: Loading datasets dataset rotten_tomatoes, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (96%)</font><br><font color = green>lovingly</font> photographed in the manner of a golden book sprung to life , stuart little 2 manages <font color = green>sweetness</font> largely <font color = green>without</font> stickiness .<br><font color = red>giantesses</font> photographed in the manner of a golden book sprung to life , stuart little 2 manages <font color = red>ripening</font> largely <font color = red>whatsoever</font> stickiness .
#  10%|█         | 1/10 [00:00<00:08,  1.12it/s]
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:08,  1.11it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>consistently clever and suspenseful .
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:01<00:05,  1.59it/s]
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:01<00:05,  1.58it/s]
# <font color = red>Negative (92%)</font> --> <font color = gray>[SKIPPED]</font><br>it's like a " big chill " reunion of the baader-meinhof gang , only these guys are more harmless pranksters than political activists .
# [Succeeded / Failed / Total] 1 / 1 / 3:  30%|███       | 3/10 [00:01<00:03,  2.27it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (90%)</font><br>the story <font color = green>gives</font> <font color = green>ample</font> <font color = green>opportunity</font> for large-scale <font color = green>action</font> and <font color = green>suspense</font> , which director shekhar kapur <font color = green>supplies</font> with <font color = green>tremendous</font> skill .<br>the story <font color = red>gave</font> <font color = red>insufficient</font> <font color = red>incentive</font> for large-scale <font color = red>affirmative</font> and <font color = red>thrillers</font> , which director shekhar kapur <font color = red>supply</font> with <font color = red>considerable</font> skill .
# [Succeeded / Failed / Total] 1 / 1 / 3:  40%|████      | 4/10 [00:02<00:03,  1.71it/s]
# [Succeeded / Failed / Total] 2 / 1 / 4:  40%|████      | 4/10 [00:02<00:03,  1.70it/s]
# <font color = green>Positive (88%)</font> --> <font color = red>Negative (98%)</font><br>red dragon " never cuts <font color = green>corners</font> .<br>red dragon " never cuts <font color = red>edges</font> .
# [Succeeded / Failed / Total] 3 / 1 / 5:  50%|█████     | 5/10 [00:02<00:02,  1.90it/s]
# <font color = green>Positive (91%)</font> --> <font color = red>Negative (90%)</font><br>fresnadillo has <font color = green>something</font> <font color = green>serious</font> to say about the <font color = green>ways</font> in which extravagant chance can distort our perspective and throw us off the <font color = green>path</font> of good sense .<br>fresnadillo has <font color = red>anything</font> <font color = red>severe</font> to say about the <font color = red>way</font> in which extravagant chance can distort our perspective and throw us off the <font color = red>eightfold</font> of good sense .
# [Succeeded / Failed / Total] 3 / 1 / 5:  60%|██████    | 6/10 [00:03<00:02,  1.65it/s]
# [Succeeded / Failed / Total] 4 / 1 / 6:  60%|██████    | 6/10 [00:03<00:02,  1.65it/s]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (87%)</font><br>throws in enough <font color = green>clever</font> and <font color = green>unexpected</font> twists to make the formula feel <font color = green>fresh</font> .<br>throws in enough <font color = red>witty</font> and <font color = red>embarrassing</font> twists to make the formula feel <font color = red>rotting</font> .
# [Succeeded / Failed / Total] 5 / 1 / 7:  70%|███████   | 7/10 [00:04<00:01,  1.64it/s]
# <font color = red>Negative (54%)</font> --> <font color = gray>[SKIPPED]</font><br>weighty and ponderous but every bit as filling as the treat of the title .
# [Succeeded / Failed / Total] 5 / 1 / 7:  80%|████████  | 8/10 [00:04<00:01,  1.86it/s]
# [Succeeded / Failed / Total] 5 / 1 / 8:  80%|████████  | 8/10 [00:04<00:01,  1.85it/s]
# <font color = green>Positive (99%)</font> --> <font color = red>[FAILED]</font><br>a real audience-pleaser that will strike a chord with anyone who's ever waited in a doctor's office , emergency room , hospital bed or insurance company office .
# [Succeeded / Failed / Total] 5 / 2 / 9:  90%|█████████ | 9/10 [00:05<00:00,  1.55it/s]
# <font color = green>Positive (99%)</font> --> <font color = red>[FAILED]</font><br>generates an enormous feeling of empathy for its characters .
# [Succeeded / Failed / Total] 5 / 2 / 9: 100%|██████████| 10/10 [00:06<00:00,  1.57it/s]
# [Succeeded / Failed / Total] 5 / 3 / 10: 100%|██████████| 10/10 [00:06<00:00,  1.56it/s]
# <font color = green>Positive (97%)</font> --> <font color = red>[FAILED]</font><br>exposing the ways we fool ourselves is one hour photo's real strength .
# [Succeeded / Failed / Total] 5 / 4 / 11: : 11it [00:07,  1.54it/s]
# <font color = green>Positive (80%)</font> --> <font color = red>Negative (52%)</font><br>it's up to you to <font color = green>decide</font> whether to <font color = green>admire</font> these people's dedication to their cause or be <font color = green>repelled</font> by their dogmatism , manipulativeness and narrow , fearful <font color = green>view</font> of <font color = green>american</font> life .<br>it's up to you to <font color = red>instruct</font> whether to <font color = red>reconsider</font> these people's dedication to their cause or be <font color = red>repulsed</font> by their dogmatism , manipulativeness and narrow , fearful <font color = red>perspective</font> of <font color = red>bronxites</font> life .
# [Succeeded / Failed / Total] 5 / 4 / 11: : 12it [00:08,  1.42it/s]
# [Succeeded / Failed / Total] 6 / 4 / 12: : 12it [00:08,  1.42it/s]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 6      |
# | Number of failed attacks:     | 4      |
# | Number of skipped attacks:    | 2      |
# | Original accuracy:            | 83.33% |
# | Accuracy under attack:        | 33.33% |
# | Attack success rate:          | 60.0%  |
# | Average perturbed word %:     | 21.6%  |
# | Average num. words per input: | 16.25  |
# | Avg num queries:              | 22.7   |
# +-------------------------------+--------+
# textattack: Attack time: 8.445930242538452s

# %%
#glove
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("rotten_tomatoes", None, "test")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Using custom data configuration default
# Reusing dataset rotten_tomatoes_movie_review (/root/.cache/huggingface/datasets/rotten_tomatoes_movie_review/default/1.0.0/9c411f7ecd9f3045389de0d9ce984061a1056507703d2e3183b1ac1a90816e4d)
# textattack: Loading datasets dataset rotten_tomatoes, split test.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (82%)</font><br><font color = green>lovingly</font> photographed in the manner of a golden book sprung to life , stuart little 2 manages <font color = green>sweetness</font> largely <font color = green>without</font> stickiness .<br><font color = red>retroactively</font> photographed in the manner of a golden book sprung to life , stuart little 2 manages <font color = red>thematic</font> largely <font color = red>any</font> stickiness .
#  10%|█         | 1/10 [00:01<00:09,  1.00s/it]
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:01<00:09,  1.01s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (85%)</font><br>consistently <font color = green>clever</font> and <font color = green>suspenseful</font> .<br>consistently <font color = red>comical</font> and <font color = red>mannitol</font> .
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:01<00:05,  1.47it/s]
# [Succeeded / Failed / Total] 2 / 0 / 2:  20%|██        | 2/10 [00:01<00:05,  1.46it/s]
# <font color = red>Negative (92%)</font> --> <font color = gray>[SKIPPED]</font><br>it's like a " big chill " reunion of the baader-meinhof gang , only these guys are more harmless pranksters than political activists .
# [Succeeded / Failed / Total] 2 / 0 / 3:  30%|███       | 3/10 [00:01<00:03,  2.10it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (60%)</font><br>the story gives ample <font color = green>opportunity</font> for large-scale action and <font color = green>suspense</font> , which director shekhar kapur <font color = green>supplies</font> with <font color = green>tremendous</font> <font color = green>skill</font> .<br>the story gives ample <font color = red>homage</font> for large-scale action and <font color = red>dunwich</font> , which director shekhar kapur <font color = red>inadequate</font> with <font color = red>enormous</font> <font color = red>experience</font> .
# [Succeeded / Failed / Total] 2 / 0 / 3:  40%|████      | 4/10 [00:02<00:03,  1.65it/s]
# [Succeeded / Failed / Total] 3 / 0 / 4:  40%|████      | 4/10 [00:02<00:03,  1.64it/s]
# <font color = green>Positive (88%)</font> --> <font color = red>Negative (96%)</font><br>red dragon " never cuts <font color = green>corners</font> .<br>red dragon " never cuts <font color = red>bats</font> .
# [Succeeded / Failed / Total] 4 / 0 / 5:  50%|█████     | 5/10 [00:02<00:02,  1.81it/s]
# <font color = green>Positive (91%)</font> --> <font color = red>Negative (93%)</font><br>fresnadillo has <font color = green>something</font> <font color = green>serious</font> to say about the <font color = green>ways</font> in which extravagant chance can distort our perspective and throw us off the <font color = green>path</font> of good sense .<br>fresnadillo has <font color = red>anything</font> <font color = red>severe</font> to say about the <font color = red>different</font> in which extravagant chance can distort our perspective and throw us off the <font color = red>shortest</font> of good sense .
# [Succeeded / Failed / Total] 4 / 0 / 5:  60%|██████    | 6/10 [00:03<00:02,  1.56it/s]
# [Succeeded / Failed / Total] 5 / 0 / 6:  60%|██████    | 6/10 [00:03<00:02,  1.56it/s]
# <font color = green>Positive (98%)</font> --> <font color = red>Negative (86%)</font><br><font color = green>throws</font> in enough <font color = green>clever</font> and <font color = green>unexpected</font> twists to make the formula feel <font color = green>fresh</font> .<br><font color = red>throw</font> in enough <font color = red>comical</font> and <font color = red>repeated</font> twists to make the formula feel <font color = red>supplies</font> .
# [Succeeded / Failed / Total] 6 / 0 / 7:  70%|███████   | 7/10 [00:04<00:01,  1.54it/s]
# <font color = red>Negative (54%)</font> --> <font color = gray>[SKIPPED]</font><br>weighty and ponderous but every bit as filling as the treat of the title .
# [Succeeded / Failed / Total] 6 / 0 / 7:  80%|████████  | 8/10 [00:04<00:01,  1.74it/s]
# [Succeeded / Failed / Total] 6 / 0 / 8:  80%|████████  | 8/10 [00:04<00:01,  1.73it/s]
# <font color = green>Positive (99%)</font> --> <font color = red>[FAILED]</font><br>a real audience-pleaser that will strike a chord with anyone who's ever waited in a doctor's office , emergency room , hospital bed or insurance company office .
# [Succeeded / Failed / Total] 6 / 1 / 9:  90%|█████████ | 9/10 [00:06<00:00,  1.40it/s]
# <font color = green>Positive (99%)</font> --> <font color = red>Negative (71%)</font><br>generates an enormous <font color = green>feeling</font> of <font color = green>empathy</font> for its <font color = green>characters</font> .<br>generates an enormous <font color = red>fear</font> of <font color = red>decompression</font> for its <font color = red>character</font> .
# [Succeeded / Failed / Total] 6 / 1 / 9: 100%|██████████| 10/10 [00:07<00:00,  1.40it/s]
# [Succeeded / Failed / Total] 7 / 1 / 10: 100%|██████████| 10/10 [00:07<00:00,  1.40it/s]
# <font color = green>Positive (97%)</font> --> <font color = red>Negative (57%)</font><br><font color = green>exposing</font> the ways we fool ourselves is one hour photo's <font color = green>real</font> <font color = green>strength</font> .<br><font color = red>issuing</font> the ways we fool ourselves is one hour photo's <font color = red>numbers</font> <font color = red>tensile</font> .
# [Succeeded / Failed / Total] 8 / 1 / 11: : 11it [00:07,  1.41it/s]
# <font color = green>Positive (80%)</font> --> <font color = red>Negative (53%)</font><br>it's up to you to <font color = green>decide</font> whether to admire these people's dedication to their cause or be <font color = green>repelled</font> by their dogmatism , manipulativeness and narrow , <font color = green>fearful</font> view of american life .<br>it's up to you to <font color = red>whether</font> whether to admire these people's dedication to their cause or be <font color = red>distracted</font> by their dogmatism , manipulativeness and narrow , <font color = red>metaphysical</font> view of american life .
# [Succeeded / Failed / Total] 8 / 1 / 11: : 12it [00:08,  1.35it/s]
# [Succeeded / Failed / Total] 9 / 1 / 12: : 12it [00:08,  1.34it/s]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 9      |
# | Number of failed attacks:     | 1      |
# | Number of skipped attacks:    | 2      |
# | Original accuracy:            | 83.33% |
# | Accuracy under attack:        | 8.33%  |
# | Attack success rate:          | 90.0%  |
# | Average perturbed word %:     | 25.29% |
# | Average num. words per input: | 16.25  |
# | Avg num queries:              | 21.5   |
# +-------------------------------+--------+
# textattack: Attack time: 8.930619239807129s

# %%
model = transformers.AutoModelForSequenceClassification.from_pretrained("textattack/roberta-base-SST-2")
tokenizer = AutoTokenizer("textattack/roberta-base-SST-2")

model_wrapper = HuggingFaceModelWrapper(model, tokenizer)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=525.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=501003010.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at textattack/roberta-base-SST-2 were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=898822.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=150.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=25.0, style=ProgressStyle(description_w…

# %%
#Fasttext
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("glue", "sst2", "validation")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=7777.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=4473.0, style=ProgressStyle(description…
# Downloading and preparing dataset glue/sst2 (download: 7.09 MiB, generated: 4.81 MiB, post-processed: Unknown size, total: 11.90 MiB) to /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad...
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=7439277.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# textattack: Loading datasets dataset glue, subset sst2, split validation.
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>it 's a charming and often affecting journey .
#  10%|█         | 1/10 [00:01<00:17,  1.95s/it]
#
# [Succeeded / Failed / Total] 0 / 1 / 1:  10%|█         | 1/10 [00:01<00:17,  1.96s/it]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>unflinchingly bleak and desperate
# [Succeeded / Failed / Total] 0 / 1 / 1:  20%|██        | 2/10 [00:02<00:09,  1.13s/it]
#
# [Succeeded / Failed / Total] 0 / 2 / 2:  20%|██        | 2/10 [00:02<00:09,  1.13s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (79%)</font><br>allows us to hope that nolan is <font color = green>poised</font> to embark a major career as a commercial yet inventive filmmaker . <br>allows us to hope that nolan is <font color = red>gassed</font> to embark a major career as a commercial yet inventive filmmaker .
# [Succeeded / Failed / Total] 0 / 2 / 2:  30%|███       | 3/10 [00:02<00:06,  1.10it/s]
#
# [Succeeded / Failed / Total] 1 / 2 / 3:  30%|███       | 3/10 [00:02<00:06,  1.10it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>the acting , costumes , music , cinematography and sound are all astounding given the production 's austere locales .
# [Succeeded / Failed / Total] 1 / 2 / 3:  40%|████      | 4/10 [00:13<00:20,  3.41s/it]
#
# [Succeeded / Failed / Total] 1 / 3 / 4:  40%|████      | 4/10 [00:13<00:20,  3.41s/it]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (95%)</font><br>it 's <font color = red>slow</font> -- very , very <font color = red>slow</font> . <br>it 's <font color = green>quickened</font> -- very , very <font color = green>quickened</font> .
# [Succeeded / Failed / Total] 1 / 3 / 4:  50%|█████     | 5/10 [00:14<00:14,  2.81s/it]
#
# [Succeeded / Failed / Total] 2 / 3 / 5:  50%|█████     | 5/10 [00:14<00:14,  2.81s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>although laced with humor and a few fanciful touches , the film is a refreshingly serious look at young women .
# [Succeeded / Failed / Total] 2 / 3 / 5:  60%|██████    | 6/10 [00:27<00:18,  4.64s/it]
#
# [Succeeded / Failed / Total] 2 / 4 / 6:  60%|██████    | 6/10 [00:27<00:18,  4.64s/it]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (99%)</font><br>a sometimes <font color = red>tedious</font> film . <br>a sometimes <font color = green>audacious</font> film .
# [Succeeded / Failed / Total] 2 / 4 / 6:  70%|███████   | 7/10 [00:28<00:12,  4.01s/it]
#
# [Succeeded / Failed / Total] 3 / 4 / 7:  70%|███████   | 7/10 [00:28<00:12,  4.01s/it]
# <font color = red>Negative (97%)</font> --> <font color = green>Positive (65%)</font><br>or doing last year 's taxes with <font color = red>your</font> <font color = red>ex-wife</font> . <br>or doing last year 's taxes with <font color = green>my</font> <font color = green>daughter</font> .
# [Succeeded / Failed / Total] 3 / 4 / 7:  80%|████████  | 8/10 [00:29<00:07,  3.63s/it]
#
# [Succeeded / Failed / Total] 4 / 4 / 8:  80%|████████  | 8/10 [00:29<00:07,  3.63s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (67%)</font><br><font color = green>you</font> <font color = green>do</font> n't <font color = green>have</font> to <font color = green>know</font> about <font color = green>music</font> to <font color = green>appreciate</font> the <font color = green>film</font> 's <font color = green>easygoing</font> <font color = green>blend</font> of comedy and <font color = green>romance</font> . <br><font color = red>we</font> <font color = red>want</font> n't <font color = red>has</font> to <font color = red>say</font> about <font color = red>dance</font> to <font color = red>appreciating</font> the <font color = red>movie</font> 's <font color = red>foregoing</font> <font color = red>texture</font> of comedy and <font color = red>romanic</font> .
# [Succeeded / Failed / Total] 4 / 4 / 8:  90%|█████████ | 9/10 [00:39<00:04,  4.40s/it]
#
# [Succeeded / Failed / Total] 5 / 4 / 9:  90%|█████████ | 9/10 [00:39<00:04,  4.41s/it]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (81%)</font><br>in exactly 89 <font color = red>minutes</font> , most of which <font color = red>passed</font> <font color = red>as</font> <font color = red>slowly</font> <font color = red>as</font> if i 'd been sitting naked on an igloo , formula 51 <font color = red>sank</font> <font color = red>from</font> quirky to <font color = red>jerky</font> to utter <font color = red>turkey</font> . <br>in exactly 89 <font color = green>minute</font> , most of which <font color = green>enacted</font> <font color = green>well</font> <font color = green>rapidly</font> <font color = green>well</font> if i 'd been sitting naked on an igloo , formula 51 <font color = green>rattled</font> <font color = green>through</font> quirky to <font color = green>jerk</font> to utter <font color = green>turkestan</font> .
# [Succeeded / Failed / Total] 5 / 4 / 9: 100%|██████████| 10/10 [01:03<00:00,  6.30s/it]
#
# [Succeeded / Failed / Total] 6 / 4 / 10: 100%|██████████| 10/10 [01:03<00:00,  6.31s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 6      |
# | Number of failed attacks:     | 4      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 40.0%  |
# | Attack success rate:          | 60.0%  |
# | Average perturbed word %:     | 28.08% |
# | Average num. words per input: | 13.4   |
# | Avg num queries:              | 294.3  |
# +-------------------------------+--------+
# textattack: Attack time: 63.06574749946594s

# %%
#Word2vec
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("glue", "sst2", "validation")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset glue (/root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# textattack: Loading datasets dataset glue, subset sst2, split validation.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (73%)</font><br>it 's a charming and often <font color = green>affecting</font> <font color = green>journey</font> . <br>it 's a charming and often <font color = red>wasting</font> <font color = red>trip</font> .
#  10%|█         | 1/10 [00:00<00:04,  2.14it/s]
#
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:04,  2.12it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>unflinchingly bleak and desperate
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:00<00:02,  3.16it/s]
#
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:00<00:02,  3.14it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (76%)</font><br><font color = green>allows</font> us to hope that nolan <font color = green>is</font> poised to <font color = green>embark</font> a major <font color = green>career</font> as a commercial <font color = green>yet</font> <font color = green>inventive</font> <font color = green>filmmaker</font> . <br><font color = red>enables</font> us to hope that nolan <font color = red>was</font> poised to <font color = red>capitalize</font> a major <font color = red>sophomore</font> as a commercial <font color = red>satisfactorily</font> <font color = red>introspective</font> <font color = red>screenwriter</font> .
# [Succeeded / Failed / Total] 1 / 1 / 2:  30%|███       | 3/10 [00:07<00:17,  2.49s/it]
#
# [Succeeded / Failed / Total] 2 / 1 / 3:  30%|███       | 3/10 [00:07<00:17,  2.49s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>the acting , costumes , music , cinematography and sound are all astounding given the production 's austere locales .
# [Succeeded / Failed / Total] 2 / 1 / 3:  40%|████      | 4/10 [00:14<00:21,  3.60s/it]
#
# [Succeeded / Failed / Total] 2 / 2 / 4:  40%|████      | 4/10 [00:14<00:21,  3.61s/it]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>it 's slow -- very , very slow .
# [Succeeded / Failed / Total] 2 / 2 / 4:  50%|█████     | 5/10 [00:17<00:17,  3.57s/it]
#
# [Succeeded / Failed / Total] 2 / 3 / 5:  50%|█████     | 5/10 [00:17<00:17,  3.57s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (54%)</font><br>although laced with humor and a few fanciful <font color = green>touches</font> , the <font color = green>film</font> <font color = green>is</font> a refreshingly <font color = green>serious</font> <font color = green>look</font> <font color = green>at</font> young women . <br>although laced with humor and a few fanciful <font color = red>bounces</font> , the <font color = red>movie</font> <font color = red>was</font> a refreshingly <font color = red>severe</font> <font color = red>tarry</font> <font color = red>near</font> young women .
# [Succeeded / Failed / Total] 2 / 3 / 5:  60%|██████    | 6/10 [00:26<00:17,  4.40s/it]
#
# [Succeeded / Failed / Total] 3 / 3 / 6:  60%|██████    | 6/10 [00:26<00:17,  4.40s/it]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>a sometimes tedious film .
# [Succeeded / Failed / Total] 3 / 3 / 6:  70%|███████   | 7/10 [00:27<00:11,  3.90s/it]
#
# [Succeeded / Failed / Total] 3 / 4 / 7:  70%|███████   | 7/10 [00:27<00:11,  3.90s/it]
# <font color = red>Negative (97%)</font> --> <font color = green>Positive (90%)</font><br>or doing last <font color = red>year</font> 's <font color = red>taxes</font> with <font color = red>your</font> ex-wife . <br>or doing last <font color = green>week</font> 's <font color = green>dividends</font> with <font color = green>my</font> ex-wife .
# [Succeeded / Failed / Total] 3 / 4 / 7:  80%|████████  | 8/10 [00:29<00:07,  3.63s/it]
#
# [Succeeded / Failed / Total] 4 / 4 / 8:  80%|████████  | 8/10 [00:29<00:07,  3.63s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (99%)</font><br>you <font color = green>do</font> n't <font color = green>have</font> to know <font color = green>about</font> music to <font color = green>appreciate</font> the <font color = green>film</font> 's easygoing <font color = green>blend</font> of <font color = green>comedy</font> and romance . <br>you <font color = red>want</font> n't <font color = red>has</font> to know <font color = red>approximately</font> music to <font color = red>undo</font> the <font color = red>movie</font> 's easygoing <font color = red>melding</font> of <font color = red>drama</font> and romance .
# [Succeeded / Failed / Total] 4 / 4 / 8:  90%|█████████ | 9/10 [00:31<00:03,  3.46s/it]
#
# [Succeeded / Failed / Total] 5 / 4 / 9:  90%|█████████ | 9/10 [00:31<00:03,  3.46s/it]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (62%)</font><br>in exactly 89 minutes , most of which passed <font color = red>as</font> <font color = red>slowly</font> as if i '<font color = red>d</font> been sitting <font color = red>naked</font> on an igloo , <font color = red>formula</font> 51 <font color = red>sank</font> <font color = red>from</font> quirky to jerky to utter turkey . <br>in exactly 89 minutes , most of which passed <font color = green>well</font> <font color = green>rapidly</font> as if i '<font color = green>b</font> been sitting <font color = green>unaided</font> on an igloo , <font color = green>equation</font> 51 <font color = green>canoeing</font> <font color = green>through</font> quirky to jerky to utter turkey .
# [Succeeded / Failed / Total] 5 / 4 / 9: 100%|██████████| 10/10 [00:43<00:00,  4.37s/it]
#
# [Succeeded / Failed / Total] 6 / 4 / 10: 100%|██████████| 10/10 [00:43<00:00,  4.37s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 6      |
# | Number of failed attacks:     | 4      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 40.0%  |
# | Attack success rate:          | 60.0%  |
# | Average perturbed word %:     | 31.15% |
# | Average num. words per input: | 13.4   |
# | Avg num queries:              | 259.4  |
# +-------------------------------+--------+
# textattack: Attack time: 43.665701150894165s

# %%
#glove
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("glue", "sst2", "validation")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=7777.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=4473.0, style=ProgressStyle(description…
# Downloading and preparing dataset glue/sst2 (download: 7.09 MiB, generated: 4.81 MiB, post-processed: Unknown size, total: 11.90 MiB) to /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad...
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=7439277.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
# textattack: Loading datasets dataset glue, subset sst2, split validation.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>it 's a charming and often affecting journey .
#  10%|█         | 1/10 [00:05<00:47,  5.23s/it]
#
#
#
# [Succeeded / Failed / Total] 0 / 1 / 1:  10%|█         | 1/10 [00:05<00:47,  5.24s/it]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>unflinchingly bleak and desperate
# [Succeeded / Failed / Total] 0 / 1 / 1:  20%|██        | 2/10 [00:05<00:23,  2.91s/it]
#
#
#
# [Succeeded / Failed / Total] 0 / 2 / 2:  20%|██        | 2/10 [00:05<00:23,  2.91s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (61%)</font><br><font color = green>allows</font> us to hope that nolan is <font color = green>poised</font> to <font color = green>embark</font> a major career as a commercial yet inventive filmmaker . <br><font color = red>allow</font> us to hope that nolan is <font color = red>transfered</font> to <font color = red>capitalize</font> a major career as a commercial yet inventive filmmaker .
# [Succeeded / Failed / Total] 0 / 2 / 2:  30%|███       | 3/10 [00:09<00:23,  3.30s/it]
#
#
#
# [Succeeded / Failed / Total] 1 / 2 / 3:  30%|███       | 3/10 [00:09<00:23,  3.31s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (85%)</font><br>the acting , costumes , music , cinematography and sound are all <font color = green>astounding</font> given the production 's austere locales . <br>the acting , costumes , music , cinematography and sound are all <font color = red>review</font> given the production 's austere locales .
# [Succeeded / Failed / Total] 1 / 2 / 3:  40%|████      | 4/10 [00:10<00:15,  2.61s/it]
#
#
#
# [Succeeded / Failed / Total] 2 / 2 / 4:  40%|████      | 4/10 [00:10<00:15,  2.62s/it]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>it 's slow -- very , very slow .
# [Succeeded / Failed / Total] 2 / 2 / 4:  50%|█████     | 5/10 [00:14<00:14,  2.99s/it]
#
#
#
# [Succeeded / Failed / Total] 2 / 3 / 5:  50%|█████     | 5/10 [00:14<00:14,  2.99s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (89%)</font><br>although laced with humor and a few fanciful touches , the film <font color = green>is</font> a refreshingly <font color = green>serious</font> <font color = green>look</font> at young women . <br>although laced with humor and a few fanciful touches , the film <font color = red>polylogarithm</font> a refreshingly <font color = red>severe</font> <font color = red>icknield</font> at young women .
# [Succeeded / Failed / Total] 2 / 3 / 5:  60%|██████    | 6/10 [00:19<00:12,  3.18s/it]
#
#
#
# [Succeeded / Failed / Total] 3 / 3 / 6:  60%|██████    | 6/10 [00:19<00:12,  3.18s/it]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>a sometimes tedious film .
# [Succeeded / Failed / Total] 3 / 3 / 6:  70%|███████   | 7/10 [00:20<00:08,  2.94s/it]
#
#
#
# [Succeeded / Failed / Total] 3 / 4 / 7:  70%|███████   | 7/10 [00:20<00:08,  2.94s/it]
# <font color = red>Negative (97%)</font> --> <font color = red>[FAILED]</font><br>or doing last year 's taxes with your ex-wife .
# [Succeeded / Failed / Total] 3 / 4 / 7:  80%|████████  | 8/10 [00:22<00:05,  2.79s/it]
#
#
#
# [Succeeded / Failed / Total] 3 / 5 / 8:  80%|████████  | 8/10 [00:22<00:05,  2.80s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (90%)</font><br>you <font color = green>do</font> n't <font color = green>have</font> to know about music to <font color = green>appreciate</font> the film 's easygoing <font color = green>blend</font> of comedy and romance . <br>you <font color = red>thoil</font> n't <font color = red>statins</font> to know about music to <font color = red>hamper</font> the film 's easygoing <font color = red>alignment</font> of comedy and romance .
# [Succeeded / Failed / Total] 3 / 5 / 8:  90%|█████████ | 9/10 [00:26<00:02,  2.99s/it]
#
#
#
# [Succeeded / Failed / Total] 4 / 5 / 9:  90%|█████████ | 9/10 [00:26<00:02,  2.99s/it]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey .
# [Succeeded / Failed / Total] 4 / 5 / 9: 100%|██████████| 10/10 [01:04<00:00,  6.42s/it]
#
#
#
# [Succeeded / Failed / Total] 4 / 6 / 10: 100%|██████████| 10/10 [01:04<00:00,  6.42s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 4      |
# | Number of failed attacks:     | 6      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 60.0%  |
# | Attack success rate:          | 40.0%  |
# | Average perturbed word %:     | 14.72% |
# | Average num. words per input: | 13.4   |
# | Avg num queries:              | 194.9  |
# +-------------------------------+--------+
# textattack: Attack time: 64.2168447971344s

# %%
#fasttext
from textattack.search_methods import GreedySearch
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedySearch()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("glue", "sst2", "validation")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=7777.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=4473.0, style=ProgressStyle(description…
# Downloading and preparing dataset glue/sst2 (download: 7.09 MiB, generated: 4.81 MiB, post-processed: Unknown size, total: 11.90 MiB) to /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad...
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=7439277.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
# textattack: Loading datasets dataset glue, subset sst2, split validation.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedySearch
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (75%)</font><br>it 's a <font color = green>charming</font> and often <font color = green>affecting</font> <font color = green>journey</font> . <br>it 's a <font color = red>harming</font> and often <font color = red>affectional</font> <font color = red>journ</font> .
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:05,  1.68it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>unflinchingly bleak and desperate
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:00<00:03,  2.59it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (79%)</font><br>allows us to hope that nolan is <font color = green>poised</font> to embark a major career as a commercial yet inventive filmmaker . <br>allows us to hope that nolan is <font color = red>gassed</font> to embark a major career as a commercial yet inventive filmmaker .
# [Succeeded / Failed / Total] 2 / 1 / 3:  30%|███       | 3/10 [00:01<00:02,  2.77it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>the acting , costumes , music , cinematography and sound are all astounding given the production 's austere locales .
# [Succeeded / Failed / Total] 2 / 2 / 4:  40%|████      | 4/10 [00:02<00:03,  1.56it/s]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (95%)</font><br>it 's <font color = red>slow</font> -- very , very <font color = red>slow</font> . <br>it 's <font color = green>quickened</font> -- very , very <font color = green>quickened</font> .
# [Succeeded / Failed / Total] 3 / 2 / 5:  50%|█████     | 5/10 [00:02<00:02,  1.85it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>although laced with humor and a few fanciful touches , the film is a refreshingly serious look at young women .
# [Succeeded / Failed / Total] 3 / 3 / 6:  60%|██████    | 6/10 [00:04<00:02,  1.46it/s]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (66%)</font><br>a <font color = red>sometimes</font> <font color = red>tedious</font> film . <br>a <font color = green>often</font> <font color = green>sidious</font> film .
# [Succeeded / Failed / Total] 4 / 3 / 7:  70%|███████   | 7/10 [00:04<00:01,  1.65it/s]
# <font color = red>Negative (97%)</font> --> <font color = red>[FAILED]</font><br>or doing last year 's taxes with your ex-wife .
# [Succeeded / Failed / Total] 4 / 4 / 8:  80%|████████  | 8/10 [00:04<00:01,  1.78it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>you do n't have to know about music to appreciate the film 's easygoing blend of comedy and romance .
# [Succeeded / Failed / Total] 4 / 5 / 9:  90%|█████████ | 9/10 [00:05<00:00,  1.58it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey .
# [Succeeded / Failed / Total] 4 / 6 / 10: 100%|██████████| 10/10 [00:08<00:00,  1.16it/s]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 4      |
# | Number of failed attacks:     | 6      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 60.0%  |
# | Attack success rate:          | 40.0%  |
# | Average perturbed word %:     | 31.52% |
# | Average num. words per input: | 13.4   |
# | Avg num queries:              | 34.1   |
# +-------------------------------+--------+
# textattack: Attack time: 8.628039836883545s

# %%
#Word2vec
from textattack.search_methods import GreedySearch
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedySearch()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("glue", "sst2", "validation")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset glue (/root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# textattack: Loading datasets dataset glue, subset sst2, split validation.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedySearch
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (100%)</font><br>it 's a <font color = green>charming</font> and often <font color = green>affecting</font> journey . <br>it 's a <font color = red>laconic</font> and often <font color = red>wasting</font> journey .
#  10%|█         | 1/10 [00:00<00:02,  4.31it/s]
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:02,  4.18it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>unflinchingly bleak and desperate
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:00<00:01,  5.42it/s]
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:00<00:01,  5.32it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (88%)</font><br>allows us to hope that nolan is <font color = green>poised</font> to <font color = green>embark</font> a major career as a commercial yet inventive filmmaker . <br>allows us to hope that nolan is <font color = red>wane</font> to <font color = red>capitalize</font> a major career as a commercial yet inventive filmmaker .
# [Succeeded / Failed / Total] 1 / 1 / 2:  30%|███       | 3/10 [00:00<00:01,  3.51it/s]
# [Succeeded / Failed / Total] 2 / 1 / 3:  30%|███       | 3/10 [00:00<00:02,  3.47it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>the acting , costumes , music , cinematography and sound are all astounding given the production 's austere locales .
# [Succeeded / Failed / Total] 2 / 1 / 3:  40%|████      | 4/10 [00:02<00:03,  1.99it/s]
# [Succeeded / Failed / Total] 2 / 2 / 4:  40%|████      | 4/10 [00:02<00:03,  1.99it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>it 's slow -- very , very slow .
# [Succeeded / Failed / Total] 2 / 2 / 4:  50%|█████     | 5/10 [00:02<00:02,  2.37it/s]
# [Succeeded / Failed / Total] 2 / 3 / 5:  50%|█████     | 5/10 [00:02<00:02,  2.36it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>although laced with humor and a few fanciful touches , the film is a refreshingly serious look at young women .
# [Succeeded / Failed / Total] 2 / 3 / 5:  60%|██████    | 6/10 [00:03<00:02,  1.85it/s]
# [Succeeded / Failed / Total] 2 / 4 / 6:  60%|██████    | 6/10 [00:03<00:02,  1.84it/s]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (68%)</font><br>a <font color = red>sometimes</font> <font color = red>tedious</font> film . <br>a <font color = green>often</font> <font color = green>computationally</font> film .
# [Succeeded / Failed / Total] 2 / 4 / 6:  70%|███████   | 7/10 [00:03<00:01,  2.06it/s]
# [Succeeded / Failed / Total] 3 / 4 / 7:  70%|███████   | 7/10 [00:03<00:01,  2.05it/s]
# <font color = red>Negative (97%)</font> --> <font color = red>[FAILED]</font><br>or doing last year 's taxes with your ex-wife .
# [Succeeded / Failed / Total] 3 / 4 / 7:  80%|████████  | 8/10 [00:03<00:00,  2.24it/s]
# [Succeeded / Failed / Total] 3 / 5 / 8:  80%|████████  | 8/10 [00:03<00:00,  2.23it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (67%)</font><br>you do n't have to know about <font color = green>music</font> to <font color = green>appreciate</font> the film 's easygoing blend of comedy and romance . <br>you do n't have to know about <font color = red>folk</font> to <font color = red>undo</font> the film 's easygoing blend of comedy and romance .
# [Succeeded / Failed / Total] 3 / 5 / 8:  90%|█████████ | 9/10 [00:03<00:00,  2.32it/s]
# [Succeeded / Failed / Total] 4 / 5 / 9:  90%|█████████ | 9/10 [00:03<00:00,  2.32it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey .
# [Succeeded / Failed / Total] 4 / 5 / 9: 100%|██████████| 10/10 [00:05<00:00,  1.82it/s]
# [Succeeded / Failed / Total] 4 / 6 / 10: 100%|██████████| 10/10 [00:05<00:00,  1.82it/s]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 4      |
# | Number of failed attacks:     | 6      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 60.0%  |
# | Attack success rate:          | 40.0%  |
# | Average perturbed word %:     | 24.01% |
# | Average num. words per input: | 13.4   |
# | Avg num queries:              | 25.8   |
# +-------------------------------+--------+
# textattack: Attack time: 5.5004167556762695s

# %%
#glove
from textattack.search_methods import GreedySearch
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedySearch()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("glue", "sst2", "validation")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset glue (/root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# textattack: Loading datasets dataset glue, subset sst2, split validation.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedySearch
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (100%)</font><br>it 's a <font color = green>charming</font> and often <font color = green>affecting</font> journey . <br>it 's a <font color = red>pedantic</font> and often <font color = red>destructive</font> journey .
#  10%|█         | 1/10 [00:00<00:03,  2.91it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:03,  2.86it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>unflinchingly bleak and desperate
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:00<00:02,  3.22it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:00<00:02,  3.18it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (70%)</font><br>allows <font color = green>us</font> to hope that nolan is <font color = green>poised</font> to <font color = green>embark</font> a major career as a commercial yet inventive filmmaker . <br>allows <font color = red>karamursel</font> to hope that nolan is <font color = red>transfered</font> to <font color = red>capitalize</font> a major career as a commercial yet inventive filmmaker .
# [Succeeded / Failed / Total] 1 / 1 / 2:  30%|███       | 3/10 [00:01<00:04,  1.62it/s]
#
#
#
# [Succeeded / Failed / Total] 2 / 1 / 3:  30%|███       | 3/10 [00:01<00:04,  1.62it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (85%)</font><br>the acting , costumes , music , cinematography and sound are all <font color = green>astounding</font> given the production 's austere locales . <br>the acting , costumes , music , cinematography and sound are all <font color = red>review</font> given the production 's austere locales .
# [Succeeded / Failed / Total] 2 / 1 / 3:  40%|████      | 4/10 [00:02<00:03,  1.78it/s]
#
#
#
# [Succeeded / Failed / Total] 3 / 1 / 4:  40%|████      | 4/10 [00:02<00:03,  1.77it/s]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (100%)</font><br>it 's <font color = red>slow</font> -- very , very <font color = red>slow</font> . <br>it 's <font color = green>fast</font> -- very , very <font color = green>fast</font> .
# [Succeeded / Failed / Total] 3 / 1 / 4:  50%|█████     | 5/10 [00:02<00:02,  2.08it/s]
#
#
#
# [Succeeded / Failed / Total] 4 / 1 / 5:  50%|█████     | 5/10 [00:02<00:02,  2.08it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (89%)</font><br>although laced with humor and a few fanciful touches , the film is a <font color = green>refreshingly</font> <font color = green>serious</font> <font color = green>look</font> at young women . <br>although laced with humor and a few fanciful touches , the film is a <font color = red>alacran</font> <font color = red>severe</font> <font color = red>find</font> at young women .
# [Succeeded / Failed / Total] 4 / 1 / 5:  60%|██████    | 6/10 [00:03<00:02,  1.70it/s]
#
#
#
# [Succeeded / Failed / Total] 5 / 1 / 6:  60%|██████    | 6/10 [00:03<00:02,  1.70it/s]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (68%)</font><br>a <font color = red>sometimes</font> <font color = red>tedious</font> film . <br>a <font color = green>often</font> <font color = green>computationally</font> film .
# [Succeeded / Failed / Total] 5 / 1 / 6:  70%|███████   | 7/10 [00:03<00:01,  1.87it/s]
#
#
#
# [Succeeded / Failed / Total] 6 / 1 / 7:  70%|███████   | 7/10 [00:03<00:01,  1.87it/s]
# <font color = red>Negative (97%)</font> --> <font color = red>[FAILED]</font><br>or doing last year 's taxes with your ex-wife .
# [Succeeded / Failed / Total] 6 / 1 / 7:  80%|████████  | 8/10 [00:04<00:01,  2.00it/s]
#
#
#
# [Succeeded / Failed / Total] 6 / 2 / 8:  80%|████████  | 8/10 [00:04<00:01,  2.00it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>you do n't have to know about music to appreciate the film 's easygoing blend of comedy and romance .
# [Succeeded / Failed / Total] 6 / 2 / 8:  90%|█████████ | 9/10 [00:05<00:00,  1.68it/s]
#
#
#
# [Succeeded / Failed / Total] 6 / 3 / 9:  90%|█████████ | 9/10 [00:05<00:00,  1.67it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey .
# [Succeeded / Failed / Total] 6 / 3 / 9: 100%|██████████| 10/10 [00:08<00:00,  1.14it/s]
#
#
#
# [Succeeded / Failed / Total] 6 / 4 / 10: 100%|██████████| 10/10 [00:08<00:00,  1.13it/s]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 6      |
# | Number of failed attacks:     | 4      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 40.0%  |
# | Attack success rate:          | 60.0%  |
# | Average perturbed word %:     | 24.36% |
# | Average num. words per input: | 13.4   |
# | Avg num queries:              | 23.7   |
# +-------------------------------+--------+
# textattack: Attack time: 8.82177996635437s

# %%
#Fasttext
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("glue", "sst2", "validation")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=7777.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=4473.0, style=ProgressStyle(description…
# Downloading and preparing dataset glue/sst2 (download: 7.09 MiB, generated: 4.81 MiB, post-processed: Unknown size, total: 11.90 MiB) to /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad...
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=7439277.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# textattack: Loading datasets dataset glue, subset sst2, split validation.
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>it 's a charming and often affecting journey .
# [Succeeded / Failed / Total] 0 / 1 / 1:  10%|█         | 1/10 [00:01<00:09,  1.08s/it]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>unflinchingly bleak and desperate
# [Succeeded / Failed / Total] 0 / 2 / 2:  20%|██        | 2/10 [00:01<00:05,  1.48it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (99%)</font><br><font color = green>allows</font> us to hope that nolan is <font color = green>poised</font> to <font color = green>embark</font> a major career as a commercial yet inventive filmmaker . <br><font color = red>enables</font> us to hope that nolan is <font color = red>gassed</font> to <font color = red>embargo</font> a major career as a commercial yet inventive filmmaker .
# [Succeeded / Failed / Total] 1 / 2 / 3:  30%|███       | 3/10 [00:02<00:05,  1.35it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>the acting , costumes , music , cinematography and sound are all astounding given the production 's austere locales .
# [Succeeded / Failed / Total] 1 / 3 / 4:  40%|████      | 4/10 [00:03<00:05,  1.17it/s]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (86%)</font><br>it 's <font color = red>slow</font> -- <font color = red>very</font> , <font color = red>very</font> <font color = red>slow</font> . <br>it 's <font color = green>quickened</font> -- <font color = green>quite</font> , <font color = green>quite</font> <font color = green>quickened</font> .
# [Succeeded / Failed / Total] 2 / 3 / 5:  50%|█████     | 5/10 [00:03<00:03,  1.27it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>although laced with humor and a few fanciful touches , the film is a refreshingly serious look at young women .
# [Succeeded / Failed / Total] 2 / 4 / 6:  60%|██████    | 6/10 [00:05<00:03,  1.12it/s]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (69%)</font><br>a <font color = red>sometimes</font> <font color = red>tedious</font> <font color = red>film</font> . <br>a <font color = green>often</font> <font color = green>sidious</font> <font color = green>movie</font> .
# [Succeeded / Failed / Total] 3 / 4 / 7:  70%|███████   | 7/10 [00:05<00:02,  1.22it/s]
# <font color = red>Negative (97%)</font> --> <font color = red>[FAILED]</font><br>or doing last year 's taxes with your ex-wife .
# [Succeeded / Failed / Total] 3 / 5 / 8:  80%|████████  | 8/10 [00:06<00:01,  1.24it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>you do n't have to know about music to appreciate the film 's easygoing blend of comedy and romance .
# [Succeeded / Failed / Total] 3 / 6 / 9:  90%|█████████ | 9/10 [00:07<00:00,  1.14it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey .
# [Succeeded / Failed / Total] 3 / 7 / 10: 100%|██████████| 10/10 [00:10<00:00,  1.01s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 3      |
# | Number of failed attacks:     | 7      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 70.0%  |
# | Attack success rate:          | 30.0%  |
# | Average perturbed word %:     | 52.49% |
# | Average num. words per input: | 13.4   |
# | Avg num queries:              | 22.0   |
# +-------------------------------+--------+
# textattack: Attack time: 10.129703998565674s

# %%
#word2vec
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("glue", "sst2", "validation")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset glue (/root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# textattack: Loading datasets dataset glue, subset sst2, split validation.

# %%
print(attack)
table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (73%)</font><br>it 's a charming and often <font color = green>affecting</font> <font color = green>journey</font> . <br>it 's a charming and often <font color = red>wasting</font> <font color = red>trip</font> .
#  10%|█         | 1/10 [00:00<00:03,  2.65it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:03,  2.60it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>unflinchingly bleak and desperate
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:00<00:02,  3.88it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:00<00:02,  3.82it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>allows us to hope that nolan is poised to embark a major career as a commercial yet inventive filmmaker .
# [Succeeded / Failed / Total] 1 / 1 / 2:  30%|███       | 3/10 [00:01<00:02,  2.67it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 2 / 3:  30%|███       | 3/10 [00:01<00:02,  2.65it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>the acting , costumes , music , cinematography and sound are all astounding given the production 's austere locales .
# [Succeeded / Failed / Total] 1 / 2 / 3:  40%|████      | 4/10 [00:01<00:02,  2.45it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 3 / 4:  40%|████      | 4/10 [00:01<00:02,  2.44it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>it 's slow -- very , very slow .
# [Succeeded / Failed / Total] 1 / 3 / 4:  50%|█████     | 5/10 [00:01<00:01,  2.67it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 4 / 5:  50%|█████     | 5/10 [00:01<00:01,  2.65it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>although laced with humor and a few fanciful touches , the film is a refreshingly serious look at young women .
# [Succeeded / Failed / Total] 1 / 4 / 5:  60%|██████    | 6/10 [00:02<00:01,  2.40it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 5 / 6:  60%|██████    | 6/10 [00:02<00:01,  2.39it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>a sometimes tedious film .
# [Succeeded / Failed / Total] 1 / 5 / 6:  70%|███████   | 7/10 [00:02<00:01,  2.63it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 6 / 7:  70%|███████   | 7/10 [00:02<00:01,  2.62it/s]
# <font color = red>Negative (97%)</font> --> <font color = red>[FAILED]</font><br>or doing last year 's taxes with your ex-wife .
# [Succeeded / Failed / Total] 1 / 6 / 7:  80%|████████  | 8/10 [00:02<00:00,  2.71it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 7 / 8:  80%|████████  | 8/10 [00:02<00:00,  2.70it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (82%)</font><br>you do n't <font color = green>have</font> to know about music to <font color = green>appreciate</font> the film 's easygoing blend of comedy and romance . <br>you do n't <font color = red>has</font> to know about music to <font color = red>undo</font> the film 's easygoing blend of comedy and romance .
# [Succeeded / Failed / Total] 1 / 7 / 8:  90%|█████████ | 9/10 [00:03<00:00,  2.74it/s]
#
#
#
# [Succeeded / Failed / Total] 2 / 7 / 9:  90%|█████████ | 9/10 [00:03<00:00,  2.73it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey .
# [Succeeded / Failed / Total] 2 / 7 / 9: 100%|██████████| 10/10 [00:04<00:00,  2.37it/s]
#
#
#
# [Succeeded / Failed / Total] 2 / 8 / 10: 100%|██████████| 10/10 [00:04<00:00,  2.36it/s]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 2      |
# | Number of failed attacks:     | 8      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 80.0%  |
# | Attack success rate:          | 20.0%  |
# | Average perturbed word %:     | 17.76% |
# | Average num. words per input: | 13.4   |
# | Avg num queries:              | 21.4   |
# +-------------------------------+--------+
# textattack: Attack time: 4.241545677185059s

# %%
#glove
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.grammaticality import PartOfSpeech
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [PartOfSpeech()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("glue", "sst2", "validation")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset glue (/root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# textattack: Loading datasets dataset glue, subset sst2, split validation.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): PartOfSpeech(
#         (tagger_type):  nltk
#         (tagset):  universal
#         (allow_verb_noun_swap):  True
#         (compare_against_original):  True
#       )
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>it 's a charming and often affecting journey .
#  10%|█         | 1/10 [00:00<00:04,  2.11it/s]
#
#
#
# [Succeeded / Failed / Total] 0 / 1 / 1:  10%|█         | 1/10 [00:00<00:04,  2.07it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>unflinchingly bleak and desperate
# [Succeeded / Failed / Total] 0 / 1 / 1:  20%|██        | 2/10 [00:00<00:02,  2.91it/s]
#
#
#
# [Succeeded / Failed / Total] 0 / 2 / 2:  20%|██        | 2/10 [00:00<00:02,  2.88it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (61%)</font><br><font color = green>allows</font> us to hope that nolan is <font color = green>poised</font> to <font color = green>embark</font> a major career as a commercial yet inventive filmmaker . <br><font color = red>allow</font> us to hope that nolan is <font color = red>transfered</font> to <font color = red>capitalize</font> a major career as a commercial yet inventive filmmaker .
# [Succeeded / Failed / Total] 0 / 2 / 2:  30%|███       | 3/10 [00:01<00:02,  2.62it/s]
#
#
#
# [Succeeded / Failed / Total] 1 / 2 / 3:  30%|███       | 3/10 [00:01<00:02,  2.61it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (85%)</font><br>the acting , costumes , music , cinematography and sound are all <font color = green>astounding</font> given the production 's austere locales . <br>the acting , costumes , music , cinematography and sound are all <font color = red>review</font> given the production 's austere locales .
# [Succeeded / Failed / Total] 1 / 2 / 3:  40%|████      | 4/10 [00:01<00:02,  2.80it/s]
#
#
#
# [Succeeded / Failed / Total] 2 / 2 / 4:  40%|████      | 4/10 [00:01<00:02,  2.78it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>it 's slow -- very , very slow .
# [Succeeded / Failed / Total] 2 / 2 / 4:  50%|█████     | 5/10 [00:01<00:01,  2.82it/s]
#
#
#
# [Succeeded / Failed / Total] 2 / 3 / 5:  50%|█████     | 5/10 [00:01<00:01,  2.80it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (56%)</font><br>although <font color = green>laced</font> with humor and a few fanciful touches , the film <font color = green>is</font> a refreshingly <font color = green>serious</font> <font color = green>look</font> at young <font color = green>women</font> . <br>although <font color = red>partnered</font> with humor and a few fanciful touches , the film <font color = red>polylogarithm</font> a refreshingly <font color = red>severe</font> <font color = red>find</font> at young <font color = red>men</font> .
# [Succeeded / Failed / Total] 2 / 3 / 5:  60%|██████    | 6/10 [00:02<00:01,  2.41it/s]
#
#
#
# [Succeeded / Failed / Total] 3 / 3 / 6:  60%|██████    | 6/10 [00:02<00:01,  2.41it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>a sometimes tedious film .
# [Succeeded / Failed / Total] 3 / 3 / 6:  70%|███████   | 7/10 [00:02<00:01,  2.56it/s]
#
#
#
# [Succeeded / Failed / Total] 3 / 4 / 7:  70%|███████   | 7/10 [00:02<00:01,  2.55it/s]
# <font color = red>Negative (97%)</font> --> <font color = red>[FAILED]</font><br>or doing last year 's taxes with your ex-wife .
# [Succeeded / Failed / Total] 3 / 4 / 7:  80%|████████  | 8/10 [00:03<00:00,  2.57it/s]
#
#
#
# [Succeeded / Failed / Total] 3 / 5 / 8:  80%|████████  | 8/10 [00:03<00:00,  2.56it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (64%)</font><br>you do n't <font color = green>have</font> to know about music to <font color = green>appreciate</font> the film '<font color = green>s</font> easygoing <font color = green>blend</font> of comedy and romance . <br>you do n't <font color = red>statins</font> to know about music to <font color = red>hamper</font> the film '<font color = red>ridgwayi</font> easygoing <font color = red>alignment</font> of comedy and romance .
# [Succeeded / Failed / Total] 3 / 5 / 8:  90%|█████████ | 9/10 [00:03<00:00,  2.47it/s]
#
#
#
# [Succeeded / Failed / Total] 4 / 5 / 9:  90%|█████████ | 9/10 [00:03<00:00,  2.46it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey .
# [Succeeded / Failed / Total] 4 / 5 / 9: 100%|██████████| 10/10 [00:04<00:00,  2.02it/s]
#
#
#
# [Succeeded / Failed / Total] 4 / 6 / 10: 100%|██████████| 10/10 [00:04<00:00,  2.01it/s]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 4      |
# | Number of failed attacks:     | 6      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 60.0%  |
# | Attack success rate:          | 40.0%  |
# | Average perturbed word %:     | 17.35% |
# | Average num. words per input: | 13.4   |
# | Avg num queries:              | 18.8   |
# +-------------------------------+--------+
# textattack: Attack time: 4.972453832626343s

# %%
#fasttext
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("glue", "sst2", "validation")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=7777.0, style=ProgressStyle(description…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=4473.0, style=ProgressStyle(description…
# Downloading and preparing dataset glue/sst2 (download: 7.09 MiB, generated: 4.81 MiB, post-processed: Unknown size, total: 11.90 MiB) to /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad...
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=7439277.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# textattack: Loading datasets dataset glue, subset sst2, split validation.
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (75%)</font><br>it 's a <font color = green>charming</font> and often <font color = green>affecting</font> <font color = green>journey</font> . <br>it 's a <font color = red>harming</font> and often <font color = red>affectional</font> <font color = red>journ</font> .
#  10%|█         | 1/10 [00:00<00:06,  1.38it/s]
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:06,  1.36it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>unflinchingly bleak and desperate
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:01<00:06,  1.26it/s]
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:01<00:06,  1.25it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (79%)</font><br>allows us to hope that nolan is <font color = green>poised</font> to embark a major career as a commercial yet inventive filmmaker . <br>allows us to hope that nolan is <font color = red>gassed</font> to embark a major career as a commercial yet inventive filmmaker .
# [Succeeded / Failed / Total] 1 / 1 / 2:  30%|███       | 3/10 [00:02<00:05,  1.32it/s]
# [Succeeded / Failed / Total] 2 / 1 / 3:  30%|███       | 3/10 [00:02<00:05,  1.32it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>the acting , costumes , music , cinematography and sound are all astounding given the production 's austere locales .
# [Succeeded / Failed / Total] 2 / 1 / 3:  40%|████      | 4/10 [00:11<00:17,  2.88s/it]
# [Succeeded / Failed / Total] 2 / 2 / 4:  40%|████      | 4/10 [00:11<00:17,  2.88s/it]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (95%)</font><br>it 's <font color = red>slow</font> -- very , very <font color = red>slow</font> . <br>it 's <font color = green>quickened</font> -- very , very <font color = green>quickened</font> .
# [Succeeded / Failed / Total] 2 / 2 / 4:  50%|█████     | 5/10 [00:11<00:11,  2.38s/it]
# [Succeeded / Failed / Total] 3 / 2 / 5:  50%|█████     | 5/10 [00:11<00:11,  2.38s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>although laced with humor and a few fanciful touches , the film is a refreshingly serious look at young women .
# [Succeeded / Failed / Total] 3 / 2 / 5:  60%|██████    | 6/10 [00:21<00:14,  3.60s/it]
# [Succeeded / Failed / Total] 3 / 3 / 6:  60%|██████    | 6/10 [00:21<00:14,  3.60s/it]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (66%)</font><br>a <font color = red>sometimes</font> <font color = red>tedious</font> film . <br>a <font color = green>often</font> <font color = green>sidious</font> film .
# [Succeeded / Failed / Total] 3 / 3 / 6:  70%|███████   | 7/10 [00:21<00:09,  3.13s/it]
# [Succeeded / Failed / Total] 4 / 3 / 7:  70%|███████   | 7/10 [00:21<00:09,  3.13s/it]
# <font color = red>Negative (97%)</font> --> <font color = red>[FAILED]</font><br>or doing last year 's taxes with your ex-wife .
# [Succeeded / Failed / Total] 4 / 3 / 7:  80%|████████  | 8/10 [00:22<00:05,  2.86s/it]
# [Succeeded / Failed / Total] 4 / 4 / 8:  80%|████████  | 8/10 [00:22<00:05,  2.86s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>you do n't have to know about music to appreciate the film 's easygoing blend of comedy and romance .
# [Succeeded / Failed / Total] 4 / 4 / 8:  90%|█████████ | 9/10 [00:35<00:03,  3.92s/it]
# [Succeeded / Failed / Total] 4 / 5 / 9:  90%|█████████ | 9/10 [00:35<00:03,  3.92s/it]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey .
# [Succeeded / Failed / Total] 4 / 5 / 9: 100%|██████████| 10/10 [00:59<00:00,  5.94s/it]
# [Succeeded / Failed / Total] 4 / 6 / 10: 100%|██████████| 10/10 [00:59<00:00,  5.95s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 4      |
# | Number of failed attacks:     | 6      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 60.0%  |
# | Attack success rate:          | 40.0%  |
# | Average perturbed word %:     | 31.52% |
# | Average num. words per input: | 13.4   |
# | Avg num queries:              | 193.7  |
# +-------------------------------+--------+
# textattack: Attack time: 59.473532915115356s

# %%
#word2vec
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("glue", "sst2", "validation")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset glue (/root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# textattack: Loading datasets dataset glue, subset sst2, split validation.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (100%)</font><br>it 's a <font color = green>charming</font> and <font color = green>often</font> <font color = green>affecting</font> <font color = green>journey</font> . <br>it 's a <font color = red>laconic</font> and <font color = red>sometimes</font> <font color = red>wasting</font> <font color = red>trip</font> .
#  10%|█         | 1/10 [00:00<00:06,  1.42it/s]
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:06,  1.41it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>unflinchingly bleak and desperate
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:01<00:04,  1.75it/s]
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:01<00:04,  1.74it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (88%)</font><br>allows us to hope that nolan is <font color = green>poised</font> to <font color = green>embark</font> a major career as a commercial yet inventive filmmaker . <br>allows us to hope that nolan is <font color = red>wane</font> to <font color = red>capitalize</font> a major career as a commercial yet inventive filmmaker .
# [Succeeded / Failed / Total] 1 / 1 / 2:  30%|███       | 3/10 [00:02<00:05,  1.27it/s]
# [Succeeded / Failed / Total] 2 / 1 / 3:  30%|███       | 3/10 [00:02<00:05,  1.27it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>the acting , costumes , music , cinematography and sound are all astounding given the production 's austere locales .
# [Succeeded / Failed / Total] 2 / 1 / 3:  40%|████      | 4/10 [00:11<00:17,  2.91s/it]
# [Succeeded / Failed / Total] 2 / 2 / 4:  40%|████      | 4/10 [00:11<00:17,  2.91s/it]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>it 's slow -- very , very slow .
# [Succeeded / Failed / Total] 2 / 2 / 4:  50%|█████     | 5/10 [00:12<00:12,  2.40s/it]
# [Succeeded / Failed / Total] 2 / 3 / 5:  50%|█████     | 5/10 [00:12<00:12,  2.40s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>although laced with humor and a few fanciful touches , the film is a refreshingly serious look at young women .
# [Succeeded / Failed / Total] 2 / 3 / 5:  60%|██████    | 6/10 [00:20<00:13,  3.47s/it]
# [Succeeded / Failed / Total] 2 / 4 / 6:  60%|██████    | 6/10 [00:20<00:13,  3.47s/it]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (68%)</font><br>a <font color = red>sometimes</font> <font color = red>tedious</font> film . <br>a <font color = green>often</font> <font color = green>computationally</font> film .
# [Succeeded / Failed / Total] 2 / 4 / 6:  70%|███████   | 7/10 [00:21<00:09,  3.02s/it]
# [Succeeded / Failed / Total] 3 / 4 / 7:  70%|███████   | 7/10 [00:21<00:09,  3.02s/it]
# <font color = red>Negative (97%)</font> --> <font color = red>[FAILED]</font><br>or doing last year 's taxes with your ex-wife .
# [Succeeded / Failed / Total] 3 / 4 / 7:  80%|████████  | 8/10 [00:21<00:05,  2.70s/it]
# [Succeeded / Failed / Total] 3 / 5 / 8:  80%|████████  | 8/10 [00:21<00:05,  2.70s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (91%)</font><br>you do n't have to know about <font color = green>music</font> to <font color = green>appreciate</font> the <font color = green>film</font> 's easygoing blend of <font color = green>comedy</font> and romance . <br>you do n't have to know about <font color = red>folk</font> to <font color = red>undo</font> the <font color = red>movie</font> 's easygoing blend of <font color = red>drama</font> and romance .
# [Succeeded / Failed / Total] 3 / 5 / 8:  90%|█████████ | 9/10 [00:22<00:02,  2.53s/it]
# [Succeeded / Failed / Total] 4 / 5 / 9:  90%|█████████ | 9/10 [00:22<00:02,  2.53s/it]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey .
# [Succeeded / Failed / Total] 4 / 5 / 9: 100%|██████████| 10/10 [00:34<00:00,  3.43s/it]
# [Succeeded / Failed / Total] 4 / 6 / 10: 100%|██████████| 10/10 [00:34<00:00,  3.43s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 4      |
# | Number of failed attacks:     | 6      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 60.0%  |
# | Attack success rate:          | 40.0%  |
# | Average perturbed word %:     | 32.89% |
# | Average num. words per input: | 13.4   |
# | Avg num queries:              | 162.4  |
# +-------------------------------+--------+
# textattack: Attack time: 34.33498954772949s

# %%
#glove
from textattack.search_methods import ParticleSwarmOptimization
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = ParticleSwarmOptimization(pop_size=10,max_iters=5,post_turn_check=True,max_turn_retries=5)
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("glue", "sst2", "validation")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset glue (/root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# textattack: Loading datasets dataset glue, subset sst2, split validation.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): ParticleSwarmOptimization(
#     (pop_size):  10
#     (max_iters):  5
#     (post_turn_check):  True
#     (max_turn_retries):  20
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (100%)</font><br>it 's a <font color = green>charming</font> and often <font color = green>affecting</font> journey . <br>it 's a <font color = red>pedantic</font> and often <font color = red>destructive</font> journey .
#  10%|█         | 1/10 [00:00<00:08,  1.10it/s]
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:08,  1.09it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>unflinchingly bleak and desperate
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:01<00:06,  1.30it/s]
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:01<00:06,  1.29it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (70%)</font><br>allows <font color = green>us</font> to hope that nolan is <font color = green>poised</font> to <font color = green>embark</font> a major career as a commercial yet inventive filmmaker . <br>allows <font color = red>karamursel</font> to hope that nolan is <font color = red>transfered</font> to <font color = red>capitalize</font> a major career as a commercial yet inventive filmmaker .
# [Succeeded / Failed / Total] 1 / 1 / 2:  30%|███       | 3/10 [00:04<00:11,  1.64s/it]
# [Succeeded / Failed / Total] 2 / 1 / 3:  30%|███       | 3/10 [00:04<00:11,  1.65s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (85%)</font><br>the acting , costumes , music , cinematography and sound are all <font color = green>astounding</font> given the production 's austere locales . <br>the acting , costumes , music , cinematography and sound are all <font color = red>review</font> given the production 's austere locales .
# [Succeeded / Failed / Total] 2 / 1 / 3:  40%|████      | 4/10 [00:05<00:08,  1.44s/it]
# [Succeeded / Failed / Total] 3 / 1 / 4:  40%|████      | 4/10 [00:05<00:08,  1.44s/it]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (100%)</font><br>it 's <font color = red>slow</font> -- very , very <font color = red>slow</font> . <br>it 's <font color = green>fast</font> -- very , very <font color = green>fast</font> .
# [Succeeded / Failed / Total] 3 / 1 / 4:  50%|█████     | 5/10 [00:06<00:06,  1.22s/it]
# [Succeeded / Failed / Total] 4 / 1 / 5:  50%|█████     | 5/10 [00:06<00:06,  1.22s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (89%)</font><br>although laced with humor and a few fanciful touches , the film is a <font color = green>refreshingly</font> <font color = green>serious</font> <font color = green>look</font> at young women . <br>although laced with humor and a few fanciful touches , the film is a <font color = red>alacran</font> <font color = red>severe</font> <font color = red>find</font> at young women .
# [Succeeded / Failed / Total] 4 / 1 / 5:  60%|██████    | 6/10 [00:09<00:06,  1.51s/it]
# [Succeeded / Failed / Total] 5 / 1 / 6:  60%|██████    | 6/10 [00:09<00:06,  1.51s/it]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (84%)</font><br>a <font color = red>sometimes</font> <font color = red>tedious</font> <font color = red>film</font> . <br>a <font color = green>often</font> <font color = green>computationally</font> <font color = green>remodernist</font> .
# [Succeeded / Failed / Total] 5 / 1 / 6:  70%|███████   | 7/10 [00:09<00:04,  1.37s/it]
# [Succeeded / Failed / Total] 6 / 1 / 7:  70%|███████   | 7/10 [00:09<00:04,  1.37s/it]
# <font color = red>Negative (97%)</font> --> <font color = red>[FAILED]</font><br>or doing last year 's taxes with your ex-wife .
# [Succeeded / Failed / Total] 6 / 1 / 7:  80%|████████  | 8/10 [00:10<00:02,  1.32s/it]
# [Succeeded / Failed / Total] 6 / 2 / 8:  80%|████████  | 8/10 [00:10<00:02,  1.32s/it]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>you do n't have to know about music to appreciate the film 's easygoing blend of comedy and romance .
# [Succeeded / Failed / Total] 6 / 2 / 8:  90%|█████████ | 9/10 [00:15<00:01,  1.75s/it]
# [Succeeded / Failed / Total] 6 / 3 / 9:  90%|█████████ | 9/10 [00:15<00:01,  1.76s/it]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey .
# [Succeeded / Failed / Total] 6 / 3 / 9: 100%|██████████| 10/10 [00:33<00:00,  3.40s/it]
# [Succeeded / Failed / Total] 6 / 4 / 10: 100%|██████████| 10/10 [00:33<00:00,  3.40s/it]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 6      |
# | Number of failed attacks:     | 4      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 40.0%  |
# | Attack success rate:          | 60.0%  |
# | Average perturbed word %:     | 28.53% |
# | Average num. words per input: | 13.4   |
# | Avg num queries:              | 116.5  |
# +-------------------------------+--------+
# textattack: Attack time: 33.995563983917236s

# %%
#fasttext
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("glue", "sst2", "validation")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset glue (/root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# textattack: Loading datasets dataset glue, subset sst2, split validation.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (54%)</font><br>it 's a <font color = green>charming</font> and <font color = green>often</font> <font color = green>affecting</font> journey . <br>it 's a <font color = red>harming</font> and <font color = red>sometimes</font> <font color = red>affectional</font> journey .
#  10%|█         | 1/10 [00:00<00:04,  1.83it/s]
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:05,  1.80it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>unflinchingly bleak and desperate
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:00<00:03,  2.25it/s]
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:00<00:03,  2.24it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (99%)</font><br><font color = green>allows</font> us to hope that nolan is <font color = green>poised</font> to <font color = green>embark</font> a major career as a commercial yet <font color = green>inventive</font> filmmaker . <br><font color = red>enables</font> us to hope that nolan is <font color = red>gassed</font> to <font color = red>embargo</font> a major career as a commercial yet <font color = red>inventing</font> filmmaker .
# [Succeeded / Failed / Total] 1 / 1 / 2:  30%|███       | 3/10 [00:01<00:04,  1.69it/s]
# [Succeeded / Failed / Total] 2 / 1 / 3:  30%|███       | 3/10 [00:01<00:04,  1.68it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>the acting , costumes , music , cinematography and sound are all astounding given the production 's austere locales .
# [Succeeded / Failed / Total] 2 / 1 / 3:  40%|████      | 4/10 [00:02<00:04,  1.40it/s]
# [Succeeded / Failed / Total] 2 / 2 / 4:  40%|████      | 4/10 [00:02<00:04,  1.39it/s]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (95%)</font><br>it 's <font color = red>slow</font> -- very , very <font color = red>slow</font> . <br>it 's <font color = green>quickened</font> -- very , very <font color = green>quickened</font> .
# [Succeeded / Failed / Total] 2 / 2 / 4:  50%|█████     | 5/10 [00:03<00:03,  1.54it/s]
# [Succeeded / Failed / Total] 3 / 2 / 5:  50%|█████     | 5/10 [00:03<00:03,  1.54it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>although laced with humor and a few fanciful touches , the film is a refreshingly serious look at young women .
# [Succeeded / Failed / Total] 3 / 2 / 5:  60%|██████    | 6/10 [00:04<00:02,  1.34it/s]
# [Succeeded / Failed / Total] 3 / 3 / 6:  60%|██████    | 6/10 [00:04<00:02,  1.34it/s]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (69%)</font><br>a <font color = red>sometimes</font> <font color = red>tedious</font> <font color = red>film</font> . <br>a <font color = green>often</font> <font color = green>sidious</font> <font color = green>movie</font> .
# [Succeeded / Failed / Total] 3 / 3 / 6:  70%|███████   | 7/10 [00:04<00:02,  1.46it/s]
# [Succeeded / Failed / Total] 4 / 3 / 7:  70%|███████   | 7/10 [00:04<00:02,  1.46it/s]
# <font color = red>Negative (97%)</font> --> <font color = red>[FAILED]</font><br>or doing last year 's taxes with your ex-wife .
# [Succeeded / Failed / Total] 4 / 3 / 7:  80%|████████  | 8/10 [00:05<00:01,  1.50it/s]
# [Succeeded / Failed / Total] 4 / 4 / 8:  80%|████████  | 8/10 [00:05<00:01,  1.49it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>you do n't have to know about music to appreciate the film 's easygoing blend of comedy and romance .
# [Succeeded / Failed / Total] 4 / 4 / 8:  90%|█████████ | 9/10 [00:06<00:00,  1.39it/s]
# [Succeeded / Failed / Total] 4 / 5 / 9:  90%|█████████ | 9/10 [00:06<00:00,  1.39it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey .
# [Succeeded / Failed / Total] 4 / 5 / 9: 100%|██████████| 10/10 [00:08<00:00,  1.22it/s]
# [Succeeded / Failed / Total] 4 / 6 / 10: 100%|██████████| 10/10 [00:08<00:00,  1.22it/s]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 4      |
# | Number of failed attacks:     | 6      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 60.0%  |
# | Attack success rate:          | 40.0%  |
# | Average perturbed word %:     | 41.72% |
# | Average num. words per input: | 13.4   |
# | Avg num queries:              | 20.9   |
# +-------------------------------+--------+
# textattack: Attack time: 8.221373319625854s

# %%
#word2vec
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper_()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("glue", "sst2", "validation")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset glue (/root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# textattack: Loading datasets dataset glue, subset sst2, split validation.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper_
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (100%)</font><br>it 's a <font color = green>charming</font> and often <font color = green>affecting</font> journey . <br>it 's a <font color = red>laconic</font> and often <font color = red>wasting</font> journey .
#  10%|█         | 1/10 [00:00<00:04,  2.04it/s]
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:04,  2.01it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>unflinchingly bleak and desperate
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:00<00:03,  2.54it/s]
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:00<00:03,  2.52it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (97%)</font><br>allows <font color = green>us</font> to hope that nolan is <font color = green>poised</font> to <font color = green>embark</font> a major career as a commercial yet <font color = green>inventive</font> filmmaker . <br>allows <font color = red>states</font> to hope that nolan is <font color = red>wane</font> to <font color = red>capitalize</font> a major career as a commercial yet <font color = red>imaginative</font> filmmaker .
# [Succeeded / Failed / Total] 1 / 1 / 2:  30%|███       | 3/10 [00:01<00:03,  1.79it/s]
# [Succeeded / Failed / Total] 2 / 1 / 3:  30%|███       | 3/10 [00:01<00:03,  1.78it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>the acting , costumes , music , cinematography and sound are all astounding given the production 's austere locales .
# [Succeeded / Failed / Total] 2 / 1 / 3:  40%|████      | 4/10 [00:02<00:04,  1.47it/s]
# [Succeeded / Failed / Total] 2 / 2 / 4:  40%|████      | 4/10 [00:02<00:04,  1.46it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>it 's slow -- very , very slow .
# [Succeeded / Failed / Total] 2 / 2 / 4:  50%|█████     | 5/10 [00:03<00:03,  1.63it/s]
# [Succeeded / Failed / Total] 2 / 3 / 5:  50%|█████     | 5/10 [00:03<00:03,  1.62it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>although laced with humor and a few fanciful touches , the film is a refreshingly serious look at young women .
# [Succeeded / Failed / Total] 2 / 3 / 5:  60%|██████    | 6/10 [00:04<00:02,  1.42it/s]
# [Succeeded / Failed / Total] 2 / 4 / 6:  60%|██████    | 6/10 [00:04<00:02,  1.42it/s]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (76%)</font><br>a <font color = red>sometimes</font> <font color = red>tedious</font> <font color = red>film</font> . <br>a <font color = green>often</font> <font color = green>computationally</font> <font color = green>movie</font> .
# [Succeeded / Failed / Total] 2 / 4 / 6:  70%|███████   | 7/10 [00:04<00:01,  1.53it/s]
# [Succeeded / Failed / Total] 3 / 4 / 7:  70%|███████   | 7/10 [00:04<00:01,  1.53it/s]
# <font color = red>Negative (97%)</font> --> <font color = red>[FAILED]</font><br>or doing last year 's taxes with your ex-wife .
# [Succeeded / Failed / Total] 3 / 4 / 7:  80%|████████  | 8/10 [00:05<00:01,  1.58it/s]
# [Succeeded / Failed / Total] 3 / 5 / 8:  80%|████████  | 8/10 [00:05<00:01,  1.58it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (73%)</font><br>you do n't have to know about music to <font color = green>appreciate</font> the film 's easygoing <font color = green>blend</font> of comedy and <font color = green>romance</font> . <br>you do n't have to know about music to <font color = red>undo</font> the film 's easygoing <font color = red>melding</font> of comedy and <font color = red>sardinian</font> .
# [Succeeded / Failed / Total] 3 / 5 / 8:  90%|█████████ | 9/10 [00:05<00:00,  1.54it/s]
# [Succeeded / Failed / Total] 4 / 5 / 9:  90%|█████████ | 9/10 [00:05<00:00,  1.54it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey .
# [Succeeded / Failed / Total] 4 / 5 / 9: 100%|██████████| 10/10 [00:07<00:00,  1.36it/s]
# [Succeeded / Failed / Total] 4 / 6 / 10: 100%|██████████| 10/10 [00:07<00:00,  1.35it/s]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 4      |
# | Number of failed attacks:     | 6      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 60.0%  |
# | Attack success rate:          | 40.0%  |
# | Average perturbed word %:     | 34.21% |
# | Average num. words per input: | 13.4   |
# | Avg num queries:              | 19.6   |
# +-------------------------------+--------+
# textattack: Attack time: 7.393679141998291s

# %%
#glove
from textattack.search_methods import GreedyWordSwapWIR
from textattack.constraints.pre_transformation import RepeatModification, StopwordModification
from textattack.shared import Attack
from textattack.goal_functions import UntargetedClassification
from textattack.datasets import HuggingFaceDataset

# We're going to use our word swap class as the attack transformation.
transformation = Swapper3()
# We'll constrain modification of already modified indices and stopwords
constraints = [RepeatModification(),
               StopwordModification()]
# We'll use the Greedy search method
search_method = GreedyWordSwapWIR()
# Create the goal function using the model

goal_function = UntargetedClassification(model_wrapper)

# Now, let's make the attack from the 4 components:
attack = Attack(goal_function, constraints, transformation, search_method)

dataset = HuggingFaceDataset("glue", "sst2", "validation")
# Out:
# textattack: Unknown if model of class <class 'transformers.models.roberta.modeling_roberta.RobertaForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Reusing dataset glue (/root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad)
# textattack: Loading datasets dataset glue, subset sst2, split validation.

# %%
# print(attack)
# table(dataset,attack)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  Swapper3
#   (constraints):
#     (0): RepeatModification
#     (1): StopwordModification
#   (is_black_box):  True
# )
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (100%)</font><br>it 's a <font color = green>charming</font> and often <font color = green>affecting</font> journey . <br>it 's a <font color = red>pedantic</font> and often <font color = red>destructive</font> journey .
#  10%|█         | 1/10 [00:00<00:04,  1.95it/s]
# [Succeeded / Failed / Total] 1 / 0 / 1:  10%|█         | 1/10 [00:00<00:04,  1.90it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>unflinchingly bleak and desperate
# [Succeeded / Failed / Total] 1 / 0 / 1:  20%|██        | 2/10 [00:00<00:03,  2.11it/s]
# [Succeeded / Failed / Total] 1 / 1 / 2:  20%|██        | 2/10 [00:00<00:03,  2.09it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (70%)</font><br>allows <font color = green>us</font> to hope that nolan is <font color = green>poised</font> to <font color = green>embark</font> a major career as a commercial yet inventive filmmaker . <br>allows <font color = red>karamursel</font> to hope that nolan is <font color = red>transfered</font> to <font color = red>capitalize</font> a major career as a commercial yet inventive filmmaker .
# [Succeeded / Failed / Total] 1 / 1 / 2:  30%|███       | 3/10 [00:01<00:04,  1.56it/s]
# [Succeeded / Failed / Total] 2 / 1 / 3:  30%|███       | 3/10 [00:01<00:04,  1.55it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (85%)</font><br>the acting , costumes , music , cinematography and sound are all <font color = green>astounding</font> given the production 's austere locales . <br>the acting , costumes , music , cinematography and sound are all <font color = red>review</font> given the production 's austere locales .
# [Succeeded / Failed / Total] 2 / 1 / 3:  40%|████      | 4/10 [00:02<00:03,  1.59it/s]
# [Succeeded / Failed / Total] 3 / 1 / 4:  40%|████      | 4/10 [00:02<00:03,  1.58it/s]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (100%)</font><br>it 's <font color = red>slow</font> -- very , very <font color = red>slow</font> . <br>it 's <font color = green>fast</font> -- very , very <font color = green>fast</font> .
# [Succeeded / Failed / Total] 3 / 1 / 4:  50%|█████     | 5/10 [00:02<00:02,  1.70it/s]
# [Succeeded / Failed / Total] 4 / 1 / 5:  50%|█████     | 5/10 [00:02<00:02,  1.70it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>Negative (94%)</font><br>although <font color = green>laced</font> with humor and a few fanciful touches , the film is a <font color = green>refreshingly</font> <font color = green>serious</font> <font color = green>look</font> at young <font color = green>women</font> . <br>although <font color = red>partnered</font> with humor and a few fanciful touches , the film is a <font color = red>alacran</font> <font color = red>severe</font> <font color = red>find</font> at young <font color = red>men</font> .
# [Succeeded / Failed / Total] 4 / 1 / 5:  60%|██████    | 6/10 [00:04<00:02,  1.47it/s]
# [Succeeded / Failed / Total] 5 / 1 / 6:  60%|██████    | 6/10 [00:04<00:02,  1.47it/s]
# <font color = red>Negative (100%)</font> --> <font color = green>Positive (55%)</font><br>a sometimes <font color = red>tedious</font> <font color = red>film</font> . <br>a sometimes <font color = green>computationally</font> <font color = green>remodernist</font> .
# [Succeeded / Failed / Total] 5 / 1 / 6:  70%|███████   | 7/10 [00:04<00:01,  1.58it/s]
# [Succeeded / Failed / Total] 6 / 1 / 7:  70%|███████   | 7/10 [00:04<00:01,  1.58it/s]
# <font color = red>Negative (97%)</font> --> <font color = red>[FAILED]</font><br>or doing last year 's taxes with your ex-wife .
# [Succeeded / Failed / Total] 6 / 1 / 7:  80%|████████  | 8/10 [00:04<00:01,  1.60it/s]
# [Succeeded / Failed / Total] 6 / 2 / 8:  80%|████████  | 8/10 [00:04<00:01,  1.60it/s]
# <font color = green>Positive (100%)</font> --> <font color = red>[FAILED]</font><br>you do n't have to know about music to appreciate the film 's easygoing blend of comedy and romance .
# [Succeeded / Failed / Total] 6 / 2 / 8:  90%|█████████ | 9/10 [00:06<00:00,  1.46it/s]
# [Succeeded / Failed / Total] 6 / 3 / 9:  90%|█████████ | 9/10 [00:06<00:00,  1.45it/s]
# <font color = red>Negative (100%)</font> --> <font color = red>[FAILED]</font><br>in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey .
# [Succeeded / Failed / Total] 6 / 3 / 9: 100%|██████████| 10/10 [00:08<00:00,  1.24it/s]
# [Succeeded / Failed / Total] 6 / 4 / 10: 100%|██████████| 10/10 [00:08<00:00,  1.24it/s]
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 6      |
# | Number of failed attacks:     | 4      |
# | Number of skipped attacks:    | 0      |
# | Original accuracy:            | 100.0% |
# | Accuracy under attack:        | 40.0%  |
# | Attack success rate:          | 60.0%  |
# | Average perturbed word %:     | 26.11% |
# | Average num. words per input: | 13.4   |
# | Avg num queries:              | 19.0   |
# +-------------------------------+--------+
# textattack: Attack time: 8.073108673095703s

# %%
# from textattack.search_methods import BeamSearch
# from textattack.constraints.semantics import WordEmbeddingDistance
# from textattack.shared import Attack
# from textattack.goal_functions import UntargetedClassification
# from textattack.datasets import HuggingFaceDataset


# transformation = Swapper()

# constraints = [WordEmbeddingDistance(min_cos_sim=0.8)]

# search_method = BeamSearch(beam_width=2)
# # Create the goal function using the model

# goal_function = UntargetedClassification(model_wrapper)

# # Now, let's make the attack from the 4 components:
# attack = Attack(goal_function, constraints, transformation, search_method)

# dataset = HuggingFaceDataset("ag_news", None, "test")

# %%
# print(attack)
